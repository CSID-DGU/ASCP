# %%
import pandas as pd
import os
from multiprocessing import Process
import copy
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# Node의 부모 Class
class Node:
    def __init__(self, node_name):
        self.node_name = node_name

# Edge의 부모 Class
class Edge:
    def __init__(self, origin, dest):
        self.origin = origin
        self.dest = dest

# Airport Class
class Airport(Node):
    def __init__(self, airport_name):
        super().__init__(airport_name)

# Flight Class
class Flight(Edge):
    def __init__(self, index, origin, dest, origin_date, dest_date, flight_duration, flight_type):
        super().__init__(origin, dest)
        self.index = index
        self.origin_date = origin_date
        self.dest_date = dest_date
        self.flight_duration = flight_duration
        self.flight_type = flight_type

    def print(self):
        print(self.index, self.origin, self.origin_date, self.dest,
              self.dest_date, self.flight_duration, self.flight_type)
        

# Stack Node의 구조
class Stackitem:
    def __init__(self, flight: Flight, flights_sequence: list = None, landing_number = None):
        if flights_sequence:
            self.flight = flight
            flights_sequence.append(flight.index)
            self.flights_sequence = flights_sequence
            self.landing_number = landing_number + 1
            # self.time = time + dt.timedelta(flight.flight_duration)
        else:
            self.flight = flight
            self.flights_sequence = [flight.index]
            self.landing_number = 1
            # self.time = flight.flight_duration;

# %%
# Initial Setting - Test
flight_graph = dict()
flight_excel = pd.read_excel("flight.xlsx")
flight_excel.columns = ['INDEX', 'ORIGIN', 'ORIGIN_DATE', 'DEST','DEST_DATE', 'FLIGHT_DURATION','AIRCRAFT_TYPE' ]
airports_set = set()

# %%
# Graph insert Node
for i in range(100) :
    airports_set.add(flight_excel.loc[i]['ORIGIN'])
    airports_set.add(flight_excel.loc[i]['DEST'])
    
for airports in airports_set :
    flight_graph[airports] = list()

# Graph insert Edge
for i in range(100) :
    flight_graph[flight_excel.loc[i]['ORIGIN']].append(Flight(flight_excel.loc[i]['INDEX'], flight_excel.loc[i]['ORIGIN'], flight_excel.loc[i]['DEST'],
                                                              flight_excel.loc[i]['ORIGIN_DATE'], flight_excel.loc[i]['DEST_DATE'],
                                                              flight_excel.loc[i]['FLIGHT_DURATION'], flight_excel.loc[i]['AIRCRAFT_TYPE']))

# %%
print(len(airports_set))
# Out:
# 5

# %%
pairing_set = list()

# clustering을 통한 flights set의 크기를 줄여야지 경우의 수가 줄어듬
# 하지만 그렇다면 시간을 어떻게 배분해야하는가? 기준은? 시간 → 기종? 조금더 생각해봐야 할 거 같다.

# 여기서 Node 시작에 따라 끝나는 경우는
# 만나는 Base가 같은경우가 있고,
# 만약 끝이 Base가 아닌데 갈 곳이 없는 경우가 있다.
# 그렇다면 모든 pairing의 모든 경우를 넣어도 모든 경우가 나온다!
# 

for airport in airports_set :
    # pairing_set.append(["-" * 10, airport, "-" * 10])

    for flight in flight_graph[airport] :
        # 항공편, 항공편의 순서를 넣는다
        stack_temp = [Stackitem(flight)]
        
        while stack_temp:
            # 현재 진행 중인 항공편의 정보
            flights_information_now = stack_temp.pop()

            pairing_set.append(copy.deepcopy(flights_information_now.flights_sequence))
            # 만약 해당 항공편이 진행됨으로서 base로 간다면 해당 항공편은 더 진행할 필요가 없음
            if (flights_information_now.flight.dest == flight.origin) :
                continue
            
            else :
                pairing_set[-1].append("DeadHead")

            # Search Space Extend
            for flight_next in flight_graph[flights_information_now.flight.dest] :
                # 항공기 기종이 같은지? 시간이 가능한지? (날짜가 같다면 시간까지 비교, 다르다면 날짜 비교)
                flight_type_equal = (flights_information_now.flight.flight_type == flight_next.flight_type)
                flight_time_possible = flights_information_now.flight.dest_date < flight_next.origin_date and (flight_next.origin_date - flights_information_now.flight.dest_date).seconds/3600 >= 3
                flight_day_possible = (flight_next.dest_date  - flight.origin_date).days <= 7
                flight_landing_possible = (flights_information_now.landing_number <= 3)

                # 기종이 다르거나 시간이 불가능하면 해당 항공편은 Search에 사용하지 않음
                if (not flight_type_equal or not flight_time_possible or not flight_day_possible or not flight_landing_possible) :
                    continue

                # 기종이 같고, 시간이 가능하다면 Search를 위해 stack에 추가(항공편의 순서까지)
                temp_list = copy.deepcopy(flights_information_now.flights_sequence)
                #if (flights_information_now.flight.dest_date < flight_next.origin_date) :
                    #for i in range(0, int(flight_next.origin_date.day - flights_information_now.flight.dest_date.day)) :
                        #temp_list.append("Layover")
                        
                stack_temp.append(Stackitem(flight_next, temp_list, flights_information_now.landing_number))
                

#for pairing in pairing_set :
    #print(pairing)

# 첫번째 방안 : 모든 항공편들의 순서를 저장한다
# 그렇다면 만들 수 있는(DeadHead, Layover, Feasible) Pairing의 모든 경우가 나온다.
# 하지만 이럴때는 시간이 n^n까지 나올 수 있는 것으로 보인다.
# 여기서 경우의 수를 줄이는 조건을 넣을 때
# 첫번째 - 항공기 종류
# 두번째 - 전 항공편의 도착시간보다 현 항공편의 출발시간이 느려야한다
# 세번째 - Crew의 Trun Time이 MMT보다 크거나 같아야 한다.(Slack Time은 어떻게 될려나?)
# feasible pairing은 좀 많다. -> 그럼 DeadHead가 존재하는 pairing은 넣어야하는 것인가?
# 지연전파? 존재한다?

# stack에 넣을 때 모든 정보를 넣어버린다면? 오히려 쉬워진다. 하지만 메모리를 많이 쓰므로 최적화가 필요함(조건을 생각해야 함)

# %%
import re

# 엑셀 파일명
filename = 'output.xlsx'

# 데이터프레임으로 변환
df = pd.DataFrame(pairing_set)

# 엑셀로 출력
df.to_excel(filename, index=False, header=False)

# %%
# 비행기 기종 : {크루원 수, 비행 수당, 기본급}
salary={}

salary_excel = pd.read_excel("salary.xlsx")
for index, row in salary_excel.iterrows():
    aircraft = row['AIRCRAFT']
    crew_num = row['CREW_NUM']
    flight_salary = row['FLIGHT_SALARY']
    base_salary = row['BASE_SALARY']
    salary[aircraft] = {'CREW_NUM': crew_num, 'FLIGHT_SALARY': flight_salary, 'BASE_SALARY': base_salary}




for pairing in pairing_set :
    crew_num = salary[flight_excel.loc[int(re.search(r'\d+', pairing[0]).group())-1]['AIRCRAFT_TYPE']]['CREW_NUM']
    base_salary = salary[flight_excel.loc[int(re.search(r'\d+', pairing[0]).group())-1]['AIRCRAFT_TYPE']]['BASE_SALARY']
    flight_salary = salary[flight_excel.loc[int(re.search(r'\d+', pairing[0]).group())-1]['AIRCRAFT_TYPE']]['FLIGHT_SALARY']
    layover_time = 0
    layover_cost = 50
    flight_time = flight_excel.loc[int(re.search(r'\d+', pairing[0]).group())]['FLIGHT_DURATION']
    deadhead=0
    for idx,pair in enumerate(pairing[1:],start=1):
        if(pair != "DeadHead") :
            n = int(re.search(r'\d+', pair).group())
            flight_time+=flight_excel.loc[n-1]['FLIGHT_DURATION']
            before_flight = flight_excel.loc[int(re.search(r'\d+', pairing[idx-1]).group())-1]['ORIGIN_DATE']
            current_flight = flight_excel.loc[int(re.search(r'\d+', pair).group())-1]['ORIGIN_DATE']
            layover_time += (current_flight-before_flight).seconds/3600
        else :
            #deadhead cost 정의하기
            deadhead_cost = 100
            deadhead = deadhead_cost * crew_num
        
            
            
    print(pairing)
    print('base_salary :',base_salary,'flight_salary :', flight_salary*flight_time,'layover_cost :',layover_cost*layover_time,'deadhead :',deadhead)
    print('Total: ',base_salary+flight_salary*flight_time+layover_cost*layover_time)
        
    #print(pairing)
# Out:
# ['F3', 'DeadHead']
# base_salary : 1925 flight_salary : 228.8 layover_cost : 0 deadhead : 500
# Total:  2153.8
# ['F13', 'DeadHead']
# base_salary : 2275 flight_salary : 279.5 layover_cost : 0 deadhead : 600
# Total:  2554.5
# ['F13', 'F85', 'DeadHead']
# base_salary : 2275 flight_salary : 828.0999999999999 layover_cost : 514.1666666666666 deadhead : 600
# Total:  3617.2666666666664
# ['F13', 'F36', 'DeadHead']
# base_salary : 2275 flight_salary : 578.4999999999999 layover_cost : 1183.3333333333335 deadhead : 600
# Total:  4036.8333333333335
# ['F13', 'F28', 'DeadHead']
# base_salary : 2275 flight_salary : 562.9 layover_cost : 436.66666666666663 deadhead : 600
# Total:  3274.5666666666666
# ['F13', 'F28', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 851.5000000000001 layover_cost : 1412.5 deadhead : 600
# Total:  4539.0
# ['F13', 'F7', 'DeadHead']
# base_salary : 2275 flight_salary : 562.9 layover_cost : 436.66666666666663 deadhead : 600
# Total:  3274.5666666666666
# ['F16', 'DeadHead']
# base_salary : 1925 flight_salary : 300.3 layover_cost : 0 deadhead : 500
# Total:  2225.3
# ['F23', 'DeadHead']
# base_salary : 2275 flight_salary : 474.5 layover_cost : 0 deadhead : 600
# Total:  2749.5
# ['F42', 'DeadHead']
# base_salary : 2275 flight_salary : 347.09999999999997 layover_cost : 0 deadhead : 600
# Total:  2622.1
# ['F42', 'F69', 'DeadHead']
# base_salary : 2275 flight_salary : 682.5 layover_cost : 766.6666666666667 deadhead : 600
# Total:  3724.166666666667
# ['F42', 'F69', 'F90', 'DeadHead']
# base_salary : 2275 flight_salary : 978.8999999999999 layover_cost : 1602.4999999999998 deadhead : 600
# Total:  4856.4
# ['F42', 'F69', 'F84', 'DeadHead']
# base_salary : 2275 flight_salary : 1231.1 layover_cost : 1185.0000000000002 deadhead : 600
# Total:  4691.1
# ['F42', 'F69', 'F84', 'F38']
# base_salary : 2275 flight_salary : 1553.5 layover_cost : 1220.8333333333335 deadhead : 0
# Total:  5049.333333333334
# ['F42', 'F69', 'F66', 'DeadHead']
# base_salary : 2275 flight_salary : 962.0 layover_cost : 1261.6666666666667 deadhead : 600
# Total:  4498.666666666667
# ['F42', 'F69', 'F41', 'DeadHead']
# base_salary : 2275 flight_salary : 1231.1 layover_cost : 1185.0000000000002 deadhead : 600
# Total:  4691.1
# ['F42', 'F69', 'F12', 'DeadHead']
# base_salary : 2275 flight_salary : 1231.1 layover_cost : 1185.0000000000002 deadhead : 600
# Total:  4691.1
# ['F42', 'F38']
# base_salary : 2275 flight_salary : 669.5 layover_cost : 20.833333333333336 deadhead : 0
# Total:  2965.3333333333335
# ['F42', 'F1', 'DeadHead']
# base_salary : 2275 flight_salary : 819.0 layover_cost : 45.83333333333333 deadhead : 600
# Total:  3139.8333333333335
# ['F42', 'F1', 'F37']
# base_salary : 2275 flight_salary : 1166.1 layover_cost : 1100.0 deadhead : 0
# Total:  4541.1
# ['F42', 'F1', 'F18', 'DeadHead']
# base_salary : 2275 flight_salary : 1101.1 layover_cost : 1195.8333333333335 deadhead : 600
# Total:  4571.933333333333
# ['F42', 'F1', 'F18', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 1465.1 layover_cost : 1520.8333333333335 deadhead : 600
# Total:  5260.933333333333
# ['F42', 'F1', 'F18', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 1462.4999999999998 layover_cost : 2320.8333333333335 deadhead : 600
# Total:  6058.333333333334
# ['F42', 'F1', 'F18', 'F8', 'DeadHead']
# base_salary : 2275 flight_salary : 1374.1 layover_cost : 2129.166666666667 deadhead : 600
# Total:  5778.266666666666
# ['F43', 'DeadHead']
# base_salary : 1925 flight_salary : 346.5 layover_cost : 0 deadhead : 500
# Total:  2271.5
# ['F43', 'F71', 'DeadHead']
# base_salary : 1925 flight_salary : 643.5 layover_cost : 53.333333333333336 deadhead : 500
# Total:  2621.8333333333335
# ['F43', 'F67']
# base_salary : 1925 flight_salary : 717.1999999999999 layover_cost : 33.33333333333333 deadhead : 0
# Total:  2675.5333333333333
# ['F43', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 583.0 layover_cost : 450.0 deadhead : 500
# Total:  2958.0
# ['F43', 'F52', 'F40']
# base_salary : 1925 flight_salary : 803.0 layover_cost : 1506.6666666666667 deadhead : 0
# Total:  4234.666666666667
# ['F43', 'F52', 'F11', 'DeadHead']
# base_salary : 1925 flight_salary : 821.6999999999999 layover_cost : 1316.6666666666665 deadhead : 500
# Total:  4063.3666666666663
# ['F43', 'F21']
# base_salary : 1925 flight_salary : 709.4999999999999 layover_cost : 4.166666666666666 deadhead : 0
# Total:  2638.6666666666665
# ['F43', 'F6', 'DeadHead']
# base_salary : 1925 flight_salary : 643.5 layover_cost : 304.16666666666663 deadhead : 500
# Total:  2872.6666666666665
# ['F43', 'F6', 'F97', 'DeadHead']
# base_salary : 1925 flight_salary : 872.3 layover_cost : 1279.1666666666665 deadhead : 500
# Total:  4076.4666666666667
# ['F43', 'F6', 'F97', 'F67']
# base_salary : 1925 flight_salary : 1243.0 layover_cost : 2433.333333333333 deadhead : 0
# Total:  5601.333333333333
# ['F43', 'F6', 'F97', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 1108.8 layover_cost : 1650.0 deadhead : 500
# Total:  4683.8
# ['F43', 'F6', 'F95', 'DeadHead']
# base_salary : 1925 flight_salary : 855.8 layover_cost : 1471.6666666666667 deadhead : 500
# Total:  4252.466666666667
# ['F43', 'F6', 'F64', 'DeadHead']
# base_salary : 1925 flight_salary : 877.8 layover_cost : 1379.1666666666665 deadhead : 500
# Total:  4181.966666666667
# ['F43', 'F6', 'F64', 'F67']
# base_salary : 1925 flight_salary : 1248.5 layover_cost : 2433.333333333333 deadhead : 0
# Total:  5606.833333333333
# ['F43', 'F6', 'F64', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 1114.3 layover_cost : 1650.0 deadhead : 500
# Total:  4689.3
# ['F43', 'F6', 'F59', 'DeadHead']
# base_salary : 1925 flight_salary : 850.3 layover_cost : 1422.5 deadhead : 500
# Total:  4197.8
# ['F43', 'F6', 'F59', 'F40']
# base_salary : 1925 flight_salary : 1070.3 layover_cost : 1506.6666666666667 deadhead : 0
# Total:  4501.966666666667
# ['F43', 'F6', 'F59', 'F11', 'DeadHead']
# base_salary : 1925 flight_salary : 1088.9999999999998 layover_cost : 2516.6666666666665 deadhead : 500
# Total:  5530.666666666666
# ['F44', 'DeadHead']
# base_salary : 1925 flight_salary : 401.5 layover_cost : 0 deadhead : 500
# Total:  2326.5
# ['F44', 'F54']
# base_salary : 1925 flight_salary : 698.5 layover_cost : 54.166666666666664 deadhead : 0
# Total:  2677.6666666666665
# ['F44', 'F50']
# base_salary : 1925 flight_salary : 803.0 layover_cost : 653.3333333333334 deadhead : 0
# Total:  3381.3333333333335
# ['F44', 'F45']
# base_salary : 1925 flight_salary : 803.0 layover_cost : 653.3333333333334 deadhead : 0
# Total:  3381.3333333333335
# ['F47', 'DeadHead']
# base_salary : 2275 flight_salary : 289.9 layover_cost : 0 deadhead : 600
# Total:  2564.9
# ['F47', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 651.3 layover_cost : 1042.5 deadhead : 600
# Total:  3968.8
# ['F47', 'F76', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 941.2 layover_cost : 1417.5 deadhead : 600
# Total:  4633.7
# ['F47', 'F76', 'F48', 'F5']
# base_salary : 2275 flight_salary : 1363.7 layover_cost : 1466.6666666666667 deadhead : 0
# Total:  5105.366666666667
# ['F47', 'F33', 'DeadHead']
# base_salary : 2275 flight_salary : 627.9 layover_cost : 792.5 deadhead : 600
# Total:  3695.4
# ['F47', 'F33', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 917.8000000000001 layover_cost : 1417.5 deadhead : 600
# Total:  4610.3
# ['F47', 'F33', 'F48', 'F5']
# base_salary : 2275 flight_salary : 1340.3 layover_cost : 1466.6666666666667 deadhead : 0
# Total:  5081.966666666667
# ['F47', 'F33', 'F18', 'DeadHead']
# base_salary : 2275 flight_salary : 910.0 layover_cost : 1117.5 deadhead : 600
# Total:  4302.5
# ['F47', 'F33', 'F18', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 1274.0 layover_cost : 1442.5 deadhead : 600
# Total:  4991.5
# ['F47', 'F33', 'F18', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 1271.3999999999999 layover_cost : 2242.5 deadhead : 600
# Total:  5788.9
# ['F47', 'F33', 'F18', 'F8', 'DeadHead']
# base_salary : 2275 flight_salary : 1183.0 layover_cost : 2050.8333333333335 deadhead : 600
# Total:  5508.833333333334
# ['F47', 'F33', 'F18', 'F5']
# base_salary : 2275 flight_salary : 1332.5 layover_cost : 1466.6666666666667 deadhead : 0
# Total:  5074.166666666667
# ['F47', 'F8', 'DeadHead']
# base_salary : 2275 flight_salary : 562.9 layover_cost : 850.8333333333333 deadhead : 600
# Total:  3688.7333333333336
# ['F47', 'F8', 'F90', 'DeadHead']
# base_salary : 2275 flight_salary : 859.3 layover_cost : 1524.1666666666667 deadhead : 600
# Total:  4658.466666666667
# ['F47', 'F8', 'F66', 'DeadHead']
# base_salary : 2275 flight_salary : 842.4000000000001 layover_cost : 1183.3333333333333 deadhead : 600
# Total:  4300.733333333334
# ['F57', 'DeadHead']
# base_salary : 1925 flight_salary : 390.5 layover_cost : 0 deadhead : 500
# Total:  2315.5
# ['F63', 'DeadHead']
# base_salary : 2275 flight_salary : 276.9 layover_cost : 0 deadhead : 600
# Total:  2551.9
# ['F65', 'DeadHead']
# base_salary : 2275 flight_salary : 279.5 layover_cost : 0 deadhead : 600
# Total:  2554.5
# ['F68', 'DeadHead']
# base_salary : 2275 flight_salary : 335.40000000000003 layover_cost : 0 deadhead : 600
# Total:  2610.4
# ['F77', 'DeadHead']
# base_salary : 1925 flight_salary : 363.0 layover_cost : 0 deadhead : 500
# Total:  2288.0
# ['F88', 'DeadHead']
# base_salary : 2275 flight_salary : 574.6 layover_cost : 0 deadhead : 600
# Total:  2849.6
# ['F88', 'F75', 'DeadHead']
# base_salary : 2275 flight_salary : 928.2 layover_cost : 45.83333333333333 deadhead : 600
# Total:  3249.0333333333333
# ['F88', 'F75', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 1216.8000000000002 layover_cost : 121.66666666666666 deadhead : 600
# Total:  3613.4666666666667
# ['F91', 'DeadHead']
# base_salary : 1925 flight_salary : 238.7 layover_cost : 0 deadhead : 500
# Total:  2163.7
# ['F94', 'DeadHead']
# base_salary : 2275 flight_salary : 250.9 layover_cost : 0 deadhead : 600
# Total:  2525.9
# ['F94', 'F69', 'DeadHead']
# base_salary : 2275 flight_salary : 586.3 layover_cost : 766.6666666666667 deadhead : 600
# Total:  3627.966666666667
# ['F94', 'F69', 'F90', 'DeadHead']
# base_salary : 2275 flight_salary : 882.6999999999999 layover_cost : 1602.4999999999998 deadhead : 600
# Total:  4760.2
# ['F94', 'F69', 'F84', 'DeadHead']
# base_salary : 2275 flight_salary : 1134.9 layover_cost : 1185.0000000000002 deadhead : 600
# Total:  4594.900000000001
# ['F94', 'F69', 'F84', 'F38']
# base_salary : 2275 flight_salary : 1457.3000000000002 layover_cost : 1220.8333333333335 deadhead : 0
# Total:  4953.133333333333
# ['F94', 'F69', 'F66', 'DeadHead']
# base_salary : 2275 flight_salary : 865.8000000000001 layover_cost : 1261.6666666666667 deadhead : 600
# Total:  4402.466666666667
# ['F94', 'F69', 'F41', 'DeadHead']
# base_salary : 2275 flight_salary : 1134.9 layover_cost : 1185.0000000000002 deadhead : 600
# Total:  4594.900000000001
# ['F94', 'F69', 'F12', 'DeadHead']
# base_salary : 2275 flight_salary : 1134.9 layover_cost : 1185.0000000000002 deadhead : 600
# Total:  4594.900000000001
# ['F94', 'F38']
# base_salary : 2275 flight_salary : 573.3000000000001 layover_cost : 20.833333333333336 deadhead : 0
# Total:  2869.1333333333337
# ['F94', 'F1', 'DeadHead']
# base_salary : 2275 flight_salary : 722.8 layover_cost : 45.83333333333333 deadhead : 600
# Total:  3043.6333333333337
# ['F94', 'F1', 'F37']
# base_salary : 2275 flight_salary : 1069.9 layover_cost : 1100.0 deadhead : 0
# Total:  4444.9
# ['F94', 'F1', 'F18', 'DeadHead']
# base_salary : 2275 flight_salary : 1004.9 layover_cost : 1195.8333333333335 deadhead : 600
# Total:  4475.733333333334
# ['F94', 'F1', 'F18', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 1368.8999999999999 layover_cost : 1520.8333333333335 deadhead : 600
# Total:  5164.733333333334
# ['F94', 'F1', 'F18', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 1366.3 layover_cost : 2320.8333333333335 deadhead : 600
# Total:  5962.133333333333
# ['F94', 'F1', 'F18', 'F8', 'DeadHead']
# base_salary : 2275 flight_salary : 1277.9 layover_cost : 2129.166666666667 deadhead : 600
# Total:  5682.0666666666675
# ['F99', 'DeadHead']
# base_salary : 2275 flight_salary : 260.0 layover_cost : 0 deadhead : 600
# Total:  2535.0
# ['F2', 'DeadHead']
# base_salary : 2275 flight_salary : 392.6 layover_cost : 0 deadhead : 600
# Total:  2667.6
# ['F2', 'F85', 'DeadHead']
# base_salary : 2275 flight_salary : 941.2 layover_cost : 605.8333333333334 deadhead : 600
# Total:  3822.0333333333333
# ['F2', 'F82']
# base_salary : 2275 flight_salary : 672.1 layover_cost : 320.0 deadhead : 0
# Total:  3267.1
# ['F2', 'F36']
# base_salary : 2275 flight_salary : 691.6 layover_cost : 75.0 deadhead : 0
# Total:  3041.6
# ['F2', 'F28']
# base_salary : 2275 flight_salary : 676.0 layover_cost : 528.3333333333334 deadhead : 0
# Total:  3479.3333333333335
# ['F2', 'F7']
# base_salary : 2275 flight_salary : 676.0 layover_cost : 528.3333333333334 deadhead : 0
# Total:  3479.3333333333335
# ['F4', 'DeadHead']
# base_salary : 1925 flight_salary : 357.5 layover_cost : 0 deadhead : 500
# Total:  2282.5
# ['F4', 'F71']
# base_salary : 1925 flight_salary : 654.5 layover_cost : 74.16666666666667 deadhead : 0
# Total:  2653.6666666666665
# ['F4', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 728.2 layover_cost : 54.166666666666664 deadhead : 500
# Total:  2707.3666666666663
# ['F4', 'F67', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 1027.4 layover_cost : 1208.3333333333333 deadhead : 500
# Total:  4160.733333333334
# ['F4', 'F67', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 1060.4 layover_cost : 1199.1666666666665 deadhead : 500
# Total:  4184.566666666667
# ['F4', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 594.0 layover_cost : 470.8333333333333 deadhead : 500
# Total:  2989.8333333333335
# ['F4', 'F52', 'F40', 'DeadHead']
# base_salary : 1925 flight_salary : 814.0 layover_cost : 1527.4999999999998 deadhead : 500
# Total:  4266.5
# ['F4', 'F52', 'F40', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 998.8 layover_cost : 2670.833333333333 deadhead : 500
# Total:  5594.633333333333
# ['F4', 'F52', 'F40', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 998.8 layover_cost : 2670.833333333333 deadhead : 500
# Total:  5594.633333333333
# ['F4', 'F52', 'F40', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 1146.2 layover_cost : 2399.1666666666665 deadhead : 500
# Total:  5470.366666666667
# ['F4', 'F52', 'F11']
# base_salary : 1925 flight_salary : 832.7 layover_cost : 1337.5 deadhead : 0
# Total:  4095.2
# ['F4', 'F21', 'DeadHead']
# base_salary : 1925 flight_salary : 720.5 layover_cost : 25.0 deadhead : 500
# Total:  2670.5
# ['F4', 'F21', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 1019.6999999999999 layover_cost : 1208.3333333333335 deadhead : 500
# Total:  4153.033333333333
# ['F4', 'F21', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 1052.7 layover_cost : 1199.1666666666667 deadhead : 500
# Total:  4176.866666666667
# ['F4', 'F6']
# base_salary : 1925 flight_salary : 654.5 layover_cost : 325.0 deadhead : 0
# Total:  2904.5
# ['F9', 'DeadHead']
# base_salary : 2275 flight_salary : 429.0 layover_cost : 0 deadhead : 600
# Total:  2704.0
# ['F9', 'F90']
# base_salary : 2275 flight_salary : 725.4 layover_cost : 560.8333333333334 deadhead : 0
# Total:  3561.2333333333336
# ['F9', 'F89', 'DeadHead']
# base_salary : 2275 flight_salary : 1003.6 layover_cost : 1129.1666666666665 deadhead : 600
# Total:  4407.766666666666
# ['F9', 'F89', 'F73', 'DeadHead']
# base_salary : 2275 flight_salary : 1443.0 layover_cost : 1539.1666666666665 deadhead : 600
# Total:  5257.166666666666
# ['F9', 'F89', 'F73', 'F84', 'DeadHead']
# base_salary : 2275 flight_salary : 1991.6000000000001 layover_cost : 2543.333333333333 deadhead : 600
# Total:  6809.933333333333
# ['F9', 'F89', 'F73', 'F66']
# base_salary : 2275 flight_salary : 1722.5 layover_cost : 2620.0 deadhead : 0
# Total:  6617.5
# ['F9', 'F89', 'F73', 'F56', 'DeadHead']
# base_salary : 2275 flight_salary : 1722.5 layover_cost : 2270.833333333333 deadhead : 600
# Total:  6268.333333333333
# ['F9', 'F89', 'F73', 'F41', 'DeadHead']
# base_salary : 2275 flight_salary : 1991.6000000000001 layover_cost : 2543.333333333333 deadhead : 600
# Total:  6809.933333333333
# ['F9', 'F89', 'F73', 'F12', 'DeadHead']
# base_salary : 2275 flight_salary : 1991.6000000000001 layover_cost : 2543.333333333333 deadhead : 600
# Total:  6809.933333333333
# ['F9', 'F56', 'DeadHead']
# base_salary : 2275 flight_salary : 708.4999999999999 layover_cost : 1070.8333333333335 deadhead : 600
# Total:  4054.3333333333335
# ['F9', 'F56', 'F79']
# base_salary : 2275 flight_salary : 1072.5 layover_cost : 1679.1666666666667 deadhead : 0
# Total:  5026.666666666667
# ['F9', 'F56', 'F8', 'DeadHead']
# base_salary : 2275 flight_salary : 981.4999999999999 layover_cost : 1087.5 deadhead : 600
# Total:  4344.0
# ['F9', 'F56', 'F8', 'F90']
# base_salary : 2275 flight_salary : 1277.8999999999999 layover_cost : 1760.8333333333335 deadhead : 0
# Total:  5313.733333333334
# ['F9', 'F56', 'F8', 'F66']
# base_salary : 2275 flight_salary : 1261.0 layover_cost : 1420.0 deadhead : 0
# Total:  4956.0
# ['F9', 'F56', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 1131.0 layover_cost : 1703.3333333333335 deadhead : 600
# Total:  5109.333333333334
# ['F9', 'F34', 'DeadHead']
# base_salary : 2275 flight_salary : 673.4 layover_cost : 426.6666666666667 deadhead : 600
# Total:  3375.0666666666666
# ['F9', 'F34', 'F79']
# base_salary : 2275 flight_salary : 1037.3999999999999 layover_cost : 479.1666666666667 deadhead : 0
# Total:  3791.566666666666
# ['F9', 'F34', 'F76']
# base_salary : 2275 flight_salary : 1034.8 layover_cost : 1279.1666666666667 deadhead : 0
# Total:  4588.966666666667
# ['F9', 'F34', 'F33']
# base_salary : 2275 flight_salary : 1011.3999999999999 layover_cost : 1029.1666666666667 deadhead : 0
# Total:  4315.566666666667
# ['F9', 'F34', 'F8', 'DeadHead']
# base_salary : 2275 flight_salary : 946.3999999999999 layover_cost : 1087.5 deadhead : 600
# Total:  4308.9
# ['F9', 'F34', 'F8', 'F90']
# base_salary : 2275 flight_salary : 1242.7999999999997 layover_cost : 1760.8333333333335 deadhead : 0
# Total:  5278.633333333333
# ['F9', 'F34', 'F8', 'F66']
# base_salary : 2275 flight_salary : 1225.8999999999999 layover_cost : 1420.0 deadhead : 0
# Total:  4920.9
# ['F9', 'F34', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 1095.8999999999999 layover_cost : 503.3333333333333 deadhead : 600
# Total:  3874.233333333333
# ['F15', 'DeadHead']
# base_salary : 3220 flight_salary : 309.12 layover_cost : 0 deadhead : 800
# Total:  3529.12
# ['F18', 'DeadHead']
# base_salary : 2275 flight_salary : 474.5 layover_cost : 0 deadhead : 600
# Total:  2749.5
# ['F18', 'F79']
# base_salary : 2275 flight_salary : 838.4999999999999 layover_cost : 325.0 deadhead : 0
# Total:  3438.5
# ['F18', 'F76']
# base_salary : 2275 flight_salary : 835.9 layover_cost : 1125.0 deadhead : 0
# Total:  4235.9
# ['F18', 'F8', 'DeadHead']
# base_salary : 2275 flight_salary : 747.5 layover_cost : 933.3333333333334 deadhead : 600
# Total:  3955.8333333333335
# ['F18', 'F8', 'F90']
# base_salary : 2275 flight_salary : 1043.8999999999999 layover_cost : 1606.6666666666667 deadhead : 0
# Total:  4925.566666666667
# ['F18', 'F8', 'F66']
# base_salary : 2275 flight_salary : 1027.0 layover_cost : 1265.8333333333335 deadhead : 0
# Total:  4567.833333333334
# ['F18', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 897.0 layover_cost : 349.1666666666667 deadhead : 600
# Total:  3521.1666666666665
# ['F22', 'DeadHead']
# base_salary : 2275 flight_salary : 348.40000000000003 layover_cost : 0 deadhead : 600
# Total:  2623.4
# ['F29', 'DeadHead']
# base_salary : 2275 flight_salary : 425.1 layover_cost : 0 deadhead : 600
# Total:  2700.1
# ['F29', 'F99', 'DeadHead']
# base_salary : 2275 flight_salary : 821.6 layover_cost : 347.5 deadhead : 600
# Total:  3444.1
# ['F29', 'F63', 'DeadHead']
# base_salary : 2275 flight_salary : 815.0999999999999 layover_cost : 1125.0 deadhead : 600
# Total:  4215.1
# ['F29', 'F23', 'DeadHead']
# base_salary : 2275 flight_salary : 773.5 layover_cost : 1065.8333333333333 deadhead : 600
# Total:  4114.333333333333
# ['F31', 'DeadHead']
# base_salary : 3220 flight_salary : 368.0 layover_cost : 0 deadhead : 800
# Total:  3588.0
# ['F31', 'F62']
# base_salary : 3220 flight_salary : 1048.8 layover_cost : 1025.8333333333333 deadhead : 0
# Total:  5294.633333333333
# ['F31', 'F19']
# base_salary : 3220 flight_salary : 1039.6000000000001 layover_cost : 146.66666666666666 deadhead : 0
# Total:  4406.266666666667
# ['F32', 'DeadHead']
# base_salary : 1925 flight_salary : 286.0 layover_cost : 0 deadhead : 500
# Total:  2211.0
# ['F32', 'F100', 'DeadHead']
# base_salary : 1925 flight_salary : 505.99999999999994 layover_cost : 1050.0 deadhead : 500
# Total:  3481.0
# ['F32', 'F100', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 690.8 layover_cost : 1108.3333333333335 deadhead : 500
# Total:  3724.1333333333337
# ['F32', 'F100', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 805.2 layover_cost : 2045.8333333333335 deadhead : 500
# Total:  4776.033333333333
# ['F32', 'F100', 'F57', 'DeadHead']
# base_salary : 1925 flight_salary : 794.1999999999999 layover_cost : 1065.0 deadhead : 500
# Total:  3784.2
# ['F32', 'F100', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 690.8 layover_cost : 1108.3333333333335 deadhead : 500
# Total:  3724.1333333333337
# ['F32', 'F100', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 838.1999999999999 layover_cost : 2036.6666666666667 deadhead : 500
# Total:  4799.866666666667
# ['F32', 'F55']
# base_salary : 1925 flight_salary : 520.3000000000001 layover_cost : 60.0 deadhead : 0
# Total:  2505.3
# ['F32', 'F40', 'DeadHead']
# base_salary : 1925 flight_salary : 505.99999999999994 layover_cost : 1165.0 deadhead : 500
# Total:  3596.0
# ['F32', 'F40', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 690.8 layover_cost : 2308.3333333333335 deadhead : 500
# Total:  4924.133333333333
# ['F32', 'F40', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 690.8 layover_cost : 2308.3333333333335 deadhead : 500
# Total:  4924.133333333333
# ['F32', 'F40', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 838.1999999999999 layover_cost : 2036.6666666666667 deadhead : 500
# Total:  4799.866666666667
# ['F32', 'F20', 'DeadHead']
# base_salary : 1925 flight_salary : 497.19999999999993 layover_cost : 712.5 deadhead : 500
# Total:  3134.7
# ['F32', 'F20', 'F74']
# base_salary : 1925 flight_salary : 797.5 layover_cost : 962.5 deadhead : 0
# Total:  3685.0
# ['F32', 'F20', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 733.7 layover_cost : 1308.3333333333333 deadhead : 500
# Total:  3967.033333333333
# ['F32', 'F20', 'F52', 'F40', 'DeadHead']
# base_salary : 1925 flight_salary : 953.7 layover_cost : 2365.0 deadhead : 500
# Total:  5243.7
# ['F32', 'F20', 'F52', 'F11']
# base_salary : 1925 flight_salary : 972.4 layover_cost : 2175.0 deadhead : 0
# Total:  5072.4
# ['F32', 'F20', 'F51']
# base_salary : 1925 flight_salary : 788.7 layover_cost : 1012.5 deadhead : 0
# Total:  3726.2
# ['F32', 'F20', 'F6']
# base_salary : 1925 flight_salary : 794.1999999999999 layover_cost : 1162.5 deadhead : 0
# Total:  3881.7
# ['F32', 'F11']
# base_salary : 1925 flight_salary : 524.6999999999999 layover_cost : 975.0 deadhead : 0
# Total:  3424.7
# ['F35', 'DeadHead']
# base_salary : 1925 flight_salary : 252.99999999999997 layover_cost : 0 deadhead : 500
# Total:  2178.0
# ['F35', 'F71']
# base_salary : 1925 flight_salary : 550.0 layover_cost : 1174.1666666666667 deadhead : 0
# Total:  3649.166666666667
# ['F35', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 623.7 layover_cost : 1154.1666666666665 deadhead : 500
# Total:  3702.8666666666663
# ['F35', 'F67', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 922.9000000000001 layover_cost : 2308.333333333333 deadhead : 500
# Total:  5156.233333333334
# ['F35', 'F67', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 955.9 layover_cost : 2299.1666666666665 deadhead : 500
# Total:  5180.066666666667
# ['F35', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 489.49999999999994 layover_cost : 370.83333333333337 deadhead : 500
# Total:  2785.3333333333335
# ['F35', 'F52', 'F40', 'DeadHead']
# base_salary : 1925 flight_salary : 709.4999999999999 layover_cost : 1427.5 deadhead : 500
# Total:  4062.0
# ['F35', 'F52', 'F40', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 894.2999999999998 layover_cost : 2570.8333333333335 deadhead : 500
# Total:  5390.133333333333
# ['F35', 'F52', 'F40', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 894.2999999999998 layover_cost : 2570.8333333333335 deadhead : 500
# Total:  5390.133333333333
# ['F35', 'F52', 'F40', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 1041.6999999999998 layover_cost : 2299.1666666666665 deadhead : 500
# Total:  5265.866666666667
# ['F35', 'F52', 'F11']
# base_salary : 1925 flight_salary : 728.1999999999999 layover_cost : 1237.5 deadhead : 0
# Total:  3890.7
# ['F35', 'F21', 'DeadHead']
# base_salary : 1925 flight_salary : 616.0 layover_cost : 1125.0 deadhead : 500
# Total:  3666.0
# ['F35', 'F21', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 915.2 layover_cost : 2308.3333333333335 deadhead : 500
# Total:  5148.533333333333
# ['F35', 'F21', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 948.1999999999999 layover_cost : 2299.1666666666665 deadhead : 500
# Total:  5172.366666666667
# ['F37', 'DeadHead']
# base_salary : 2275 flight_salary : 322.4 layover_cost : 0 deadhead : 600
# Total:  2597.4
# ['F37', 'F65', 'DeadHead']
# base_salary : 2275 flight_salary : 682.5 layover_cost : 424.16666666666663 deadhead : 600
# Total:  3381.6666666666665
# ['F48', 'DeadHead']
# base_salary : 2275 flight_salary : 286.0 layover_cost : 0 deadhead : 600
# Total:  2561.0
# ['F48', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 708.5 layover_cost : 49.166666666666664 deadhead : 600
# Total:  3032.6666666666665
# ['F49', 'DeadHead']
# base_salary : 2275 flight_salary : 474.5 layover_cost : 0 deadhead : 600
# Total:  2749.5
# ['F53', 'DeadHead']
# base_salary : 3220 flight_salary : 496.8 layover_cost : 0 deadhead : 800
# Total:  3716.8
# ['F53', 'F62']
# base_salary : 3220 flight_salary : 1177.6000000000001 layover_cost : 30.0 deadhead : 0
# Total:  4427.6
# ['F53', 'F58']
# base_salary : 3220 flight_salary : 1150.0 layover_cost : 471.6666666666667 deadhead : 0
# Total:  4841.666666666667
# ['F59', 'DeadHead']
# base_salary : 1925 flight_salary : 403.7 layover_cost : 0 deadhead : 500
# Total:  2328.7
# ['F59', 'F40', 'DeadHead']
# base_salary : 1925 flight_salary : 623.7 layover_cost : 84.16666666666667 deadhead : 500
# Total:  2632.8666666666663
# ['F59', 'F40', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 808.5 layover_cost : 1227.5 deadhead : 500
# Total:  3961.0
# ['F59', 'F40', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 808.5 layover_cost : 1227.5 deadhead : 500
# Total:  3961.0
# ['F59', 'F40', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 955.9 layover_cost : 955.8333333333334 deadhead : 500
# Total:  3836.7333333333336
# ['F59', 'F11']
# base_salary : 1925 flight_salary : 642.4 layover_cost : 1094.1666666666667 deadhead : 0
# Total:  3661.5666666666666
# ['F61', 'DeadHead']
# base_salary : 2275 flight_salary : 481.0 layover_cost : 0 deadhead : 600
# Total:  2756.0
# ['F61', 'F85', 'DeadHead']
# base_salary : 2275 flight_salary : 1029.6 layover_cost : 605.8333333333334 deadhead : 600
# Total:  3910.4333333333334
# ['F61', 'F82']
# base_salary : 2275 flight_salary : 760.5 layover_cost : 320.0 deadhead : 0
# Total:  3355.5
# ['F61', 'F36']
# base_salary : 2275 flight_salary : 780.0 layover_cost : 75.0 deadhead : 0
# Total:  3130.0
# ['F61', 'F28']
# base_salary : 2275 flight_salary : 764.4000000000001 layover_cost : 528.3333333333334 deadhead : 0
# Total:  3567.7333333333336
# ['F61', 'F7']
# base_salary : 2275 flight_salary : 764.4000000000001 layover_cost : 528.3333333333334 deadhead : 0
# Total:  3567.7333333333336
# ['F64', 'DeadHead']
# base_salary : 1925 flight_salary : 304.7 layover_cost : 0 deadhead : 500
# Total:  2229.7
# ['F64', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 675.4000000000001 layover_cost : 1054.1666666666665 deadhead : 500
# Total:  3654.5666666666666
# ['F64', 'F67', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 974.6000000000001 layover_cost : 2208.333333333333 deadhead : 500
# Total:  5107.933333333333
# ['F64', 'F67', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 1007.6 layover_cost : 2199.1666666666665 deadhead : 500
# Total:  5131.766666666666
# ['F64', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 541.2 layover_cost : 270.83333333333337 deadhead : 500
# Total:  2737.0333333333333
# ['F64', 'F52', 'F40', 'DeadHead']
# base_salary : 1925 flight_salary : 761.2 layover_cost : 1327.5 deadhead : 500
# Total:  4013.7
# ['F64', 'F52', 'F40', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 946.0 layover_cost : 2470.8333333333335 deadhead : 500
# Total:  5341.833333333334
# ['F64', 'F52', 'F40', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 946.0 layover_cost : 2470.8333333333335 deadhead : 500
# Total:  5341.833333333334
# ['F64', 'F52', 'F40', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 1093.3999999999999 layover_cost : 2199.1666666666665 deadhead : 500
# Total:  5217.566666666666
# ['F64', 'F52', 'F11']
# base_salary : 1925 flight_salary : 779.9 layover_cost : 1137.5 deadhead : 0
# Total:  3842.4
# ['F81', 'DeadHead']
# base_salary : 3220 flight_salary : 395.59999999999997 layover_cost : 0 deadhead : 800
# Total:  3615.6
# ['F92', 'DeadHead']
# base_salary : 2275 flight_salary : 351.0 layover_cost : 0 deadhead : 600
# Total:  2626.0
# ['F92', 'F87', 'DeadHead']
# base_salary : 2275 flight_salary : 634.4000000000001 layover_cost : 1050.8333333333333 deadhead : 600
# Total:  3960.2333333333336
# ['F92', 'F87', 'F85', 'DeadHead']
# base_salary : 2275 flight_salary : 1183.0000000000002 layover_cost : 1551.6666666666665 deadhead : 600
# Total:  5009.666666666666
# ['F92', 'F87', 'F36']
# base_salary : 2275 flight_salary : 933.4000000000001 layover_cost : 2220.833333333333 deadhead : 0
# Total:  5429.233333333334
# ['F92', 'F87', 'F28']
# base_salary : 2275 flight_salary : 917.8000000000001 layover_cost : 1474.1666666666667 deadhead : 0
# Total:  4666.966666666667
# ['F92', 'F87', 'F25']
# base_salary : 2275 flight_salary : 913.9000000000001 layover_cost : 1137.5 deadhead : 0
# Total:  4326.4
# ['F92', 'F87', 'F7']
# base_salary : 2275 flight_salary : 917.8000000000001 layover_cost : 1474.1666666666667 deadhead : 0
# Total:  4666.966666666667
# ['F92', 'F83', 'DeadHead']
# base_salary : 2275 flight_salary : 763.1 layover_cost : 875.0 deadhead : 600
# Total:  3913.1
# ['F92', 'F83', 'F99', 'DeadHead']
# base_salary : 2275 flight_salary : 1159.6 layover_cost : 1610.0000000000002 deadhead : 600
# Total:  5044.6
# ['F92', 'F83', 'F68', 'DeadHead']
# base_salary : 2275 flight_salary : 1153.1000000000001 layover_cost : 1187.5 deadhead : 600
# Total:  4615.6
# ['F92', 'F83', 'F63', 'DeadHead']
# base_salary : 2275 flight_salary : 1153.1000000000001 layover_cost : 1187.5 deadhead : 600
# Total:  4615.6
# ['F92', 'F75']
# base_salary : 2275 flight_salary : 704.6 layover_cost : 1174.1666666666667 deadhead : 0
# Total:  4153.766666666666
# ['F92', 'F17']
# base_salary : 2275 flight_salary : 705.9 layover_cost : 1025.0 deadhead : 0
# Total:  4005.9
# ['F95', 'DeadHead']
# base_salary : 1925 flight_salary : 577.5 layover_cost : 0 deadhead : 500
# Total:  2502.5
# ['F96', 'DeadHead']
# base_salary : 2275 flight_salary : 270.40000000000003 layover_cost : 0 deadhead : 600
# Total:  2545.4
# ['F97', 'DeadHead']
# base_salary : 1925 flight_salary : 234.29999999999998 layover_cost : 0 deadhead : 500
# Total:  2159.3
# ['F97', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 605.0 layover_cost : 1154.1666666666665 deadhead : 500
# Total:  3684.1666666666665
# ['F97', 'F67', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 904.2 layover_cost : 2308.333333333333 deadhead : 500
# Total:  5137.533333333333
# ['F97', 'F67', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 937.1999999999999 layover_cost : 2299.1666666666665 deadhead : 500
# Total:  5161.366666666667
# ['F97', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 470.79999999999995 layover_cost : 370.83333333333337 deadhead : 500
# Total:  2766.6333333333337
# ['F97', 'F52', 'F40', 'DeadHead']
# base_salary : 1925 flight_salary : 690.8 layover_cost : 1427.5 deadhead : 500
# Total:  4043.3
# ['F97', 'F52', 'F40', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 875.5999999999999 layover_cost : 2570.8333333333335 deadhead : 500
# Total:  5371.433333333333
# ['F97', 'F52', 'F40', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 875.5999999999999 layover_cost : 2570.8333333333335 deadhead : 500
# Total:  5371.433333333333
# ['F97', 'F52', 'F40', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 1022.9999999999999 layover_cost : 2299.1666666666665 deadhead : 500
# Total:  5247.166666666666
# ['F97', 'F52', 'F11']
# base_salary : 1925 flight_salary : 709.4999999999999 layover_cost : 1237.5 deadhead : 0
# Total:  3872.0
# ['F98', 'DeadHead']
# base_salary : 1925 flight_salary : 335.5 layover_cost : 0 deadhead : 500
# Total:  2260.5
# ['F98', 'F71']
# base_salary : 1925 flight_salary : 632.5 layover_cost : 1074.1666666666667 deadhead : 0
# Total:  3631.666666666667
# ['F98', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 706.2 layover_cost : 1054.1666666666665 deadhead : 500
# Total:  3685.3666666666663
# ['F98', 'F67', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 1005.4000000000001 layover_cost : 2208.333333333333 deadhead : 500
# Total:  5138.733333333334
# ['F98', 'F67', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 1038.3999999999999 layover_cost : 2199.1666666666665 deadhead : 500
# Total:  5162.566666666666
# ['F98', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 571.9999999999999 layover_cost : 270.83333333333337 deadhead : 500
# Total:  2767.8333333333335
# ['F98', 'F52', 'F40', 'DeadHead']
# base_salary : 1925 flight_salary : 791.9999999999999 layover_cost : 1327.5 deadhead : 500
# Total:  4044.5
# ['F98', 'F52', 'F40', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 976.7999999999998 layover_cost : 2470.8333333333335 deadhead : 500
# Total:  5372.633333333333
# ['F98', 'F52', 'F40', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 976.7999999999998 layover_cost : 2470.8333333333335 deadhead : 500
# Total:  5372.633333333333
# ['F98', 'F52', 'F40', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 1124.1999999999998 layover_cost : 2199.1666666666665 deadhead : 500
# Total:  5248.366666666667
# ['F98', 'F52', 'F11']
# base_salary : 1925 flight_salary : 810.6999999999999 layover_cost : 1137.5 deadhead : 0
# Total:  3873.2
# ['F98', 'F21', 'DeadHead']
# base_salary : 1925 flight_salary : 698.5 layover_cost : 1025.0 deadhead : 500
# Total:  3648.5
# ['F98', 'F21', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 997.7 layover_cost : 2208.3333333333335 deadhead : 500
# Total:  5131.033333333333
# ['F98', 'F21', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 1030.6999999999998 layover_cost : 2199.1666666666665 deadhead : 500
# Total:  5154.866666666667
# ['F5', 'DeadHead']
# base_salary : 2275 flight_salary : 351.0 layover_cost : 0 deadhead : 600
# Total:  2626.0
# ['F6', 'DeadHead']
# base_salary : 1925 flight_salary : 239.8 layover_cost : 0 deadhead : 500
# Total:  2164.8
# ['F6', 'F97']
# base_salary : 1925 flight_salary : 468.59999999999997 layover_cost : 975.0 deadhead : 0
# Total:  3368.6
# ['F6', 'F95', 'DeadHead']
# base_salary : 1925 flight_salary : 452.1 layover_cost : 1167.5 deadhead : 500
# Total:  3544.6
# ['F6', 'F64']
# base_salary : 1925 flight_salary : 474.1000000000001 layover_cost : 1075.0 deadhead : 0
# Total:  3474.1
# ['F6', 'F59', 'DeadHead']
# base_salary : 1925 flight_salary : 446.6000000000001 layover_cost : 1118.3333333333333 deadhead : 500
# Total:  3489.9333333333334
# ['F6', 'F59', 'F40', 'DeadHead']
# base_salary : 1925 flight_salary : 666.6 layover_cost : 1202.5 deadhead : 500
# Total:  3794.1
# ['F6', 'F59', 'F40', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 851.4 layover_cost : 2345.8333333333335 deadhead : 500
# Total:  5122.233333333334
# ['F6', 'F59', 'F40', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 851.4 layover_cost : 2345.8333333333335 deadhead : 500
# Total:  5122.233333333334
# ['F6', 'F59', 'F40', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 998.8 layover_cost : 2074.1666666666665 deadhead : 500
# Total:  4997.966666666667
# ['F6', 'F59', 'F11', 'DeadHead']
# base_salary : 1925 flight_salary : 685.3000000000001 layover_cost : 2212.5 deadhead : 500
# Total:  4822.8
# ['F8', 'DeadHead']
# base_salary : 2275 flight_salary : 247.0 layover_cost : 0 deadhead : 600
# Total:  2522.0
# ['F8', 'F90', 'DeadHead']
# base_salary : 2275 flight_salary : 543.4 layover_cost : 673.3333333333334 deadhead : 600
# Total:  3491.7333333333336
# ['F8', 'F66', 'DeadHead']
# base_salary : 2275 flight_salary : 526.5 layover_cost : 332.5 deadhead : 600
# Total:  3134.0
# ['F10', 'DeadHead']
# base_salary : 1925 flight_salary : 238.7 layover_cost : 0 deadhead : 500
# Total:  2163.7
# ['F10', 'F77']
# base_salary : 1925 flight_salary : 537.9000000000001 layover_cost : 1183.3333333333335 deadhead : 0
# Total:  3646.2333333333336
# ['F10', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 570.9 layover_cost : 1174.1666666666667 deadhead : 500
# Total:  3670.0666666666666
# ['F17', 'DeadHead']
# base_salary : 2275 flight_salary : 282.09999999999997 layover_cost : 0 deadhead : 600
# Total:  2557.1
# ['F17', 'F49']
# base_salary : 2275 flight_salary : 568.1 layover_cost : 325.0 deadhead : 0
# Total:  3168.1
# ['F21', 'DeadHead']
# base_salary : 1925 flight_salary : 244.20000000000002 layover_cost : 0 deadhead : 500
# Total:  2169.2
# ['F21', 'F77']
# base_salary : 1925 flight_salary : 543.4000000000001 layover_cost : 1183.3333333333335 deadhead : 0
# Total:  3651.7333333333336
# ['F21', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 576.4 layover_cost : 1174.1666666666667 deadhead : 500
# Total:  3675.5666666666666
# ['F30', 'DeadHead']
# base_salary : 2275 flight_salary : 565.5 layover_cost : 0 deadhead : 600
# Total:  2840.5
# ['F30', 'F88']
# base_salary : 2275 flight_salary : 913.8999999999999 layover_cost : 919.9999999999999 deadhead : 0
# Total:  4108.9
# ['F30', 'F68', 'DeadHead']
# base_salary : 2275 flight_salary : 955.5 layover_cost : 979.1666666666666 deadhead : 600
# Total:  4209.666666666667
# ['F30', 'F63', 'DeadHead']
# base_salary : 2275 flight_salary : 955.5 layover_cost : 979.1666666666666 deadhead : 600
# Total:  4209.666666666667
# ['F30', 'F23']
# base_salary : 2275 flight_salary : 913.8999999999999 layover_cost : 919.9999999999999 deadhead : 0
# Total:  4108.9
# ['F30', 'F13', 'DeadHead']
# base_salary : 2275 flight_salary : 793.0 layover_cost : 829.1666666666666 deadhead : 600
# Total:  3897.1666666666665
# ['F30', 'F13', 'F85', 'DeadHead']
# base_salary : 2275 flight_salary : 1341.6000000000001 layover_cost : 1343.3333333333333 deadhead : 600
# Total:  4959.933333333333
# ['F30', 'F13', 'F36', 'DeadHead']
# base_salary : 2275 flight_salary : 1091.9999999999998 layover_cost : 2012.5 deadhead : 600
# Total:  5379.5
# ['F30', 'F13', 'F28', 'DeadHead']
# base_salary : 2275 flight_salary : 1076.3999999999999 layover_cost : 1265.833333333333 deadhead : 600
# Total:  4617.233333333333
# ['F30', 'F13', 'F28', 'F22']
# base_salary : 2275 flight_salary : 1365.0 layover_cost : 2241.6666666666665 deadhead : 0
# Total:  5881.666666666666
# ['F30', 'F13', 'F7', 'DeadHead']
# base_salary : 2275 flight_salary : 1076.3999999999999 layover_cost : 1265.833333333333 deadhead : 600
# Total:  4617.233333333333
# ['F33', 'DeadHead']
# base_salary : 2275 flight_salary : 244.39999999999998 layover_cost : 0 deadhead : 600
# Total:  2519.4
# ['F33', 'F48']
# base_salary : 2275 flight_salary : 534.3 layover_cost : 625.0 deadhead : 0
# Total:  3434.3
# ['F33', 'F18']
# base_salary : 2275 flight_salary : 526.5 layover_cost : 325.0 deadhead : 0
# Total:  3126.5
# ['F39', 'DeadHead']
# base_salary : 1925 flight_salary : 220.0 layover_cost : 0 deadhead : 500
# Total:  2145.0
# ['F39', 'F55', 'DeadHead']
# base_salary : 1925 flight_salary : 454.3 layover_cost : 447.49999999999994 deadhead : 500
# Total:  2826.8
# ['F39', 'F55', 'F95', 'DeadHead']
# base_salary : 1925 flight_salary : 666.5999999999999 layover_cost : 1517.5 deadhead : 500
# Total:  4109.1
# ['F39', 'F55', 'F59', 'DeadHead']
# base_salary : 1925 flight_salary : 661.1 layover_cost : 1468.3333333333333 deadhead : 500
# Total:  4054.4333333333334
# ['F39', 'F55', 'F59', 'F40', 'DeadHead']
# base_salary : 1925 flight_salary : 881.1 layover_cost : 1552.5 deadhead : 500
# Total:  4358.6
# ['F39', 'F55', 'F59', 'F11', 'DeadHead']
# base_salary : 1925 flight_salary : 899.8 layover_cost : 2562.5 deadhead : 500
# Total:  5387.3
# ['F39', 'F40', 'DeadHead']
# base_salary : 1925 flight_salary : 440.0 layover_cost : 352.5 deadhead : 500
# Total:  2717.5
# ['F39', 'F20']
# base_salary : 1925 flight_salary : 431.2 layover_cost : 1100.0 deadhead : 0
# Total:  3456.2
# ['F51', 'DeadHead']
# base_salary : 1925 flight_salary : 236.5 layover_cost : 0 deadhead : 500
# Total:  2161.5
# ['F51', 'F98']
# base_salary : 1925 flight_salary : 470.79999999999995 layover_cost : 25.0 deadhead : 0
# Total:  2420.8
# ['F51', 'F97']
# base_salary : 1925 flight_salary : 465.30000000000007 layover_cost : 1125.0 deadhead : 0
# Total:  3515.3
# ['F51', 'F95', 'DeadHead']
# base_salary : 1925 flight_salary : 448.8 layover_cost : 117.5 deadhead : 500
# Total:  2491.3
# ['F51', 'F64']
# base_salary : 1925 flight_salary : 470.79999999999995 layover_cost : 25.0 deadhead : 0
# Total:  2420.8
# ['F51', 'F59', 'DeadHead']
# base_salary : 1925 flight_salary : 443.29999999999995 layover_cost : 68.33333333333333 deadhead : 500
# Total:  2436.6333333333337
# ['F51', 'F59', 'F40', 'DeadHead']
# base_salary : 1925 flight_salary : 663.3 layover_cost : 152.5 deadhead : 500
# Total:  2740.8
# ['F51', 'F59', 'F40', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 848.0999999999999 layover_cost : 1295.8333333333335 deadhead : 500
# Total:  4068.9333333333334
# ['F51', 'F59', 'F40', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 848.0999999999999 layover_cost : 1295.8333333333335 deadhead : 500
# Total:  4068.9333333333334
# ['F51', 'F59', 'F40', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 995.4999999999999 layover_cost : 1024.1666666666667 deadhead : 500
# Total:  3944.666666666667
# ['F51', 'F59', 'F11', 'DeadHead']
# base_salary : 1925 flight_salary : 681.9999999999999 layover_cost : 1162.5 deadhead : 500
# Total:  3769.5
# ['F51', 'F4']
# base_salary : 1925 flight_salary : 465.30000000000007 layover_cost : 1025.0 deadhead : 0
# Total:  3415.3
# ['F52', 'DeadHead']
# base_salary : 1925 flight_salary : 487.29999999999995 layover_cost : 0 deadhead : 500
# Total:  2412.3
# ['F52', 'F40', 'DeadHead']
# base_salary : 1925 flight_salary : 707.3 layover_cost : 1056.6666666666667 deadhead : 500
# Total:  3688.966666666667
# ['F52', 'F40', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 892.0999999999999 layover_cost : 2200.0 deadhead : 500
# Total:  5017.1
# ['F52', 'F40', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 892.0999999999999 layover_cost : 2200.0 deadhead : 500
# Total:  5017.1
# ['F52', 'F40', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 1039.5 layover_cost : 1928.333333333333 deadhead : 500
# Total:  4892.833333333333
# ['F52', 'F11', 'DeadHead']
# base_salary : 1925 flight_salary : 726.0 layover_cost : 866.6666666666666 deadhead : 500
# Total:  3517.6666666666665
# ['F67', 'DeadHead']
# base_salary : 1925 flight_salary : 330.0 layover_cost : 0 deadhead : 500
# Total:  2255.0
# ['F67', 'F77']
# base_salary : 1925 flight_salary : 629.2 layover_cost : 1154.1666666666665 deadhead : 0
# Total:  3708.3666666666663
# ['F67', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 662.1999999999999 layover_cost : 1145.0 deadhead : 500
# Total:  3732.2
# ['F70', 'DeadHead']
# base_salary : 1925 flight_salary : 297.0 layover_cost : 0 deadhead : 500
# Total:  2222.0
# ['F70', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 481.8 layover_cost : 337.5 deadhead : 500
# Total:  2744.3
# ['F70', 'F77']
# base_salary : 1925 flight_salary : 596.2 layover_cost : 75.0 deadhead : 0
# Total:  2596.2
# ['F70', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 481.8 layover_cost : 337.5 deadhead : 500
# Total:  2744.3
# ['F70', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 629.2 layover_cost : 65.83333333333333 deadhead : 500
# Total:  2620.0333333333333
# ['F71', 'DeadHead']
# base_salary : 1925 flight_salary : 363.0 layover_cost : 0 deadhead : 500
# Total:  2288.0
# ['F72', 'DeadHead']
# base_salary : 1925 flight_salary : 371.8 layover_cost : 0 deadhead : 500
# Total:  2296.8
# ['F72', 'F77']
# base_salary : 1925 flight_salary : 671.0 layover_cost : 1183.3333333333335 deadhead : 0
# Total:  3779.3333333333335
# ['F72', 'F44', 'DeadHead']
# base_salary : 1925 flight_salary : 718.3 layover_cost : 1167.5 deadhead : 500
# Total:  3810.8
# ['F72', 'F44', 'F54', 'DeadHead']
# base_salary : 1925 flight_salary : 1015.3000000000001 layover_cost : 1221.6666666666667 deadhead : 500
# Total:  4161.966666666667
# ['F72', 'F44', 'F54', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 1347.5 layover_cost : 2374.1666666666665 deadhead : 500
# Total:  5646.666666666666
# ['F72', 'F44', 'F50', 'DeadHead']
# base_salary : 1925 flight_salary : 1119.8 layover_cost : 1820.8333333333335 deadhead : 500
# Total:  4865.633333333333
# ['F72', 'F44', 'F50', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 1304.6 layover_cost : 2645.8333333333335 deadhead : 500
# Total:  5875.433333333333
# ['F72', 'F44', 'F50', 'F77']
# base_salary : 1925 flight_salary : 1419.0 layover_cost : 2383.3333333333335 deadhead : 0
# Total:  5727.333333333334
# ['F72', 'F44', 'F50', 'F57']
# base_salary : 1925 flight_salary : 1408.0 layover_cost : 2602.5 deadhead : 0
# Total:  5935.5
# ['F72', 'F44', 'F50', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 1304.6 layover_cost : 2645.8333333333335 deadhead : 500
# Total:  5875.433333333333
# ['F72', 'F44', 'F50', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 1452.0 layover_cost : 2374.1666666666665 deadhead : 500
# Total:  5751.166666666666
# ['F72', 'F44', 'F45', 'DeadHead']
# base_salary : 1925 flight_salary : 1119.8 layover_cost : 1820.8333333333335 deadhead : 500
# Total:  4865.633333333333
# ['F72', 'F44', 'F45', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 1304.6 layover_cost : 2645.8333333333335 deadhead : 500
# Total:  5875.433333333333
# ['F72', 'F44', 'F45', 'F77']
# base_salary : 1925 flight_salary : 1419.0 layover_cost : 2383.3333333333335 deadhead : 0
# Total:  5727.333333333334
# ['F72', 'F44', 'F45', 'F57']
# base_salary : 1925 flight_salary : 1408.0 layover_cost : 2602.5 deadhead : 0
# Total:  5935.5
# ['F72', 'F44', 'F45', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 1304.6 layover_cost : 2645.8333333333335 deadhead : 500
# Total:  5875.433333333333
# ['F72', 'F44', 'F45', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 1452.0 layover_cost : 2374.1666666666665 deadhead : 500
# Total:  5751.166666666666
# ['F72', 'F43']
# base_salary : 1925 flight_salary : 665.5 layover_cost : 1195.8333333333335 deadhead : 0
# Total:  3786.3333333333335
# ['F72', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 704.0 layover_cost : 1174.1666666666667 deadhead : 500
# Total:  3803.166666666667
# ['F74', 'DeadHead']
# base_salary : 1925 flight_salary : 299.20000000000005 layover_cost : 0 deadhead : 500
# Total:  2224.2
# ['F74', 'F98']
# base_salary : 1925 flight_salary : 533.5 layover_cost : 75.0 deadhead : 0
# Total:  2533.5
# ['F74', 'F97']
# base_salary : 1925 flight_salary : 528.0000000000001 layover_cost : 1175.0 deadhead : 0
# Total:  3628.0
# ['F74', 'F64']
# base_salary : 1925 flight_salary : 533.5 layover_cost : 75.0 deadhead : 0
# Total:  2533.5
# ['F74', 'F59', 'DeadHead']
# base_salary : 1925 flight_salary : 505.99999999999994 layover_cost : 118.33333333333333 deadhead : 500
# Total:  2549.3333333333335
# ['F74', 'F59', 'F40', 'DeadHead']
# base_salary : 1925 flight_salary : 726.0 layover_cost : 202.5 deadhead : 500
# Total:  2853.5
# ['F74', 'F59', 'F40', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 910.8 layover_cost : 1345.8333333333335 deadhead : 500
# Total:  4181.633333333333
# ['F74', 'F59', 'F40', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 910.8 layover_cost : 1345.8333333333335 deadhead : 500
# Total:  4181.633333333333
# ['F74', 'F59', 'F40', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 1058.1999999999998 layover_cost : 1074.1666666666667 deadhead : 500
# Total:  4057.366666666667
# ['F74', 'F59', 'F11', 'DeadHead']
# base_salary : 1925 flight_salary : 744.6999999999999 layover_cost : 1212.5 deadhead : 500
# Total:  3882.2
# ['F74', 'F4']
# base_salary : 1925 flight_salary : 528.0000000000001 layover_cost : 1075.0 deadhead : 0
# Total:  3528.0
# ['F75', 'DeadHead']
# base_salary : 2275 flight_salary : 361.4 layover_cost : 0 deadhead : 600
# Total:  2636.4
# ['F75', 'F22']
# base_salary : 2275 flight_salary : 650.0 layover_cost : 75.83333333333333 deadhead : 0
# Total:  3000.8333333333335
# ...
# ['F14', 'F92', 'F17', 'DeadHead']
# base_salary : 2275 flight_salary : 1202.5 layover_cost : 1100.0 deadhead : 600
# Total:  4577.5
# ['F14', 'F92', 'F17', 'F49', 'DeadHead']
# base_salary : 2275 flight_salary : 1488.5 layover_cost : 1425.0 deadhead : 600
# Total:  5188.5
# ['F14', 'F61']
# base_salary : 2275 flight_salary : 816.3999999999999 layover_cost : 1020.8333333333334 deadhead : 0
# Total:  4112.233333333333
# ['F14', 'F2']
# base_salary : 2275 flight_salary : 816.3999999999999 layover_cost : 1020.8333333333334 deadhead : 0
# Total:  4112.233333333333
# ['F20', 'DeadHead']
# base_salary : 1925 flight_salary : 363.0 layover_cost : 0 deadhead : 500
# Total:  2288.0
# ['F20', 'F74', 'DeadHead']
# base_salary : 1925 flight_salary : 663.3 layover_cost : 250.0 deadhead : 500
# Total:  2838.3
# ['F20', 'F74', 'F98', 'DeadHead']
# base_salary : 1925 flight_salary : 897.6 layover_cost : 325.0 deadhead : 500
# Total:  3147.6
# ['F20', 'F74', 'F98', 'F71', 'DeadHead']
# base_salary : 1925 flight_salary : 1194.6 layover_cost : 1399.1666666666667 deadhead : 500
# Total:  4518.766666666666
# ['F20', 'F74', 'F98', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1268.3000000000002 layover_cost : 1379.1666666666665 deadhead : 500
# Total:  4572.466666666667
# ['F20', 'F74', 'F98', 'F52']
# base_salary : 1925 flight_salary : 1134.1000000000001 layover_cost : 595.8333333333334 deadhead : 0
# Total:  3654.933333333334
# ['F20', 'F74', 'F98', 'F21', 'DeadHead']
# base_salary : 1925 flight_salary : 1260.6000000000001 layover_cost : 1350.0 deadhead : 500
# Total:  4535.6
# ['F20', 'F74', 'F97', 'DeadHead']
# base_salary : 1925 flight_salary : 892.0999999999999 layover_cost : 1425.0 deadhead : 500
# Total:  4242.1
# ['F20', 'F74', 'F97', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1262.8 layover_cost : 2579.1666666666665 deadhead : 500
# Total:  5766.966666666667
# ['F20', 'F74', 'F97', 'F52']
# base_salary : 1925 flight_salary : 1128.6 layover_cost : 1795.8333333333333 deadhead : 0
# Total:  4849.433333333333
# ['F20', 'F74', 'F64', 'DeadHead']
# base_salary : 1925 flight_salary : 897.6 layover_cost : 325.0 deadhead : 500
# Total:  3147.6
# ['F20', 'F74', 'F64', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1268.3000000000002 layover_cost : 1379.1666666666665 deadhead : 500
# Total:  4572.466666666667
# ['F20', 'F74', 'F64', 'F52']
# base_salary : 1925 flight_salary : 1134.1000000000001 layover_cost : 595.8333333333334 deadhead : 0
# Total:  3654.933333333334
# ['F20', 'F74', 'F59']
# base_salary : 1925 flight_salary : 870.0999999999999 layover_cost : 368.33333333333337 deadhead : 0
# Total:  3163.4333333333334
# ['F20', 'F74', 'F4', 'DeadHead']
# base_salary : 1925 flight_salary : 892.0999999999999 layover_cost : 1325.0 deadhead : 500
# Total:  4142.1
# ['F20', 'F74', 'F4', 'F71', 'DeadHead']
# base_salary : 1925 flight_salary : 1189.1 layover_cost : 1399.1666666666667 deadhead : 500
# Total:  4513.266666666666
# ['F20', 'F74', 'F4', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1262.8 layover_cost : 1379.1666666666665 deadhead : 500
# Total:  4566.966666666667
# ['F20', 'F74', 'F4', 'F52']
# base_salary : 1925 flight_salary : 1128.6 layover_cost : 1795.8333333333333 deadhead : 0
# Total:  4849.433333333333
# ['F20', 'F74', 'F4', 'F21', 'DeadHead']
# base_salary : 1925 flight_salary : 1255.1 layover_cost : 1350.0 deadhead : 500
# Total:  4530.1
# ['F20', 'F74', 'F4', 'F6', 'DeadHead']
# base_salary : 1925 flight_salary : 1189.1 layover_cost : 1650.0 deadhead : 500
# Total:  4764.1
# ['F20', 'F52']
# base_salary : 1925 flight_salary : 599.4999999999999 layover_cost : 595.8333333333333 deadhead : 0
# Total:  3120.333333333333
# ['F20', 'F51', 'DeadHead']
# base_salary : 1925 flight_salary : 654.4999999999999 layover_cost : 300.0 deadhead : 500
# Total:  2879.5
# ['F20', 'F51', 'F98', 'DeadHead']
# base_salary : 1925 flight_salary : 888.7999999999998 layover_cost : 325.0 deadhead : 500
# Total:  3138.7999999999997
# ['F20', 'F51', 'F98', 'F71', 'DeadHead']
# base_salary : 1925 flight_salary : 1185.7999999999997 layover_cost : 1399.1666666666667 deadhead : 500
# Total:  4509.966666666666
# ['F20', 'F51', 'F98', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1259.5 layover_cost : 1379.1666666666665 deadhead : 500
# Total:  4563.666666666666
# ['F20', 'F51', 'F98', 'F52']
# base_salary : 1925 flight_salary : 1125.3 layover_cost : 595.8333333333334 deadhead : 0
# Total:  3646.1333333333337
# ['F20', 'F51', 'F98', 'F21', 'DeadHead']
# base_salary : 1925 flight_salary : 1251.8 layover_cost : 1350.0 deadhead : 500
# Total:  4526.8
# ['F20', 'F51', 'F97', 'DeadHead']
# base_salary : 1925 flight_salary : 883.3 layover_cost : 1425.0 deadhead : 500
# Total:  4233.3
# ['F20', 'F51', 'F97', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1253.9999999999998 layover_cost : 2579.1666666666665 deadhead : 500
# Total:  5758.166666666666
# ['F20', 'F51', 'F97', 'F52']
# base_salary : 1925 flight_salary : 1119.8 layover_cost : 1795.8333333333333 deadhead : 0
# Total:  4840.633333333333
# ['F20', 'F51', 'F95']
# base_salary : 1925 flight_salary : 866.7999999999998 layover_cost : 417.5 deadhead : 0
# Total:  3209.2999999999997
# ['F20', 'F51', 'F64', 'DeadHead']
# base_salary : 1925 flight_salary : 888.7999999999998 layover_cost : 325.0 deadhead : 500
# Total:  3138.7999999999997
# ['F20', 'F51', 'F64', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1259.5 layover_cost : 1379.1666666666665 deadhead : 500
# Total:  4563.666666666666
# ['F20', 'F51', 'F64', 'F52']
# base_salary : 1925 flight_salary : 1125.3 layover_cost : 595.8333333333334 deadhead : 0
# Total:  3646.1333333333337
# ['F20', 'F51', 'F59']
# base_salary : 1925 flight_salary : 861.3 layover_cost : 368.33333333333337 deadhead : 0
# Total:  3154.6333333333337
# ['F20', 'F51', 'F4', 'DeadHead']
# base_salary : 1925 flight_salary : 883.3 layover_cost : 1325.0 deadhead : 500
# Total:  4133.3
# ['F20', 'F51', 'F4', 'F71', 'DeadHead']
# base_salary : 1925 flight_salary : 1180.3 layover_cost : 1399.1666666666667 deadhead : 500
# Total:  4504.466666666667
# ['F20', 'F51', 'F4', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1253.9999999999998 layover_cost : 1379.1666666666665 deadhead : 500
# Total:  4558.166666666666
# ['F20', 'F51', 'F4', 'F52']
# base_salary : 1925 flight_salary : 1119.8 layover_cost : 1795.8333333333333 deadhead : 0
# Total:  4840.633333333333
# ['F20', 'F51', 'F4', 'F21', 'DeadHead']
# base_salary : 1925 flight_salary : 1246.2999999999997 layover_cost : 1350.0 deadhead : 500
# Total:  4521.299999999999
# ['F20', 'F51', 'F4', 'F6', 'DeadHead']
# base_salary : 1925 flight_salary : 1180.3 layover_cost : 1650.0 deadhead : 500
# Total:  4755.3
# ['F20', 'F6', 'DeadHead']
# base_salary : 1925 flight_salary : 660.0 layover_cost : 450.0 deadhead : 500
# Total:  3035.0
# ['F20', 'F6', 'F97', 'DeadHead']
# base_salary : 1925 flight_salary : 888.8 layover_cost : 1425.0 deadhead : 500
# Total:  4238.8
# ['F20', 'F6', 'F97', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1259.5 layover_cost : 2579.1666666666665 deadhead : 500
# Total:  5763.666666666666
# ['F20', 'F6', 'F97', 'F52']
# base_salary : 1925 flight_salary : 1125.3 layover_cost : 1795.8333333333333 deadhead : 0
# Total:  4846.133333333333
# ['F20', 'F6', 'F95']
# base_salary : 1925 flight_salary : 872.3 layover_cost : 1617.5 deadhead : 0
# Total:  4414.8
# ['F20', 'F6', 'F64', 'DeadHead']
# base_salary : 1925 flight_salary : 894.2999999999998 layover_cost : 1525.0 deadhead : 500
# Total:  4344.299999999999
# ['F20', 'F6', 'F64', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1265.0 layover_cost : 2579.1666666666665 deadhead : 500
# Total:  5769.166666666666
# ['F20', 'F6', 'F64', 'F52']
# base_salary : 1925 flight_salary : 1130.8 layover_cost : 1795.8333333333333 deadhead : 0
# Total:  4851.633333333333
# ['F20', 'F6', 'F59']
# base_salary : 1925 flight_salary : 866.8 layover_cost : 1568.3333333333333 deadhead : 0
# Total:  4360.133333333333
# ['F25', 'DeadHead']
# base_salary : 2275 flight_salary : 279.5 layover_cost : 0 deadhead : 600
# Total:  2554.5
# ['F26', 'DeadHead']
# base_salary : 2275 flight_salary : 347.09999999999997 layover_cost : 0 deadhead : 600
# Total:  2622.1
# ['F28', 'DeadHead']
# base_salary : 2275 flight_salary : 351.0 layover_cost : 0 deadhead : 600
# Total:  2626.0
# ['F28', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 639.6 layover_cost : 975.8333333333333 deadhead : 600
# Total:  3890.4333333333334
# ['F34', 'DeadHead']
# base_salary : 2275 flight_salary : 270.40000000000003 layover_cost : 0 deadhead : 600
# Total:  2545.4
# ['F34', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 634.4 layover_cost : 52.5 deadhead : 600
# Total:  2961.9
# ['F34', 'F79', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 924.3 layover_cost : 1227.5 deadhead : 600
# Total:  4426.8
# ['F34', 'F79', 'F48', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 1346.8 layover_cost : 1276.6666666666667 deadhead : 600
# Total:  4898.466666666667
# ['F34', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 631.8 layover_cost : 852.5 deadhead : 600
# Total:  3759.3
# ['F34', 'F76', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 921.6999999999999 layover_cost : 1227.5 deadhead : 600
# Total:  4424.2
# ['F34', 'F76', 'F48', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 1344.2 layover_cost : 1276.6666666666667 deadhead : 600
# Total:  4895.866666666667
# ['F34', 'F33', 'DeadHead']
# base_salary : 2275 flight_salary : 608.4 layover_cost : 602.5 deadhead : 600
# Total:  3485.9
# ['F34', 'F33', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 898.3000000000001 layover_cost : 1227.5 deadhead : 600
# Total:  4400.8
# ['F34', 'F33', 'F48', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 1320.8 layover_cost : 1276.6666666666667 deadhead : 600
# Total:  4872.466666666667
# ['F34', 'F33', 'F18', 'DeadHead']
# base_salary : 2275 flight_salary : 890.5 layover_cost : 927.5 deadhead : 600
# Total:  4093.0
# ['F34', 'F33', 'F18', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 1254.4999999999998 layover_cost : 1252.5 deadhead : 600
# Total:  4782.0
# ['F34', 'F33', 'F18', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 1251.8999999999999 layover_cost : 2052.5 deadhead : 600
# Total:  5579.4
# ['F34', 'F33', 'F18', 'F8']
# base_salary : 2275 flight_salary : 1163.5 layover_cost : 1860.8333333333335 deadhead : 0
# Total:  5299.333333333334
# ['F34', 'F33', 'F18', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 1313.0 layover_cost : 1276.6666666666667 deadhead : 600
# Total:  4864.666666666667
# ['F34', 'F8']
# base_salary : 2275 flight_salary : 543.4 layover_cost : 660.8333333333334 deadhead : 0
# Total:  3479.2333333333336
# ['F34', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 692.9 layover_cost : 76.66666666666667 deadhead : 600
# Total:  3044.5666666666666
# ['F36', 'DeadHead']
# base_salary : 2275 flight_salary : 347.09999999999997 layover_cost : 0 deadhead : 600
# Total:  2622.1
# ['F40', 'DeadHead']
# base_salary : 1925 flight_salary : 464.2 layover_cost : 0 deadhead : 500
# Total:  2389.2
# ['F40', 'F91']
# base_salary : 1925 flight_salary : 648.9999999999999 layover_cost : 1143.3333333333333 deadhead : 0
# Total:  3717.333333333333
# ['F40', 'F16']
# base_salary : 1925 flight_salary : 648.9999999999999 layover_cost : 1143.3333333333333 deadhead : 0
# Total:  3717.333333333333
# ['F40', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 796.4 layover_cost : 871.6666666666666 deadhead : 500
# Total:  3593.0666666666666
# ['F41', 'DeadHead']
# base_salary : 2275 flight_salary : 392.6 layover_cost : 0 deadhead : 600
# Total:  2667.6
# ['F46', 'DeadHead']
# base_salary : 2275 flight_salary : 347.09999999999997 layover_cost : 0 deadhead : 600
# Total:  2622.1
# ['F46', 'F73']
# base_salary : 2275 flight_salary : 786.5 layover_cost : 195.83333333333331 deadhead : 0
# Total:  3257.3333333333335
# ['F46', 'F69']
# base_salary : 2275 flight_salary : 682.5 layover_cost : 781.6666666666666 deadhead : 0
# Total:  3739.1666666666665
# ['F46', 'F38', 'DeadHead']
# base_salary : 2275 flight_salary : 669.5 layover_cost : 35.833333333333336 deadhead : 600
# Total:  2980.3333333333335
# ['F46', 'F1', 'DeadHead']
# base_salary : 2275 flight_salary : 819.0 layover_cost : 60.83333333333333 deadhead : 600
# Total:  3154.8333333333335
# ['F46', 'F1', 'F37', 'DeadHead']
# base_salary : 2275 flight_salary : 1166.1 layover_cost : 1114.9999999999998 deadhead : 600
# Total:  4556.099999999999
# ['F46', 'F1', 'F18', 'DeadHead']
# base_salary : 2275 flight_salary : 1101.1 layover_cost : 1210.8333333333333 deadhead : 600
# Total:  4586.933333333333
# ['F46', 'F1', 'F18', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 1465.1 layover_cost : 1535.8333333333333 deadhead : 600
# Total:  5275.933333333333
# ['F46', 'F1', 'F18', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 1462.4999999999998 layover_cost : 2335.8333333333335 deadhead : 600
# Total:  6073.333333333334
# ['F46', 'F1', 'F18', 'F8']
# base_salary : 2275 flight_salary : 1374.1 layover_cost : 2144.1666666666665 deadhead : 0
# Total:  5793.266666666666
# ['F55', 'DeadHead']
# base_salary : 1925 flight_salary : 236.5 layover_cost : 0 deadhead : 500
# Total:  2161.5
# ['F55', 'F95']
# base_salary : 1925 flight_salary : 448.8 layover_cost : 1070.0 deadhead : 0
# Total:  3443.8
# ['F55', 'F59']
# base_salary : 1925 flight_salary : 443.29999999999995 layover_cost : 1020.8333333333334 deadhead : 0
# Total:  3389.1333333333337
# ['F56', 'DeadHead']
# base_salary : 2275 flight_salary : 340.6 layover_cost : 0 deadhead : 600
# Total:  2615.6
# ['F56', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 704.6 layover_cost : 608.3333333333333 deadhead : 600
# Total:  3587.9333333333334
# ['F56', 'F79', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 994.5 layover_cost : 1783.3333333333333 deadhead : 600
# Total:  5052.833333333333
# ['F56', 'F79', 'F48', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 1417.0 layover_cost : 1832.5 deadhead : 600
# Total:  5524.5
# ['F56', 'F8']
# base_salary : 2275 flight_salary : 613.6000000000001 layover_cost : 16.666666666666664 deadhead : 0
# Total:  2905.266666666667
# ['F56', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 763.1 layover_cost : 632.5 deadhead : 600
# Total:  3670.6
# ['F66', 'DeadHead']
# base_salary : 2275 flight_salary : 438.1 layover_cost : 0 deadhead : 600
# Total:  2713.1
# ['F82', 'DeadHead']
# base_salary : 2275 flight_salary : 412.09999999999997 layover_cost : 0 deadhead : 600
# Total:  2687.1
# ['F82', 'F49', 'DeadHead']
# base_salary : 2275 flight_salary : 698.1 layover_cost : 84.16666666666667 deadhead : 600
# Total:  3057.2666666666664
# ['F82', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 700.7 layover_cost : 1184.1666666666667 deadhead : 600
# Total:  4159.866666666667
# ['F84', 'DeadHead']
# base_salary : 2275 flight_salary : 548.6 layover_cost : 0 deadhead : 600
# Total:  2823.6
# ['F84', 'F38', 'DeadHead']
# base_salary : 2275 flight_salary : 870.9999999999999 layover_cost : 35.833333333333336 deadhead : 600
# Total:  3181.8333333333335
# ['F84', 'F38', 'F65', 'DeadHead']
# base_salary : 2275 flight_salary : 1231.1 layover_cost : 339.1666666666667 deadhead : 600
# Total:  3845.2666666666664
# ['F85', 'DeadHead']
# base_salary : 2275 flight_salary : 474.5 layover_cost : 0 deadhead : 600
# Total:  2749.5
# ['F89', 'DeadHead']
# base_salary : 2275 flight_salary : 296.4 layover_cost : 0 deadhead : 600
# Total:  2571.4
# ['F89', 'F73']
# base_salary : 2275 flight_salary : 735.8000000000001 layover_cost : 409.99999999999994 deadhead : 0
# Total:  3420.8
# ['F90', 'DeadHead']
# base_salary : 2275 flight_salary : 218.4 layover_cost : 0 deadhead : 600
# Total:  2493.4
# ['F100', 'DeadHead']
# base_salary : 1925 flight_salary : nan layover_cost : 0 deadhead : 500
# Total:  nan
# ['F100', 'F91']
# base_salary : 1925 flight_salary : nan layover_cost : 58.333333333333336 deadhead : 0
# Total:  nan
# ['F100', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : nan layover_cost : 995.8333333333334 deadhead : 500
# Total:  nan
# ['F100', 'F57', 'DeadHead']
# base_salary : 1925 flight_salary : nan layover_cost : 15.0 deadhead : 500
# Total:  nan
# ['F100', 'F16']
# base_salary : 1925 flight_salary : nan layover_cost : 58.333333333333336 deadhead : 0
# Total:  nan
# ['F100', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : nan layover_cost : 986.6666666666667 deadhead : 500
# Total:  nan
