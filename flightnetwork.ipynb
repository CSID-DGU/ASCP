# %%
import pandas as pd
import os
from multiprocessing import Process
import copy
import matplotlib.pyplot as plt
import numpy as np

# Node의 부모 Class
class Node:
    def __init__(self, node_name):
        self.node_name = node_name

# Edge의 부모 Class
class Edge:
    def __init__(self, origin, dest):
        self.origin = origin
        self.dest = dest

# Airport Class
class Airport(Node):
    def __init__(self, airport_name):
        super().__init__(airport_name)

# Flight Class
class Flight(Edge):
    def __init__(self, index, origin, dest, origin_date, origin_time, dest_date, dest_time, flight_duration, flight_type):
        super().__init__(origin, dest)
        self.index = index
        self.origin_date = origin_date
        self.origin_time = origin_time
        self.dest_date = dest_date
        self.dest_time = dest_time
        self.flight_duration = flight_duration
        self.flight_type = flight_type

    def print(self):
        print(self.index, self.origin, self.origin_date, self.origin_time, self.dest,
              self.dest_date, self.dest_time, self.flight_duration, self.flight_type)
        

# Stack Node의 구조
class Stackitem:
    def __init__(self, flight: Flight, flights_sequence: list = None, landing_number = None):
        if flights_sequence:
            self.flight = flight
            flights_sequence.append(flight.index)
            self.flights_sequence = flights_sequence
            self.landing_number = landing_number + 1
            # self.time = time + dt.timedelta(flight.flight_duration)
        else:
            self.flight = flight
            self.flights_sequence = [flight.index]
            self.landing_number = 1
            # self.time = flight.flight_duration;

# %%
# Initial Setting - Test
flight_graph = dict()
flight_excel = pd.read_excel("flight.xlsx")
flight_excel.columns = ['INDEX', 'ORIGIN', 'ORIGIN_DATE','ORIGIN_TIME', 'DEST','DEST_DATE', 'DEST_TIME', 'FLIGHT_DURATION','AIRCRAFT_TYPE' ]
airports_set = set()

# %%
# Graph insert Node
for i in range(100) :
    airports_set.add(flight_excel.loc[i]['ORIGIN'])
    airports_set.add(flight_excel.loc[i]['DEST'])
    
for airports in airports_set :
    flight_graph[airports] = list()

# Graph insert Edge
for i in range(100) :
    flight_graph[flight_excel.loc[i]['ORIGIN']].append(Flight(flight_excel.loc[i]['INDEX'], flight_excel.loc[i]['ORIGIN'], flight_excel.loc[i]['DEST'],
                                                              flight_excel.loc[i]['ORIGIN_DATE'], flight_excel.loc[i]['ORIGIN_TIME'], flight_excel.loc[i]['DEST_DATE'], flight_excel.loc[i]['DEST_TIME'],
                                                              flight_excel.loc[i]['FLIGHT_DURATION'], flight_excel.loc[i]['AIRCRAFT_TYPE']))

# %%
print(len(airports_set))
# Out:
# 5

# %%
pairing_set = list()

# clustering을 통한 flights set의 크기를 줄여야지 경우의 수가 줄어듬
# 하지만 그렇다면 시간을 어떻게 배분해야하는가? 기준은? 시간 → 기종? 조금더 생각해봐야 할 거 같다.

# 여기서 Node 시작에 따라 끝나는 경우는
# 만나는 Base가 같은경우가 있고,
# 만약 끝이 Base가 아닌데 갈 곳이 없는 경우가 있다.
# 그렇다면 모든 pairing의 모든 경우를 넣어도 모든 경우가 나온다!
# 

for airport in airports_set :
    # pairing_set.append(["-" * 10, airport, "-" * 10])

    for flight in flight_graph[airport] :
        # 항공편, 항공편의 순서를 넣는다
        stack_temp = [Stackitem(flight)]
        
        while stack_temp:
            # 현재 진행 중인 항공편의 정보
            flights_information_now = stack_temp.pop()

            pairing_set.append(copy.deepcopy(flights_information_now.flights_sequence))
            # 만약 해당 항공편이 진행됨으로서 base로 간다면 해당 항공편은 더 진행할 필요가 없음
            if (flights_information_now.flight.dest == flight.origin) :
                continue
            
            else :
                pairing_set[-1].append("DeadHead")

            # Search Space Extend
            for flight_next in flight_graph[flights_information_now.flight.dest] :
                # 항공기 기종이 같은지? 시간이 가능한지? (날짜가 같다면 시간까지 비교, 다르다면 날짜 비교)
                flight_type_equal = (flights_information_now.flight.flight_type == flight_next.flight_type)
                flight_time_possible = (flights_information_now.flight.dest_date == flight_next.origin_date and flights_information_now.flight.dest_time < flight_next.origin_time) or (flights_information_now.flight.dest_date < flight_next.origin_date)
                flight_day_possible = ((flight_next.dest_date.month - flight.origin_date.month) * 30 + flight_next.dest_date.day  - flight.origin_date.day <= 7) 
                flight_landing_possible = (flights_information_now.landing_number <= 3)

                # 기종이 다르거나 시간이 불가능하면 해당 항공편은 Search에 사용하지 않음
                if (not flight_type_equal or not flight_time_possible or not flight_day_possible or not flight_landing_possible) :
                    continue

                # 기종이 같고, 시간이 가능하다면 Search를 위해 stack에 추가(항공편의 순서까지)
                temp_list = copy.deepcopy(flights_information_now.flights_sequence)
                if (flights_information_now.flight.dest_date < flight_next.origin_date) :
                    for i in range(0, int(flight_next.origin_date.day - flights_information_now.flight.dest_date.day)) :
                        temp_list.append("Layover")
                        
                stack_temp.append(Stackitem(flight_next, temp_list, flights_information_now.landing_number))
                

#for pairing in pairing_set :
    #print(pairing)

# 첫번째 방안 : 모든 항공편들의 순서를 저장한다
# 그렇다면 만들 수 있는(DeadHead, Layover, Feasible) Pairing의 모든 경우가 나온다.
# 하지만 이럴때는 시간이 n^n까지 나올 수 있는 것으로 보인다.
# 여기서 경우의 수를 줄이는 조건을 넣을 때
# 첫번째 - 항공기 종류
# 두번째 - 전 항공편의 도착시간보다 현 항공편의 출발시간이 느려야한다
# 세번째 - Crew의 Trun Time이 MMT보다 크거나 같아야 한다.(Slack Time은 어떻게 될려나?)
# feasible pairing은 좀 많다. -> 그럼 DeadHead가 존재하는 pairing은 넣어야하는 것인가?
# 지연전파? 존재한다?

# stack에 넣을 때 모든 정보를 넣어버린다면? 오히려 쉬워진다. 하지만 메모리를 많이 쓰므로 최적화가 필요함(조건을 생각해야 함)

# %%
import re

# 엑셀 파일명
filename = 'output.xlsx'

# 데이터프레임으로 변환
df = pd.DataFrame(pairing_set)

# 엑셀로 출력
df.to_excel(filename, index=False, header=False)

# %%
# 비행기 기종 : {크루원 수, 비행 수당, 기본급}
salary={}

salary_excel = pd.read_excel("salary.xlsx")
for index, row in salary_excel.iterrows():
    aircraft = row['AIRCRAFT']
    crew_num = row['CREW_NUM']
    flight_salary = row['FLIGHT_SALARY']
    base_salary = row['BASE_SALARY']
    salary[aircraft] = {'CREW_NUM': crew_num, 'FLIGHT_SALARY': flight_salary, 'BASE_SALARY': base_salary}




for pairing in pairing_set :
    
    base_salary = salary[flight_excel.loc[int(re.search(r'\d+', pairing[0]).group())-1]['AIRCRAFT_TYPE']]['BASE_SALARY']
    flight_salary = salary[flight_excel.loc[int(re.search(r'\d+', pairing[0]).group())-1]['AIRCRAFT_TYPE']]['FLIGHT_SALARY']
    layover_time = 0
    layover_cost = 50
    flight_time = 0
    deadhead=0
    for pair in pairing:
        #layover 경우
        if (pair == 'Layover'):
            layover_time+=1
        #Flight 경우
        elif(pair != "DeadHead") :
            n = int(re.search(r'\d+', pair).group())
            flight_time+=flight_excel.loc[n-1]['FLIGHT_DURATION']
        else :
            #deadhead cost 정의하기
            deadhead_cost = 100

            deadhead = deadhead_cost * salary[flight_excel.loc[int(re.search(r'\d+', pairing[0]).group())-1]['AIRCRAFT_TYPE']]['CREW_NUM']
            
    print(pairing)
    print('base_salary :',base_salary,'flight_salary :', flight_salary*flight_time,'layover_cost :',layover_cost*layover_time,'deadhead :',deadhead)
    print('Total: ',base_salary+flight_salary*flight_time+layover_cost*layover_time)
        
    #print(pairing)
# Out:
# ['F1', 'DeadHead']
# base_salary : 2275 flight_salary : 471.9 layover_cost : 0
# Total:  2746.9
# ['F1', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 761.8 layover_cost : 250
# Total:  3286.8
# ['F1', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F48', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 1184.3 layover_cost : 250
# Total:  3709.3
# ['F1', 'Layover', 'Layover', 'Layover', 'Layover', 'F37', 'DeadHead']
# base_salary : 2275 flight_salary : 819.0 layover_cost : 200
# Total:  3294.0
# ['F1', 'Layover', 'Layover', 'Layover', 'Layover', 'F37', 'Layover', 'Layover', 'F65', 'DeadHead']
# base_salary : 2275 flight_salary : 1179.1000000000001 layover_cost : 300
# Total:  3754.1000000000004
# ['F1', 'Layover', 'Layover', 'Layover', 'Layover', 'F18', 'DeadHead']
# base_salary : 2275 flight_salary : 754.0 layover_cost : 200
# Total:  3229.0
# ['F1', 'Layover', 'Layover', 'Layover', 'Layover', 'F18', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 1118.0 layover_cost : 200
# Total:  3593.0
# ['F1', 'Layover', 'Layover', 'Layover', 'Layover', 'F18', 'F79', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 1407.9 layover_cost : 200
# Total:  3882.9
# ['F1', 'Layover', 'Layover', 'Layover', 'Layover', 'F18', 'Layover', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 1115.4 layover_cost : 250
# Total:  3640.4
# ['F1', 'Layover', 'Layover', 'Layover', 'Layover', 'F18', 'Layover', 'F76', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 1405.3 layover_cost : 250
# Total:  3930.3
# ['F1', 'Layover', 'Layover', 'Layover', 'Layover', 'F18', 'Layover', 'F8', 'DeadHead']
# base_salary : 2275 flight_salary : 1027.0 layover_cost : 250
# Total:  3552.0
# ['F1', 'Layover', 'Layover', 'Layover', 'Layover', 'F18', 'Layover', 'F8', 'Layover', 'F90', 'DeadHead']
# base_salary : 2275 flight_salary : 1323.3999999999999 layover_cost : 300
# Total:  3898.3999999999996
# ['F1', 'Layover', 'Layover', 'Layover', 'Layover', 'F18', 'Layover', 'F8', 'F66', 'DeadHead']
# base_salary : 2275 flight_salary : 1306.5 layover_cost : 250
# Total:  3831.5
# ['F1', 'Layover', 'Layover', 'Layover', 'Layover', 'F18', 'Layover', 'Layover', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 1176.5 layover_cost : 300
# Total:  3751.5
# ['F19', 'DeadHead']
# base_salary : 3220 flight_salary : 671.6 layover_cost : 0
# Total:  3891.6
# ['F19', 'Layover', 'Layover', 'Layover', 'Layover', 'F81']
# base_salary : 3220 flight_salary : 1472.0 layover_cost : 200
# Total:  4892.0
# ['F19', 'Layover', 'Layover', 'Layover', 'F15']
# base_salary : 3220 flight_salary : 1472.0 layover_cost : 150
# Total:  4842.0
# ['F24', 'DeadHead']
# base_salary : 3220 flight_salary : 671.6 layover_cost : 0
# Total:  3891.6
# ['F24', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F81']
# base_salary : 3220 flight_salary : 1472.0 layover_cost : 350
# Total:  5042.0
# ['F24', 'Layover', 'F53']
# base_salary : 3220 flight_salary : 1486.72 layover_cost : 50
# Total:  4756.72
# ['F24', 'Layover', 'Layover', 'F31']
# base_salary : 3220 flight_salary : 1472.0 layover_cost : 100
# Total:  4792.0
# ['F24', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F15']
# base_salary : 3220 flight_salary : 1472.0 layover_cost : 300
# Total:  4992.0
# ['F27', 'DeadHead']
# base_salary : 3220 flight_salary : 491.28 layover_cost : 0
# Total:  3711.2799999999997
# ['F27', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F81']
# base_salary : 3220 flight_salary : 1291.6799999999998 layover_cost : 350
# Total:  4861.68
# ['F27', 'Layover', 'F53']
# base_salary : 3220 flight_salary : 1306.3999999999999 layover_cost : 50
# Total:  4576.4
# ['F27', 'Layover', 'Layover', 'F31']
# base_salary : 3220 flight_salary : 1291.6799999999998 layover_cost : 100
# Total:  4611.68
# ['F27', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F15']
# base_salary : 3220 flight_salary : 1291.6799999999998 layover_cost : 300
# Total:  4811.68
# ['F38', 'DeadHead']
# base_salary : 2275 flight_salary : 322.4 layover_cost : 0
# Total:  2597.4
# ['F38', 'Layover', 'Layover', 'F65', 'DeadHead']
# base_salary : 2275 flight_salary : 682.5 layover_cost : 100
# Total:  3057.5
# ['F45', 'DeadHead']
# base_salary : 1925 flight_salary : 401.5 layover_cost : 0
# Total:  2326.5
# ['F45', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 586.3 layover_cost : 250
# Total:  2761.3
# ['F45', 'Layover', 'Layover', 'Layover', 'Layover', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 700.7 layover_cost : 200
# Total:  2825.7
# ['F45', 'Layover', 'Layover', 'Layover', 'F57', 'DeadHead']
# base_salary : 1925 flight_salary : 689.6999999999999 layover_cost : 150
# Total:  2764.7
# ['F45', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 586.3 layover_cost : 250
# Total:  2761.3
# ['F45', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F3']
# base_salary : 1925 flight_salary : 733.7 layover_cost : 250
# Total:  2908.7
# ['F50', 'DeadHead']
# base_salary : 1925 flight_salary : 401.5 layover_cost : 0
# Total:  2326.5
# ['F50', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 586.3 layover_cost : 250
# Total:  2761.3
# ['F50', 'Layover', 'Layover', 'Layover', 'Layover', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 700.7 layover_cost : 200
# Total:  2825.7
# ['F50', 'Layover', 'Layover', 'Layover', 'F57', 'DeadHead']
# base_salary : 1925 flight_salary : 689.6999999999999 layover_cost : 150
# Total:  2764.7
# ['F50', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 586.3 layover_cost : 250
# Total:  2761.3
# ['F50', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F3']
# base_salary : 1925 flight_salary : 733.7 layover_cost : 250
# Total:  2908.7
# ['F54', 'DeadHead']
# base_salary : 1925 flight_salary : 297.0 layover_cost : 0
# Total:  2222.0
# ['F54', 'Layover', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 481.8 layover_cost : 50
# Total:  2456.8
# ['F54', 'Layover', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 481.8 layover_cost : 50
# Total:  2456.8
# ['F54', 'Layover', 'F3']
# base_salary : 1925 flight_salary : 629.2 layover_cost : 50
# Total:  2604.2
# ['F58', 'DeadHead']
# base_salary : 3220 flight_salary : 653.1999999999999 layover_cost : 0
# Total:  3873.2
# ['F58', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F81']
# base_salary : 3220 flight_salary : 1453.6 layover_cost : 250
# Total:  4923.6
# ['F58', 'F31']
# base_salary : 3220 flight_salary : 1453.6 layover_cost : 0
# Total:  4673.6
# ['F58', 'Layover', 'Layover', 'Layover', 'Layover', 'F15']
# base_salary : 3220 flight_salary : 1453.6 layover_cost : 200
# Total:  4873.6
# ['F60', 'DeadHead']
# base_salary : 2275 flight_salary : 477.09999999999997 layover_cost : 0
# Total:  2752.1
# ['F60', 'Layover', 'F96']
# base_salary : 2275 flight_salary : 1159.6 layover_cost : 50
# Total:  3484.6
# ['F60', 'Layover', 'Layover', 'F61', 'DeadHead']
# base_salary : 2275 flight_salary : 728.0 layover_cost : 100
# Total:  3103.0
# ['F60', 'Layover', 'Layover', 'F61', 'Layover', 'Layover', 'F85']
# base_salary : 2275 flight_salary : 1276.6000000000001 layover_cost : 200
# Total:  3751.6000000000004
# ['F60', 'Layover', 'Layover', 'F61', 'Layover', 'F82', 'DeadHead']
# base_salary : 2275 flight_salary : 1007.5 layover_cost : 150
# Total:  3432.5
# ['F60', 'Layover', 'Layover', 'F61', 'Layover', 'F82', 'Layover', 'F49', 'DeadHead']
# base_salary : 2275 flight_salary : 1293.5 layover_cost : 200
# Total:  3768.5
# ['F60', 'Layover', 'Layover', 'F61', 'Layover', 'F82', 'Layover', 'Layover', 'Layover', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 1296.1000000000001 layover_cost : 300
# Total:  3871.1000000000004
# ['F60', 'Layover', 'Layover', 'F61', 'Layover', 'Layover', 'Layover', 'Layover', 'F36', 'DeadHead']
# base_salary : 2275 flight_salary : 1027.0 layover_cost : 300
# Total:  3602.0
# ['F60', 'Layover', 'Layover', 'F61', 'Layover', 'Layover', 'Layover', 'Layover', 'F36', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 1315.6 layover_cost : 300
# Total:  3890.6
# ['F60', 'Layover', 'Layover', 'F61', 'Layover', 'Layover', 'F28', 'DeadHead']
# base_salary : 2275 flight_salary : 1011.3999999999999 layover_cost : 200
# Total:  3486.3999999999996
# ['F60', 'Layover', 'Layover', 'F61', 'Layover', 'Layover', 'F28', 'Layover', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 1300.0 layover_cost : 250
# Total:  3825.0
# ['F60', 'Layover', 'Layover', 'F61', 'F26', 'DeadHead']
# base_salary : 2275 flight_salary : 1007.5 layover_cost : 100
# Total:  3382.5
# ['F60', 'Layover', 'Layover', 'F61', 'F26', 'Layover', 'Layover', 'F49', 'DeadHead']
# base_salary : 2275 flight_salary : 1293.5 layover_cost : 200
# Total:  3768.5
# ['F60', 'Layover', 'Layover', 'F61', 'F26', 'Layover', 'F29', 'DeadHead']
# base_salary : 2275 flight_salary : 1358.5 layover_cost : 150
# Total:  3783.5
# ['F60', 'Layover', 'Layover', 'F61', 'F26', 'Layover', 'Layover', 'Layover', 'Layover', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 1296.1000000000001 layover_cost : 300
# Total:  3871.1000000000004
# ['F60', 'Layover', 'Layover', 'F61', 'Layover', 'Layover', 'F25', 'DeadHead']
# base_salary : 2275 flight_salary : 1007.5 layover_cost : 200
# Total:  3482.5
# ['F60', 'Layover', 'Layover', 'F61', 'Layover', 'Layover', 'F25', 'F49', 'DeadHead']
# base_salary : 2275 flight_salary : 1293.5 layover_cost : 200
# Total:  3768.5
# ['F60', 'Layover', 'Layover', 'F61', 'Layover', 'Layover', 'F25', 'Layover', 'Layover', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 1296.1000000000001 layover_cost : 300
# Total:  3871.1000000000004
# ['F60', 'Layover', 'Layover', 'F61', 'Layover', 'Layover', 'Layover', 'Layover', 'F7', 'DeadHead']
# base_salary : 2275 flight_salary : 1011.3999999999999 layover_cost : 300
# Total:  3586.3999999999996
# ['F60', 'Layover', 'Layover', 'Layover', 'Layover', 'F49', 'DeadHead']
# base_salary : 2275 flight_salary : 763.1 layover_cost : 200
# Total:  3238.1
# ['F60', 'Layover', 'Layover', 'Layover', 'F29', 'DeadHead']
# base_salary : 2275 flight_salary : 828.1 layover_cost : 150
# Total:  3253.1
# ['F60', 'Layover', 'Layover', 'Layover', 'F29', 'Layover', 'Layover', 'F99']
# base_salary : 2275 flight_salary : 1224.6 layover_cost : 250
# Total:  3749.6
# ['F60', 'Layover', 'Layover', 'Layover', 'F29', 'Layover', 'Layover', 'Layover', 'F63']
# base_salary : 2275 flight_salary : 1218.1000000000001 layover_cost : 300
# Total:  3793.1000000000004
# ['F60', 'Layover', 'Layover', 'Layover', 'F29', 'Layover', 'F23', 'DeadHead']
# base_salary : 2275 flight_salary : 1176.5 layover_cost : 200
# Total:  3651.5
# ['F60', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 765.7 layover_cost : 300
# Total:  3340.7
# ['F60', 'Layover', 'Layover', 'F2', 'DeadHead']
# base_salary : 2275 flight_salary : 728.0 layover_cost : 100
# Total:  3103.0
# ['F60', 'Layover', 'Layover', 'F2', 'Layover', 'Layover', 'F85']
# base_salary : 2275 flight_salary : 1276.6000000000001 layover_cost : 200
# Total:  3751.6000000000004
# ['F60', 'Layover', 'Layover', 'F2', 'Layover', 'F82', 'DeadHead']
# base_salary : 2275 flight_salary : 1007.5 layover_cost : 150
# Total:  3432.5
# ['F60', 'Layover', 'Layover', 'F2', 'Layover', 'F82', 'Layover', 'F49', 'DeadHead']
# base_salary : 2275 flight_salary : 1293.5 layover_cost : 200
# Total:  3768.5
# ['F60', 'Layover', 'Layover', 'F2', 'Layover', 'F82', 'Layover', 'Layover', 'Layover', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 1296.1000000000001 layover_cost : 300
# Total:  3871.1000000000004
# ['F60', 'Layover', 'Layover', 'F2', 'Layover', 'Layover', 'Layover', 'Layover', 'F36', 'DeadHead']
# base_salary : 2275 flight_salary : 1027.0 layover_cost : 300
# Total:  3602.0
# ['F60', 'Layover', 'Layover', 'F2', 'Layover', 'Layover', 'Layover', 'Layover', 'F36', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 1315.6 layover_cost : 300
# Total:  3890.6
# ['F60', 'Layover', 'Layover', 'F2', 'Layover', 'Layover', 'F28', 'DeadHead']
# base_salary : 2275 flight_salary : 1011.3999999999999 layover_cost : 200
# Total:  3486.3999999999996
# ['F60', 'Layover', 'Layover', 'F2', 'Layover', 'Layover', 'F28', 'Layover', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 1300.0 layover_cost : 250
# Total:  3825.0
# ['F60', 'Layover', 'Layover', 'F2', 'F26', 'DeadHead']
# base_salary : 2275 flight_salary : 1007.5 layover_cost : 100
# Total:  3382.5
# ['F60', 'Layover', 'Layover', 'F2', 'F26', 'Layover', 'Layover', 'F49', 'DeadHead']
# base_salary : 2275 flight_salary : 1293.5 layover_cost : 200
# Total:  3768.5
# ['F60', 'Layover', 'Layover', 'F2', 'F26', 'Layover', 'F29', 'DeadHead']
# base_salary : 2275 flight_salary : 1358.5 layover_cost : 150
# Total:  3783.5
# ['F60', 'Layover', 'Layover', 'F2', 'F26', 'Layover', 'Layover', 'Layover', 'Layover', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 1296.1000000000001 layover_cost : 300
# Total:  3871.1000000000004
# ['F60', 'Layover', 'Layover', 'F2', 'Layover', 'Layover', 'F25', 'DeadHead']
# base_salary : 2275 flight_salary : 1007.5 layover_cost : 200
# Total:  3482.5
# ['F60', 'Layover', 'Layover', 'F2', 'Layover', 'Layover', 'F25', 'F49', 'DeadHead']
# base_salary : 2275 flight_salary : 1293.5 layover_cost : 200
# Total:  3768.5
# ['F60', 'Layover', 'Layover', 'F2', 'Layover', 'Layover', 'F25', 'Layover', 'Layover', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 1296.1000000000001 layover_cost : 300
# Total:  3871.1000000000004
# ['F60', 'Layover', 'Layover', 'F2', 'Layover', 'Layover', 'Layover', 'Layover', 'F7', 'DeadHead']
# base_salary : 2275 flight_salary : 1011.3999999999999 layover_cost : 300
# Total:  3586.3999999999996
# ['F62', 'DeadHead']
# base_salary : 3220 flight_salary : 680.8000000000001 layover_cost : 0
# Total:  3900.8
# ['F62', 'Layover', 'Layover', 'Layover', 'Layover', 'F81']
# base_salary : 3220 flight_salary : 1481.2 layover_cost : 200
# Total:  4901.2
# ['F62', 'Layover', 'Layover', 'Layover', 'F15']
# base_salary : 3220 flight_salary : 1481.2 layover_cost : 150
# Total:  4851.2
# ['F69', 'DeadHead']
# base_salary : 2275 flight_salary : 335.40000000000003 layover_cost : 0
# Total:  2610.4
# ['F69', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F90', 'DeadHead']
# base_salary : 2275 flight_salary : 631.8 layover_cost : 250
# Total:  3156.8
# ['F69', 'F89']
# base_salary : 2275 flight_salary : 910.0 layover_cost : 0
# Total:  3185.0
# ['F69', 'Layover', 'F84']
# base_salary : 2275 flight_salary : 884.0 layover_cost : 50
# Total:  3209.0
# ['F69', 'Layover', 'Layover', 'Layover', 'Layover', 'F66', 'DeadHead']
# base_salary : 2275 flight_salary : 614.9000000000001 layover_cost : 200
# Total:  3089.9
# ['F69', 'Layover', 'Layover', 'Layover', 'Layover', 'F66', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 904.8000000000001 layover_cost : 200
# Total:  3379.8
# ['F69', 'Layover', 'Layover', 'Layover', 'Layover', 'F66', 'F48', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 1327.3000000000002 layover_cost : 200
# Total:  3802.3
# ['F69', 'Layover', 'Layover', 'Layover', 'F56', 'DeadHead']
# base_salary : 2275 flight_salary : 614.9000000000001 layover_cost : 150
# Total:  3039.9
# ['F69', 'Layover', 'Layover', 'Layover', 'F56', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 978.9 layover_cost : 150
# Total:  3403.9
# ['F69', 'Layover', 'Layover', 'Layover', 'F56', 'F79', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 1268.8 layover_cost : 150
# Total:  3693.8
# ['F69', 'Layover', 'Layover', 'Layover', 'F56', 'Layover', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 976.3 layover_cost : 200
# Total:  3451.3
# ['F69', 'Layover', 'Layover', 'Layover', 'F56', 'Layover', 'F76', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 1266.2 layover_cost : 200
# Total:  3741.2
# ['F69', 'Layover', 'Layover', 'Layover', 'F56', 'Layover', 'F8', 'DeadHead']
# base_salary : 2275 flight_salary : 887.9 layover_cost : 200
# Total:  3362.9
# ['F69', 'Layover', 'Layover', 'Layover', 'F56', 'Layover', 'F8', 'Layover', 'F90', 'DeadHead']
# base_salary : 2275 flight_salary : 1184.3 layover_cost : 250
# Total:  3709.3
# ['F69', 'Layover', 'Layover', 'Layover', 'F56', 'Layover', 'F8', 'F66', 'DeadHead']
# base_salary : 2275 flight_salary : 1167.4 layover_cost : 200
# Total:  3642.4
# ['F69', 'Layover', 'Layover', 'Layover', 'F56', 'Layover', 'Layover', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 1037.4 layover_cost : 250
# Total:  3562.4
# ['F69', 'Layover', 'Layover', 'Layover', 'F41']
# base_salary : 2275 flight_salary : 884.0 layover_cost : 150
# Total:  3309.0
# ['F69', 'Layover', 'Layover', 'Layover', 'F12']
# base_salary : 2275 flight_salary : 884.0 layover_cost : 150
# Total:  3309.0
# ['F73', 'DeadHead']
# base_salary : 2275 flight_salary : 439.4 layover_cost : 0
# Total:  2714.4
# ['F73', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F90', 'DeadHead']
# base_salary : 2275 flight_salary : 735.8000000000001 layover_cost : 250
# Total:  3260.8
# ['F73', 'Layover', 'F84']
# base_salary : 2275 flight_salary : 988.0 layover_cost : 50
# Total:  3313.0
# ['F73', 'Layover', 'Layover', 'Layover', 'Layover', 'F66', 'DeadHead']
# base_salary : 2275 flight_salary : 718.8999999999999 layover_cost : 200
# Total:  3193.8999999999996
# ['F73', 'Layover', 'Layover', 'Layover', 'Layover', 'F66', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 1008.8 layover_cost : 200
# Total:  3483.8
# ['F73', 'Layover', 'Layover', 'Layover', 'Layover', 'F66', 'F48', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 1431.3 layover_cost : 200
# Total:  3906.3
# ['F73', 'Layover', 'Layover', 'Layover', 'F56', 'DeadHead']
# base_salary : 2275 flight_salary : 718.8999999999999 layover_cost : 150
# Total:  3143.8999999999996
# ['F73', 'Layover', 'Layover', 'Layover', 'F56', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 1082.8999999999999 layover_cost : 150
# Total:  3507.8999999999996
# ['F73', 'Layover', 'Layover', 'Layover', 'F56', 'F79', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 1372.7999999999997 layover_cost : 150
# Total:  3797.7999999999997
# ['F73', 'Layover', 'Layover', 'Layover', 'F56', 'Layover', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 1080.2999999999997 layover_cost : 200
# Total:  3555.2999999999997
# ['F73', 'Layover', 'Layover', 'Layover', 'F56', 'Layover', 'F76', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 1370.1999999999998 layover_cost : 200
# Total:  3845.2
# ['F73', 'Layover', 'Layover', 'Layover', 'F56', 'Layover', 'F8', 'DeadHead']
# base_salary : 2275 flight_salary : 991.8999999999999 layover_cost : 200
# Total:  3466.8999999999996
# ['F73', 'Layover', 'Layover', 'Layover', 'F56', 'Layover', 'F8', 'Layover', 'F90', 'DeadHead']
# base_salary : 2275 flight_salary : 1288.2999999999997 layover_cost : 250
# Total:  3813.2999999999997
# ['F73', 'Layover', 'Layover', 'Layover', 'F56', 'Layover', 'F8', 'F66', 'DeadHead']
# base_salary : 2275 flight_salary : 1271.3999999999999 layover_cost : 200
# Total:  3746.3999999999996
# ['F73', 'Layover', 'Layover', 'Layover', 'F56', 'Layover', 'Layover', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 1141.3999999999999 layover_cost : 250
# Total:  3666.3999999999996
# ['F73', 'Layover', 'Layover', 'Layover', 'F41']
# base_salary : 2275 flight_salary : 988.0 layover_cost : 150
# Total:  3413.0
# ['F73', 'Layover', 'Layover', 'Layover', 'F12']
# base_salary : 2275 flight_salary : 988.0 layover_cost : 150
# Total:  3413.0
# ['F80', 'DeadHead']
# base_salary : 2275 flight_salary : 477.09999999999997 layover_cost : 0
# Total:  2752.1
# ['F80', 'Layover', 'F96']
# base_salary : 2275 flight_salary : 1159.6 layover_cost : 50
# Total:  3484.6
# ['F80', 'Layover', 'Layover', 'F61', 'DeadHead']
# base_salary : 2275 flight_salary : 728.0 layover_cost : 100
# Total:  3103.0
# ['F80', 'Layover', 'Layover', 'F61', 'Layover', 'Layover', 'F85']
# base_salary : 2275 flight_salary : 1276.6000000000001 layover_cost : 200
# Total:  3751.6000000000004
# ['F80', 'Layover', 'Layover', 'F61', 'Layover', 'F82', 'DeadHead']
# base_salary : 2275 flight_salary : 1007.5 layover_cost : 150
# Total:  3432.5
# ['F80', 'Layover', 'Layover', 'F61', 'Layover', 'F82', 'Layover', 'F49', 'DeadHead']
# base_salary : 2275 flight_salary : 1293.5 layover_cost : 200
# Total:  3768.5
# ['F80', 'Layover', 'Layover', 'F61', 'Layover', 'F82', 'Layover', 'Layover', 'Layover', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 1296.1000000000001 layover_cost : 300
# Total:  3871.1000000000004
# ['F80', 'Layover', 'Layover', 'F61', 'Layover', 'Layover', 'Layover', 'Layover', 'F36', 'DeadHead']
# base_salary : 2275 flight_salary : 1027.0 layover_cost : 300
# Total:  3602.0
# ['F80', 'Layover', 'Layover', 'F61', 'Layover', 'Layover', 'Layover', 'Layover', 'F36', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 1315.6 layover_cost : 300
# Total:  3890.6
# ['F80', 'Layover', 'Layover', 'F61', 'Layover', 'Layover', 'F28', 'DeadHead']
# base_salary : 2275 flight_salary : 1011.3999999999999 layover_cost : 200
# Total:  3486.3999999999996
# ['F80', 'Layover', 'Layover', 'F61', 'Layover', 'Layover', 'F28', 'Layover', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 1300.0 layover_cost : 250
# Total:  3825.0
# ['F80', 'Layover', 'Layover', 'F61', 'F26', 'DeadHead']
# base_salary : 2275 flight_salary : 1007.5 layover_cost : 100
# Total:  3382.5
# ['F80', 'Layover', 'Layover', 'F61', 'F26', 'Layover', 'Layover', 'F49', 'DeadHead']
# base_salary : 2275 flight_salary : 1293.5 layover_cost : 200
# Total:  3768.5
# ['F80', 'Layover', 'Layover', 'F61', 'F26', 'Layover', 'F29', 'DeadHead']
# base_salary : 2275 flight_salary : 1358.5 layover_cost : 150
# Total:  3783.5
# ['F80', 'Layover', 'Layover', 'F61', 'F26', 'Layover', 'Layover', 'Layover', 'Layover', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 1296.1000000000001 layover_cost : 300
# Total:  3871.1000000000004
# ['F80', 'Layover', 'Layover', 'F61', 'Layover', 'Layover', 'F25', 'DeadHead']
# base_salary : 2275 flight_salary : 1007.5 layover_cost : 200
# Total:  3482.5
# ['F80', 'Layover', 'Layover', 'F61', 'Layover', 'Layover', 'F25', 'F49', 'DeadHead']
# base_salary : 2275 flight_salary : 1293.5 layover_cost : 200
# Total:  3768.5
# ['F80', 'Layover', 'Layover', 'F61', 'Layover', 'Layover', 'F25', 'Layover', 'Layover', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 1296.1000000000001 layover_cost : 300
# Total:  3871.1000000000004
# ['F80', 'Layover', 'Layover', 'F61', 'Layover', 'Layover', 'Layover', 'Layover', 'F7', 'DeadHead']
# base_salary : 2275 flight_salary : 1011.3999999999999 layover_cost : 300
# Total:  3586.3999999999996
# ['F80', 'Layover', 'Layover', 'Layover', 'Layover', 'F49', 'DeadHead']
# base_salary : 2275 flight_salary : 763.1 layover_cost : 200
# Total:  3238.1
# ['F80', 'Layover', 'Layover', 'Layover', 'F29', 'DeadHead']
# base_salary : 2275 flight_salary : 828.1 layover_cost : 150
# Total:  3253.1
# ['F80', 'Layover', 'Layover', 'Layover', 'F29', 'Layover', 'Layover', 'F99']
# base_salary : 2275 flight_salary : 1224.6 layover_cost : 250
# Total:  3749.6
# ['F80', 'Layover', 'Layover', 'Layover', 'F29', 'Layover', 'Layover', 'Layover', 'F63']
# base_salary : 2275 flight_salary : 1218.1000000000001 layover_cost : 300
# Total:  3793.1000000000004
# ['F80', 'Layover', 'Layover', 'Layover', 'F29', 'Layover', 'F23', 'DeadHead']
# base_salary : 2275 flight_salary : 1176.5 layover_cost : 200
# Total:  3651.5
# ['F80', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 765.7 layover_cost : 300
# Total:  3340.7
# ['F80', 'Layover', 'Layover', 'F2', 'DeadHead']
# base_salary : 2275 flight_salary : 728.0 layover_cost : 100
# Total:  3103.0
# ['F80', 'Layover', 'Layover', 'F2', 'Layover', 'Layover', 'F85']
# base_salary : 2275 flight_salary : 1276.6000000000001 layover_cost : 200
# Total:  3751.6000000000004
# ['F80', 'Layover', 'Layover', 'F2', 'Layover', 'F82', 'DeadHead']
# base_salary : 2275 flight_salary : 1007.5 layover_cost : 150
# Total:  3432.5
# ['F80', 'Layover', 'Layover', 'F2', 'Layover', 'F82', 'Layover', 'F49', 'DeadHead']
# base_salary : 2275 flight_salary : 1293.5 layover_cost : 200
# Total:  3768.5
# ['F80', 'Layover', 'Layover', 'F2', 'Layover', 'F82', 'Layover', 'Layover', 'Layover', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 1296.1000000000001 layover_cost : 300
# Total:  3871.1000000000004
# ['F80', 'Layover', 'Layover', 'F2', 'Layover', 'Layover', 'Layover', 'Layover', 'F36', 'DeadHead']
# base_salary : 2275 flight_salary : 1027.0 layover_cost : 300
# Total:  3602.0
# ['F80', 'Layover', 'Layover', 'F2', 'Layover', 'Layover', 'Layover', 'Layover', 'F36', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 1315.6 layover_cost : 300
# Total:  3890.6
# ['F80', 'Layover', 'Layover', 'F2', 'Layover', 'Layover', 'F28', 'DeadHead']
# base_salary : 2275 flight_salary : 1011.3999999999999 layover_cost : 200
# Total:  3486.3999999999996
# ['F80', 'Layover', 'Layover', 'F2', 'Layover', 'Layover', 'F28', 'Layover', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 1300.0 layover_cost : 250
# Total:  3825.0
# ['F80', 'Layover', 'Layover', 'F2', 'F26', 'DeadHead']
# base_salary : 2275 flight_salary : 1007.5 layover_cost : 100
# Total:  3382.5
# ['F80', 'Layover', 'Layover', 'F2', 'F26', 'Layover', 'Layover', 'F49', 'DeadHead']
# base_salary : 2275 flight_salary : 1293.5 layover_cost : 200
# Total:  3768.5
# ['F80', 'Layover', 'Layover', 'F2', 'F26', 'Layover', 'F29', 'DeadHead']
# base_salary : 2275 flight_salary : 1358.5 layover_cost : 150
# Total:  3783.5
# ['F80', 'Layover', 'Layover', 'F2', 'F26', 'Layover', 'Layover', 'Layover', 'Layover', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 1296.1000000000001 layover_cost : 300
# Total:  3871.1000000000004
# ['F80', 'Layover', 'Layover', 'F2', 'Layover', 'Layover', 'F25', 'DeadHead']
# base_salary : 2275 flight_salary : 1007.5 layover_cost : 200
# Total:  3482.5
# ['F80', 'Layover', 'Layover', 'F2', 'Layover', 'Layover', 'F25', 'F49', 'DeadHead']
# base_salary : 2275 flight_salary : 1293.5 layover_cost : 200
# Total:  3768.5
# ['F80', 'Layover', 'Layover', 'F2', 'Layover', 'Layover', 'F25', 'Layover', 'Layover', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 1296.1000000000001 layover_cost : 300
# Total:  3871.1000000000004
# ['F80', 'Layover', 'Layover', 'F2', 'Layover', 'Layover', 'Layover', 'Layover', 'F7', 'DeadHead']
# base_salary : 2275 flight_salary : 1011.3999999999999 layover_cost : 300
# Total:  3586.3999999999996
# ['F86', 'DeadHead']
# base_salary : 1925 flight_salary : 401.5 layover_cost : 0
# Total:  2326.5
# ['F86', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 586.3 layover_cost : 300
# Total:  2811.3
# ['F86', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 700.7 layover_cost : 250
# Total:  2875.7
# ['F86', 'Layover', 'Layover', 'Layover', 'Layover', 'F57', 'DeadHead']
# base_salary : 1925 flight_salary : 689.6999999999999 layover_cost : 200
# Total:  2814.7
# ['F86', 'F44']
# base_salary : 1925 flight_salary : 748.0 layover_cost : 0
# Total:  2673.0
# ['F86', 'F43', 'DeadHead']
# base_salary : 1925 flight_salary : 695.2 layover_cost : 0
# Total:  2620.2
# ['F86', 'F43', 'Layover', 'Layover', 'F71', 'DeadHead']
# base_salary : 1925 flight_salary : 992.1999999999999 layover_cost : 100
# Total:  3017.2
# ['F86', 'F43', 'Layover', 'Layover', 'F71', 'Layover', 'Layover', 'Layover', 'F95', 'DeadHead']
# base_salary : 1925 flight_salary : 1204.5 layover_cost : 250
# Total:  3379.5
# ['F86', 'F43', 'Layover', 'Layover', 'F71', 'Layover', 'F59', 'DeadHead']
# base_salary : 1925 flight_salary : 1198.9999999999998 layover_cost : 150
# Total:  3274.0
# ['F86', 'F43', 'Layover', 'Layover', 'Layover', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1065.9 layover_cost : 150
# Total:  3140.9
# ['F86', 'F43', 'Layover', 'Layover', 'Layover', 'F67', 'Layover', 'Layover', 'Layover', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 1250.7 layover_cost : 300
# Total:  3475.7
# ['F86', 'F43', 'Layover', 'Layover', 'Layover', 'F67', 'Layover', 'Layover', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 1365.1000000000001 layover_cost : 250
# Total:  3540.1000000000004
# ['F86', 'F43', 'Layover', 'Layover', 'Layover', 'F67', 'Layover', 'F57', 'DeadHead']
# base_salary : 1925 flight_salary : 1354.1000000000004 layover_cost : 200
# Total:  3479.1000000000004
# ['F86', 'F43', 'Layover', 'Layover', 'Layover', 'F67', 'Layover', 'Layover', 'Layover', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 1250.7 layover_cost : 300
# Total:  3475.7
# ['F86', 'F43', 'Layover', 'Layover', 'Layover', 'F67', 'Layover', 'Layover', 'Layover', 'F3']
# base_salary : 1925 flight_salary : 1398.1000000000001 layover_cost : 300
# Total:  3623.1000000000004
# ['F86', 'F43', 'Layover', 'Layover', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 931.7 layover_cost : 100
# Total:  2956.7
# ['F86', 'F43', 'Layover', 'Layover', 'F52', 'Layover', 'Layover', 'F40', 'DeadHead']
# base_salary : 1925 flight_salary : 1151.7 layover_cost : 200
# Total:  3276.7
# ['F86', 'F43', 'Layover', 'Layover', 'F52', 'Layover', 'F11', 'DeadHead']
# base_salary : 1925 flight_salary : 1170.4 layover_cost : 150
# Total:  3245.4
# ['F86', 'F43', 'F51', 'DeadHead']
# base_salary : 1925 flight_salary : 986.7 layover_cost : 0
# Total:  2911.7
# ['F86', 'F43', 'F51', 'Layover', 'F98', 'DeadHead']
# base_salary : 1925 flight_salary : 1221.0000000000002 layover_cost : 50
# Total:  3196.0
# ['F86', 'F43', 'F51', 'Layover', 'Layover', 'F97', 'DeadHead']
# base_salary : 1925 flight_salary : 1215.5 layover_cost : 100
# Total:  3240.5
# ['F86', 'F43', 'F51', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F95', 'DeadHead']
# base_salary : 1925 flight_salary : 1199.0 layover_cost : 250
# Total:  3374.0
# ['F86', 'F43', 'F51', 'Layover', 'Layover', 'F64', 'DeadHead']
# base_salary : 1925 flight_salary : 1221.0000000000002 layover_cost : 100
# Total:  3246.0
# ['F86', 'F43', 'F51', 'Layover', 'Layover', 'Layover', 'F59', 'DeadHead']
# base_salary : 1925 flight_salary : 1193.5000000000002 layover_cost : 150
# Total:  3268.5
# ['F86', 'F43', 'F51', 'Layover', 'F4', 'DeadHead']
# base_salary : 1925 flight_salary : 1215.5 layover_cost : 50
# Total:  3190.5
# ['F86', 'F43', 'Layover', 'Layover', 'F21', 'DeadHead']
# base_salary : 1925 flight_salary : 1058.2 layover_cost : 100
# Total:  3083.2
# ['F86', 'F43', 'Layover', 'Layover', 'F21', 'Layover', 'Layover', 'Layover', 'Layover', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 1243.0 layover_cost : 300
# Total:  3468.0
# ['F86', 'F43', 'Layover', 'Layover', 'F21', 'Layover', 'Layover', 'Layover', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 1357.4 layover_cost : 250
# Total:  3532.4
# ['F86', 'F43', 'Layover', 'Layover', 'F21', 'Layover', 'Layover', 'F57', 'DeadHead']
# base_salary : 1925 flight_salary : 1346.4000000000003 layover_cost : 200
# Total:  3471.4000000000005
# ['F86', 'F43', 'Layover', 'Layover', 'F21', 'Layover', 'Layover', 'Layover', 'Layover', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 1243.0 layover_cost : 300
# Total:  3468.0
# ['F86', 'F43', 'Layover', 'Layover', 'F21', 'Layover', 'Layover', 'Layover', 'Layover', 'F3']
# base_salary : 1925 flight_salary : 1390.4 layover_cost : 300
# Total:  3615.4
# ['F86', 'F43', 'Layover', 'F6', 'DeadHead']
# base_salary : 1925 flight_salary : 992.1999999999999 layover_cost : 50
# Total:  2967.2
# ['F86', 'F43', 'Layover', 'F6', 'Layover', 'F97', 'DeadHead']
# base_salary : 1925 flight_salary : 1221.0 layover_cost : 100
# Total:  3246.0
# ['F86', 'F43', 'Layover', 'F6', 'Layover', 'Layover', 'Layover', 'Layover', 'F95', 'DeadHead']
# base_salary : 1925 flight_salary : 1204.5 layover_cost : 250
# Total:  3379.5
# ['F86', 'F43', 'Layover', 'F6', 'Layover', 'F64', 'DeadHead']
# base_salary : 1925 flight_salary : 1226.4999999999998 layover_cost : 100
# Total:  3251.5
# ['F86', 'F43', 'Layover', 'F6', 'Layover', 'Layover', 'F59', 'DeadHead']
# base_salary : 1925 flight_salary : 1198.9999999999998 layover_cost : 150
# Total:  3274.0
# ['F86', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 586.3 layover_cost : 300
# Total:  2811.3
# ['F86', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F3']
# base_salary : 1925 flight_salary : 733.7 layover_cost : 300
# Total:  2958.7
# ['F3', 'DeadHead']
# base_salary : 1925 flight_salary : 332.2 layover_cost : 0
# Total:  2257.2
# ['F13', 'DeadHead']
# base_salary : 2275 flight_salary : 227.5 layover_cost : 0
# Total:  2502.5
# ['F13', 'Layover', 'F85', 'DeadHead']
# base_salary : 2275 flight_salary : 776.1 layover_cost : 50
# Total:  3101.1
# ['F13', 'F82', 'DeadHead']
# base_salary : 2275 flight_salary : 507.0 layover_cost : 0
# Total:  2782.0
# ['F13', 'F82', 'Layover', 'F49', 'DeadHead']
# base_salary : 2275 flight_salary : 793.0 layover_cost : 50
# Total:  3118.0
# ['F13', 'F82', 'Layover', 'Layover', 'Layover', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 795.6 layover_cost : 150
# Total:  3220.6
# ['F13', 'Layover', 'Layover', 'Layover', 'F36', 'DeadHead']
# base_salary : 2275 flight_salary : 526.5 layover_cost : 150
# Total:  2951.5
# ['F13', 'Layover', 'Layover', 'Layover', 'F36', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 815.0999999999999 layover_cost : 150
# Total:  3240.1
# ['F13', 'Layover', 'F28', 'DeadHead']
# base_salary : 2275 flight_salary : 510.90000000000003 layover_cost : 50
# Total:  2835.9
# ['F13', 'Layover', 'F28', 'Layover', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 799.5 layover_cost : 100
# Total:  3174.5
# ['F13', 'Layover', 'F25', 'DeadHead']
# base_salary : 2275 flight_salary : 507.0 layover_cost : 50
# Total:  2832.0
# ['F13', 'Layover', 'F25', 'F49', 'DeadHead']
# base_salary : 2275 flight_salary : 793.0 layover_cost : 50
# Total:  3118.0
# ['F13', 'Layover', 'F25', 'Layover', 'Layover', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 795.6 layover_cost : 150
# Total:  3220.6
# ['F13', 'Layover', 'Layover', 'Layover', 'F7', 'DeadHead']
# base_salary : 2275 flight_salary : 510.90000000000003 layover_cost : 150
# Total:  2935.9
# ['F16', 'DeadHead']
# base_salary : 1925 flight_salary : 184.79999999999998 layover_cost : 0
# Total:  2109.8
# ['F23', 'DeadHead']
# base_salary : 2275 flight_salary : 348.40000000000003 layover_cost : 0
# Total:  2623.4
# ['F42', 'DeadHead']
# base_salary : 2275 flight_salary : 392.6 layover_cost : 0
# Total:  2667.6
# ['F42', 'Layover', 'Layover', 'Layover', 'F73', 'DeadHead']
# base_salary : 2275 flight_salary : 832.0 layover_cost : 150
# Total:  3257.0
# ['F42', 'Layover', 'Layover', 'Layover', 'F73', 'Layover', 'F84', 'DeadHead']
# base_salary : 2275 flight_salary : 1380.6000000000001 layover_cost : 200
# Total:  3855.6000000000004
# ['F42', 'Layover', 'Layover', 'Layover', 'F73', 'Layover', 'F84', 'Layover', 'Layover', 'F38']
# base_salary : 2275 flight_salary : 1703.0000000000002 layover_cost : 300
# Total:  4278.0
# ['F42', 'Layover', 'Layover', 'Layover', 'F73', 'Layover', 'Layover', 'Layover', 'Layover', 'F66', 'DeadHead']
# base_salary : 2275 flight_salary : 1111.5 layover_cost : 350
# Total:  3736.5
# ['F42', 'Layover', 'Layover', 'Layover', 'F73', 'Layover', 'Layover', 'Layover', 'F56', 'DeadHead']
# base_salary : 2275 flight_salary : 1111.5 layover_cost : 300
# Total:  3686.5
# ['F42', 'Layover', 'Layover', 'Layover', 'F73', 'Layover', 'Layover', 'Layover', 'F56', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 1475.5000000000002 layover_cost : 300
# Total:  4050.5
# ['F42', 'Layover', 'Layover', 'Layover', 'F73', 'Layover', 'Layover', 'Layover', 'F56', 'Layover', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 1472.9 layover_cost : 350
# Total:  4097.9
# ['F42', 'Layover', 'Layover', 'Layover', 'F73', 'Layover', 'Layover', 'Layover', 'F56', 'Layover', 'F8', 'DeadHead']
# base_salary : 2275 flight_salary : 1384.5 layover_cost : 350
# Total:  4009.5
# ['F42', 'Layover', 'Layover', 'Layover', 'F73', 'Layover', 'Layover', 'Layover', 'F41', 'DeadHead']
# base_salary : 2275 flight_salary : 1380.6000000000001 layover_cost : 300
# Total:  3955.6000000000004
# ['F42', 'Layover', 'Layover', 'Layover', 'F73', 'Layover', 'Layover', 'Layover', 'F12', 'DeadHead']
# base_salary : 2275 flight_salary : 1380.6000000000001 layover_cost : 300
# Total:  3955.6000000000004
# ['F42', 'Layover', 'Layover', 'Layover', 'F69', 'DeadHead']
# base_salary : 2275 flight_salary : 728.0 layover_cost : 150
# Total:  3153.0
# ['F42', 'Layover', 'Layover', 'Layover', 'F69', 'F89', 'DeadHead']
# base_salary : 2275 flight_salary : 1302.6 layover_cost : 150
# Total:  3727.6
# ['F42', 'Layover', 'Layover', 'Layover', 'F69', 'F89', 'F73', 'DeadHead']
# base_salary : 2275 flight_salary : 1741.9999999999998 layover_cost : 150
# Total:  4167.0
# ['F42', 'Layover', 'Layover', 'Layover', 'F69', 'F89', 'Layover', 'Layover', 'Layover', 'F38']
# base_salary : 2275 flight_salary : 1625.0 layover_cost : 300
# Total:  4200.0
# ['F42', 'Layover', 'Layover', 'Layover', 'F69', 'Layover', 'F84', 'DeadHead']
# base_salary : 2275 flight_salary : 1276.6000000000001 layover_cost : 200
# Total:  3751.6000000000004
# ['F42', 'Layover', 'Layover', 'Layover', 'F69', 'Layover', 'F84', 'Layover', 'Layover', 'F38']
# base_salary : 2275 flight_salary : 1599.0 layover_cost : 300
# Total:  4174.0
# ['F42', 'Layover', 'Layover', 'Layover', 'F69', 'Layover', 'Layover', 'Layover', 'Layover', 'F66', 'DeadHead']
# base_salary : 2275 flight_salary : 1007.5 layover_cost : 350
# Total:  3632.5
# ['F42', 'Layover', 'Layover', 'Layover', 'F69', 'Layover', 'Layover', 'Layover', 'F56', 'DeadHead']
# base_salary : 2275 flight_salary : 1007.5 layover_cost : 300
# Total:  3582.5
# ['F42', 'Layover', 'Layover', 'Layover', 'F69', 'Layover', 'Layover', 'Layover', 'F56', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 1371.5 layover_cost : 300
# Total:  3946.5
# ['F42', 'Layover', 'Layover', 'Layover', 'F69', 'Layover', 'Layover', 'Layover', 'F56', 'Layover', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 1368.8999999999999 layover_cost : 350
# Total:  3993.8999999999996
# ['F42', 'Layover', 'Layover', 'Layover', 'F69', 'Layover', 'Layover', 'Layover', 'F56', 'Layover', 'F8', 'DeadHead']
# base_salary : 2275 flight_salary : 1280.5 layover_cost : 350
# Total:  3905.5
# ['F42', 'Layover', 'Layover', 'Layover', 'F69', 'Layover', 'Layover', 'Layover', 'F41', 'DeadHead']
# base_salary : 2275 flight_salary : 1276.6000000000001 layover_cost : 300
# Total:  3851.6000000000004
# ['F42', 'Layover', 'Layover', 'Layover', 'F69', 'Layover', 'Layover', 'Layover', 'F12', 'DeadHead']
# base_salary : 2275 flight_salary : 1276.6000000000001 layover_cost : 300
# Total:  3851.6000000000004
# ['F42', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F38']
# base_salary : 2275 flight_salary : 715.0 layover_cost : 300
# Total:  3290.0
# ['F42', 'Layover', 'Layover', 'F1', 'DeadHead']
# base_salary : 2275 flight_salary : 864.5 layover_cost : 100
# Total:  3239.5
# ['F42', 'Layover', 'Layover', 'F1', 'Layover', 'Layover', 'Layover', 'Layover', 'F37']
# base_salary : 2275 flight_salary : 1211.6000000000001 layover_cost : 300
# Total:  3786.6000000000004
# ['F42', 'Layover', 'Layover', 'F1', 'Layover', 'Layover', 'Layover', 'Layover', 'F18', 'DeadHead']
# base_salary : 2275 flight_salary : 1146.6000000000001 layover_cost : 300
# Total:  3721.6000000000004
# ['F42', 'Layover', 'Layover', 'F1', 'Layover', 'Layover', 'Layover', 'Layover', 'F18', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 1510.6000000000001 layover_cost : 300
# Total:  4085.6000000000004
# ['F42', 'Layover', 'Layover', 'F1', 'Layover', 'Layover', 'Layover', 'Layover', 'F18', 'Layover', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 1508.0 layover_cost : 350
# Total:  4133.0
# ['F42', 'Layover', 'Layover', 'F1', 'Layover', 'Layover', 'Layover', 'Layover', 'F18', 'Layover', 'F8', 'DeadHead']
# base_salary : 2275 flight_salary : 1419.6 layover_cost : 350
# Total:  4044.6
# ['F43', 'DeadHead']
# base_salary : 1925 flight_salary : 293.7 layover_cost : 0
# Total:  2218.7
# ['F43', 'Layover', 'Layover', 'F71', 'DeadHead']
# base_salary : 1925 flight_salary : 590.7 layover_cost : 100
# Total:  2615.7
# ['F43', 'Layover', 'Layover', 'F71', 'Layover', 'Layover', 'Layover', 'F95', 'DeadHead']
# base_salary : 1925 flight_salary : 803.0 layover_cost : 250
# Total:  2978.0
# ['F43', 'Layover', 'Layover', 'F71', 'Layover', 'F59', 'DeadHead']
# base_salary : 1925 flight_salary : 797.5 layover_cost : 150
# Total:  2872.5
# ['F43', 'Layover', 'Layover', 'F71', 'Layover', 'F59', 'Layover', 'Layover', 'F40']
# base_salary : 1925 flight_salary : 1017.5 layover_cost : 250
# Total:  3192.5
# ['F43', 'Layover', 'Layover', 'F71', 'Layover', 'F59', 'Layover', 'F11', 'DeadHead']
# base_salary : 1925 flight_salary : 1036.2 layover_cost : 200
# Total:  3161.2
# ['F43', 'Layover', 'Layover', 'Layover', 'F67']
# base_salary : 1925 flight_salary : 664.4 layover_cost : 150
# Total:  2739.4
# ['F43', 'Layover', 'Layover', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 530.2 layover_cost : 100
# Total:  2555.2
# ['F43', 'Layover', 'Layover', 'F52', 'Layover', 'Layover', 'F40']
# base_salary : 1925 flight_salary : 750.2 layover_cost : 200
# Total:  2875.2
# ['F43', 'Layover', 'Layover', 'F52', 'Layover', 'F11', 'DeadHead']
# base_salary : 1925 flight_salary : 768.9 layover_cost : 150
# Total:  2843.9
# ['F43', 'Layover', 'Layover', 'F52', 'Layover', 'F11', 'Layover', 'F95', 'DeadHead']
# base_salary : 1925 flight_salary : 981.2 layover_cost : 200
# Total:  3106.2
# ['F43', 'F51', 'DeadHead']
# base_salary : 1925 flight_salary : 585.2 layover_cost : 0
# Total:  2510.2
# ['F43', 'F51', 'Layover', 'F98', 'DeadHead']
# base_salary : 1925 flight_salary : 819.5 layover_cost : 50
# Total:  2794.5
# ['F43', 'F51', 'Layover', 'F98', 'Layover', 'F71', 'DeadHead']
# base_salary : 1925 flight_salary : 1116.5 layover_cost : 100
# Total:  3141.5
# ['F43', 'F51', 'Layover', 'F98', 'Layover', 'Layover', 'F67']
# base_salary : 1925 flight_salary : 1190.2 layover_cost : 150
# Total:  3265.2
# ['F43', 'F51', 'Layover', 'F98', 'Layover', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 1056.0 layover_cost : 100
# Total:  3081.0
# ['F43', 'F51', 'Layover', 'F98', 'Layover', 'F21']
# base_salary : 1925 flight_salary : 1182.5 layover_cost : 100
# Total:  3207.5
# ['F43', 'F51', 'Layover', 'F98', 'F6', 'DeadHead']
# base_salary : 1925 flight_salary : 1116.5 layover_cost : 50
# Total:  3091.5
# ['F43', 'F51', 'Layover', 'Layover', 'F97', 'DeadHead']
# base_salary : 1925 flight_salary : 814.0 layover_cost : 100
# Total:  2839.0
# ['F43', 'F51', 'Layover', 'Layover', 'F97', 'Layover', 'F67']
# base_salary : 1925 flight_salary : 1184.7 layover_cost : 150
# Total:  3259.7
# ['F43', 'F51', 'Layover', 'Layover', 'F97', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 1050.5 layover_cost : 100
# Total:  3075.5
# ['F43', 'F51', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F95', 'DeadHead']
# base_salary : 1925 flight_salary : 797.5 layover_cost : 250
# Total:  2972.5
# ['F43', 'F51', 'Layover', 'Layover', 'F64', 'DeadHead']
# base_salary : 1925 flight_salary : 819.5 layover_cost : 100
# Total:  2844.5
# ['F43', 'F51', 'Layover', 'Layover', 'F64', 'Layover', 'F67']
# base_salary : 1925 flight_salary : 1190.2 layover_cost : 150
# Total:  3265.2
# ['F43', 'F51', 'Layover', 'Layover', 'F64', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 1056.0 layover_cost : 100
# Total:  3081.0
# ['F43', 'F51', 'Layover', 'Layover', 'Layover', 'F59', 'DeadHead']
# base_salary : 1925 flight_salary : 792.0 layover_cost : 150
# Total:  2867.0
# ['F43', 'F51', 'Layover', 'Layover', 'Layover', 'F59', 'Layover', 'Layover', 'F40']
# base_salary : 1925 flight_salary : 1011.9999999999999 layover_cost : 250
# Total:  3187.0
# ['F43', 'F51', 'Layover', 'Layover', 'Layover', 'F59', 'Layover', 'F11', 'DeadHead']
# base_salary : 1925 flight_salary : 1030.7 layover_cost : 200
# Total:  3155.7
# ['F43', 'F51', 'Layover', 'F4', 'DeadHead']
# base_salary : 1925 flight_salary : 814.0 layover_cost : 50
# Total:  2789.0
# ['F43', 'F51', 'Layover', 'F4', 'Layover', 'F71', 'DeadHead']
# base_salary : 1925 flight_salary : 1111.0000000000002 layover_cost : 100
# Total:  3136.0
# ['F43', 'F51', 'Layover', 'F4', 'Layover', 'Layover', 'F67']
# base_salary : 1925 flight_salary : 1184.7 layover_cost : 150
# Total:  3259.7
# ['F43', 'F51', 'Layover', 'F4', 'Layover', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 1050.5 layover_cost : 100
# Total:  3075.5
# ['F43', 'F51', 'Layover', 'F4', 'Layover', 'F21']
# base_salary : 1925 flight_salary : 1177.0 layover_cost : 100
# Total:  3202.0
# ['F43', 'F51', 'Layover', 'F4', 'F6', 'DeadHead']
# base_salary : 1925 flight_salary : 1111.0000000000002 layover_cost : 50
# Total:  3086.0
# ['F43', 'Layover', 'Layover', 'F21']
# base_salary : 1925 flight_salary : 656.6999999999999 layover_cost : 100
# Total:  2681.7
# ['F43', 'Layover', 'F6', 'DeadHead']
# base_salary : 1925 flight_salary : 590.7 layover_cost : 50
# Total:  2565.7
# ['F43', 'Layover', 'F6', 'Layover', 'F97', 'DeadHead']
# base_salary : 1925 flight_salary : 819.5 layover_cost : 100
# Total:  2844.5
# ['F43', 'Layover', 'F6', 'Layover', 'F97', 'Layover', 'F67']
# base_salary : 1925 flight_salary : 1190.2 layover_cost : 150
# Total:  3265.2
# ['F43', 'Layover', 'F6', 'Layover', 'F97', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 1056.0 layover_cost : 100
# Total:  3081.0
# ['F43', 'Layover', 'F6', 'Layover', 'Layover', 'Layover', 'Layover', 'F95', 'DeadHead']
# base_salary : 1925 flight_salary : 803.0 layover_cost : 250
# Total:  2978.0
# ['F43', 'Layover', 'F6', 'Layover', 'F64', 'DeadHead']
# base_salary : 1925 flight_salary : 825.0 layover_cost : 100
# Total:  2850.0
# ['F43', 'Layover', 'F6', 'Layover', 'F64', 'Layover', 'F67']
# base_salary : 1925 flight_salary : 1195.7 layover_cost : 150
# Total:  3270.7
# ['F43', 'Layover', 'F6', 'Layover', 'F64', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 1061.5 layover_cost : 100
# Total:  3086.5
# ['F43', 'Layover', 'F6', 'Layover', 'Layover', 'F59', 'DeadHead']
# base_salary : 1925 flight_salary : 797.5 layover_cost : 150
# Total:  2872.5
# ['F43', 'Layover', 'F6', 'Layover', 'Layover', 'F59', 'Layover', 'Layover', 'F40']
# base_salary : 1925 flight_salary : 1017.5 layover_cost : 250
# Total:  3192.5
# ['F43', 'Layover', 'F6', 'Layover', 'Layover', 'F59', 'Layover', 'F11', 'DeadHead']
# base_salary : 1925 flight_salary : 1036.2 layover_cost : 200
# Total:  3161.2
# ['F44', 'DeadHead']
# base_salary : 1925 flight_salary : 346.5 layover_cost : 0
# Total:  2271.5
# ['F44', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F54']
# base_salary : 1925 flight_salary : 643.5 layover_cost : 250
# Total:  2818.5
# ['F44', 'Layover', 'F50']
# base_salary : 1925 flight_salary : 748.0 layover_cost : 50
# Total:  2723.0
# ['F44', 'Layover', 'F45']
# base_salary : 1925 flight_salary : 748.0 layover_cost : 50
# Total:  2723.0
# ['F47', 'DeadHead']
# base_salary : 2275 flight_salary : 347.09999999999997 layover_cost : 0
# Total:  2622.1
# ['F47', 'Layover', 'Layover', 'Layover', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 711.1 layover_cost : 150
# Total:  3136.1
# ['F47', 'Layover', 'Layover', 'Layover', 'F79', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 1000.9999999999999 layover_cost : 150
# Total:  3426.0
# ['F47', 'Layover', 'Layover', 'Layover', 'F79', 'F48', 'F5']
# base_salary : 2275 flight_salary : 1423.5 layover_cost : 150
# Total:  3848.5
# ['F47', 'Layover', 'Layover', 'Layover', 'Layover', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 708.4999999999999 layover_cost : 200
# Total:  3183.5
# ['F47', 'Layover', 'Layover', 'Layover', 'Layover', 'F76', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 998.4 layover_cost : 200
# Total:  3473.4
# ['F47', 'Layover', 'Layover', 'Layover', 'Layover', 'F76', 'F48', 'F5']
# base_salary : 2275 flight_salary : 1420.8999999999999 layover_cost : 200
# Total:  3895.8999999999996
# ['F47', 'Layover', 'Layover', 'Layover', 'F33', 'DeadHead']
# base_salary : 2275 flight_salary : 685.0999999999999 layover_cost : 150
# Total:  3110.1
# ['F47', 'Layover', 'Layover', 'Layover', 'F33', 'Layover', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 975.0 layover_cost : 200
# Total:  3450.0
# ['F47', 'Layover', 'Layover', 'Layover', 'F33', 'Layover', 'F48', 'F5']
# base_salary : 2275 flight_salary : 1397.5 layover_cost : 200
# Total:  3872.5
# ['F47', 'Layover', 'Layover', 'Layover', 'F33', 'F37']
# base_salary : 2275 flight_salary : 1032.2 layover_cost : 150
# Total:  3457.2
# ['F47', 'Layover', 'Layover', 'Layover', 'F33', 'F18', 'DeadHead']
# base_salary : 2275 flight_salary : 967.1999999999999 layover_cost : 150
# ...
# Total:  2472.7
# ['F20', 'F51', 'DeadHead']
# base_salary : 1925 flight_salary : 502.70000000000005 layover_cost : 0
# Total:  2427.7
# ['F20', 'F51', 'Layover', 'F98', 'DeadHead']
# base_salary : 1925 flight_salary : 737.0 layover_cost : 50
# Total:  2712.0
# ['F20', 'F51', 'Layover', 'F98', 'Layover', 'F71', 'DeadHead']
# base_salary : 1925 flight_salary : 1034.0 layover_cost : 100
# Total:  3059.0
# ['F20', 'F51', 'Layover', 'F98', 'Layover', 'Layover', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1107.7 layover_cost : 150
# Total:  3182.7
# ['F20', 'F51', 'Layover', 'F98', 'Layover', 'F52']
# base_salary : 1925 flight_salary : 973.5 layover_cost : 100
# Total:  2998.5
# ['F20', 'F51', 'Layover', 'F98', 'Layover', 'F21', 'DeadHead']
# base_salary : 1925 flight_salary : 1100.0 layover_cost : 100
# Total:  3125.0
# ['F20', 'F51', 'Layover', 'F98', 'F6', 'DeadHead']
# base_salary : 1925 flight_salary : 1034.0 layover_cost : 50
# Total:  3009.0
# ['F20', 'F51', 'Layover', 'Layover', 'F97', 'DeadHead']
# base_salary : 1925 flight_salary : 731.5 layover_cost : 100
# Total:  2756.5
# ['F20', 'F51', 'Layover', 'Layover', 'F97', 'Layover', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1102.2 layover_cost : 150
# Total:  3177.2
# ['F20', 'F51', 'Layover', 'Layover', 'F97', 'F52']
# base_salary : 1925 flight_salary : 968.0000000000001 layover_cost : 100
# Total:  2993.0
# ['F20', 'F51', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F95']
# base_salary : 1925 flight_salary : 715.0 layover_cost : 250
# Total:  2890.0
# ['F20', 'F51', 'Layover', 'Layover', 'F64', 'DeadHead']
# base_salary : 1925 flight_salary : 737.0 layover_cost : 100
# Total:  2762.0
# ['F20', 'F51', 'Layover', 'Layover', 'F64', 'Layover', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1107.7 layover_cost : 150
# Total:  3182.7
# ['F20', 'F51', 'Layover', 'Layover', 'F64', 'F52']
# base_salary : 1925 flight_salary : 973.5 layover_cost : 100
# Total:  2998.5
# ['F20', 'F51', 'Layover', 'Layover', 'Layover', 'F59']
# base_salary : 1925 flight_salary : 709.5 layover_cost : 150
# Total:  2784.5
# ['F20', 'F51', 'Layover', 'F4', 'DeadHead']
# base_salary : 1925 flight_salary : 731.5 layover_cost : 50
# Total:  2706.5
# ['F20', 'F51', 'Layover', 'F4', 'Layover', 'F71', 'DeadHead']
# base_salary : 1925 flight_salary : 1028.5000000000002 layover_cost : 100
# Total:  3053.5
# ['F20', 'F51', 'Layover', 'F4', 'Layover', 'Layover', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1102.2 layover_cost : 150
# Total:  3177.2
# ['F20', 'F51', 'Layover', 'F4', 'Layover', 'F52']
# base_salary : 1925 flight_salary : 968.0000000000001 layover_cost : 100
# Total:  2993.0
# ['F20', 'F51', 'Layover', 'F4', 'Layover', 'F21', 'DeadHead']
# base_salary : 1925 flight_salary : 1094.5 layover_cost : 100
# Total:  3119.5
# ['F20', 'F51', 'Layover', 'F4', 'F6', 'DeadHead']
# base_salary : 1925 flight_salary : 1028.5000000000002 layover_cost : 50
# Total:  3003.5
# ['F20', 'Layover', 'Layover', 'F21', 'DeadHead']
# base_salary : 1925 flight_salary : 574.1999999999999 layover_cost : 100
# Total:  2599.2
# ['F20', 'Layover', 'Layover', 'F21', 'Layover', 'Layover', 'Layover', 'Layover', 'F91']
# base_salary : 1925 flight_salary : 758.9999999999999 layover_cost : 300
# Total:  2984.0
# ['F20', 'Layover', 'Layover', 'F21', 'Layover', 'Layover', 'Layover', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 873.4 layover_cost : 250
# Total:  3048.4
# ['F20', 'Layover', 'Layover', 'F21', 'Layover', 'Layover', 'F57', 'DeadHead']
# base_salary : 1925 flight_salary : 862.4 layover_cost : 200
# Total:  2987.4
# ['F20', 'Layover', 'Layover', 'F21', 'Layover', 'Layover', 'Layover', 'Layover', 'F16']
# base_salary : 1925 flight_salary : 758.9999999999999 layover_cost : 300
# Total:  2984.0
# ['F20', 'Layover', 'Layover', 'F21', 'Layover', 'Layover', 'Layover', 'Layover', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 906.4 layover_cost : 300
# Total:  3131.4
# ['F20', 'F10', 'DeadHead']
# base_salary : 1925 flight_salary : 574.1999999999999 layover_cost : 0
# Total:  2499.2
# ['F20', 'F10', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F91']
# base_salary : 1925 flight_salary : 758.9999999999999 layover_cost : 300
# Total:  2984.0
# ['F20', 'F10', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 873.4 layover_cost : 250
# Total:  3048.4
# ['F20', 'F10', 'Layover', 'Layover', 'Layover', 'Layover', 'F57', 'DeadHead']
# base_salary : 1925 flight_salary : 862.4 layover_cost : 200
# Total:  2987.4
# ['F20', 'F10', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F16']
# base_salary : 1925 flight_salary : 758.9999999999999 layover_cost : 300
# Total:  2984.0
# ['F20', 'F10', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 906.4 layover_cost : 300
# Total:  3131.4
# ['F20', 'Layover', 'F6', 'DeadHead']
# base_salary : 1925 flight_salary : 508.2 layover_cost : 50
# Total:  2483.2
# ['F20', 'Layover', 'F6', 'Layover', 'F97', 'DeadHead']
# base_salary : 1925 flight_salary : 737.0 layover_cost : 100
# Total:  2762.0
# ['F20', 'Layover', 'F6', 'Layover', 'F97', 'Layover', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1107.7 layover_cost : 150
# Total:  3182.7
# ['F20', 'Layover', 'F6', 'Layover', 'F97', 'F52']
# base_salary : 1925 flight_salary : 973.5 layover_cost : 100
# Total:  2998.5
# ['F20', 'Layover', 'F6', 'Layover', 'Layover', 'Layover', 'Layover', 'F95']
# base_salary : 1925 flight_salary : 720.5 layover_cost : 250
# Total:  2895.5
# ['F20', 'Layover', 'F6', 'Layover', 'F64', 'DeadHead']
# base_salary : 1925 flight_salary : 742.5 layover_cost : 100
# Total:  2767.5
# ['F20', 'Layover', 'F6', 'Layover', 'F64', 'Layover', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1113.2 layover_cost : 150
# Total:  3188.2
# ['F20', 'Layover', 'F6', 'Layover', 'F64', 'F52']
# base_salary : 1925 flight_salary : 979.0 layover_cost : 100
# Total:  3004.0
# ['F20', 'Layover', 'F6', 'Layover', 'Layover', 'F59']
# base_salary : 1925 flight_salary : 715.0 layover_cost : 150
# Total:  2790.0
# ['F25', 'DeadHead']
# base_salary : 2275 flight_salary : 279.5 layover_cost : 0
# Total:  2554.5
# ['F25', 'F49', 'DeadHead']
# base_salary : 2275 flight_salary : 565.5 layover_cost : 0
# Total:  2840.5
# ['F25', 'Layover', 'Layover', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 568.1 layover_cost : 100
# Total:  2943.1
# ['F26', 'DeadHead']
# base_salary : 2275 flight_salary : 279.5 layover_cost : 0
# Total:  2554.5
# ['F26', 'Layover', 'Layover', 'F49', 'DeadHead']
# base_salary : 2275 flight_salary : 565.5 layover_cost : 100
# Total:  2940.5
# ['F26', 'Layover', 'F29', 'DeadHead']
# base_salary : 2275 flight_salary : 630.5 layover_cost : 50
# Total:  2955.5
# ['F26', 'Layover', 'F29', 'Layover', 'Layover', 'F99', 'DeadHead']
# base_salary : 2275 flight_salary : 1027.0 layover_cost : 150
# Total:  3452.0
# ['F26', 'Layover', 'F29', 'Layover', 'Layover', 'Layover', 'F63', 'DeadHead']
# base_salary : 2275 flight_salary : 1020.5 layover_cost : 200
# Total:  3495.5
# ['F26', 'Layover', 'F29', 'Layover', 'F23', 'DeadHead']
# base_salary : 2275 flight_salary : 978.8999999999999 layover_cost : 100
# Total:  3353.8999999999996
# ['F26', 'Layover', 'Layover', 'Layover', 'Layover', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 568.1 layover_cost : 200
# Total:  3043.1
# ['F28', 'DeadHead']
# base_salary : 2275 flight_salary : 283.40000000000003 layover_cost : 0
# Total:  2558.4
# ['F28', 'Layover', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 572.0 layover_cost : 50
# Total:  2897.0
# ['F34', 'DeadHead']
# base_salary : 2275 flight_salary : 244.39999999999998 layover_cost : 0
# Total:  2519.4
# ['F34', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 608.4 layover_cost : 250
# Total:  3133.4
# ['F34', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F79', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 898.3000000000001 layover_cost : 250
# Total:  3423.3
# ['F34', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 605.8000000000001 layover_cost : 300
# Total:  3180.8
# ['F34', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F76', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 895.7 layover_cost : 300
# Total:  3470.7
# ['F34', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F33', 'DeadHead']
# base_salary : 2275 flight_salary : 582.4000000000001 layover_cost : 250
# Total:  3107.4
# ['F34', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F33', 'Layover', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 872.3000000000001 layover_cost : 300
# Total:  3447.3
# ['F34', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F33', 'F37', 'DeadHead']
# base_salary : 2275 flight_salary : 929.5 layover_cost : 250
# Total:  3454.5
# ['F34', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F33', 'F18', 'DeadHead']
# base_salary : 2275 flight_salary : 864.5 layover_cost : 250
# Total:  3389.5
# ['F34', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F33', 'F18', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 1228.5 layover_cost : 250
# Total:  3753.5
# ['F34', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F33', 'F18', 'Layover', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 1225.8999999999999 layover_cost : 300
# Total:  3800.8999999999996
# ['F34', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F33', 'F18', 'Layover', 'F8']
# base_salary : 2275 flight_salary : 1137.5 layover_cost : 300
# Total:  3712.5
# ['F34', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F8']
# base_salary : 2275 flight_salary : 517.4 layover_cost : 300
# Total:  3092.4
# ['F36', 'DeadHead']
# base_salary : 2275 flight_salary : 299.0 layover_cost : 0
# Total:  2574.0
# ['F36', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 587.5999999999999 layover_cost : 0
# Total:  2862.6
# ['F40', 'DeadHead']
# base_salary : 1925 flight_salary : 220.0 layover_cost : 0
# Total:  2145.0
# ['F40', 'Layover', 'F91']
# base_salary : 1925 flight_salary : 404.79999999999995 layover_cost : 50
# Total:  2379.8
# ['F40', 'Layover', 'F16']
# base_salary : 1925 flight_salary : 404.79999999999995 layover_cost : 50
# Total:  2379.8
# ['F40', 'Layover', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 552.1999999999999 layover_cost : 50
# Total:  2527.2
# ['F41', 'DeadHead']
# base_salary : 2275 flight_salary : 548.6 layover_cost : 0
# Total:  2823.6
# ['F46', 'DeadHead']
# base_salary : 2275 flight_salary : 548.6 layover_cost : 0
# Total:  2823.6
# ['F46', 'Layover', 'Layover', 'Layover', 'F73']
# base_salary : 2275 flight_salary : 988.0 layover_cost : 150
# Total:  3413.0
# ['F46', 'Layover', 'Layover', 'Layover', 'F69']
# base_salary : 2275 flight_salary : 884.0 layover_cost : 150
# Total:  3309.0
# ['F46', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F38', 'DeadHead']
# base_salary : 2275 flight_salary : 870.9999999999999 layover_cost : 300
# Total:  3446.0
# ['F46', 'Layover', 'Layover', 'F1', 'DeadHead']
# base_salary : 2275 flight_salary : 1020.5 layover_cost : 100
# Total:  3395.5
# ['F46', 'Layover', 'Layover', 'F1', 'Layover', 'Layover', 'Layover', 'Layover', 'F37', 'DeadHead']
# base_salary : 2275 flight_salary : 1367.6 layover_cost : 300
# Total:  3942.6
# ['F46', 'Layover', 'Layover', 'F1', 'Layover', 'Layover', 'Layover', 'Layover', 'F18', 'DeadHead']
# base_salary : 2275 flight_salary : 1302.6 layover_cost : 300
# Total:  3877.6
# ['F46', 'Layover', 'Layover', 'F1', 'Layover', 'Layover', 'Layover', 'Layover', 'F18', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 1666.6000000000001 layover_cost : 300
# Total:  4241.6
# ['F46', 'Layover', 'Layover', 'F1', 'Layover', 'Layover', 'Layover', 'Layover', 'F18', 'Layover', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 1663.9999999999998 layover_cost : 350
# Total:  4289.0
# ['F46', 'Layover', 'Layover', 'F1', 'Layover', 'Layover', 'Layover', 'Layover', 'F18', 'Layover', 'F8']
# base_salary : 2275 flight_salary : 1575.6 layover_cost : 350
# Total:  4200.6
# ['F55', 'DeadHead']
# base_salary : 1925 flight_salary : 234.29999999999998 layover_cost : 0
# Total:  2159.3
# ['F55', 'Layover', 'Layover', 'F95']
# base_salary : 1925 flight_salary : 446.59999999999997 layover_cost : 100
# Total:  2471.6
# ['F55', 'F59']
# base_salary : 1925 flight_salary : 441.09999999999997 layover_cost : 0
# Total:  2366.1
# ['F56', 'DeadHead']
# base_salary : 2275 flight_salary : 279.5 layover_cost : 0
# Total:  2554.5
# ['F56', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 643.4999999999999 layover_cost : 0
# Total:  2918.5
# ['F56', 'F79', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 933.4 layover_cost : 0
# Total:  3208.4
# ['F56', 'F79', 'F48', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 1355.8999999999999 layover_cost : 0
# Total:  3630.8999999999996
# ['F56', 'Layover', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 640.9 layover_cost : 50
# Total:  2965.9
# ['F56', 'Layover', 'F76', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 930.8000000000001 layover_cost : 50
# Total:  3255.8
# ['F56', 'Layover', 'F76', 'F48', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 1353.3 layover_cost : 50
# Total:  3678.3
# ['F56', 'Layover', 'F8']
# base_salary : 2275 flight_salary : 552.5 layover_cost : 50
# Total:  2877.5
# ['F56', 'Layover', 'Layover', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 702.0 layover_cost : 100
# Total:  3077.0
# ['F66', 'DeadHead']
# base_salary : 2275 flight_salary : 279.5 layover_cost : 0
# Total:  2554.5
# ['F66', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 569.4 layover_cost : 0
# Total:  2844.4
# ['F66', 'F48', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 991.9 layover_cost : 0
# Total:  3266.9
# ['F82', 'DeadHead']
# base_salary : 2275 flight_salary : 279.5 layover_cost : 0
# Total:  2554.5
# ['F82', 'Layover', 'F49', 'DeadHead']
# base_salary : 2275 flight_salary : 565.5 layover_cost : 50
# Total:  2890.5
# ['F82', 'Layover', 'Layover', 'Layover', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 568.1 layover_cost : 150
# Total:  2993.1
# ['F84', 'DeadHead']
# base_salary : 2275 flight_salary : 548.6 layover_cost : 0
# Total:  2823.6
# ['F84', 'Layover', 'Layover', 'F38', 'DeadHead']
# base_salary : 2275 flight_salary : 870.9999999999999 layover_cost : 100
# Total:  3246.0
# ['F84', 'Layover', 'Layover', 'F38', 'Layover', 'Layover', 'F65', 'DeadHead']
# base_salary : 2275 flight_salary : 1231.1 layover_cost : 200
# Total:  3706.1
# ['F85', 'DeadHead']
# base_salary : 2275 flight_salary : 548.6 layover_cost : 0
# Total:  2823.6
# ['F89', 'DeadHead']
# base_salary : 2275 flight_salary : 574.6 layover_cost : 0
# Total:  2849.6
# ['F89', 'F73']
# base_salary : 2275 flight_salary : 1014.0 layover_cost : 0
# Total:  3289.0
# ['F89', 'Layover', 'Layover', 'Layover', 'F38', 'DeadHead']
# base_salary : 2275 flight_salary : 897.0 layover_cost : 150
# Total:  3322.0
# ['F89', 'Layover', 'Layover', 'Layover', 'F38', 'Layover', 'Layover', 'F65', 'DeadHead']
# base_salary : 2275 flight_salary : 1257.1 layover_cost : 250
# Total:  3782.1
# ['F90', 'DeadHead']
# base_salary : 2275 flight_salary : 296.4 layover_cost : 0
# Total:  2571.4
# ['F100', 'DeadHead']
# base_salary : 1925 flight_salary : 220.0 layover_cost : 0
# Total:  2145.0
# ['F100', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F91']
# base_salary : 1925 flight_salary : 404.79999999999995 layover_cost : 300
# Total:  2629.8
# ['F100', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 519.2 layover_cost : 250
# Total:  2694.2
# ['F100', 'Layover', 'Layover', 'Layover', 'Layover', 'F57', 'DeadHead']
# base_salary : 1925 flight_salary : 508.2 layover_cost : 200
# Total:  2633.2
# ['F100', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F16']
# base_salary : 1925 flight_salary : 404.79999999999995 layover_cost : 300
# Total:  2629.8
# ['F100', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'Layover', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 552.1999999999999 layover_cost : 300
# Total:  2777.2
