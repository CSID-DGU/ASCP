# %%
import pandas as pd
import os
from multiprocessing import Process
import copy
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# Node의 부모 Class
class Node:
    def __init__(self, node_name):
        self.node_name = node_name

# Edge의 부모 Class
class Edge:
    def __init__(self, origin, dest):
        self.origin = origin
        self.dest = dest

# Airport Class
class Airport(Node):
    def __init__(self, airport_name):
        super().__init__(airport_name)

# Flight Class
class Flight(Edge):
    def __init__(self, index, origin, dest, origin_date, dest_date, flight_duration, flight_type):
        super().__init__(origin, dest)
        self.index = index
        self.origin_date = origin_date
        self.dest_date = dest_date
        self.flight_duration = flight_duration
        self.flight_type = flight_type

    def print(self):
        print(self.index, self.origin, self.origin_date, self.dest,
              self.dest_date, self.flight_duration, self.flight_type)
        

# Stack Node의 구조
class Stackitem:
    def __init__(self, flight: Flight, flights_sequence: list = None, landing_number = None):
        if flights_sequence:
            self.flight = flight
            flights_sequence.append(flight.index)
            self.flights_sequence = flights_sequence
            self.landing_number = landing_number + 1
            # self.time = time + dt.timedelta(flight.flight_duration)
        else:
            self.flight = flight
            self.flights_sequence = [flight.index]
            self.landing_number = 1
            # self.time = flight.flight_duration;

# %%
# Initial Setting - Test
flight_graph = dict()
flight_excel = pd.read_excel("flight.xlsx")
flight_excel.columns = ['INDEX', 'ORIGIN', 'ORIGIN_DATE', 'DEST','DEST_DATE', 'FLIGHT_DURATION','AIRCRAFT_TYPE' ]
airports_set = set()

# %%
# Graph insert Node
for i in range(100) :
    airports_set.add(flight_excel.loc[i]['ORIGIN'])
    airports_set.add(flight_excel.loc[i]['DEST'])
    
for airports in airports_set :
    flight_graph[airports] = list()

# Graph insert Edge
for i in range(100) :
    flight_graph[flight_excel.loc[i]['ORIGIN']].append(Flight(flight_excel.loc[i]['INDEX'], flight_excel.loc[i]['ORIGIN'], flight_excel.loc[i]['DEST'],
                                                              flight_excel.loc[i]['ORIGIN_DATE'], flight_excel.loc[i]['DEST_DATE'],
                                                              flight_excel.loc[i]['FLIGHT_DURATION'], flight_excel.loc[i]['AIRCRAFT_TYPE']))

# %%
print(len(airports_set))
# Out:
# 5

# %%
pairing_set = list()

# clustering을 통한 flights set의 크기를 줄여야지 경우의 수가 줄어듬
# 하지만 그렇다면 시간을 어떻게 배분해야하는가? 기준은? 시간 → 기종? 조금더 생각해봐야 할 거 같다.

# 여기서 Node 시작에 따라 끝나는 경우는
# 만나는 Base가 같은경우가 있고,
# 만약 끝이 Base가 아닌데 갈 곳이 없는 경우가 있다.
# 그렇다면 모든 pairing의 모든 경우를 넣어도 모든 경우가 나온다!
# 

for airport in airports_set :
    # pairing_set.append(["-" * 10, airport, "-" * 10])

    for flight in flight_graph[airport] :
        # 항공편, 항공편의 순서를 넣는다
        stack_temp = [Stackitem(flight)]
        
        while stack_temp:
            # 현재 진행 중인 항공편의 정보
            flights_information_now = stack_temp.pop()

            pairing_set.append(copy.deepcopy(flights_information_now.flights_sequence))
            # 만약 해당 항공편이 진행됨으로서 base로 간다면 해당 항공편은 더 진행할 필요가 없음
            if (flights_information_now.flight.dest == flight.origin) :
                continue
            
            else :
                pairing_set[-1].append("DeadHead")

            # Search Space Extend
            for flight_next in flight_graph[flights_information_now.flight.dest] :
                # 항공기 기종이 같은지? 시간이 가능한지? (날짜가 같다면 시간까지 비교, 다르다면 날짜 비교)
                flight_type_equal = (flights_information_now.flight.flight_type == flight_next.flight_type)
                flight_time_possible = flights_information_now.flight.dest_date < flight_next.origin_date and (flight_next.origin_date - flights_information_now.flight.dest_date).seconds/3600 >= 3
                flight_day_possible = (flight_next.dest_date  - flight.origin_date).days <= 7
                flight_landing_possible = (flights_information_now.landing_number <= 3)

                # 기종이 다르거나 시간이 불가능하면 해당 항공편은 Search에 사용하지 않음
                if (not flight_type_equal or not flight_time_possible or not flight_day_possible or not flight_landing_possible) :
                    continue

                # 기종이 같고, 시간이 가능하다면 Search를 위해 stack에 추가(항공편의 순서까지)
                temp_list = copy.deepcopy(flights_information_now.flights_sequence)
                #if (flights_information_now.flight.dest_date < flight_next.origin_date) :
                    #for i in range(0, int(flight_next.origin_date.day - flights_information_now.flight.dest_date.day)) :
                        #temp_list.append("Layover")
                        
                stack_temp.append(Stackitem(flight_next, temp_list, flights_information_now.landing_number))
                

#for pairing in pairing_set :
    #print(pairing)

# 첫번째 방안 : 모든 항공편들의 순서를 저장한다
# 그렇다면 만들 수 있는(DeadHead, Layover, Feasible) Pairing의 모든 경우가 나온다.
# 하지만 이럴때는 시간이 n^n까지 나올 수 있는 것으로 보인다.
# 여기서 경우의 수를 줄이는 조건을 넣을 때
# 첫번째 - 항공기 종류
# 두번째 - 전 항공편의 도착시간보다 현 항공편의 출발시간이 느려야한다
# 세번째 - Crew의 Trun Time이 MMT보다 크거나 같아야 한다.(Slack Time은 어떻게 될려나?)
# feasible pairing은 좀 많다. -> 그럼 DeadHead가 존재하는 pairing은 넣어야하는 것인가?
# 지연전파? 존재한다?

# stack에 넣을 때 모든 정보를 넣어버린다면? 오히려 쉬워진다. 하지만 메모리를 많이 쓰므로 최적화가 필요함(조건을 생각해야 함)

# %%
import re

# 엑셀 파일명
filename = 'output.xlsx'

# 데이터프레임으로 변환
df = pd.DataFrame(pairing_set)

# 엑셀로 출력
df.to_excel(filename, index=False, header=False)

# %%
# 비행기 기종 : {크루원 수, 비행 수당, 기본급}
salary={}

salary_excel = pd.read_excel("salary.xlsx")
for index, row in salary_excel.iterrows():
    aircraft = row['AIRCRAFT']
    crew_num = row['CREW_NUM']
    flight_salary = row['FLIGHT_SALARY']
    base_salary = row['BASE_SALARY']
    layover_cost = row['BASE_SALARY']
    salary[aircraft] = {'CREW_NUM': crew_num, 'FLIGHT_SALARY': flight_salary, 'BASE_SALARY': base_salary,'LAYOVER_COST': layover_cost}

deadhead_cost={}
salary_excel = pd.read_excel("deadhead.xlsx")
for index, row in salary_excel.iterrows():
    origin = row['ORIGIN']
    dest = row['DEST']
    cost = row['deadhead']
    deadhead_cost[origin,dest]=cost

print(deadhead_cost)

total = []
i=0

for pairing in pairing_set :
    crew_num = salary[flight_excel.loc[int(re.search(r'\d+', pairing[0]).group())-1]['AIRCRAFT_TYPE']]['CREW_NUM']
    base_salary = salary[flight_excel.loc[int(re.search(r'\d+', pairing[0]).group())-1]['AIRCRAFT_TYPE']]['BASE_SALARY']
    flight_salary = salary[flight_excel.loc[int(re.search(r'\d+', pairing[0]).group())-1]['AIRCRAFT_TYPE']]['FLIGHT_SALARY']
    layover_cost =  salary[flight_excel.loc[int(re.search(r'\d+', pairing[0]).group())-1]['AIRCRAFT_TYPE']]['LAYOVER_COST']
    layover_time = 0
    flight_time = flight_excel.loc[int(re.search(r'\d+', pairing[0]).group())-1]['FLIGHT_DURATION']
    deadhead=0
    for idx,pair in enumerate(pairing[1:],start=1):
        if(pair != "DeadHead") :
            n = int(re.search(r'\d+', pair).group())
            flight_time+=flight_excel.loc[n-1]['FLIGHT_DURATION']
            before_flight = flight_excel.loc[int(re.search(r'\d+', pairing[idx-1]).group())-1]['ORIGIN_DATE']
            current_flight = flight_excel.loc[int(re.search(r'\d+', pair).group())-1]['ORIGIN_DATE']
            layover_time += (current_flight-before_flight).seconds/3600
        else :
            #deadhead cost 정의하기
            before_flight_airport=flight_excel.loc[int(re.search(r'\d+', pairing[idx-1]).group())-1]['DEST']
            base_airport = flight_excel.loc[int(re.search(r'\d+', pairing[0]).group())-1]['ORIGIN']
            print(before_flight_airport,base_airport)
            
            deadhead = deadhead_cost[before_flight_airport,base_airport]* crew_num
        
            
    
    print(i,pairing)
    i+=1
    print('base_salary :',base_salary,'flight_salary :', flight_salary*flight_time,'layover_cost :',0.1*layover_cost*layover_time,'deadhead :',deadhead)
    total.append(base_salary+(flight_salary*flight_time)+(0.1*layover_cost*layover_time)+deadhead)
    print('Total: ',base_salary+flight_salary*flight_time+0.1*layover_cost*layover_time)
    #print(pairing)
    #print(total)

print('Total paring :',len(pairing_set))
# Out:
# {('ATL', 'LGA'): 100, ('ATL', 'DTW'): 200, ('ATL', 'MSP'): 230, ('ATL', 'SLC'): 380, ('LGA', 'ATL'): 200, ('LGA', 'DTW'): 150, ('LGA', 'MSP'): 300, ('LGA', 'SLC'): 250, ('DTW', 'ATL'): 150, ('DTW', 'LGA'): 150, ('DTW', 'MSP'): 180, ('DTW', 'SLC'): 390, ('MSP', 'ATL'): 230, ('MSP', 'LGA'): 300, ('MSP', 'DTW'): 210, ('MSP', 'SLC'): 330, ('SLC', 'ATL'): 400, ('SLC', 'LGA'): 390, ('SLC', 'DTW'): 390, ('SLC', 'MSP'): 330}
# ATL DTW
# 0 ['F7', 'DeadHead']
# base_salary : 2275 flight_salary : 283.40000000000003 layover_cost : 0.0 deadhead : 1200
# Total:  2558.4
# ATL DTW
# 1 ['F11', 'DeadHead']
# base_salary : 1925 flight_salary : 238.7 layover_cost : 0.0 deadhead : 1000
# Total:  2163.7
# SLC DTW
# 2 ['F12', 'DeadHead']
# base_salary : 2275 flight_salary : 548.6 layover_cost : 0.0 deadhead : 2340
# Total:  2823.6
# ATL DTW
# 3 ['F14', 'DeadHead']
# base_salary : 2275 flight_salary : 279.5 layover_cost : 0.0 deadhead : 1200
# Total:  2554.5
# SLC DTW
# 4 ['F14', 'F96', 'DeadHead']
# base_salary : 2275 flight_salary : 962.0 layover_cost : 2654.1666666666665 deadhead : 2340
# Total:  5891.166666666666
# LGA DTW
# 5 ['F14', 'F92', 'DeadHead']
# base_salary : 2275 flight_salary : 561.6 layover_cost : 341.25 deadhead : 900
# Total:  3177.85
# 6 ['F14', 'F92', 'F87']
# base_salary : 2275 flight_salary : 845.0 layover_cost : 5122.541666666666 deadhead : 0
# Total:  8242.541666666666
# MSP DTW
# 7 ['F14', 'F92', 'F83', 'DeadHead']
# base_salary : 2275 flight_salary : 973.7 layover_cost : 4322.5 deadhead : 1260
# Total:  7571.2
# SLC DTW
# 8 ['F14', 'F92', 'F83', 'F99', 'DeadHead']
# base_salary : 2275 flight_salary : 1370.1999999999998 layover_cost : 7666.750000000001 deadhead : 2340
# Total:  11311.95
# SLC DTW
# 9 ['F14', 'F92', 'F83', 'F68', 'DeadHead']
# base_salary : 2275 flight_salary : 1363.7 layover_cost : 5744.375 deadhead : 2340
# Total:  9383.075
# SLC DTW
# 10 ['F14', 'F92', 'F83', 'F63', 'DeadHead']
# base_salary : 2275 flight_salary : 1363.7 layover_cost : 5744.375 deadhead : 2340
# Total:  9383.075
# ATL DTW
# 11 ['F14', 'F92', 'F75', 'DeadHead']
# base_salary : 2275 flight_salary : 915.2000000000002 layover_cost : 5683.708333333334 deadhead : 1200
# Total:  8873.908333333335
# LGA DTW
# 12 ['F14', 'F92', 'F75', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 1203.8000000000002 layover_cost : 6028.75 deadhead : 900
# Total:  9507.55
# ATL DTW
# 13 ['F14', 'F92', 'F17', 'DeadHead']
# base_salary : 2275 flight_salary : 916.5000000000001 layover_cost : 5005.0 deadhead : 1200
# Total:  8196.5
# LGA DTW
# 14 ['F14', 'F92', 'F17', 'F49', 'DeadHead']
# base_salary : 2275 flight_salary : 1202.5 layover_cost : 6483.75 deadhead : 900
# Total:  9961.25
# 15 ['F14', 'F61']
# base_salary : 2275 flight_salary : 530.4 layover_cost : 4644.791666666667 deadhead : 0
# Total:  7450.1916666666675
# 16 ['F14', 'F2']
# base_salary : 2275 flight_salary : 530.4 layover_cost : 4644.791666666667 deadhead : 0
# Total:  7450.1916666666675
# LGA DTW
# 17 ['F20', 'DeadHead']
# base_salary : 1925 flight_salary : 211.2 layover_cost : 0.0 deadhead : 750
# Total:  2136.2
# ATL DTW
# 18 ['F20', 'F74', 'DeadHead']
# base_salary : 1925 flight_salary : 511.50000000000006 layover_cost : 962.5 deadhead : 1000
# Total:  3399.0
# LGA DTW
# 19 ['F20', 'F74', 'F98', 'DeadHead']
# base_salary : 1925 flight_salary : 745.8000000000001 layover_cost : 1251.25 deadhead : 750
# Total:  3922.05
# ATL DTW
# 20 ['F20', 'F74', 'F98', 'F71', 'DeadHead']
# base_salary : 1925 flight_salary : 1042.8 layover_cost : 5386.791666666667 deadhead : 1000
# Total:  8354.591666666667
# MSP DTW
# 21 ['F20', 'F74', 'F98', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1116.5 layover_cost : 5309.791666666666 deadhead : 1050
# Total:  8351.291666666666
# 22 ['F20', 'F74', 'F98', 'F52']
# base_salary : 1925 flight_salary : 982.3 layover_cost : 2293.9583333333335 deadhead : 0
# Total:  5201.258333333333
# MSP DTW
# 23 ['F20', 'F74', 'F98', 'F21', 'DeadHead']
# base_salary : 1925 flight_salary : 1108.8 layover_cost : 5197.5 deadhead : 1050
# Total:  8231.3
# LGA DTW
# 24 ['F20', 'F74', 'F97', 'DeadHead']
# base_salary : 1925 flight_salary : 740.3000000000001 layover_cost : 5486.25 deadhead : 750
# Total:  8151.55
# MSP DTW
# 25 ['F20', 'F74', 'F97', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1111.0000000000002 layover_cost : 9929.791666666666 deadhead : 1050
# Total:  12965.791666666666
# 26 ['F20', 'F74', 'F97', 'F52']
# base_salary : 1925 flight_salary : 976.8000000000001 layover_cost : 6913.958333333333 deadhead : 0
# Total:  9815.758333333333
# LGA DTW
# 27 ['F20', 'F74', 'F64', 'DeadHead']
# base_salary : 1925 flight_salary : 745.8000000000001 layover_cost : 1251.25 deadhead : 750
# Total:  3922.05
# MSP DTW
# 28 ['F20', 'F74', 'F64', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1116.5 layover_cost : 5309.791666666666 deadhead : 1050
# Total:  8351.291666666666
# 29 ['F20', 'F74', 'F64', 'F52']
# base_salary : 1925 flight_salary : 982.3 layover_cost : 2293.9583333333335 deadhead : 0
# Total:  5201.258333333333
# 30 ['F20', 'F74', 'F59']
# base_salary : 1925 flight_salary : 718.3000000000001 layover_cost : 1418.0833333333335 deadhead : 0
# Total:  4061.3833333333337
# LGA DTW
# 31 ['F20', 'F74', 'F4', 'DeadHead']
# base_salary : 1925 flight_salary : 740.3000000000001 layover_cost : 5101.25 deadhead : 750
# Total:  7766.55
# ATL DTW
# 32 ['F20', 'F74', 'F4', 'F71', 'DeadHead']
# base_salary : 1925 flight_salary : 1037.3 layover_cost : 5386.791666666667 deadhead : 1000
# Total:  8349.091666666667
# MSP DTW
# 33 ['F20', 'F74', 'F4', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1111.0000000000002 layover_cost : 5309.791666666666 deadhead : 1050
# Total:  8345.791666666666
# 34 ['F20', 'F74', 'F4', 'F52']
# base_salary : 1925 flight_salary : 976.8000000000001 layover_cost : 6913.958333333333 deadhead : 0
# Total:  9815.758333333333
# MSP DTW
# 35 ['F20', 'F74', 'F4', 'F21', 'DeadHead']
# base_salary : 1925 flight_salary : 1103.3000000000002 layover_cost : 5197.5 deadhead : 1050
# Total:  8225.8
# ATL DTW
# 36 ['F20', 'F74', 'F4', 'F6', 'DeadHead']
# base_salary : 1925 flight_salary : 1037.3 layover_cost : 6352.5 deadhead : 1000
# Total:  9314.8
# 37 ['F20', 'F52']
# base_salary : 1925 flight_salary : 447.70000000000005 layover_cost : 2293.958333333333 deadhead : 0
# Total:  4666.658333333333
# ATL DTW
# 38 ['F20', 'F51', 'DeadHead']
# base_salary : 1925 flight_salary : 502.70000000000005 layover_cost : 1155.0 deadhead : 1000
# Total:  3582.7
# LGA DTW
# 39 ['F20', 'F51', 'F98', 'DeadHead']
# base_salary : 1925 flight_salary : 737.0 layover_cost : 1251.25 deadhead : 750
# Total:  3913.25
# ATL DTW
# 40 ['F20', 'F51', 'F98', 'F71', 'DeadHead']
# base_salary : 1925 flight_salary : 1034.0 layover_cost : 5386.791666666667 deadhead : 1000
# Total:  8345.791666666668
# MSP DTW
# 41 ['F20', 'F51', 'F98', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1107.7 layover_cost : 5309.791666666666 deadhead : 1050
# Total:  8342.491666666665
# 42 ['F20', 'F51', 'F98', 'F52']
# base_salary : 1925 flight_salary : 973.5 layover_cost : 2293.9583333333335 deadhead : 0
# Total:  5192.458333333334
# MSP DTW
# 43 ['F20', 'F51', 'F98', 'F21', 'DeadHead']
# base_salary : 1925 flight_salary : 1100.0 layover_cost : 5197.5 deadhead : 1050
# Total:  8222.5
# LGA DTW
# 44 ['F20', 'F51', 'F97', 'DeadHead']
# base_salary : 1925 flight_salary : 731.5 layover_cost : 5486.25 deadhead : 750
# Total:  8142.75
# MSP DTW
# 45 ['F20', 'F51', 'F97', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1102.2 layover_cost : 9929.791666666666 deadhead : 1050
# Total:  12956.991666666665
# 46 ['F20', 'F51', 'F97', 'F52']
# base_salary : 1925 flight_salary : 968.0000000000001 layover_cost : 6913.958333333333 deadhead : 0
# Total:  9806.958333333332
# 47 ['F20', 'F51', 'F95']
# base_salary : 1925 flight_salary : 715.0 layover_cost : 1607.375 deadhead : 0
# Total:  4247.375
# LGA DTW
# 48 ['F20', 'F51', 'F64', 'DeadHead']
# base_salary : 1925 flight_salary : 737.0 layover_cost : 1251.25 deadhead : 750
# Total:  3913.25
# MSP DTW
# 49 ['F20', 'F51', 'F64', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1107.7 layover_cost : 5309.791666666666 deadhead : 1050
# Total:  8342.491666666665
# 50 ['F20', 'F51', 'F64', 'F52']
# base_salary : 1925 flight_salary : 973.5 layover_cost : 2293.9583333333335 deadhead : 0
# Total:  5192.458333333334
# 51 ['F20', 'F51', 'F59']
# base_salary : 1925 flight_salary : 709.5 layover_cost : 1418.0833333333335 deadhead : 0
# Total:  4052.5833333333335
# LGA DTW
# 52 ['F20', 'F51', 'F4', 'DeadHead']
# base_salary : 1925 flight_salary : 731.5 layover_cost : 5101.25 deadhead : 750
# Total:  7757.75
# ATL DTW
# 53 ['F20', 'F51', 'F4', 'F71', 'DeadHead']
# base_salary : 1925 flight_salary : 1028.5000000000002 layover_cost : 5386.791666666667 deadhead : 1000
# Total:  8340.291666666668
# MSP DTW
# 54 ['F20', 'F51', 'F4', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1102.2 layover_cost : 5309.791666666666 deadhead : 1050
# Total:  8336.991666666665
# 55 ['F20', 'F51', 'F4', 'F52']
# base_salary : 1925 flight_salary : 968.0000000000001 layover_cost : 6913.958333333333 deadhead : 0
# Total:  9806.958333333332
# MSP DTW
# 56 ['F20', 'F51', 'F4', 'F21', 'DeadHead']
# base_salary : 1925 flight_salary : 1094.5 layover_cost : 5197.5 deadhead : 1050
# Total:  8217.0
# ATL DTW
# 57 ['F20', 'F51', 'F4', 'F6', 'DeadHead']
# base_salary : 1925 flight_salary : 1028.5000000000002 layover_cost : 6352.5 deadhead : 1000
# Total:  9306.0
# ATL DTW
# 58 ['F20', 'F6', 'DeadHead']
# base_salary : 1925 flight_salary : 508.2 layover_cost : 1732.5 deadhead : 1000
# Total:  4165.7
# LGA DTW
# 59 ['F20', 'F6', 'F97', 'DeadHead']
# base_salary : 1925 flight_salary : 737.0 layover_cost : 5486.25 deadhead : 750
# Total:  8148.25
# MSP DTW
# 60 ['F20', 'F6', 'F97', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1107.7 layover_cost : 9929.791666666666 deadhead : 1050
# Total:  12962.491666666665
# 61 ['F20', 'F6', 'F97', 'F52']
# base_salary : 1925 flight_salary : 973.5 layover_cost : 6913.958333333333 deadhead : 0
# Total:  9812.458333333332
# 62 ['F20', 'F6', 'F95']
# base_salary : 1925 flight_salary : 720.5 layover_cost : 6227.375 deadhead : 0
# Total:  8872.875
# LGA DTW
# 63 ['F20', 'F6', 'F64', 'DeadHead']
# base_salary : 1925 flight_salary : 742.5 layover_cost : 5871.25 deadhead : 750
# Total:  8538.75
# MSP DTW
# 64 ['F20', 'F6', 'F64', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 1113.2 layover_cost : 9929.791666666666 deadhead : 1050
# Total:  12967.991666666665
# 65 ['F20', 'F6', 'F64', 'F52']
# base_salary : 1925 flight_salary : 979.0 layover_cost : 6913.958333333333 deadhead : 0
# Total:  9817.958333333332
# 66 ['F20', 'F6', 'F59']
# base_salary : 1925 flight_salary : 715.0 layover_cost : 6038.083333333333 deadhead : 0
# Total:  8678.083333333332
# ATL DTW
# 67 ['F25', 'DeadHead']
# base_salary : 2275 flight_salary : 279.5 layover_cost : 0.0 deadhead : 1200
# Total:  2554.5
# ATL DTW
# 68 ['F26', 'DeadHead']
# base_salary : 2275 flight_salary : 279.5 layover_cost : 0.0 deadhead : 1200
# Total:  2554.5
# ATL DTW
# 69 ['F28', 'DeadHead']
# base_salary : 2275 flight_salary : 283.40000000000003 layover_cost : 0.0 deadhead : 1200
# Total:  2558.4
# LGA DTW
# 70 ['F28', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 572.0 layover_cost : 4440.041666666666 deadhead : 900
# Total:  7287.041666666666
# LGA DTW
# 71 ['F34', 'DeadHead']
# base_salary : 2275 flight_salary : 244.39999999999998 layover_cost : 0.0 deadhead : 900
# Total:  2519.4
# ATL DTW
# 72 ['F34', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 608.4 layover_cost : 238.875 deadhead : 1200
# Total:  3122.275
# LGA DTW
# 73 ['F34', 'F79', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 898.3000000000001 layover_cost : 5585.125 deadhead : 900
# Total:  8758.425
# MSP DTW
# 74 ['F34', 'F79', 'F48', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 1320.8 layover_cost : 5808.833333333334 deadhead : 1260
# Total:  9404.633333333335
# ATL DTW
# 75 ['F34', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 605.8000000000001 layover_cost : 3878.875 deadhead : 1200
# Total:  6759.675
# LGA DTW
# 76 ['F34', 'F76', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 895.7 layover_cost : 5585.125 deadhead : 900
# Total:  8755.825
# MSP DTW
# 77 ['F34', 'F76', 'F48', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 1318.2 layover_cost : 5808.833333333334 deadhead : 1260
# Total:  9402.033333333333
# ATL DTW
# 78 ['F34', 'F33', 'DeadHead']
# base_salary : 2275 flight_salary : 582.4000000000001 layover_cost : 2741.375 deadhead : 1200
# Total:  5598.775
# LGA DTW
# 79 ['F34', 'F33', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 872.3000000000001 layover_cost : 5585.125 deadhead : 900
# Total:  8732.425
# MSP DTW
# 80 ['F34', 'F33', 'F48', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 1294.8000000000002 layover_cost : 5808.833333333334 deadhead : 1260
# Total:  9378.633333333335
# LGA DTW
# 81 ['F34', 'F33', 'F18', 'DeadHead']
# base_salary : 2275 flight_salary : 864.5 layover_cost : 4220.125 deadhead : 900
# Total:  7359.625
# ATL DTW
# 82 ['F34', 'F33', 'F18', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 1228.5 layover_cost : 5698.875 deadhead : 1200
# Total:  9202.375
# ATL DTW
# 83 ['F34', 'F33', 'F18', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 1225.8999999999999 layover_cost : 9338.875 deadhead : 1200
# Total:  12839.775
# 84 ['F34', 'F33', 'F18', 'F8']
# base_salary : 2275 flight_salary : 1137.5 layover_cost : 8466.791666666668 deadhead : 0
# Total:  11879.291666666668
# MSP DTW
# 85 ['F34', 'F33', 'F18', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 1287.0 layover_cost : 5808.833333333334 deadhead : 1260
# Total:  9370.833333333334
# 86 ['F34', 'F8']
# base_salary : 2275 flight_salary : 517.4 layover_cost : 3006.7916666666665 deadhead : 0
# Total:  5799.191666666667
# MSP DTW
# 87 ['F34', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 666.9 layover_cost : 348.83333333333337 deadhead : 1260
# Total:  3290.7333333333336
# ATL DTW
# 88 ['F36', 'DeadHead']
# base_salary : 2275 flight_salary : 299.0 layover_cost : 0.0 deadhead : 1200
# Total:  2574.0
# MSP DTW
# 89 ['F40', 'DeadHead']
# base_salary : 1925 flight_salary : 220.0 layover_cost : 0.0 deadhead : 1050
# Total:  2145.0
# 90 ['F40', 'F91']
# base_salary : 1925 flight_salary : 404.79999999999995 layover_cost : 4401.833333333333 deadhead : 0
# Total:  6731.633333333333
# 91 ['F40', 'F16']
# base_salary : 1925 flight_salary : 404.79999999999995 layover_cost : 4401.833333333333 deadhead : 0
# Total:  6731.633333333333
# SLC DTW
# 92 ['F40', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 552.1999999999999 layover_cost : 3355.9166666666665 deadhead : 1950
# Total:  5833.116666666667
# SLC DTW
# 93 ['F41', 'DeadHead']
# base_salary : 2275 flight_salary : 548.6 layover_cost : 0.0 deadhead : 2340
# Total:  2823.6
# SLC DTW
# 94 ['F46', 'DeadHead']
# base_salary : 2275 flight_salary : 548.6 layover_cost : 0.0 deadhead : 2340
# Total:  2823.6
# 95 ['F46', 'F73']
# base_salary : 2275 flight_salary : 988.0 layover_cost : 891.0416666666666 deadhead : 0
# Total:  4154.041666666667
# 96 ['F46', 'F69']
# base_salary : 2275 flight_salary : 884.0 layover_cost : 3556.583333333333 deadhead : 0
# Total:  6715.583333333333
# MSP DTW
# 97 ['F46', 'F38', 'DeadHead']
# base_salary : 2275 flight_salary : 870.9999999999999 layover_cost : 163.04166666666666 deadhead : 1260
# Total:  3309.0416666666665
# ATL DTW
# 98 ['F46', 'F1', 'DeadHead']
# base_salary : 2275 flight_salary : 1020.5 layover_cost : 276.79166666666663 deadhead : 1200
# Total:  3572.2916666666665
# MSP DTW
# 99 ['F46', 'F1', 'F37', 'DeadHead']
# base_salary : 2275 flight_salary : 1367.6 layover_cost : 5073.249999999999 deadhead : 1260
# Total:  8715.849999999999
# LGA DTW
# 100 ['F46', 'F1', 'F18', 'DeadHead']
# base_salary : 2275 flight_salary : 1302.6 layover_cost : 5509.291666666666 deadhead : 900
# Total:  9086.891666666666
# ATL DTW
# 101 ['F46', 'F1', 'F18', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 1666.6000000000001 layover_cost : 6988.041666666666 deadhead : 1200
# Total:  10929.641666666666
# ATL DTW
# 102 ['F46', 'F1', 'F18', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 1663.9999999999998 layover_cost : 10628.041666666668 deadhead : 1200
# Total:  14567.041666666668
# 103 ['F46', 'F1', 'F18', 'F8']
# base_salary : 2275 flight_salary : 1575.6 layover_cost : 9755.958333333334 deadhead : 0
# Total:  13606.558333333334
# ATL DTW
# 104 ['F55', 'DeadHead']
# base_salary : 1925 flight_salary : 234.29999999999998 layover_cost : 0.0 deadhead : 1000
# Total:  2159.3
# 105 ['F55', 'F95']
# base_salary : 1925 flight_salary : 446.59999999999997 layover_cost : 4119.5 deadhead : 0
# Total:  6491.1
# 106 ['F55', 'F59']
# base_salary : 1925 flight_salary : 441.09999999999997 layover_cost : 3930.2083333333335 deadhead : 0
# Total:  6296.308333333333
# LGA DTW
# 107 ['F56', 'DeadHead']
# base_salary : 2275 flight_salary : 279.5 layover_cost : 0.0 deadhead : 900
# Total:  2554.5
# ATL DTW
# 108 ['F56', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 643.4999999999999 layover_cost : 2767.9166666666665 deadhead : 1200
# Total:  5686.416666666666
# LGA DTW
# 109 ['F56', 'F79', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 933.4 layover_cost : 8114.166666666666 deadhead : 900
# Total:  11322.566666666666
# MSP DTW
# 110 ['F56', 'F79', 'F48', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 1355.8999999999999 layover_cost : 8337.875 deadhead : 1260
# Total:  11968.775
# 111 ['F56', 'F8']
# base_salary : 2275 flight_salary : 552.5 layover_cost : 75.83333333333333 deadhead : 0
# Total:  2903.3333333333335
# MSP DTW
# 112 ['F56', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 702.0 layover_cost : 2877.875 deadhead : 1260
# Total:  5854.875
# ATL DTW
# 113 ['F66', 'DeadHead']
# base_salary : 2275 flight_salary : 279.5 layover_cost : 0.0 deadhead : 1200
# Total:  2554.5
# ATL DTW
# 114 ['F82', 'DeadHead']
# base_salary : 2275 flight_salary : 279.5 layover_cost : 0.0 deadhead : 1200
# Total:  2554.5
# LGA DTW
# 115 ['F82', 'F49', 'DeadHead']
# base_salary : 2275 flight_salary : 565.5 layover_cost : 382.9583333333333 deadhead : 900
# Total:  3223.4583333333335
# LGA DTW
# 116 ['F82', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 568.1 layover_cost : 5387.958333333333 deadhead : 900
# Total:  8231.058333333332
# SLC DTW
# 117 ['F84', 'DeadHead']
# base_salary : 2275 flight_salary : 548.6 layover_cost : 0.0 deadhead : 2340
# Total:  2823.6
# MSP DTW
# 118 ['F84', 'F38', 'DeadHead']
# base_salary : 2275 flight_salary : 870.9999999999999 layover_cost : 163.04166666666666 deadhead : 1260
# Total:  3309.0416666666665
# LGA DTW
# 119 ['F84', 'F38', 'F65', 'DeadHead']
# base_salary : 2275 flight_salary : 1231.1 layover_cost : 1543.2083333333333 deadhead : 900
# Total:  5049.308333333333
# SLC DTW
# 120 ['F85', 'DeadHead']
# base_salary : 2275 flight_salary : 548.6 layover_cost : 0.0 deadhead : 2340
# Total:  2823.6
# SLC DTW
# 121 ['F89', 'DeadHead']
# base_salary : 2275 flight_salary : 574.6 layover_cost : 0.0 deadhead : 2340
# Total:  2849.6
# 122 ['F89', 'F73']
# base_salary : 2275 flight_salary : 1014.0 layover_cost : 1865.4999999999998 deadhead : 0
# Total:  5154.5
# ATL DTW
# 123 ['F90', 'DeadHead']
# base_salary : 2275 flight_salary : 296.4 layover_cost : 0.0 deadhead : 1200
# Total:  2571.4
# MSP DTW
# 124 ['F100', 'DeadHead']
# base_salary : 1925 flight_salary : 220.0 layover_cost : 0.0 deadhead : 1050
# Total:  2145.0
# 125 ['F100', 'F91']
# base_salary : 1925 flight_salary : 404.79999999999995 layover_cost : 224.58333333333334 deadhead : 0
# Total:  2554.3833333333337
# LGA DTW
# 126 ['F100', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 519.2 layover_cost : 3833.9583333333335 deadhead : 750
# Total:  6278.158333333333
# LGA DTW
# 127 ['F100', 'F57', 'DeadHead']
# base_salary : 1925 flight_salary : 508.2 layover_cost : 57.75 deadhead : 750
# Total:  2490.95
# 128 ['F100', 'F16']
# base_salary : 1925 flight_salary : 404.79999999999995 layover_cost : 224.58333333333334 deadhead : 0
# Total:  2554.3833333333337
# SLC DTW
# 129 ['F100', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 552.1999999999999 layover_cost : 3798.666666666667 deadhead : 1950
# Total:  6275.866666666667
# DTW ATL
# 130 ['F2', 'DeadHead']
# base_salary : 2275 flight_salary : 250.9 layover_cost : 0.0 deadhead : 900
# Total:  2525.9
# SLC ATL
# 131 ['F2', 'F85', 'DeadHead']
# base_salary : 2275 flight_salary : 799.4999999999999 layover_cost : 2756.541666666667 deadhead : 2400
# Total:  5831.041666666667
# 132 ['F2', 'F82']
# base_salary : 2275 flight_salary : 530.4 layover_cost : 1456.0 deadhead : 0
# Total:  4261.4
# 133 ['F2', 'F36']
# base_salary : 2275 flight_salary : 549.9 layover_cost : 341.25 deadhead : 0
# Total:  3166.15
# 134 ['F2', 'F28']
# base_salary : 2275 flight_salary : 534.3000000000001 layover_cost : 2403.9166666666665 deadhead : 0
# Total:  5213.216666666667
# 135 ['F2', 'F7']
# base_salary : 2275 flight_salary : 534.3000000000001 layover_cost : 2403.9166666666665 deadhead : 0
# Total:  5213.216666666667
# LGA ATL
# 136 ['F4', 'DeadHead']
# base_salary : 1925 flight_salary : 228.8 layover_cost : 0.0 deadhead : 1000
# Total:  2153.8
# 137 ['F4', 'F71']
# base_salary : 1925 flight_salary : 525.8000000000001 layover_cost : 285.5416666666667 deadhead : 0
# Total:  2736.3416666666667
# MSP ATL
# 138 ['F4', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 599.5 layover_cost : 208.54166666666666 deadhead : 1150
# Total:  2733.0416666666665
# LGA ATL
# 139 ['F4', 'F67', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 898.7 layover_cost : 4652.083333333333 deadhead : 1000
# Total:  7475.783333333333
# SLC ATL
# 140 ['F4', 'F67', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 931.7 layover_cost : 4616.791666666666 deadhead : 2000
# Total:  7473.491666666666
# DTW ATL
# 141 ['F4', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 465.30000000000007 layover_cost : 1812.7083333333333 deadhead : 750
# Total:  4203.008333333333
# MSP ATL
# 142 ['F4', 'F52', 'F40', 'DeadHead']
# base_salary : 1925 flight_salary : 685.3000000000001 layover_cost : 5880.874999999999 deadhead : 1150
# Total:  8491.175
# DTW ATL
# 143 ['F4', 'F52', 'F40', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 870.1 layover_cost : 10282.708333333332 deadhead : 750
# Total:  13077.808333333332
# DTW ATL
# 144 ['F4', 'F52', 'F40', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 870.1 layover_cost : 10282.708333333332 deadhead : 750
# Total:  13077.808333333332
# SLC ATL
# 145 ['F4', 'F52', 'F40', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 1017.5 layover_cost : 9236.791666666666 deadhead : 2000
# Total:  12179.291666666666
# 146 ['F4', 'F52', 'F11']
# base_salary : 1925 flight_salary : 704.0 layover_cost : 5149.375 deadhead : 0
# Total:  7778.375
# MSP ATL
# 147 ['F4', 'F21', 'DeadHead']
# base_salary : 1925 flight_salary : 591.8 layover_cost : 96.25 deadhead : 1150
# Total:  2613.05
# LGA ATL
# 148 ['F4', 'F21', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 891.0 layover_cost : 4652.083333333334 deadhead : 1000
# Total:  7468.083333333334
# SLC ATL
# 149 ['F4', 'F21', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 924.0 layover_cost : 4616.791666666667 deadhead : 2000
# Total:  7465.791666666667
# 150 ['F4', 'F6']
# base_salary : 1925 flight_salary : 525.8000000000001 layover_cost : 1251.25 deadhead : 0
# Total:  3702.05
# DTW ATL
# 151 ['F9', 'DeadHead']
# base_salary : 2275 flight_salary : 247.0 layover_cost : 0.0 deadhead : 900
# Total:  2522.0
# 152 ['F9', 'F90']
# base_salary : 2275 flight_salary : 543.4 layover_cost : 2551.7916666666665 deadhead : 0
# Total:  5370.191666666667
# SLC ATL
# 153 ['F9', 'F89', 'DeadHead']
# base_salary : 2275 flight_salary : 821.6 layover_cost : 5137.708333333333 deadhead : 2400
# Total:  8234.308333333332
# DTW ATL
# 154 ['F9', 'F89', 'F73', 'DeadHead']
# base_salary : 2275 flight_salary : 1261.0 layover_cost : 7003.208333333333 deadhead : 900
# Total:  10539.208333333332
# SLC ATL
# 155 ['F9', 'F89', 'F73', 'F84', 'DeadHead']
# base_salary : 2275 flight_salary : 1809.5999999999997 layover_cost : 11572.166666666666 deadhead : 2400
# Total:  15656.766666666666
# 156 ['F9', 'F89', 'F73', 'F66']
# base_salary : 2275 flight_salary : 1540.5 layover_cost : 11921.0 deadhead : 0
# Total:  15736.5
# LGA ATL
# 157 ['F9', 'F89', 'F73', 'F56', 'DeadHead']
# base_salary : 2275 flight_salary : 1540.5 layover_cost : 10332.291666666666 deadhead : 1200
# Total:  14147.791666666666
# SLC ATL
# 158 ['F9', 'F89', 'F73', 'F41', 'DeadHead']
# base_salary : 2275 flight_salary : 1809.5999999999997 layover_cost : 11572.166666666666 deadhead : 2400
# Total:  15656.766666666666
# SLC ATL
# 159 ['F9', 'F89', 'F73', 'F12', 'DeadHead']
# base_salary : 2275 flight_salary : 1809.5999999999997 layover_cost : 11572.166666666666 deadhead : 2400
# Total:  15656.766666666666
# LGA ATL
# 160 ['F9', 'F56', 'DeadHead']
# base_salary : 2275 flight_salary : 526.5 layover_cost : 4872.291666666667 deadhead : 1200
# Total:  7673.791666666667
# 161 ['F9', 'F56', 'F79']
# base_salary : 2275 flight_salary : 890.5 layover_cost : 7640.208333333334 deadhead : 0
# Total:  10805.708333333334
# DTW ATL
# 162 ['F9', 'F56', 'F8', 'DeadHead']
# base_salary : 2275 flight_salary : 799.5 layover_cost : 4948.125 deadhead : 900
# Total:  8022.625
# 163 ['F9', 'F56', 'F8', 'F90']
# base_salary : 2275 flight_salary : 1095.8999999999999 layover_cost : 8011.791666666667 deadhead : 0
# Total:  11382.691666666666
# 164 ['F9', 'F56', 'F8', 'F66']
# base_salary : 2275 flight_salary : 1079.0 layover_cost : 6461.0 deadhead : 0
# Total:  9815.0
# MSP ATL
# 165 ['F9', 'F56', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 949.0 layover_cost : 7750.166666666667 deadhead : 1380
# Total:  10974.166666666668
# LGA ATL
# 166 ['F9', 'F34', 'DeadHead']
# base_salary : 2275 flight_salary : 491.4 layover_cost : 1941.3333333333333 deadhead : 1200
# Total:  4707.733333333334
# 167 ['F9', 'F34', 'F79']
# base_salary : 2275 flight_salary : 855.4 layover_cost : 2180.2083333333335 deadhead : 0
# Total:  5310.608333333334
# 168 ['F9', 'F34', 'F76']
# base_salary : 2275 flight_salary : 852.8 layover_cost : 5820.208333333334 deadhead : 0
# Total:  8948.008333333335
# 169 ['F9', 'F34', 'F33']
# base_salary : 2275 flight_salary : 829.4 layover_cost : 4682.708333333334 deadhead : 0
# Total:  7787.108333333334
# DTW ATL
# 170 ['F9', 'F34', 'F8', 'DeadHead']
# base_salary : 2275 flight_salary : 764.4 layover_cost : 4948.125 deadhead : 900
# Total:  7987.525
# 171 ['F9', 'F34', 'F8', 'F90']
# base_salary : 2275 flight_salary : 1060.8 layover_cost : 8011.791666666667 deadhead : 0
# Total:  11347.591666666667
# 172 ['F9', 'F34', 'F8', 'F66']
# base_salary : 2275 flight_salary : 1043.8999999999999 layover_cost : 6461.0 deadhead : 0
# Total:  9779.9
# MSP ATL
# 173 ['F9', 'F34', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 913.8999999999999 layover_cost : 2290.1666666666665 deadhead : 1380
# Total:  5479.066666666666
# SLC ATL
# 174 ['F15', 'DeadHead']
# base_salary : 3220 flight_salary : 800.4 layover_cost : 0.0 deadhead : 3200
# Total:  4020.4
# LGA ATL
# 175 ['F18', 'DeadHead']
# base_salary : 2275 flight_salary : 282.09999999999997 layover_cost : 0.0 deadhead : 1200
# Total:  2557.1
# 176 ['F18', 'F79']
# base_salary : 2275 flight_salary : 646.1 layover_cost : 1478.75 deadhead : 0
# Total:  4399.85
# 177 ['F18', 'F76']
# base_salary : 2275 flight_salary : 643.4999999999999 layover_cost : 5118.75 deadhead : 0
# Total:  8037.25
# DTW ATL
# 178 ['F18', 'F8', 'DeadHead']
# base_salary : 2275 flight_salary : 555.0999999999999 layover_cost : 4246.666666666667 deadhead : 900
# Total:  7076.766666666666
# 179 ['F18', 'F8', 'F90']
# base_salary : 2275 flight_salary : 851.4999999999999 layover_cost : 7310.333333333333 deadhead : 0
# Total:  10436.833333333332
# 180 ['F18', 'F8', 'F66']
# base_salary : 2275 flight_salary : 834.6 layover_cost : 5759.541666666667 deadhead : 0
# Total:  8869.141666666666
# MSP ATL
# 181 ['F18', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 704.6 layover_cost : 1588.7083333333333 deadhead : 1380
# Total:  4568.308333333333
# LGA ATL
# 182 ['F22', 'DeadHead']
# base_salary : 2275 flight_salary : 288.6 layover_cost : 0.0 deadhead : 1200
# Total:  2563.6
# MSP ATL
# 183 ['F29', 'DeadHead']
# base_salary : 2275 flight_salary : 351.0 layover_cost : 0.0 deadhead : 1380
# Total:  2626.0
# SLC ATL
# 184 ['F29', 'F99', 'DeadHead']
# base_salary : 2275 flight_salary : 747.5 layover_cost : 1581.125 deadhead : 2400
# Total:  4603.625
# SLC ATL
# 185 ['F29', 'F63', 'DeadHead']
# base_salary : 2275 flight_salary : 741.0 layover_cost : 5118.75 deadhead : 2400
# Total:  8134.75
# LGA ATL
# 186 ['F29', 'F23', 'DeadHead']
# base_salary : 2275 flight_salary : 699.4000000000001 layover_cost : 4849.541666666667 deadhead : 1200
# Total:  7823.9416666666675
# SLC ATL
# 187 ['F31', 'DeadHead']
# base_salary : 3220 flight_salary : 800.4 layover_cost : 0.0 deadhead : 3200
# Total:  4020.4
# 188 ['F31', 'F62']
# base_salary : 3220 flight_salary : 1481.2 layover_cost : 6606.366666666667 deadhead : 0
# Total:  11307.566666666666
# 189 ['F31', 'F19']
# base_salary : 3220 flight_salary : 1472.0 layover_cost : 944.5333333333333 deadhead : 0
# Total:  5636.533333333333
# DTW ATL
# 190 ['F32', 'DeadHead']
# base_salary : 1925 flight_salary : 220.0 layover_cost : 0.0 deadhead : 750
# Total:  2145.0
# MSP ATL
# 191 ['F32', 'F100', 'DeadHead']
# base_salary : 1925 flight_salary : 440.0 layover_cost : 4042.5 deadhead : 1150
# Total:  6407.5
# DTW ATL
# 192 ['F32', 'F100', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 624.8 layover_cost : 4267.083333333334 deadhead : 750
# Total:  6816.883333333334
# LGA ATL
# 193 ['F32', 'F100', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 739.2 layover_cost : 7876.458333333334 deadhead : 1000
# Total:  10540.658333333333
# LGA ATL
# 194 ['F32', 'F100', 'F57', 'DeadHead']
# base_salary : 1925 flight_salary : 728.2 layover_cost : 4100.25 deadhead : 1000
# Total:  6753.45
# DTW ATL
# 195 ['F32', 'F100', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 624.8 layover_cost : 4267.083333333334 deadhead : 750
# Total:  6816.883333333334
# SLC ATL
# 196 ['F32', 'F100', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 772.1999999999999 layover_cost : 7841.166666666667 deadhead : 2000
# Total:  10538.366666666667
# 197 ['F32', 'F55']
# base_salary : 1925 flight_salary : 454.3 layover_cost : 231.0 deadhead : 0
# Total:  2610.3
# MSP ATL
# 198 ['F32', 'F40', 'DeadHead']
# base_salary : 1925 flight_salary : 440.0 layover_cost : 4485.25 deadhead : 1150
# Total:  6850.25
# DTW ATL
# 199 ['F32', 'F40', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 624.8 layover_cost : 8887.083333333334 deadhead : 750
# Total:  11436.883333333335
# DTW ATL
# 200 ['F32', 'F40', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 624.8 layover_cost : 8887.083333333334 deadhead : 750
# Total:  11436.883333333335
# SLC ATL
# 201 ['F32', 'F40', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 772.1999999999999 layover_cost : 7841.166666666667 deadhead : 2000
# Total:  10538.366666666667
# LGA ATL
# 202 ['F32', 'F20', 'DeadHead']
# base_salary : 1925 flight_salary : 431.2 layover_cost : 2743.125 deadhead : 1000
# Total:  5099.325
# 203 ['F32', 'F20', 'F74']
# base_salary : 1925 flight_salary : 731.5 layover_cost : 3705.625 deadhead : 0
# Total:  6362.125
# DTW ATL
# 204 ['F32', 'F20', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 667.7 layover_cost : 5037.083333333333 deadhead : 750
# Total:  7629.783333333333
# MSP ATL
# 205 ['F32', 'F20', 'F52', 'F40', 'DeadHead']
# base_salary : 1925 flight_salary : 887.7 layover_cost : 9105.25 deadhead : 1150
# Total:  11917.95
# 206 ['F32', 'F20', 'F52', 'F11']
# base_salary : 1925 flight_salary : 906.4 layover_cost : 8373.75 deadhead : 0
# Total:  11205.15
# 207 ['F32', 'F20', 'F51']
# base_salary : 1925 flight_salary : 722.7 layover_cost : 3898.125 deadhead : 0
# Total:  6545.825
# 208 ['F32', 'F20', 'F6']
# base_salary : 1925 flight_salary : 728.2 layover_cost : 4475.625 deadhead : 0
# Total:  7128.825
# 209 ['F32', 'F11']
# base_salary : 1925 flight_salary : 458.7 layover_cost : 3753.75 deadhead : 0
# Total:  6137.45
# LGA ATL
# 210 ['F35', 'DeadHead']
# base_salary : 1925 flight_salary : 228.8 layover_cost : 0.0 deadhead : 1000
# Total:  2153.8
# 211 ['F35', 'F71']
# base_salary : 1925 flight_salary : 525.8000000000001 layover_cost : 4520.541666666667 deadhead : 0
# Total:  6971.341666666667
# MSP ATL
# 212 ['F35', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 599.5 layover_cost : 4443.541666666666 deadhead : 1150
# Total:  6968.041666666666
# LGA ATL
# 213 ['F35', 'F67', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 898.7 layover_cost : 8887.083333333332 deadhead : 1000
# Total:  11710.783333333333
# SLC ATL
# 214 ['F35', 'F67', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 931.7 layover_cost : 8851.791666666666 deadhead : 2000
# Total:  11708.491666666665
# DTW ATL
# 215 ['F35', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 465.30000000000007 layover_cost : 1427.7083333333335 deadhead : 750
# Total:  3818.0083333333337
# MSP ATL
# 216 ['F35', 'F52', 'F40', 'DeadHead']
# base_salary : 1925 flight_salary : 685.3000000000001 layover_cost : 5495.875 deadhead : 1150
# Total:  8106.175
# DTW ATL
# 217 ['F35', 'F52', 'F40', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 870.1 layover_cost : 9897.708333333334 deadhead : 750
# Total:  12692.808333333334
# DTW ATL
# 218 ['F35', 'F52', 'F40', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 870.1 layover_cost : 9897.708333333334 deadhead : 750
# Total:  12692.808333333334
# SLC ATL
# 219 ['F35', 'F52', 'F40', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 1017.5 layover_cost : 8851.791666666666 deadhead : 2000
# Total:  11794.291666666666
# 220 ['F35', 'F52', 'F11']
# base_salary : 1925 flight_salary : 704.0 layover_cost : 4764.375 deadhead : 0
# Total:  7393.375
# MSP ATL
# 221 ['F35', 'F21', 'DeadHead']
# base_salary : 1925 flight_salary : 591.8 layover_cost : 4331.25 deadhead : 1150
# Total:  6848.05
# LGA ATL
# 222 ['F35', 'F21', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 891.0 layover_cost : 8887.083333333334 deadhead : 1000
# Total:  11703.083333333334
# SLC ATL
# 223 ['F35', 'F21', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 924.0 layover_cost : 8851.791666666666 deadhead : 2000
# Total:  11700.791666666666
# MSP ATL
# 224 ['F37', 'DeadHead']
# base_salary : 2275 flight_salary : 347.09999999999997 layover_cost : 0.0 deadhead : 1380
# Total:  2622.1
# LGA ATL
# 225 ['F37', 'F65', 'DeadHead']
# base_salary : 2275 flight_salary : 707.1999999999999 layover_cost : 1929.9583333333333 deadhead : 1200
# Total:  4912.158333333333
# LGA ATL
# 226 ['F48', 'DeadHead']
# base_salary : 2275 flight_salary : 289.9 layover_cost : 0.0 deadhead : 1200
# Total:  2564.9
# MSP ATL
# 227 ['F48', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 712.4000000000001 layover_cost : 223.70833333333331 deadhead : 1380
# Total:  3211.1083333333336
# LGA ATL
# 228 ['F49', 'DeadHead']
# base_salary : 2275 flight_salary : 286.0 layover_cost : 0.0 deadhead : 1200
# Total:  2561.0
# SLC ATL
# 229 ['F53', 'DeadHead']
# base_salary : 3220 flight_salary : 815.1199999999999 layover_cost : 0.0 deadhead : 3200
# Total:  4035.12
# 230 ['F53', 'F62']
# base_salary : 3220 flight_salary : 1495.9199999999998 layover_cost : 193.2 deadhead : 0
# Total:  4909.12
# 231 ['F53', 'F58']
# base_salary : 3220 flight_salary : 1468.32 layover_cost : 3037.5333333333333 deadhead : 0
# Total:  7725.853333333333
# DTW ATL
# 232 ['F59', 'DeadHead']
# base_salary : 1925 flight_salary : 206.79999999999998 layover_cost : 0.0 deadhead : 750
# Total:  2131.8
# MSP ATL
# 233 ['F59', 'F40', 'DeadHead']
# base_salary : 1925 flight_salary : 426.8 layover_cost : 324.0416666666667 deadhead : 1150
# Total:  2675.8416666666667
# DTW ATL
# 234 ['F59', 'F40', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 611.5999999999999 layover_cost : 4725.875 deadhead : 750
# Total:  7262.475
# DTW ATL
# 235 ['F59', 'F40', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 611.5999999999999 layover_cost : 4725.875 deadhead : 750
# Total:  7262.475
# SLC ATL
# 236 ['F59', 'F40', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 759.0 layover_cost : 3679.9583333333335 deadhead : 2000
# Total:  6363.958333333334
# 237 ['F59', 'F11']
# base_salary : 1925 flight_salary : 445.5 layover_cost : 4212.541666666667 deadhead : 0
# Total:  6583.041666666667
# DTW ATL
# 238 ['F61', 'DeadHead']
# base_salary : 2275 flight_salary : 250.9 layover_cost : 0.0 deadhead : 900
# Total:  2525.9
# SLC ATL
# 239 ['F61', 'F85', 'DeadHead']
# base_salary : 2275 flight_salary : 799.4999999999999 layover_cost : 2756.541666666667 deadhead : 2400
# Total:  5831.041666666667
# 240 ['F61', 'F82']
# base_salary : 2275 flight_salary : 530.4 layover_cost : 1456.0 deadhead : 0
# Total:  4261.4
# 241 ['F61', 'F36']
# base_salary : 2275 flight_salary : 549.9 layover_cost : 341.25 deadhead : 0
# Total:  3166.15
# 242 ['F61', 'F28']
# base_salary : 2275 flight_salary : 534.3000000000001 layover_cost : 2403.9166666666665 deadhead : 0
# Total:  5213.216666666667
# 243 ['F61', 'F7']
# base_salary : 2275 flight_salary : 534.3000000000001 layover_cost : 2403.9166666666665 deadhead : 0
# Total:  5213.216666666667
# LGA ATL
# 244 ['F64', 'DeadHead']
# base_salary : 1925 flight_salary : 234.29999999999998 layover_cost : 0.0 deadhead : 1000
# Total:  2159.3
# MSP ATL
# 245 ['F64', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 605.0 layover_cost : 4058.5416666666665 deadhead : 1150
# Total:  6588.541666666666
# LGA ATL
# 246 ['F64', 'F67', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 904.2 layover_cost : 8502.083333333332 deadhead : 1000
# Total:  11331.283333333333
# SLC ATL
# 247 ['F64', 'F67', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 937.1999999999999 layover_cost : 8466.791666666666 deadhead : 2000
# Total:  11328.991666666665
# DTW ATL
# 248 ['F64', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 470.79999999999995 layover_cost : 1042.7083333333335 deadhead : 750
# Total:  3438.5083333333337
# MSP ATL
# 249 ['F64', 'F52', 'F40', 'DeadHead']
# base_salary : 1925 flight_salary : 690.8 layover_cost : 5110.875 deadhead : 1150
# Total:  7726.675
# DTW ATL
# 250 ['F64', 'F52', 'F40', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 875.5999999999999 layover_cost : 9512.708333333334 deadhead : 750
# Total:  12313.308333333334
# DTW ATL
# 251 ['F64', 'F52', 'F40', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 875.5999999999999 layover_cost : 9512.708333333334 deadhead : 750
# Total:  12313.308333333334
# SLC ATL
# 252 ['F64', 'F52', 'F40', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 1022.9999999999999 layover_cost : 8466.791666666666 deadhead : 2000
# Total:  11414.791666666666
# 253 ['F64', 'F52', 'F11']
# base_salary : 1925 flight_salary : 709.4999999999999 layover_cost : 4379.375 deadhead : 0
# Total:  7013.875
# SLC ATL
# 254 ['F81', 'DeadHead']
# base_salary : 3220 flight_salary : 800.4 layover_cost : 0.0 deadhead : 3200
# Total:  4020.4
# LGA ATL
# 255 ['F92', 'DeadHead']
# base_salary : 2275 flight_salary : 282.09999999999997 layover_cost : 0.0 deadhead : 1200
# Total:  2557.1
# DTW ATL
# 256 ['F92', 'F87', 'DeadHead']
# base_salary : 2275 flight_salary : 565.5 layover_cost : 4781.291666666666 deadhead : 900
# Total:  7621.791666666666
# SLC ATL
# 257 ['F92', 'F87', 'F85', 'DeadHead']
# base_salary : 2275 flight_salary : 1114.1000000000001 layover_cost : 7060.083333333333 deadhead : 2400
# Total:  10449.183333333334
# 258 ['F92', 'F87', 'F36']
# base_salary : 2275 flight_salary : 864.4999999999999 layover_cost : 10104.791666666666 deadhead : 0
# Total:  13244.291666666666
# 259 ['F92', 'F87', 'F28']
# base_salary : 2275 flight_salary : 848.8999999999999 layover_cost : 6707.458333333334 deadhead : 0
# Total:  9831.358333333334
# 260 ['F92', 'F87', 'F25']
# base_salary : 2275 flight_salary : 845.0 layover_cost : 5175.625 deadhead : 0
# Total:  8295.625
# 261 ['F92', 'F87', 'F7']
# base_salary : 2275 flight_salary : 848.8999999999999 layover_cost : 6707.458333333334 deadhead : 0
# Total:  9831.358333333334
# MSP ATL
# 262 ['F92', 'F83', 'DeadHead']
# base_salary : 2275 flight_salary : 694.1999999999999 layover_cost : 3981.25 deadhead : 1380
# Total:  6950.45
# SLC ATL
# 263 ['F92', 'F83', 'F99', 'DeadHead']
# base_salary : 2275 flight_salary : 1090.7 layover_cost : 7325.500000000001 deadhead : 2400
# Total:  10691.2
# SLC ATL
# 264 ['F92', 'F83', 'F68', 'DeadHead']
# base_salary : 2275 flight_salary : 1084.2 layover_cost : 5403.125 deadhead : 2400
# Total:  8762.325
# SLC ATL
# 265 ['F92', 'F83', 'F63', 'DeadHead']
# base_salary : 2275 flight_salary : 1084.2 layover_cost : 5403.125 deadhead : 2400
# Total:  8762.325
# 266 ['F92', 'F75']
# base_salary : 2275 flight_salary : 635.7 layover_cost : 5342.458333333334 deadhead : 0
# Total:  8253.158333333333
# 267 ['F92', 'F17']
# base_salary : 2275 flight_salary : 637.0 layover_cost : 4663.75 deadhead : 0
# Total:  7575.75
# DTW ATL
# 268 ['F95', 'DeadHead']
# base_salary : 1925 flight_salary : 212.29999999999998 layover_cost : 0.0 deadhead : 750
# Total:  2137.3
# SLC ATL
# 269 ['F96', 'DeadHead']
# base_salary : 2275 flight_salary : 682.5 layover_cost : 0.0 deadhead : 2400
# Total:  2957.5
# LGA ATL
# 270 ['F97', 'DeadHead']
# base_salary : 1925 flight_salary : 228.8 layover_cost : 0.0 deadhead : 1000
# Total:  2153.8
# MSP ATL
# 271 ['F97', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 599.5 layover_cost : 4443.541666666666 deadhead : 1150
# Total:  6968.041666666666
# LGA ATL
# 272 ['F97', 'F67', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 898.7 layover_cost : 8887.083333333332 deadhead : 1000
# Total:  11710.783333333333
# SLC ATL
# 273 ['F97', 'F67', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 931.7 layover_cost : 8851.791666666666 deadhead : 2000
# Total:  11708.491666666665
# DTW ATL
# 274 ['F97', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 465.30000000000007 layover_cost : 1427.7083333333335 deadhead : 750
# Total:  3818.0083333333337
# MSP ATL
# 275 ['F97', 'F52', 'F40', 'DeadHead']
# base_salary : 1925 flight_salary : 685.3000000000001 layover_cost : 5495.875 deadhead : 1150
# Total:  8106.175
# DTW ATL
# 276 ['F97', 'F52', 'F40', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 870.1 layover_cost : 9897.708333333334 deadhead : 750
# Total:  12692.808333333334
# DTW ATL
# 277 ['F97', 'F52', 'F40', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 870.1 layover_cost : 9897.708333333334 deadhead : 750
# Total:  12692.808333333334
# SLC ATL
# 278 ['F97', 'F52', 'F40', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 1017.5 layover_cost : 8851.791666666666 deadhead : 2000
# Total:  11794.291666666666
# 279 ['F97', 'F52', 'F11']
# base_salary : 1925 flight_salary : 704.0 layover_cost : 4764.375 deadhead : 0
# Total:  7393.375
# LGA ATL
# 280 ['F98', 'DeadHead']
# base_salary : 1925 flight_salary : 234.29999999999998 layover_cost : 0.0 deadhead : 1000
# Total:  2159.3
# 281 ['F98', 'F71']
# base_salary : 1925 flight_salary : 531.3 layover_cost : 4135.541666666667 deadhead : 0
# Total:  6591.841666666667
# MSP ATL
# 282 ['F98', 'F67', 'DeadHead']
# base_salary : 1925 flight_salary : 605.0 layover_cost : 4058.5416666666665 deadhead : 1150
# Total:  6588.541666666666
# LGA ATL
# 283 ['F98', 'F67', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 904.2 layover_cost : 8502.083333333332 deadhead : 1000
# Total:  11331.283333333333
# SLC ATL
# 284 ['F98', 'F67', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 937.1999999999999 layover_cost : 8466.791666666666 deadhead : 2000
# Total:  11328.991666666665
# DTW ATL
# 285 ['F98', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 470.79999999999995 layover_cost : 1042.7083333333335 deadhead : 750
# Total:  3438.5083333333337
# MSP ATL
# 286 ['F98', 'F52', 'F40', 'DeadHead']
# base_salary : 1925 flight_salary : 690.8 layover_cost : 5110.875 deadhead : 1150
# Total:  7726.675
# DTW ATL
# 287 ['F98', 'F52', 'F40', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 875.5999999999999 layover_cost : 9512.708333333334 deadhead : 750
# Total:  12313.308333333334
# DTW ATL
# 288 ['F98', 'F52', 'F40', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 875.5999999999999 layover_cost : 9512.708333333334 deadhead : 750
# Total:  12313.308333333334
# SLC ATL
# 289 ['F98', 'F52', 'F40', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 1022.9999999999999 layover_cost : 8466.791666666666 deadhead : 2000
# Total:  11414.791666666666
# 290 ['F98', 'F52', 'F11']
# base_salary : 1925 flight_salary : 709.4999999999999 layover_cost : 4379.375 deadhead : 0
# Total:  7013.875
# MSP ATL
# 291 ['F98', 'F21', 'DeadHead']
# base_salary : 1925 flight_salary : 597.3 layover_cost : 3946.25 deadhead : 1150
# Total:  6468.55
# LGA ATL
# 292 ['F98', 'F21', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 896.5 layover_cost : 8502.083333333334 deadhead : 1000
# Total:  11323.583333333334
# SLC ATL
# 293 ['F98', 'F21', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 929.4999999999999 layover_cost : 8466.791666666666 deadhead : 2000
# Total:  11321.291666666666
# ATL SLC
# 294 ['F1', 'DeadHead']
# base_salary : 2275 flight_salary : 471.9 layover_cost : 0.0 deadhead : 2280
# Total:  2746.9
# MSP SLC
# 295 ['F1', 'F37', 'DeadHead']
# base_salary : 2275 flight_salary : 819.0 layover_cost : 4796.458333333333 deadhead : 1980
# Total:  7890.458333333333
# LGA SLC
# 296 ['F1', 'F37', 'F65', 'DeadHead']
# base_salary : 2275 flight_salary : 1179.1000000000001 layover_cost : 6726.416666666666 deadhead : 1500
# Total:  10180.516666666666
# LGA SLC
# 297 ['F1', 'F18', 'DeadHead']
# base_salary : 2275 flight_salary : 754.0 layover_cost : 5232.5 deadhead : 1500
# Total:  8261.5
# ATL SLC
# 298 ['F1', 'F18', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 1118.0 layover_cost : 6711.25 deadhead : 2280
# Total:  10104.25
# LGA SLC
# 299 ['F1', 'F18', 'F79', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 1407.9 layover_cost : 12057.5 deadhead : 1500
# Total:  15740.4
# ATL SLC
# 300 ['F1', 'F18', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 1115.4 layover_cost : 10351.25 deadhead : 2280
# Total:  13741.65
# LGA SLC
# 301 ['F1', 'F18', 'F76', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 1405.3 layover_cost : 12057.5 deadhead : 1500
# Total:  15737.8
# DTW SLC
# 302 ['F1', 'F18', 'F8', 'DeadHead']
# base_salary : 2275 flight_salary : 1027.0 layover_cost : 9479.166666666668 deadhead : 2340
# Total:  12781.166666666668
# ATL SLC
# 303 ['F1', 'F18', 'F8', 'F90', 'DeadHead']
# base_salary : 2275 flight_salary : 1323.3999999999999 layover_cost : 12542.833333333334 deadhead : 2280
# Total:  16141.233333333334
# ATL SLC
# 304 ['F1', 'F18', 'F8', 'F66', 'DeadHead']
# base_salary : 2275 flight_salary : 1306.5 layover_cost : 10992.041666666668 deadhead : 2280
# Total:  14573.541666666668
# MSP SLC
# 305 ['F1', 'F18', 'F5', 'DeadHead']
# base_salary : 2275 flight_salary : 1176.5 layover_cost : 6821.208333333334 deadhead : 1980
# Total:  10272.708333333334
# ATL SLC
# 306 ['F19', 'DeadHead']
# base_salary : 3220 flight_salary : 671.6 layover_cost : 0.0 deadhead : 3040
# Total:  3891.6
# 307 ['F19', 'F81']
# base_salary : 3220 flight_salary : 1472.0 layover_cost : 6783.466666666666 deadhead : 0
# Total:  11475.466666666667
# 308 ['F19', 'F15']
# base_salary : 3220 flight_salary : 1472.0 layover_cost : 6783.466666666666 deadhead : 0
# Total:  11475.466666666667
# ATL SLC
# 309 ['F24', 'DeadHead']
# base_salary : 3220 flight_salary : 671.6 layover_cost : 0.0 deadhead : 3040
# Total:  3891.6
# 310 ['F24', 'F81']
# base_salary : 3220 flight_salary : 1472.0 layover_cost : 6783.466666666666 deadhead : 0
# Total:  11475.466666666667
# 311 ['F24', 'F53']
# base_salary : 3220 flight_salary : 1486.72 layover_cost : 5468.633333333333 deadhead : 0
# Total:  10175.353333333333
# 312 ['F24', 'F31']
# base_salary : 3220 flight_salary : 1472.0 layover_cost : 6783.466666666666 deadhead : 0
# Total:  11475.466666666667
# 313 ['F24', 'F15']
# base_salary : 3220 flight_salary : 1472.0 layover_cost : 6783.466666666666 deadhead : 0
# Total:  11475.466666666667
# ATL SLC
# 314 ['F27', 'DeadHead']
# base_salary : 3220 flight_salary : 491.28 layover_cost : 0.0 deadhead : 3040
# Total:  3711.2799999999997
# 315 ['F27', 'F81']
# base_salary : 3220 flight_salary : 1291.6799999999998 layover_cost : 2629.6666666666665 deadhead : 0
# Total:  7141.346666666666
# 316 ['F27', 'F31']
# base_salary : 3220 flight_salary : 1291.6799999999998 layover_cost : 2629.6666666666665 deadhead : 0
# Total:  7141.346666666666
# 317 ['F27', 'F15']
# base_salary : 3220 flight_salary : 1291.6799999999998 layover_cost : 2629.6666666666665 deadhead : 0
# Total:  7141.346666666666
# MSP SLC
# 318 ['F38', 'DeadHead']
# base_salary : 2275 flight_salary : 322.4 layover_cost : 0.0 deadhead : 1980
# Total:  2597.4
# LGA SLC
# 319 ['F38', 'F65', 'DeadHead']
# base_salary : 2275 flight_salary : 682.5 layover_cost : 1380.1666666666665 deadhead : 1500
# Total:  4337.666666666666
# MSP SLC
# 320 ['F45', 'DeadHead']
# base_salary : 1925 flight_salary : 401.5 layover_cost : 0.0 deadhead : 1650
# Total:  2326.5
# DTW SLC
# 321 ['F45', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 586.3 layover_cost : 3176.25 deadhead : 1950
# Total:  5687.55
# LGA SLC
# 322 ['F45', 'F77', 'DeadHead']
# base_salary : 1925 flight_salary : 700.7 layover_cost : 2165.625 deadhead : 1250
# Total:  4791.325
# LGA SLC
# 323 ['F45', 'F57', 'DeadHead']
# ...
# base_salary : 2275 flight_salary : 802.1 layover_cost : 1421.875 deadhead : 2340
# Total:  4498.975
# DTW LGA
# 548 ['F87', 'DeadHead']
# base_salary : 2275 flight_salary : 283.40000000000003 layover_cost : 0.0 deadhead : 900
# Total:  2558.4
# SLC LGA
# 549 ['F87', 'F85', 'DeadHead']
# base_salary : 2275 flight_salary : 832.0 layover_cost : 2278.791666666667 deadhead : 2340
# Total:  5385.791666666667
# ATL LGA
# 550 ['F87', 'F36', 'DeadHead']
# base_salary : 2275 flight_salary : 582.4000000000001 layover_cost : 5323.5 deadhead : 600
# Total:  8180.9
# ATL LGA
# 551 ['F87', 'F28', 'DeadHead']
# base_salary : 2275 flight_salary : 566.8000000000001 layover_cost : 1926.1666666666667 deadhead : 600
# Total:  4767.966666666667
# 552 ['F87', 'F28', 'F22']
# base_salary : 2275 flight_salary : 855.4 layover_cost : 6366.208333333334 deadhead : 0
# Total:  9496.608333333334
# ATL LGA
# 553 ['F87', 'F25', 'DeadHead']
# base_salary : 2275 flight_salary : 562.9 layover_cost : 394.33333333333337 deadhead : 600
# Total:  3232.2333333333336
# ATL LGA
# 554 ['F87', 'F7', 'DeadHead']
# base_salary : 2275 flight_salary : 566.8000000000001 layover_cost : 1926.1666666666667 deadhead : 600
# Total:  4767.966666666667
# ATL LGA
# 555 ['F93', 'DeadHead']
# base_salary : 1925 flight_salary : 297.0 layover_cost : 0.0 deadhead : 500
# Total:  2222.0
# 556 ['F93', 'F98']
# base_salary : 1925 flight_salary : 531.3 layover_cost : 3753.75 deadhead : 0
# Total:  6210.05
# 557 ['F93', 'F97']
# base_salary : 1925 flight_salary : 525.8000000000001 layover_cost : 3368.75 deadhead : 0
# Total:  5819.55
# DTW LGA
# 558 ['F93', 'F95', 'DeadHead']
# base_salary : 1925 flight_salary : 509.3 layover_cost : 4109.875 deadhead : 750
# Total:  6544.175
# 559 ['F93', 'F64']
# base_salary : 1925 flight_salary : 531.3 layover_cost : 3753.75 deadhead : 0
# Total:  6210.05
# DTW LGA
# 560 ['F93', 'F59', 'DeadHead']
# base_salary : 1925 flight_salary : 503.8 layover_cost : 3920.5833333333335 deadhead : 750
# Total:  6349.383333333333
# MSP LGA
# 561 ['F93', 'F59', 'F40', 'DeadHead']
# base_salary : 1925 flight_salary : 723.8 layover_cost : 4244.625 deadhead : 1500
# Total:  6893.425
# DTW LGA
# 562 ['F93', 'F59', 'F40', 'F91', 'DeadHead']
# base_salary : 1925 flight_salary : 908.6 layover_cost : 8646.458333333334 deadhead : 750
# Total:  11480.058333333334
# DTW LGA
# 563 ['F93', 'F59', 'F40', 'F16', 'DeadHead']
# base_salary : 1925 flight_salary : 908.6 layover_cost : 8646.458333333334 deadhead : 750
# Total:  11480.058333333334
# SLC LGA
# 564 ['F93', 'F59', 'F40', 'F3', 'DeadHead']
# base_salary : 1925 flight_salary : 1056.0 layover_cost : 7600.541666666667 deadhead : 1950
# Total:  10581.541666666668
# ATL LGA
# 565 ['F93', 'F59', 'F11', 'DeadHead']
# base_salary : 1925 flight_salary : 742.5 layover_cost : 8133.125 deadhead : 500
# Total:  10800.625
# 566 ['F93', 'F35']
# base_salary : 1925 flight_salary : 525.8000000000001 layover_cost : 3368.75 deadhead : 0
# Total:  5819.55
# 567 ['F93', 'F4']
# base_salary : 1925 flight_salary : 525.8000000000001 layover_cost : 2983.75 deadhead : 0
# Total:  5434.55
# SLC MSP
# 568 ['F3', 'DeadHead']
# base_salary : 1925 flight_salary : 332.2 layover_cost : 0.0 deadhead : 1650
# Total:  2257.2
# DTW MSP
# 569 ['F13', 'DeadHead']
# base_salary : 2275 flight_salary : 227.5 layover_cost : 0.0 deadhead : 1080
# Total:  2502.5
# SLC MSP
# 570 ['F13', 'F85', 'DeadHead']
# base_salary : 2275 flight_salary : 776.1 layover_cost : 2339.4583333333335 deadhead : 1980
# Total:  5390.558333333333
# ATL MSP
# 571 ['F13', 'F36', 'DeadHead']
# base_salary : 2275 flight_salary : 526.5 layover_cost : 5384.166666666667 deadhead : 1380
# Total:  8185.666666666667
# ATL MSP
# 572 ['F13', 'F28', 'DeadHead']
# base_salary : 2275 flight_salary : 510.90000000000003 layover_cost : 1986.8333333333333 deadhead : 1380
# Total:  4772.733333333334
# LGA MSP
# 573 ['F13', 'F28', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 799.5 layover_cost : 6426.875 deadhead : 1800
# Total:  9501.375
# ATL MSP
# 574 ['F13', 'F7', 'DeadHead']
# base_salary : 2275 flight_salary : 510.90000000000003 layover_cost : 1986.8333333333333 deadhead : 1380
# Total:  4772.733333333334
# DTW MSP
# 575 ['F16', 'DeadHead']
# base_salary : 1925 flight_salary : 184.79999999999998 layover_cost : 0.0 deadhead : 900
# Total:  2109.8
# LGA MSP
# 576 ['F23', 'DeadHead']
# base_salary : 2275 flight_salary : 348.40000000000003 layover_cost : 0.0 deadhead : 1800
# Total:  2623.4
# SLC MSP
# 577 ['F42', 'DeadHead']
# base_salary : 2275 flight_salary : 392.6 layover_cost : 0.0 deadhead : 1980
# Total:  2667.6
# DTW MSP
# 578 ['F42', 'F69', 'DeadHead']
# base_salary : 2275 flight_salary : 728.0 layover_cost : 3488.3333333333335 deadhead : 1080
# Total:  6491.333333333334
# ATL MSP
# 579 ['F42', 'F69', 'F90', 'DeadHead']
# base_salary : 2275 flight_salary : 1024.3999999999999 layover_cost : 7291.374999999999 deadhead : 1380
# Total:  10590.774999999998
# SLC MSP
# 580 ['F42', 'F69', 'F84', 'DeadHead']
# base_salary : 2275 flight_salary : 1276.6000000000001 layover_cost : 5391.750000000001 deadhead : 1980
# Total:  8943.350000000002
# 581 ['F42', 'F69', 'F84', 'F38']
# base_salary : 2275 flight_salary : 1599.0 layover_cost : 5554.791666666667 deadhead : 0
# Total:  9428.791666666668
# ATL MSP
# 582 ['F42', 'F69', 'F66', 'DeadHead']
# base_salary : 2275 flight_salary : 1007.5 layover_cost : 5740.583333333334 deadhead : 1380
# Total:  9023.083333333334
# SLC MSP
# 583 ['F42', 'F69', 'F41', 'DeadHead']
# base_salary : 2275 flight_salary : 1276.6000000000001 layover_cost : 5391.750000000001 deadhead : 1980
# Total:  8943.350000000002
# SLC MSP
# 584 ['F42', 'F69', 'F12', 'DeadHead']
# base_salary : 2275 flight_salary : 1276.6000000000001 layover_cost : 5391.750000000001 deadhead : 1980
# Total:  8943.350000000002
# 585 ['F42', 'F38']
# base_salary : 2275 flight_salary : 715.0 layover_cost : 94.79166666666667 deadhead : 0
# Total:  3084.7916666666665
# ATL MSP
# 586 ['F42', 'F1', 'DeadHead']
# base_salary : 2275 flight_salary : 864.5 layover_cost : 208.54166666666666 deadhead : 1380
# Total:  3348.0416666666665
# 587 ['F42', 'F1', 'F37']
# base_salary : 2275 flight_salary : 1211.6000000000001 layover_cost : 5005.0 deadhead : 0
# Total:  8491.6
# LGA MSP
# 588 ['F42', 'F1', 'F18', 'DeadHead']
# base_salary : 2275 flight_salary : 1146.6000000000001 layover_cost : 5441.041666666667 deadhead : 1800
# Total:  8862.641666666666
# ATL MSP
# 589 ['F42', 'F1', 'F18', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 1510.6000000000001 layover_cost : 6919.791666666667 deadhead : 1380
# Total:  10705.391666666666
# ATL MSP
# 590 ['F42', 'F1', 'F18', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 1508.0 layover_cost : 10559.791666666668 deadhead : 1380
# Total:  14342.791666666668
# DTW MSP
# 591 ['F42', 'F1', 'F18', 'F8', 'DeadHead']
# base_salary : 2275 flight_salary : 1419.6 layover_cost : 9687.708333333334 deadhead : 1080
# Total:  13382.308333333334
# LGA MSP
# 592 ['F43', 'DeadHead']
# base_salary : 1925 flight_salary : 293.7 layover_cost : 0.0 deadhead : 1500
# Total:  2218.7
# ATL MSP
# 593 ['F43', 'F71', 'DeadHead']
# base_salary : 1925 flight_salary : 590.7 layover_cost : 205.33333333333334 deadhead : 1150
# Total:  2721.0333333333333
# 594 ['F43', 'F67']
# base_salary : 1925 flight_salary : 664.4 layover_cost : 128.33333333333331 deadhead : 0
# Total:  2717.7333333333336
# DTW MSP
# 595 ['F43', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 530.2 layover_cost : 1732.5 deadhead : 900
# Total:  4187.7
# 596 ['F43', 'F52', 'F40']
# base_salary : 1925 flight_salary : 750.2 layover_cost : 5800.666666666667 deadhead : 0
# Total:  8475.866666666667
# ATL MSP
# 597 ['F43', 'F52', 'F11', 'DeadHead']
# base_salary : 1925 flight_salary : 768.9 layover_cost : 5069.166666666666 deadhead : 1150
# Total:  7763.066666666666
# 598 ['F43', 'F21']
# base_salary : 1925 flight_salary : 656.6999999999999 layover_cost : 16.041666666666664 deadhead : 0
# Total:  2597.7416666666663
# ATL MSP
# 599 ['F43', 'F6', 'DeadHead']
# base_salary : 1925 flight_salary : 590.7 layover_cost : 1171.0416666666665 deadhead : 1150
# Total:  3686.7416666666663
# LGA MSP
# 600 ['F43', 'F6', 'F97', 'DeadHead']
# base_salary : 1925 flight_salary : 819.5 layover_cost : 4924.791666666666 deadhead : 1500
# Total:  7669.291666666666
# 601 ['F43', 'F6', 'F97', 'F67']
# base_salary : 1925 flight_salary : 1190.2 layover_cost : 9368.333333333332 deadhead : 0
# Total:  12483.533333333333
# DTW MSP
# 602 ['F43', 'F6', 'F97', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 1056.0 layover_cost : 6352.5 deadhead : 900
# Total:  9333.5
# DTW MSP
# 603 ['F43', 'F6', 'F95', 'DeadHead']
# base_salary : 1925 flight_salary : 803.0 layover_cost : 5665.916666666667 deadhead : 900
# Total:  8393.916666666668
# LGA MSP
# 604 ['F43', 'F6', 'F64', 'DeadHead']
# base_salary : 1925 flight_salary : 825.0 layover_cost : 5309.791666666666 deadhead : 1500
# Total:  8059.791666666666
# 605 ['F43', 'F6', 'F64', 'F67']
# base_salary : 1925 flight_salary : 1195.7 layover_cost : 9368.333333333332 deadhead : 0
# Total:  12489.033333333333
# DTW MSP
# 606 ['F43', 'F6', 'F64', 'F52', 'DeadHead']
# base_salary : 1925 flight_salary : 1061.5 layover_cost : 6352.5 deadhead : 900
# Total:  9339.0
# DTW MSP
# 607 ['F43', 'F6', 'F59', 'DeadHead']
# base_salary : 1925 flight_salary : 797.5 layover_cost : 5476.625 deadhead : 900
# Total:  8199.125
# 608 ['F43', 'F6', 'F59', 'F40']
# base_salary : 1925 flight_salary : 1017.5 layover_cost : 5800.666666666667 deadhead : 0
# Total:  8743.166666666668
# ATL MSP
# 609 ['F43', 'F6', 'F59', 'F11', 'DeadHead']
# base_salary : 1925 flight_salary : 1036.2 layover_cost : 9689.166666666666 deadhead : 1150
# Total:  12650.366666666665
# SLC MSP
# 610 ['F44', 'DeadHead']
# base_salary : 1925 flight_salary : 346.5 layover_cost : 0.0 deadhead : 1650
# Total:  2271.5
# 611 ['F44', 'F54']
# base_salary : 1925 flight_salary : 643.5 layover_cost : 208.54166666666666 deadhead : 0
# Total:  2777.0416666666665
# 612 ['F44', 'F50']
# base_salary : 1925 flight_salary : 748.0 layover_cost : 2515.3333333333335 deadhead : 0
# Total:  5188.333333333334
# 613 ['F44', 'F45']
# base_salary : 1925 flight_salary : 748.0 layover_cost : 2515.3333333333335 deadhead : 0
# Total:  5188.333333333334
# LGA MSP
# 614 ['F47', 'DeadHead']
# base_salary : 2275 flight_salary : 347.09999999999997 layover_cost : 0.0 deadhead : 1800
# Total:  2622.1
# ATL MSP
# 615 ['F47', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 708.4999999999999 layover_cost : 4743.375 deadhead : 1380
# Total:  7726.875
# LGA MSP
# 616 ['F47', 'F76', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 998.4 layover_cost : 6449.625 deadhead : 1800
# Total:  9723.025
# 617 ['F47', 'F76', 'F48', 'F5']
# base_salary : 2275 flight_salary : 1420.8999999999999 layover_cost : 6673.333333333334 deadhead : 0
# Total:  10369.233333333334
# ATL MSP
# 618 ['F47', 'F33', 'DeadHead']
# base_salary : 2275 flight_salary : 685.0999999999999 layover_cost : 3605.875 deadhead : 1380
# Total:  6565.975
# LGA MSP
# 619 ['F47', 'F33', 'F48', 'DeadHead']
# base_salary : 2275 flight_salary : 975.0 layover_cost : 6449.625 deadhead : 1800
# Total:  9699.625
# 620 ['F47', 'F33', 'F48', 'F5']
# base_salary : 2275 flight_salary : 1397.5 layover_cost : 6673.333333333334 deadhead : 0
# Total:  10345.833333333334
# LGA MSP
# 621 ['F47', 'F33', 'F18', 'DeadHead']
# base_salary : 2275 flight_salary : 967.1999999999999 layover_cost : 5084.625 deadhead : 1800
# Total:  8326.825
# ATL MSP
# 622 ['F47', 'F33', 'F18', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 1331.1999999999998 layover_cost : 6563.375 deadhead : 1380
# Total:  10169.575
# ATL MSP
# 623 ['F47', 'F33', 'F18', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 1328.6 layover_cost : 10203.375 deadhead : 1380
# Total:  13806.975
# DTW MSP
# 624 ['F47', 'F33', 'F18', 'F8', 'DeadHead']
# base_salary : 2275 flight_salary : 1240.1999999999998 layover_cost : 9331.291666666666 deadhead : 1080
# Total:  12846.491666666665
# 625 ['F47', 'F33', 'F18', 'F5']
# base_salary : 2275 flight_salary : 1389.7 layover_cost : 6673.333333333334 deadhead : 0
# Total:  10338.033333333333
# DTW MSP
# 626 ['F47', 'F8', 'DeadHead']
# base_salary : 2275 flight_salary : 620.0999999999999 layover_cost : 3871.2916666666665 deadhead : 1080
# Total:  6766.391666666666
# ATL MSP
# 627 ['F47', 'F8', 'F90', 'DeadHead']
# base_salary : 2275 flight_salary : 916.4999999999999 layover_cost : 6934.958333333334 deadhead : 1380
# Total:  10126.458333333334
# ATL MSP
# 628 ['F47', 'F8', 'F66', 'DeadHead']
# base_salary : 2275 flight_salary : 899.6 layover_cost : 5384.166666666666 deadhead : 1380
# Total:  8558.766666666666
# LGA MSP
# 629 ['F57', 'DeadHead']
# base_salary : 1925 flight_salary : 288.2 layover_cost : 0.0 deadhead : 1500
# Total:  2213.2
# SLC MSP
# 630 ['F63', 'DeadHead']
# base_salary : 2275 flight_salary : 390.0 layover_cost : 0.0 deadhead : 1980
# Total:  2665.0
# LGA MSP
# 631 ['F65', 'DeadHead']
# base_salary : 2275 flight_salary : 360.1 layover_cost : 0.0 deadhead : 1800
# Total:  2635.1
# SLC MSP
# 632 ['F68', 'DeadHead']
# base_salary : 2275 flight_salary : 390.0 layover_cost : 0.0 deadhead : 1980
# Total:  2665.0
# LGA MSP
# 633 ['F77', 'DeadHead']
# base_salary : 1925 flight_salary : 299.20000000000005 layover_cost : 0.0 deadhead : 1500
# Total:  2224.2
# LGA MSP
# 634 ['F88', 'DeadHead']
# base_salary : 2275 flight_salary : 348.40000000000003 layover_cost : 0.0 deadhead : 1800
# Total:  2623.4
# ATL MSP
# 635 ['F88', 'F75', 'DeadHead']
# base_salary : 2275 flight_salary : 702.0 layover_cost : 208.54166666666666 deadhead : 1380
# Total:  3185.5416666666665
# LGA MSP
# 636 ['F88', 'F75', 'F22', 'DeadHead']
# base_salary : 2275 flight_salary : 990.6000000000001 layover_cost : 553.5833333333333 deadhead : 1800
# Total:  3819.1833333333334
# DTW MSP
# 637 ['F91', 'DeadHead']
# base_salary : 1925 flight_salary : 184.79999999999998 layover_cost : 0.0 deadhead : 900
# Total:  2109.8
# SLC MSP
# 638 ['F94', 'DeadHead']
# base_salary : 2275 flight_salary : 392.6 layover_cost : 0.0 deadhead : 1980
# Total:  2667.6
# DTW MSP
# 639 ['F94', 'F69', 'DeadHead']
# base_salary : 2275 flight_salary : 728.0 layover_cost : 3488.3333333333335 deadhead : 1080
# Total:  6491.333333333334
# ATL MSP
# 640 ['F94', 'F69', 'F90', 'DeadHead']
# base_salary : 2275 flight_salary : 1024.3999999999999 layover_cost : 7291.374999999999 deadhead : 1380
# Total:  10590.774999999998
# SLC MSP
# 641 ['F94', 'F69', 'F84', 'DeadHead']
# base_salary : 2275 flight_salary : 1276.6000000000001 layover_cost : 5391.750000000001 deadhead : 1980
# Total:  8943.350000000002
# 642 ['F94', 'F69', 'F84', 'F38']
# base_salary : 2275 flight_salary : 1599.0 layover_cost : 5554.791666666667 deadhead : 0
# Total:  9428.791666666668
# ATL MSP
# 643 ['F94', 'F69', 'F66', 'DeadHead']
# base_salary : 2275 flight_salary : 1007.5 layover_cost : 5740.583333333334 deadhead : 1380
# Total:  9023.083333333334
# SLC MSP
# 644 ['F94', 'F69', 'F41', 'DeadHead']
# base_salary : 2275 flight_salary : 1276.6000000000001 layover_cost : 5391.750000000001 deadhead : 1980
# Total:  8943.350000000002
# SLC MSP
# 645 ['F94', 'F69', 'F12', 'DeadHead']
# base_salary : 2275 flight_salary : 1276.6000000000001 layover_cost : 5391.750000000001 deadhead : 1980
# Total:  8943.350000000002
# 646 ['F94', 'F38']
# base_salary : 2275 flight_salary : 715.0 layover_cost : 94.79166666666667 deadhead : 0
# Total:  3084.7916666666665
# ATL MSP
# 647 ['F94', 'F1', 'DeadHead']
# base_salary : 2275 flight_salary : 864.5 layover_cost : 208.54166666666666 deadhead : 1380
# Total:  3348.0416666666665
# 648 ['F94', 'F1', 'F37']
# base_salary : 2275 flight_salary : 1211.6000000000001 layover_cost : 5005.0 deadhead : 0
# Total:  8491.6
# LGA MSP
# 649 ['F94', 'F1', 'F18', 'DeadHead']
# base_salary : 2275 flight_salary : 1146.6000000000001 layover_cost : 5441.041666666667 deadhead : 1800
# Total:  8862.641666666666
# ATL MSP
# 650 ['F94', 'F1', 'F18', 'F79', 'DeadHead']
# base_salary : 2275 flight_salary : 1510.6000000000001 layover_cost : 6919.791666666667 deadhead : 1380
# Total:  10705.391666666666
# ATL MSP
# 651 ['F94', 'F1', 'F18', 'F76', 'DeadHead']
# base_salary : 2275 flight_salary : 1508.0 layover_cost : 10559.791666666668 deadhead : 1380
# Total:  14342.791666666668
# DTW MSP
# 652 ['F94', 'F1', 'F18', 'F8', 'DeadHead']
# base_salary : 2275 flight_salary : 1419.6 layover_cost : 9687.708333333334 deadhead : 1080
# Total:  13382.308333333334
# SLC MSP
# 653 ['F99', 'DeadHead']
# base_salary : 2275 flight_salary : 396.5 layover_cost : 0.0 deadhead : 1980
# Total:  2671.5
# Total paring : 654

# %%
import gurobipy as gp
from gurobipy import GRB
import random

def delta(pair, num):
    for p in pair:
      if p.startswith('F'):
            if p[1:] == str(num):
               return 1
    return 0

total_flight_num = 100

#p_set = []
#cnt = 0
#pairing_set_len = len(pairing_set)
#비행편 데드헤드있는 경우만 추출 --> 100개
#for pair in pairing_set:
#   if len(pair) == 2 and pair[-1] == 'DeadHead':
#        p_set.append(pair)

#random_percent= int(0.5*len(pairing_set))

#원래 페어에서 제거       
#for pair in pairing_set :
#    pairing_set.remove(pair)



#for i in range(random_percent) :
#    random_chocie = random.choice(pairing_set)
#    p_set.append(random_chocie)
#    pairing_set.remove(random_chocie)

#print('random_percent',random_percent)

#print(p_set)
#print(len(p_set))


# 최적화 모델 생성
model = gp.Model('Crew_Pairing')


# 변수 추가
x = []

for j in range(len(pairing_set)):
    x_j = model.addVar(vtype=GRB.CONTINUOUS, name='x_%s' % j)
    x.append(x_j)
#   model.setAttr("Start", x_j, 1)
    


for j in range(total_flight_num) :
    #비행편 마다의 제약 조건 추가?..
        model.addConstr(gp.quicksum(delta(pairing_set[i],j+1)*x[i] for i in range(len(pairing_set)))==1, name='d_%s' % j)


    
#model.addConstr(gp.quicksum(x[i] for i in range(len(p_set))) <= 80, name='extra')

# objective function 설정
obj = gp.quicksum(x[i] * total[i] for i in range(len(pairing_set)))


# Set the tolerance for optimality
#model.setParam('IntFeasTol', 1e-8)

model.setObjective(obj, GRB.MINIMIZE)
model.optimize()

if(model.Status==GRB.OPTIMAL) :
    print("최적해 찾음!!")
#print(model.ObjNVal)

# 변수 값 출력
for v in model.getVars():
    print(v.varName,v.getAttr)

#print(x,total)

# 제약 조건 슬랙 출력
for c in model.getConstrs():
   print(c.constrName,c.Slack)
# Out:
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 939893
# Academic license - for non-commercial use only - registered to skxkswls@gmail.com
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i5-8265U CPU @ 1.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license - for non-commercial use only - registered to skxkswls@gmail.com
# Optimize a model with 100 rows, 654 columns and 1676 nonzeros
# Model fingerprint: 0x5cd5127e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e+03, 2e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 3 rows and 178 columns
# Presolve time: 0.05s
# Presolved: 97 rows, 476 columns, 1187 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.4775008e+05   5.300000e+01   0.000000e+00      0s
#       69    2.5869925e+05   0.000000e+00   0.000000e+00      0s
#
# Solved in 69 iterations and 0.10 seconds (0.00 work units)
# Optimal objective  2.586992500e+05
# 최적해 찾음!!
# x_0 <bound method Var.getAttr of <gurobi.Var x_0 (value 1.0)>>
# x_1 <bound method Var.getAttr of <gurobi.Var x_1 (value 1.0)>>
# x_2 <bound method Var.getAttr of <gurobi.Var x_2 (value 1.0)>>
# x_3 <bound method Var.getAttr of <gurobi.Var x_3 (value 0.0)>>
# x_4 <bound method Var.getAttr of <gurobi.Var x_4 (value 0.0)>>
# x_5 <bound method Var.getAttr of <gurobi.Var x_5 (value 1.0)>>
# x_6 <bound method Var.getAttr of <gurobi.Var x_6 (value 0.0)>>
# x_7 <bound method Var.getAttr of <gurobi.Var x_7 (value 0.0)>>
# x_8 <bound method Var.getAttr of <gurobi.Var x_8 (value 0.0)>>
# x_9 <bound method Var.getAttr of <gurobi.Var x_9 (value 0.0)>>
# x_10 <bound method Var.getAttr of <gurobi.Var x_10 (value 0.0)>>
# x_11 <bound method Var.getAttr of <gurobi.Var x_11 (value 0.0)>>
# x_12 <bound method Var.getAttr of <gurobi.Var x_12 (value 0.0)>>
# x_13 <bound method Var.getAttr of <gurobi.Var x_13 (value 0.0)>>
# x_14 <bound method Var.getAttr of <gurobi.Var x_14 (value 0.0)>>
# x_15 <bound method Var.getAttr of <gurobi.Var x_15 (value 0.0)>>
# x_16 <bound method Var.getAttr of <gurobi.Var x_16 (value 0.0)>>
# x_17 <bound method Var.getAttr of <gurobi.Var x_17 (value 0.0)>>
# x_18 <bound method Var.getAttr of <gurobi.Var x_18 (value 0.0)>>
# x_19 <bound method Var.getAttr of <gurobi.Var x_19 (value 0.0)>>
# x_20 <bound method Var.getAttr of <gurobi.Var x_20 (value 0.0)>>
# x_21 <bound method Var.getAttr of <gurobi.Var x_21 (value 0.0)>>
# x_22 <bound method Var.getAttr of <gurobi.Var x_22 (value 1.0)>>
# x_23 <bound method Var.getAttr of <gurobi.Var x_23 (value 0.0)>>
# x_24 <bound method Var.getAttr of <gurobi.Var x_24 (value 0.0)>>
# x_25 <bound method Var.getAttr of <gurobi.Var x_25 (value 0.0)>>
# x_26 <bound method Var.getAttr of <gurobi.Var x_26 (value 0.0)>>
# x_27 <bound method Var.getAttr of <gurobi.Var x_27 (value 0.0)>>
# x_28 <bound method Var.getAttr of <gurobi.Var x_28 (value 0.0)>>
# x_29 <bound method Var.getAttr of <gurobi.Var x_29 (value 0.0)>>
# x_30 <bound method Var.getAttr of <gurobi.Var x_30 (value 0.0)>>
# x_31 <bound method Var.getAttr of <gurobi.Var x_31 (value 0.0)>>
# x_32 <bound method Var.getAttr of <gurobi.Var x_32 (value 0.0)>>
# x_33 <bound method Var.getAttr of <gurobi.Var x_33 (value 0.0)>>
# x_34 <bound method Var.getAttr of <gurobi.Var x_34 (value 0.0)>>
# x_35 <bound method Var.getAttr of <gurobi.Var x_35 (value 0.0)>>
# x_36 <bound method Var.getAttr of <gurobi.Var x_36 (value 0.0)>>
# x_37 <bound method Var.getAttr of <gurobi.Var x_37 (value 0.0)>>
# x_38 <bound method Var.getAttr of <gurobi.Var x_38 (value 0.0)>>
# x_39 <bound method Var.getAttr of <gurobi.Var x_39 (value 0.0)>>
# x_40 <bound method Var.getAttr of <gurobi.Var x_40 (value 0.0)>>
# x_41 <bound method Var.getAttr of <gurobi.Var x_41 (value 0.0)>>
# x_42 <bound method Var.getAttr of <gurobi.Var x_42 (value 0.0)>>
# x_43 <bound method Var.getAttr of <gurobi.Var x_43 (value 0.0)>>
# x_44 <bound method Var.getAttr of <gurobi.Var x_44 (value 0.0)>>
# x_45 <bound method Var.getAttr of <gurobi.Var x_45 (value 0.0)>>
# x_46 <bound method Var.getAttr of <gurobi.Var x_46 (value 0.0)>>
# x_47 <bound method Var.getAttr of <gurobi.Var x_47 (value 0.0)>>
# x_48 <bound method Var.getAttr of <gurobi.Var x_48 (value 0.0)>>
# x_49 <bound method Var.getAttr of <gurobi.Var x_49 (value 0.0)>>
# x_50 <bound method Var.getAttr of <gurobi.Var x_50 (value 0.0)>>
# x_51 <bound method Var.getAttr of <gurobi.Var x_51 (value 0.0)>>
# x_52 <bound method Var.getAttr of <gurobi.Var x_52 (value 0.0)>>
# x_53 <bound method Var.getAttr of <gurobi.Var x_53 (value 0.0)>>
# x_54 <bound method Var.getAttr of <gurobi.Var x_54 (value 0.0)>>
# x_55 <bound method Var.getAttr of <gurobi.Var x_55 (value 0.0)>>
# x_56 <bound method Var.getAttr of <gurobi.Var x_56 (value 0.0)>>
# x_57 <bound method Var.getAttr of <gurobi.Var x_57 (value 0.0)>>
# x_58 <bound method Var.getAttr of <gurobi.Var x_58 (value 0.0)>>
# x_59 <bound method Var.getAttr of <gurobi.Var x_59 (value 0.0)>>
# x_60 <bound method Var.getAttr of <gurobi.Var x_60 (value 0.0)>>
# x_61 <bound method Var.getAttr of <gurobi.Var x_61 (value 0.0)>>
# x_62 <bound method Var.getAttr of <gurobi.Var x_62 (value 0.0)>>
# x_63 <bound method Var.getAttr of <gurobi.Var x_63 (value 0.0)>>
# x_64 <bound method Var.getAttr of <gurobi.Var x_64 (value 0.0)>>
# x_65 <bound method Var.getAttr of <gurobi.Var x_65 (value 0.0)>>
# x_66 <bound method Var.getAttr of <gurobi.Var x_66 (value 0.0)>>
# x_67 <bound method Var.getAttr of <gurobi.Var x_67 (value 0.0)>>
# x_68 <bound method Var.getAttr of <gurobi.Var x_68 (value 1.0)>>
# x_69 <bound method Var.getAttr of <gurobi.Var x_69 (value 1.0)>>
# x_70 <bound method Var.getAttr of <gurobi.Var x_70 (value 0.0)>>
# x_71 <bound method Var.getAttr of <gurobi.Var x_71 (value 0.0)>>
# x_72 <bound method Var.getAttr of <gurobi.Var x_72 (value 0.0)>>
# x_73 <bound method Var.getAttr of <gurobi.Var x_73 (value 0.0)>>
# x_74 <bound method Var.getAttr of <gurobi.Var x_74 (value 0.0)>>
# x_75 <bound method Var.getAttr of <gurobi.Var x_75 (value 0.0)>>
# x_76 <bound method Var.getAttr of <gurobi.Var x_76 (value 0.0)>>
# x_77 <bound method Var.getAttr of <gurobi.Var x_77 (value 0.0)>>
# x_78 <bound method Var.getAttr of <gurobi.Var x_78 (value 0.0)>>
# x_79 <bound method Var.getAttr of <gurobi.Var x_79 (value 0.0)>>
# x_80 <bound method Var.getAttr of <gurobi.Var x_80 (value 0.0)>>
# x_81 <bound method Var.getAttr of <gurobi.Var x_81 (value 0.0)>>
# x_82 <bound method Var.getAttr of <gurobi.Var x_82 (value 0.0)>>
# x_83 <bound method Var.getAttr of <gurobi.Var x_83 (value 0.0)>>
# x_84 <bound method Var.getAttr of <gurobi.Var x_84 (value 0.0)>>
# x_85 <bound method Var.getAttr of <gurobi.Var x_85 (value 0.0)>>
# x_86 <bound method Var.getAttr of <gurobi.Var x_86 (value 0.0)>>
# x_87 <bound method Var.getAttr of <gurobi.Var x_87 (value 0.0)>>
# x_88 <bound method Var.getAttr of <gurobi.Var x_88 (value 0.0)>>
# x_89 <bound method Var.getAttr of <gurobi.Var x_89 (value 0.0)>>
# x_90 <bound method Var.getAttr of <gurobi.Var x_90 (value 0.0)>>
# x_91 <bound method Var.getAttr of <gurobi.Var x_91 (value 0.0)>>
# x_92 <bound method Var.getAttr of <gurobi.Var x_92 (value 0.0)>>
# x_93 <bound method Var.getAttr of <gurobi.Var x_93 (value 0.0)>>
# x_94 <bound method Var.getAttr of <gurobi.Var x_94 (value 0.0)>>
# x_95 <bound method Var.getAttr of <gurobi.Var x_95 (value 1.0)>>
# x_96 <bound method Var.getAttr of <gurobi.Var x_96 (value 0.0)>>
# x_97 <bound method Var.getAttr of <gurobi.Var x_97 (value 0.0)>>
# x_98 <bound method Var.getAttr of <gurobi.Var x_98 (value 0.0)>>
# x_99 <bound method Var.getAttr of <gurobi.Var x_99 (value 0.0)>>
# x_100 <bound method Var.getAttr of <gurobi.Var x_100 (value 0.0)>>
# x_101 <bound method Var.getAttr of <gurobi.Var x_101 (value 0.0)>>
# x_102 <bound method Var.getAttr of <gurobi.Var x_102 (value 0.0)>>
# x_103 <bound method Var.getAttr of <gurobi.Var x_103 (value 0.0)>>
# x_104 <bound method Var.getAttr of <gurobi.Var x_104 (value 0.0)>>
# x_105 <bound method Var.getAttr of <gurobi.Var x_105 (value 0.0)>>
# x_106 <bound method Var.getAttr of <gurobi.Var x_106 (value 0.0)>>
# x_107 <bound method Var.getAttr of <gurobi.Var x_107 (value 0.0)>>
# x_108 <bound method Var.getAttr of <gurobi.Var x_108 (value 0.0)>>
# x_109 <bound method Var.getAttr of <gurobi.Var x_109 (value 0.0)>>
# x_110 <bound method Var.getAttr of <gurobi.Var x_110 (value 0.0)>>
# x_111 <bound method Var.getAttr of <gurobi.Var x_111 (value 1.0)>>
# x_112 <bound method Var.getAttr of <gurobi.Var x_112 (value 0.0)>>
# x_113 <bound method Var.getAttr of <gurobi.Var x_113 (value 1.0)>>
# x_114 <bound method Var.getAttr of <gurobi.Var x_114 (value 0.0)>>
# x_115 <bound method Var.getAttr of <gurobi.Var x_115 (value 0.0)>>
# x_116 <bound method Var.getAttr of <gurobi.Var x_116 (value 0.0)>>
# x_117 <bound method Var.getAttr of <gurobi.Var x_117 (value 0.0)>>
# x_118 <bound method Var.getAttr of <gurobi.Var x_118 (value 0.0)>>
# x_119 <bound method Var.getAttr of <gurobi.Var x_119 (value 1.0)>>
# x_120 <bound method Var.getAttr of <gurobi.Var x_120 (value 0.0)>>
# x_121 <bound method Var.getAttr of <gurobi.Var x_121 (value 1.0)>>
# x_122 <bound method Var.getAttr of <gurobi.Var x_122 (value 0.0)>>
# x_123 <bound method Var.getAttr of <gurobi.Var x_123 (value 1.0)>>
# x_124 <bound method Var.getAttr of <gurobi.Var x_124 (value 0.0)>>
# x_125 <bound method Var.getAttr of <gurobi.Var x_125 (value 1.0)>>
# x_126 <bound method Var.getAttr of <gurobi.Var x_126 (value 0.0)>>
# x_127 <bound method Var.getAttr of <gurobi.Var x_127 (value 0.0)>>
# x_128 <bound method Var.getAttr of <gurobi.Var x_128 (value 0.0)>>
# x_129 <bound method Var.getAttr of <gurobi.Var x_129 (value 0.0)>>
# x_130 <bound method Var.getAttr of <gurobi.Var x_130 (value 0.0)>>
# x_131 <bound method Var.getAttr of <gurobi.Var x_131 (value 0.0)>>
# x_132 <bound method Var.getAttr of <gurobi.Var x_132 (value 1.0)>>
# x_133 <bound method Var.getAttr of <gurobi.Var x_133 (value 0.0)>>
# x_134 <bound method Var.getAttr of <gurobi.Var x_134 (value 0.0)>>
# x_135 <bound method Var.getAttr of <gurobi.Var x_135 (value 0.0)>>
# x_136 <bound method Var.getAttr of <gurobi.Var x_136 (value 0.0)>>
# x_137 <bound method Var.getAttr of <gurobi.Var x_137 (value 1.0)>>
# x_138 <bound method Var.getAttr of <gurobi.Var x_138 (value 0.0)>>
# x_139 <bound method Var.getAttr of <gurobi.Var x_139 (value 0.0)>>
# x_140 <bound method Var.getAttr of <gurobi.Var x_140 (value 0.0)>>
# x_141 <bound method Var.getAttr of <gurobi.Var x_141 (value 0.0)>>
# x_142 <bound method Var.getAttr of <gurobi.Var x_142 (value 0.0)>>
# x_143 <bound method Var.getAttr of <gurobi.Var x_143 (value 0.0)>>
# x_144 <bound method Var.getAttr of <gurobi.Var x_144 (value 0.0)>>
# x_145 <bound method Var.getAttr of <gurobi.Var x_145 (value 0.0)>>
# x_146 <bound method Var.getAttr of <gurobi.Var x_146 (value 0.0)>>
# x_147 <bound method Var.getAttr of <gurobi.Var x_147 (value 0.0)>>
# x_148 <bound method Var.getAttr of <gurobi.Var x_148 (value 0.0)>>
# x_149 <bound method Var.getAttr of <gurobi.Var x_149 (value 0.0)>>
# x_150 <bound method Var.getAttr of <gurobi.Var x_150 (value 0.0)>>
# x_151 <bound method Var.getAttr of <gurobi.Var x_151 (value 0.0)>>
# x_152 <bound method Var.getAttr of <gurobi.Var x_152 (value 0.0)>>
# x_153 <bound method Var.getAttr of <gurobi.Var x_153 (value 0.0)>>
# x_154 <bound method Var.getAttr of <gurobi.Var x_154 (value 0.0)>>
# x_155 <bound method Var.getAttr of <gurobi.Var x_155 (value 0.0)>>
# x_156 <bound method Var.getAttr of <gurobi.Var x_156 (value 0.0)>>
# x_157 <bound method Var.getAttr of <gurobi.Var x_157 (value 0.0)>>
# x_158 <bound method Var.getAttr of <gurobi.Var x_158 (value 0.0)>>
# x_159 <bound method Var.getAttr of <gurobi.Var x_159 (value 0.0)>>
# x_160 <bound method Var.getAttr of <gurobi.Var x_160 (value 0.0)>>
# x_161 <bound method Var.getAttr of <gurobi.Var x_161 (value 0.0)>>
# x_162 <bound method Var.getAttr of <gurobi.Var x_162 (value 0.0)>>
# x_163 <bound method Var.getAttr of <gurobi.Var x_163 (value 0.0)>>
# x_164 <bound method Var.getAttr of <gurobi.Var x_164 (value 0.0)>>
# x_165 <bound method Var.getAttr of <gurobi.Var x_165 (value 0.0)>>
# x_166 <bound method Var.getAttr of <gurobi.Var x_166 (value 0.0)>>
# x_167 <bound method Var.getAttr of <gurobi.Var x_167 (value 1.0)>>
# x_168 <bound method Var.getAttr of <gurobi.Var x_168 (value 0.0)>>
# x_169 <bound method Var.getAttr of <gurobi.Var x_169 (value 0.0)>>
# x_170 <bound method Var.getAttr of <gurobi.Var x_170 (value 0.0)>>
# x_171 <bound method Var.getAttr of <gurobi.Var x_171 (value 0.0)>>
# x_172 <bound method Var.getAttr of <gurobi.Var x_172 (value 0.0)>>
# x_173 <bound method Var.getAttr of <gurobi.Var x_173 (value 0.0)>>
# x_174 <bound method Var.getAttr of <gurobi.Var x_174 (value 0.0)>>
# x_175 <bound method Var.getAttr of <gurobi.Var x_175 (value 0.0)>>
# x_176 <bound method Var.getAttr of <gurobi.Var x_176 (value 0.0)>>
# x_177 <bound method Var.getAttr of <gurobi.Var x_177 (value 0.0)>>
# x_178 <bound method Var.getAttr of <gurobi.Var x_178 (value 0.0)>>
# x_179 <bound method Var.getAttr of <gurobi.Var x_179 (value 0.0)>>
# x_180 <bound method Var.getAttr of <gurobi.Var x_180 (value 0.0)>>
# x_181 <bound method Var.getAttr of <gurobi.Var x_181 (value 0.0)>>
# x_182 <bound method Var.getAttr of <gurobi.Var x_182 (value 0.0)>>
# x_183 <bound method Var.getAttr of <gurobi.Var x_183 (value 0.0)>>
# x_184 <bound method Var.getAttr of <gurobi.Var x_184 (value 0.0)>>
# x_185 <bound method Var.getAttr of <gurobi.Var x_185 (value 0.0)>>
# x_186 <bound method Var.getAttr of <gurobi.Var x_186 (value 0.0)>>
# x_187 <bound method Var.getAttr of <gurobi.Var x_187 (value 0.0)>>
# x_188 <bound method Var.getAttr of <gurobi.Var x_188 (value 0.0)>>
# x_189 <bound method Var.getAttr of <gurobi.Var x_189 (value 1.0)>>
# x_190 <bound method Var.getAttr of <gurobi.Var x_190 (value 0.0)>>
# x_191 <bound method Var.getAttr of <gurobi.Var x_191 (value 0.0)>>
# x_192 <bound method Var.getAttr of <gurobi.Var x_192 (value 0.0)>>
# x_193 <bound method Var.getAttr of <gurobi.Var x_193 (value 0.0)>>
# x_194 <bound method Var.getAttr of <gurobi.Var x_194 (value 0.0)>>
# x_195 <bound method Var.getAttr of <gurobi.Var x_195 (value 0.0)>>
# x_196 <bound method Var.getAttr of <gurobi.Var x_196 (value 0.0)>>
# x_197 <bound method Var.getAttr of <gurobi.Var x_197 (value 1.0)>>
# x_198 <bound method Var.getAttr of <gurobi.Var x_198 (value 0.0)>>
# x_199 <bound method Var.getAttr of <gurobi.Var x_199 (value 0.0)>>
# x_200 <bound method Var.getAttr of <gurobi.Var x_200 (value 0.0)>>
# x_201 <bound method Var.getAttr of <gurobi.Var x_201 (value 0.0)>>
# x_202 <bound method Var.getAttr of <gurobi.Var x_202 (value 0.0)>>
# x_203 <bound method Var.getAttr of <gurobi.Var x_203 (value 0.0)>>
# x_204 <bound method Var.getAttr of <gurobi.Var x_204 (value 0.0)>>
# x_205 <bound method Var.getAttr of <gurobi.Var x_205 (value 0.0)>>
# x_206 <bound method Var.getAttr of <gurobi.Var x_206 (value 0.0)>>
# x_207 <bound method Var.getAttr of <gurobi.Var x_207 (value 0.0)>>
# x_208 <bound method Var.getAttr of <gurobi.Var x_208 (value 0.0)>>
# x_209 <bound method Var.getAttr of <gurobi.Var x_209 (value 0.0)>>
# x_210 <bound method Var.getAttr of <gurobi.Var x_210 (value 1.0)>>
# x_211 <bound method Var.getAttr of <gurobi.Var x_211 (value 0.0)>>
# x_212 <bound method Var.getAttr of <gurobi.Var x_212 (value 0.0)>>
# x_213 <bound method Var.getAttr of <gurobi.Var x_213 (value 0.0)>>
# x_214 <bound method Var.getAttr of <gurobi.Var x_214 (value 0.0)>>
# x_215 <bound method Var.getAttr of <gurobi.Var x_215 (value 0.0)>>
# x_216 <bound method Var.getAttr of <gurobi.Var x_216 (value 0.0)>>
# x_217 <bound method Var.getAttr of <gurobi.Var x_217 (value 0.0)>>
# x_218 <bound method Var.getAttr of <gurobi.Var x_218 (value 0.0)>>
# x_219 <bound method Var.getAttr of <gurobi.Var x_219 (value 0.0)>>
# x_220 <bound method Var.getAttr of <gurobi.Var x_220 (value 0.0)>>
# x_221 <bound method Var.getAttr of <gurobi.Var x_221 (value 0.0)>>
# x_222 <bound method Var.getAttr of <gurobi.Var x_222 (value 0.0)>>
# x_223 <bound method Var.getAttr of <gurobi.Var x_223 (value 0.0)>>
# x_224 <bound method Var.getAttr of <gurobi.Var x_224 (value 0.0)>>
# x_225 <bound method Var.getAttr of <gurobi.Var x_225 (value 0.0)>>
# x_226 <bound method Var.getAttr of <gurobi.Var x_226 (value 0.0)>>
# x_227 <bound method Var.getAttr of <gurobi.Var x_227 (value 0.0)>>
# x_228 <bound method Var.getAttr of <gurobi.Var x_228 (value 0.0)>>
# x_229 <bound method Var.getAttr of <gurobi.Var x_229 (value 0.0)>>
# x_230 <bound method Var.getAttr of <gurobi.Var x_230 (value 0.0)>>
# x_231 <bound method Var.getAttr of <gurobi.Var x_231 (value 1.0)>>
# x_232 <bound method Var.getAttr of <gurobi.Var x_232 (value 0.0)>>
# x_233 <bound method Var.getAttr of <gurobi.Var x_233 (value 1.0)>>
# x_234 <bound method Var.getAttr of <gurobi.Var x_234 (value 0.0)>>
# x_235 <bound method Var.getAttr of <gurobi.Var x_235 (value 0.0)>>
# x_236 <bound method Var.getAttr of <gurobi.Var x_236 (value 0.0)>>
# x_237 <bound method Var.getAttr of <gurobi.Var x_237 (value 0.0)>>
# x_238 <bound method Var.getAttr of <gurobi.Var x_238 (value 0.0)>>
# x_239 <bound method Var.getAttr of <gurobi.Var x_239 (value 0.0)>>
# x_240 <bound method Var.getAttr of <gurobi.Var x_240 (value 0.0)>>
# x_241 <bound method Var.getAttr of <gurobi.Var x_241 (value 1.0)>>
# x_242 <bound method Var.getAttr of <gurobi.Var x_242 (value 0.0)>>
# x_243 <bound method Var.getAttr of <gurobi.Var x_243 (value 0.0)>>
# x_244 <bound method Var.getAttr of <gurobi.Var x_244 (value 0.0)>>
# x_245 <bound method Var.getAttr of <gurobi.Var x_245 (value 0.0)>>
# x_246 <bound method Var.getAttr of <gurobi.Var x_246 (value 0.0)>>
# x_247 <bound method Var.getAttr of <gurobi.Var x_247 (value 0.0)>>
# x_248 <bound method Var.getAttr of <gurobi.Var x_248 (value 0.0)>>
# x_249 <bound method Var.getAttr of <gurobi.Var x_249 (value 0.0)>>
# x_250 <bound method Var.getAttr of <gurobi.Var x_250 (value 0.0)>>
# x_251 <bound method Var.getAttr of <gurobi.Var x_251 (value 0.0)>>
# x_252 <bound method Var.getAttr of <gurobi.Var x_252 (value 0.0)>>
# x_253 <bound method Var.getAttr of <gurobi.Var x_253 (value 0.0)>>
# x_254 <bound method Var.getAttr of <gurobi.Var x_254 (value 0.0)>>
# x_255 <bound method Var.getAttr of <gurobi.Var x_255 (value 0.0)>>
# x_256 <bound method Var.getAttr of <gurobi.Var x_256 (value 0.0)>>
# x_257 <bound method Var.getAttr of <gurobi.Var x_257 (value 0.0)>>
# x_258 <bound method Var.getAttr of <gurobi.Var x_258 (value 0.0)>>
# x_259 <bound method Var.getAttr of <gurobi.Var x_259 (value 0.0)>>
# x_260 <bound method Var.getAttr of <gurobi.Var x_260 (value 0.0)>>
# x_261 <bound method Var.getAttr of <gurobi.Var x_261 (value 0.0)>>
# x_262 <bound method Var.getAttr of <gurobi.Var x_262 (value 0.0)>>
# x_263 <bound method Var.getAttr of <gurobi.Var x_263 (value 0.0)>>
# x_264 <bound method Var.getAttr of <gurobi.Var x_264 (value 0.0)>>
# x_265 <bound method Var.getAttr of <gurobi.Var x_265 (value 0.0)>>
# x_266 <bound method Var.getAttr of <gurobi.Var x_266 (value 0.0)>>
# x_267 <bound method Var.getAttr of <gurobi.Var x_267 (value 0.0)>>
# x_268 <bound method Var.getAttr of <gurobi.Var x_268 (value 1.0)>>
# x_269 <bound method Var.getAttr of <gurobi.Var x_269 (value 0.0)>>
# x_270 <bound method Var.getAttr of <gurobi.Var x_270 (value 0.0)>>
# x_271 <bound method Var.getAttr of <gurobi.Var x_271 (value 0.0)>>
# x_272 <bound method Var.getAttr of <gurobi.Var x_272 (value 0.0)>>
# x_273 <bound method Var.getAttr of <gurobi.Var x_273 (value 0.0)>>
# x_274 <bound method Var.getAttr of <gurobi.Var x_274 (value 0.0)>>
# x_275 <bound method Var.getAttr of <gurobi.Var x_275 (value 0.0)>>
# x_276 <bound method Var.getAttr of <gurobi.Var x_276 (value 0.0)>>
# x_277 <bound method Var.getAttr of <gurobi.Var x_277 (value 0.0)>>
# x_278 <bound method Var.getAttr of <gurobi.Var x_278 (value 0.0)>>
# x_279 <bound method Var.getAttr of <gurobi.Var x_279 (value 0.0)>>
# x_280 <bound method Var.getAttr of <gurobi.Var x_280 (value 0.0)>>
# x_281 <bound method Var.getAttr of <gurobi.Var x_281 (value 0.0)>>
# x_282 <bound method Var.getAttr of <gurobi.Var x_282 (value 0.0)>>
# x_283 <bound method Var.getAttr of <gurobi.Var x_283 (value 0.0)>>
# x_284 <bound method Var.getAttr of <gurobi.Var x_284 (value 0.0)>>
# x_285 <bound method Var.getAttr of <gurobi.Var x_285 (value 0.0)>>
# x_286 <bound method Var.getAttr of <gurobi.Var x_286 (value 0.0)>>
# x_287 <bound method Var.getAttr of <gurobi.Var x_287 (value 0.0)>>
# x_288 <bound method Var.getAttr of <gurobi.Var x_288 (value 0.0)>>
# x_289 <bound method Var.getAttr of <gurobi.Var x_289 (value 0.0)>>
# x_290 <bound method Var.getAttr of <gurobi.Var x_290 (value 0.0)>>
# x_291 <bound method Var.getAttr of <gurobi.Var x_291 (value 0.0)>>
# x_292 <bound method Var.getAttr of <gurobi.Var x_292 (value 0.0)>>
# x_293 <bound method Var.getAttr of <gurobi.Var x_293 (value 0.0)>>
# x_294 <bound method Var.getAttr of <gurobi.Var x_294 (value 0.0)>>
# x_295 <bound method Var.getAttr of <gurobi.Var x_295 (value 0.0)>>
# x_296 <bound method Var.getAttr of <gurobi.Var x_296 (value 0.0)>>
# x_297 <bound method Var.getAttr of <gurobi.Var x_297 (value 0.0)>>
# x_298 <bound method Var.getAttr of <gurobi.Var x_298 (value 0.0)>>
# x_299 <bound method Var.getAttr of <gurobi.Var x_299 (value 0.0)>>
# x_300 <bound method Var.getAttr of <gurobi.Var x_300 (value 0.0)>>
# x_301 <bound method Var.getAttr of <gurobi.Var x_301 (value 0.0)>>
# x_302 <bound method Var.getAttr of <gurobi.Var x_302 (value 0.0)>>
# x_303 <bound method Var.getAttr of <gurobi.Var x_303 (value 0.0)>>
# x_304 <bound method Var.getAttr of <gurobi.Var x_304 (value 0.0)>>
# x_305 <bound method Var.getAttr of <gurobi.Var x_305 (value 0.0)>>
# x_306 <bound method Var.getAttr of <gurobi.Var x_306 (value 0.0)>>
# x_307 <bound method Var.getAttr of <gurobi.Var x_307 (value 0.0)>>
# x_308 <bound method Var.getAttr of <gurobi.Var x_308 (value 0.0)>>
# x_309 <bound method Var.getAttr of <gurobi.Var x_309 (value 1.0)>>
# x_310 <bound method Var.getAttr of <gurobi.Var x_310 (value 0.0)>>
# x_311 <bound method Var.getAttr of <gurobi.Var x_311 (value 0.0)>>
# x_312 <bound method Var.getAttr of <gurobi.Var x_312 (value 0.0)>>
# x_313 <bound method Var.getAttr of <gurobi.Var x_313 (value 0.0)>>
# x_314 <bound method Var.getAttr of <gurobi.Var x_314 (value 0.0)>>
# x_315 <bound method Var.getAttr of <gurobi.Var x_315 (value 1.0)>>
# x_316 <bound method Var.getAttr of <gurobi.Var x_316 (value 0.0)>>
# x_317 <bound method Var.getAttr of <gurobi.Var x_317 (value 0.0)>>
# x_318 <bound method Var.getAttr of <gurobi.Var x_318 (value 0.0)>>
# x_319 <bound method Var.getAttr of <gurobi.Var x_319 (value 0.0)>>
# x_320 <bound method Var.getAttr of <gurobi.Var x_320 (value 0.0)>>
# x_321 <bound method Var.getAttr of <gurobi.Var x_321 (value 0.0)>>
# x_322 <bound method Var.getAttr of <gurobi.Var x_322 (value 0.0)>>
# x_323 <bound method Var.getAttr of <gurobi.Var x_323 (value 0.0)>>
# x_324 <bound method Var.getAttr of <gurobi.Var x_324 (value 0.0)>>
# x_325 <bound method Var.getAttr of <gurobi.Var x_325 (value 1.0)>>
# x_326 <bound method Var.getAttr of <gurobi.Var x_326 (value 0.0)>>
# x_327 <bound method Var.getAttr of <gurobi.Var x_327 (value 0.0)>>
# x_328 <bound method Var.getAttr of <gurobi.Var x_328 (value 0.0)>>
# x_329 <bound method Var.getAttr of <gurobi.Var x_329 (value 1.0)>>
# x_330 <bound method Var.getAttr of <gurobi.Var x_330 (value 0.0)>>
# x_331 <bound method Var.getAttr of <gurobi.Var x_331 (value 0.0)>>
# x_332 <bound method Var.getAttr of <gurobi.Var x_332 (value 0.0)>>
# x_333 <bound method Var.getAttr of <gurobi.Var x_333 (value 0.0)>>
# x_334 <bound method Var.getAttr of <gurobi.Var x_334 (value 0.0)>>
# x_335 <bound method Var.getAttr of <gurobi.Var x_335 (value 0.0)>>
# x_336 <bound method Var.getAttr of <gurobi.Var x_336 (value 0.0)>>
# x_337 <bound method Var.getAttr of <gurobi.Var x_337 (value 0.0)>>
# x_338 <bound method Var.getAttr of <gurobi.Var x_338 (value 0.0)>>
# x_339 <bound method Var.getAttr of <gurobi.Var x_339 (value 1.0)>>
# x_340 <bound method Var.getAttr of <gurobi.Var x_340 (value 0.0)>>
# x_341 <bound method Var.getAttr of <gurobi.Var x_341 (value 0.0)>>
# x_342 <bound method Var.getAttr of <gurobi.Var x_342 (value 0.0)>>
# x_343 <bound method Var.getAttr of <gurobi.Var x_343 (value 0.0)>>
# x_344 <bound method Var.getAttr of <gurobi.Var x_344 (value 0.0)>>
# x_345 <bound method Var.getAttr of <gurobi.Var x_345 (value 0.0)>>
# x_346 <bound method Var.getAttr of <gurobi.Var x_346 (value 0.0)>>
# x_347 <bound method Var.getAttr of <gurobi.Var x_347 (value 0.0)>>
# x_348 <bound method Var.getAttr of <gurobi.Var x_348 (value 0.0)>>
# x_349 <bound method Var.getAttr of <gurobi.Var x_349 (value 0.0)>>
# x_350 <bound method Var.getAttr of <gurobi.Var x_350 (value 0.0)>>
# x_351 <bound method Var.getAttr of <gurobi.Var x_351 (value 0.0)>>
# x_352 <bound method Var.getAttr of <gurobi.Var x_352 (value 0.0)>>
# x_353 <bound method Var.getAttr of <gurobi.Var x_353 (value 0.0)>>
# x_354 <bound method Var.getAttr of <gurobi.Var x_354 (value 0.0)>>
# x_355 <bound method Var.getAttr of <gurobi.Var x_355 (value 0.0)>>
# x_356 <bound method Var.getAttr of <gurobi.Var x_356 (value 0.0)>>
# x_357 <bound method Var.getAttr of <gurobi.Var x_357 (value 0.0)>>
# x_358 <bound method Var.getAttr of <gurobi.Var x_358 (value 0.0)>>
# x_359 <bound method Var.getAttr of <gurobi.Var x_359 (value 0.0)>>
# x_360 <bound method Var.getAttr of <gurobi.Var x_360 (value 0.0)>>
# x_361 <bound method Var.getAttr of <gurobi.Var x_361 (value 0.0)>>
# x_362 <bound method Var.getAttr of <gurobi.Var x_362 (value 0.0)>>
# x_363 <bound method Var.getAttr of <gurobi.Var x_363 (value 0.0)>>
# x_364 <bound method Var.getAttr of <gurobi.Var x_364 (value 0.0)>>
# x_365 <bound method Var.getAttr of <gurobi.Var x_365 (value 0.0)>>
# x_366 <bound method Var.getAttr of <gurobi.Var x_366 (value 1.0)>>
# x_367 <bound method Var.getAttr of <gurobi.Var x_367 (value 0.0)>>
# x_368 <bound method Var.getAttr of <gurobi.Var x_368 (value 0.0)>>
# x_369 <bound method Var.getAttr of <gurobi.Var x_369 (value 0.0)>>
# x_370 <bound method Var.getAttr of <gurobi.Var x_370 (value 0.0)>>
# x_371 <bound method Var.getAttr of <gurobi.Var x_371 (value 1.0)>>
# x_372 <bound method Var.getAttr of <gurobi.Var x_372 (value 0.0)>>
# x_373 <bound method Var.getAttr of <gurobi.Var x_373 (value 0.0)>>
# x_374 <bound method Var.getAttr of <gurobi.Var x_374 (value 0.0)>>
# x_375 <bound method Var.getAttr of <gurobi.Var x_375 (value 0.0)>>
# x_376 <bound method Var.getAttr of <gurobi.Var x_376 (value 0.0)>>
# x_377 <bound method Var.getAttr of <gurobi.Var x_377 (value 0.0)>>
# x_378 <bound method Var.getAttr of <gurobi.Var x_378 (value 0.0)>>
# x_379 <bound method Var.getAttr of <gurobi.Var x_379 (value 0.0)>>
# x_380 <bound method Var.getAttr of <gurobi.Var x_380 (value 0.0)>>
# x_381 <bound method Var.getAttr of <gurobi.Var x_381 (value 0.0)>>
# x_382 <bound method Var.getAttr of <gurobi.Var x_382 (value 0.0)>>
# x_383 <bound method Var.getAttr of <gurobi.Var x_383 (value 0.0)>>
# x_384 <bound method Var.getAttr of <gurobi.Var x_384 (value 0.0)>>
# x_385 <bound method Var.getAttr of <gurobi.Var x_385 (value 0.0)>>
# x_386 <bound method Var.getAttr of <gurobi.Var x_386 (value 0.0)>>
# x_387 <bound method Var.getAttr of <gurobi.Var x_387 (value 0.0)>>
# x_388 <bound method Var.getAttr of <gurobi.Var x_388 (value 0.0)>>
# x_389 <bound method Var.getAttr of <gurobi.Var x_389 (value 0.0)>>
# x_390 <bound method Var.getAttr of <gurobi.Var x_390 (value 0.0)>>
# x_391 <bound method Var.getAttr of <gurobi.Var x_391 (value 0.0)>>
# x_392 <bound method Var.getAttr of <gurobi.Var x_392 (value 0.0)>>
# x_393 <bound method Var.getAttr of <gurobi.Var x_393 (value 0.0)>>
# x_394 <bound method Var.getAttr of <gurobi.Var x_394 (value 0.0)>>
# x_395 <bound method Var.getAttr of <gurobi.Var x_395 (value 0.0)>>
# x_396 <bound method Var.getAttr of <gurobi.Var x_396 (value 0.0)>>
# x_397 <bound method Var.getAttr of <gurobi.Var x_397 (value 0.0)>>
# x_398 <bound method Var.getAttr of <gurobi.Var x_398 (value 1.0)>>
# x_399 <bound method Var.getAttr of <gurobi.Var x_399 (value 0.0)>>
# x_400 <bound method Var.getAttr of <gurobi.Var x_400 (value 0.0)>>
# x_401 <bound method Var.getAttr of <gurobi.Var x_401 (value 0.0)>>
# x_402 <bound method Var.getAttr of <gurobi.Var x_402 (value 0.0)>>
# x_403 <bound method Var.getAttr of <gurobi.Var x_403 (value 0.0)>>
# x_404 <bound method Var.getAttr of <gurobi.Var x_404 (value 0.0)>>
# x_405 <bound method Var.getAttr of <gurobi.Var x_405 (value 0.0)>>
# x_406 <bound method Var.getAttr of <gurobi.Var x_406 (value 0.0)>>
# x_407 <bound method Var.getAttr of <gurobi.Var x_407 (value 0.0)>>
# x_408 <bound method Var.getAttr of <gurobi.Var x_408 (value 0.0)>>
# x_409 <bound method Var.getAttr of <gurobi.Var x_409 (value 0.0)>>
# x_410 <bound method Var.getAttr of <gurobi.Var x_410 (value 0.0)>>
# x_411 <bound method Var.getAttr of <gurobi.Var x_411 (value 1.0)>>
# x_412 <bound method Var.getAttr of <gurobi.Var x_412 (value 0.0)>>
# x_413 <bound method Var.getAttr of <gurobi.Var x_413 (value 0.0)>>
# x_414 <bound method Var.getAttr of <gurobi.Var x_414 (value 0.0)>>
# x_415 <bound method Var.getAttr of <gurobi.Var x_415 (value 0.0)>>
# x_416 <bound method Var.getAttr of <gurobi.Var x_416 (value 0.0)>>
# x_417 <bound method Var.getAttr of <gurobi.Var x_417 (value 0.0)>>
# x_418 <bound method Var.getAttr of <gurobi.Var x_418 (value 0.0)>>
# x_419 <bound method Var.getAttr of <gurobi.Var x_419 (value 0.0)>>
# x_420 <bound method Var.getAttr of <gurobi.Var x_420 (value 0.0)>>
# x_421 <bound method Var.getAttr of <gurobi.Var x_421 (value 0.0)>>
# x_422 <bound method Var.getAttr of <gurobi.Var x_422 (value 0.0)>>
# x_423 <bound method Var.getAttr of <gurobi.Var x_423 (value 0.0)>>
# x_424 <bound method Var.getAttr of <gurobi.Var x_424 (value 0.0)>>
# x_425 <bound method Var.getAttr of <gurobi.Var x_425 (value 0.0)>>
# x_426 <bound method Var.getAttr of <gurobi.Var x_426 (value 0.0)>>
# x_427 <bound method Var.getAttr of <gurobi.Var x_427 (value 0.0)>>
# x_428 <bound method Var.getAttr of <gurobi.Var x_428 (value 0.0)>>
# x_429 <bound method Var.getAttr of <gurobi.Var x_429 (value 0.0)>>
# x_430 <bound method Var.getAttr of <gurobi.Var x_430 (value 0.0)>>
# x_431 <bound method Var.getAttr of <gurobi.Var x_431 (value 0.0)>>
# x_432 <bound method Var.getAttr of <gurobi.Var x_432 (value 0.0)>>
# x_433 <bound method Var.getAttr of <gurobi.Var x_433 (value 0.0)>>
# x_434 <bound method Var.getAttr of <gurobi.Var x_434 (value 0.0)>>
# x_435 <bound method Var.getAttr of <gurobi.Var x_435 (value 1.0)>>
# x_436 <bound method Var.getAttr of <gurobi.Var x_436 (value 0.0)>>
# x_437 <bound method Var.getAttr of <gurobi.Var x_437 (value 0.0)>>
# x_438 <bound method Var.getAttr of <gurobi.Var x_438 (value 0.0)>>
# x_439 <bound method Var.getAttr of <gurobi.Var x_439 (value 0.0)>>
# x_440 <bound method Var.getAttr of <gurobi.Var x_440 (value 0.0)>>
# x_441 <bound method Var.getAttr of <gurobi.Var x_441 (value 0.0)>>
# x_442 <bound method Var.getAttr of <gurobi.Var x_442 (value 0.0)>>
# x_443 <bound method Var.getAttr of <gurobi.Var x_443 (value 0.0)>>
# x_444 <bound method Var.getAttr of <gurobi.Var x_444 (value 0.0)>>
# x_445 <bound method Var.getAttr of <gurobi.Var x_445 (value 0.0)>>
# x_446 <bound method Var.getAttr of <gurobi.Var x_446 (value 0.0)>>
# x_447 <bound method Var.getAttr of <gurobi.Var x_447 (value 0.0)>>
# x_448 <bound method Var.getAttr of <gurobi.Var x_448 (value 1.0)>>
# x_449 <bound method Var.getAttr of <gurobi.Var x_449 (value 0.0)>>
# x_450 <bound method Var.getAttr of <gurobi.Var x_450 (value 0.0)>>
# x_451 <bound method Var.getAttr of <gurobi.Var x_451 (value 0.0)>>
# x_452 <bound method Var.getAttr of <gurobi.Var x_452 (value 1.0)>>
# x_453 <bound method Var.getAttr of <gurobi.Var x_453 (value 0.0)>>
# x_454 <bound method Var.getAttr of <gurobi.Var x_454 (value 0.0)>>
# x_455 <bound method Var.getAttr of <gurobi.Var x_455 (value 0.0)>>
# x_456 <bound method Var.getAttr of <gurobi.Var x_456 (value 0.0)>>
# x_457 <bound method Var.getAttr of <gurobi.Var x_457 (value 0.0)>>
# x_458 <bound method Var.getAttr of <gurobi.Var x_458 (value 0.0)>>
# x_459 <bound method Var.getAttr of <gurobi.Var x_459 (value 0.0)>>
# x_460 <bound method Var.getAttr of <gurobi.Var x_460 (value 1.0)>>
# x_461 <bound method Var.getAttr of <gurobi.Var x_461 (value 0.0)>>
# x_462 <bound method Var.getAttr of <gurobi.Var x_462 (value 0.0)>>
# x_463 <bound method Var.getAttr of <gurobi.Var x_463 (value 0.0)>>
# x_464 <bound method Var.getAttr of <gurobi.Var x_464 (value 0.0)>>
# x_465 <bound method Var.getAttr of <gurobi.Var x_465 (value 0.0)>>
# x_466 <bound method Var.getAttr of <gurobi.Var x_466 (value 0.0)>>
# x_467 <bound method Var.getAttr of <gurobi.Var x_467 (value 0.0)>>
# x_468 <bound method Var.getAttr of <gurobi.Var x_468 (value 0.0)>>
# x_469 <bound method Var.getAttr of <gurobi.Var x_469 (value 1.0)>>
# x_470 <bound method Var.getAttr of <gurobi.Var x_470 (value 1.0)>>
# x_471 <bound method Var.getAttr of <gurobi.Var x_471 (value 0.0)>>
# x_472 <bound method Var.getAttr of <gurobi.Var x_472 (value 0.0)>>
# x_473 <bound method Var.getAttr of <gurobi.Var x_473 (value 0.0)>>
# x_474 <bound method Var.getAttr of <gurobi.Var x_474 (value 0.0)>>
# x_475 <bound method Var.getAttr of <gurobi.Var x_475 (value 0.0)>>
# x_476 <bound method Var.getAttr of <gurobi.Var x_476 (value 0.0)>>
# x_477 <bound method Var.getAttr of <gurobi.Var x_477 (value 0.0)>>
# x_478 <bound method Var.getAttr of <gurobi.Var x_478 (value 0.0)>>
# x_479 <bound method Var.getAttr of <gurobi.Var x_479 (value 0.0)>>
# x_480 <bound method Var.getAttr of <gurobi.Var x_480 (value 0.0)>>
# x_481 <bound method Var.getAttr of <gurobi.Var x_481 (value 0.0)>>
# x_482 <bound method Var.getAttr of <gurobi.Var x_482 (value 1.0)>>
# x_483 <bound method Var.getAttr of <gurobi.Var x_483 (value 0.0)>>
# x_484 <bound method Var.getAttr of <gurobi.Var x_484 (value 0.0)>>
# x_485 <bound method Var.getAttr of <gurobi.Var x_485 (value 0.0)>>
# x_486 <bound method Var.getAttr of <gurobi.Var x_486 (value 0.0)>>
# x_487 <bound method Var.getAttr of <gurobi.Var x_487 (value 0.0)>>
# x_488 <bound method Var.getAttr of <gurobi.Var x_488 (value 0.0)>>
# x_489 <bound method Var.getAttr of <gurobi.Var x_489 (value 0.0)>>
# x_490 <bound method Var.getAttr of <gurobi.Var x_490 (value 0.0)>>
# x_491 <bound method Var.getAttr of <gurobi.Var x_491 (value 0.0)>>
# x_492 <bound method Var.getAttr of <gurobi.Var x_492 (value 0.0)>>
# x_493 <bound method Var.getAttr of <gurobi.Var x_493 (value 0.0)>>
# x_494 <bound method Var.getAttr of <gurobi.Var x_494 (value 0.0)>>
# x_495 <bound method Var.getAttr of <gurobi.Var x_495 (value 0.0)>>
# x_496 <bound method Var.getAttr of <gurobi.Var x_496 (value 1.0)>>
# x_497 <bound method Var.getAttr of <gurobi.Var x_497 (value 0.0)>>
# x_498 <bound method Var.getAttr of <gurobi.Var x_498 (value 0.0)>>
# x_499 <bound method Var.getAttr of <gurobi.Var x_499 (value 0.0)>>
# x_500 <bound method Var.getAttr of <gurobi.Var x_500 (value 0.0)>>
# x_501 <bound method Var.getAttr of <gurobi.Var x_501 (value 1.0)>>
# x_502 <bound method Var.getAttr of <gurobi.Var x_502 (value 0.0)>>
# x_503 <bound method Var.getAttr of <gurobi.Var x_503 (value 0.0)>>
# x_504 <bound method Var.getAttr of <gurobi.Var x_504 (value 0.0)>>
# x_505 <bound method Var.getAttr of <gurobi.Var x_505 (value 1.0)>>
# x_506 <bound method Var.getAttr of <gurobi.Var x_506 (value 0.0)>>
# x_507 <bound method Var.getAttr of <gurobi.Var x_507 (value 0.0)>>
# x_508 <bound method Var.getAttr of <gurobi.Var x_508 (value 0.0)>>
# x_509 <bound method Var.getAttr of <gurobi.Var x_509 (value 0.0)>>
# x_510 <bound method Var.getAttr of <gurobi.Var x_510 (value 0.0)>>
# x_511 <bound method Var.getAttr of <gurobi.Var x_511 (value 0.0)>>
# x_512 <bound method Var.getAttr of <gurobi.Var x_512 (value 0.0)>>
# x_513 <bound method Var.getAttr of <gurobi.Var x_513 (value 0.0)>>
# x_514 <bound method Var.getAttr of <gurobi.Var x_514 (value 0.0)>>
# x_515 <bound method Var.getAttr of <gurobi.Var x_515 (value 0.0)>>
# x_516 <bound method Var.getAttr of <gurobi.Var x_516 (value 0.0)>>
# x_517 <bound method Var.getAttr of <gurobi.Var x_517 (value 0.0)>>
# x_518 <bound method Var.getAttr of <gurobi.Var x_518 (value 0.0)>>
# x_519 <bound method Var.getAttr of <gurobi.Var x_519 (value 0.0)>>
# x_520 <bound method Var.getAttr of <gurobi.Var x_520 (value 0.0)>>
# x_521 <bound method Var.getAttr of <gurobi.Var x_521 (value 0.0)>>
# x_522 <bound method Var.getAttr of <gurobi.Var x_522 (value 0.0)>>
# x_523 <bound method Var.getAttr of <gurobi.Var x_523 (value 0.0)>>
# x_524 <bound method Var.getAttr of <gurobi.Var x_524 (value 0.0)>>
# x_525 <bound method Var.getAttr of <gurobi.Var x_525 (value 0.0)>>
# x_526 <bound method Var.getAttr of <gurobi.Var x_526 (value 0.0)>>
# x_527 <bound method Var.getAttr of <gurobi.Var x_527 (value 0.0)>>
# x_528 <bound method Var.getAttr of <gurobi.Var x_528 (value 0.0)>>
# x_529 <bound method Var.getAttr of <gurobi.Var x_529 (value 0.0)>>
# x_530 <bound method Var.getAttr of <gurobi.Var x_530 (value 0.0)>>
# x_531 <bound method Var.getAttr of <gurobi.Var x_531 (value 0.0)>>
# x_532 <bound method Var.getAttr of <gurobi.Var x_532 (value 0.0)>>
# x_533 <bound method Var.getAttr of <gurobi.Var x_533 (value 0.0)>>
# x_534 <bound method Var.getAttr of <gurobi.Var x_534 (value 0.0)>>
# x_535 <bound method Var.getAttr of <gurobi.Var x_535 (value 0.0)>>
# x_536 <bound method Var.getAttr of <gurobi.Var x_536 (value 0.0)>>
# x_537 <bound method Var.getAttr of <gurobi.Var x_537 (value 0.0)>>
# x_538 <bound method Var.getAttr of <gurobi.Var x_538 (value 0.0)>>
# x_539 <bound method Var.getAttr of <gurobi.Var x_539 (value 1.0)>>
# x_540 <bound method Var.getAttr of <gurobi.Var x_540 (value 0.0)>>
# x_541 <bound method Var.getAttr of <gurobi.Var x_541 (value 0.0)>>
# x_542 <bound method Var.getAttr of <gurobi.Var x_542 (value 0.0)>>
# x_543 <bound method Var.getAttr of <gurobi.Var x_543 (value 0.0)>>
# x_544 <bound method Var.getAttr of <gurobi.Var x_544 (value 0.0)>>
# x_545 <bound method Var.getAttr of <gurobi.Var x_545 (value 0.0)>>
# x_546 <bound method Var.getAttr of <gurobi.Var x_546 (value 1.0)>>
# x_547 <bound method Var.getAttr of <gurobi.Var x_547 (value 0.0)>>
# x_548 <bound method Var.getAttr of <gurobi.Var x_548 (value 0.0)>>
# x_549 <bound method Var.getAttr of <gurobi.Var x_549 (value 0.0)>>
# x_550 <bound method Var.getAttr of <gurobi.Var x_550 (value 0.0)>>
# x_551 <bound method Var.getAttr of <gurobi.Var x_551 (value 0.0)>>
# x_552 <bound method Var.getAttr of <gurobi.Var x_552 (value 0.0)>>
# x_553 <bound method Var.getAttr of <gurobi.Var x_553 (value 1.0)>>
# x_554 <bound method Var.getAttr of <gurobi.Var x_554 (value 0.0)>>
# x_555 <bound method Var.getAttr of <gurobi.Var x_555 (value 0.0)>>
# x_556 <bound method Var.getAttr of <gurobi.Var x_556 (value 0.0)>>
# x_557 <bound method Var.getAttr of <gurobi.Var x_557 (value 1.0)>>
# x_558 <bound method Var.getAttr of <gurobi.Var x_558 (value 0.0)>>
# x_559 <bound method Var.getAttr of <gurobi.Var x_559 (value 0.0)>>
# x_560 <bound method Var.getAttr of <gurobi.Var x_560 (value 0.0)>>
# x_561 <bound method Var.getAttr of <gurobi.Var x_561 (value 0.0)>>
# x_562 <bound method Var.getAttr of <gurobi.Var x_562 (value 0.0)>>
# x_563 <bound method Var.getAttr of <gurobi.Var x_563 (value 0.0)>>
# x_564 <bound method Var.getAttr of <gurobi.Var x_564 (value 0.0)>>
# x_565 <bound method Var.getAttr of <gurobi.Var x_565 (value 0.0)>>
# x_566 <bound method Var.getAttr of <gurobi.Var x_566 (value 0.0)>>
# x_567 <bound method Var.getAttr of <gurobi.Var x_567 (value 0.0)>>
# x_568 <bound method Var.getAttr of <gurobi.Var x_568 (value 0.0)>>
# x_569 <bound method Var.getAttr of <gurobi.Var x_569 (value 0.0)>>
# x_570 <bound method Var.getAttr of <gurobi.Var x_570 (value 1.0)>>
# x_571 <bound method Var.getAttr of <gurobi.Var x_571 (value 0.0)>>
# x_572 <bound method Var.getAttr of <gurobi.Var x_572 (value 0.0)>>
# x_573 <bound method Var.getAttr of <gurobi.Var x_573 (value 0.0)>>
# x_574 <bound method Var.getAttr of <gurobi.Var x_574 (value 0.0)>>
# x_575 <bound method Var.getAttr of <gurobi.Var x_575 (value 1.0)>>
# x_576 <bound method Var.getAttr of <gurobi.Var x_576 (value 0.0)>>
# x_577 <bound method Var.getAttr of <gurobi.Var x_577 (value 1.0)>>
# x_578 <bound method Var.getAttr of <gurobi.Var x_578 (value 0.0)>>
# x_579 <bound method Var.getAttr of <gurobi.Var x_579 (value 0.0)>>
# x_580 <bound method Var.getAttr of <gurobi.Var x_580 (value 0.0)>>
# x_581 <bound method Var.getAttr of <gurobi.Var x_581 (value 0.0)>>
# x_582 <bound method Var.getAttr of <gurobi.Var x_582 (value 0.0)>>
# x_583 <bound method Var.getAttr of <gurobi.Var x_583 (value 0.0)>>
# x_584 <bound method Var.getAttr of <gurobi.Var x_584 (value 0.0)>>
# x_585 <bound method Var.getAttr of <gurobi.Var x_585 (value 0.0)>>
# x_586 <bound method Var.getAttr of <gurobi.Var x_586 (value 0.0)>>
# x_587 <bound method Var.getAttr of <gurobi.Var x_587 (value 0.0)>>
# x_588 <bound method Var.getAttr of <gurobi.Var x_588 (value 0.0)>>
# x_589 <bound method Var.getAttr of <gurobi.Var x_589 (value 0.0)>>
# x_590 <bound method Var.getAttr of <gurobi.Var x_590 (value 0.0)>>
# x_591 <bound method Var.getAttr of <gurobi.Var x_591 (value 0.0)>>
# x_592 <bound method Var.getAttr of <gurobi.Var x_592 (value 0.0)>>
# x_593 <bound method Var.getAttr of <gurobi.Var x_593 (value 0.0)>>
# x_594 <bound method Var.getAttr of <gurobi.Var x_594 (value 0.0)>>
# x_595 <bound method Var.getAttr of <gurobi.Var x_595 (value 0.0)>>
# x_596 <bound method Var.getAttr of <gurobi.Var x_596 (value 0.0)>>
# x_597 <bound method Var.getAttr of <gurobi.Var x_597 (value 0.0)>>
# x_598 <bound method Var.getAttr of <gurobi.Var x_598 (value 1.0)>>
# x_599 <bound method Var.getAttr of <gurobi.Var x_599 (value 0.0)>>
# x_600 <bound method Var.getAttr of <gurobi.Var x_600 (value 0.0)>>
# x_601 <bound method Var.getAttr of <gurobi.Var x_601 (value 0.0)>>
# x_602 <bound method Var.getAttr of <gurobi.Var x_602 (value 0.0)>>
# x_603 <bound method Var.getAttr of <gurobi.Var x_603 (value 0.0)>>
# x_604 <bound method Var.getAttr of <gurobi.Var x_604 (value 0.0)>>
# x_605 <bound method Var.getAttr of <gurobi.Var x_605 (value 0.0)>>
# x_606 <bound method Var.getAttr of <gurobi.Var x_606 (value 0.0)>>
# x_607 <bound method Var.getAttr of <gurobi.Var x_607 (value 0.0)>>
# x_608 <bound method Var.getAttr of <gurobi.Var x_608 (value 0.0)>>
# x_609 <bound method Var.getAttr of <gurobi.Var x_609 (value 0.0)>>
# x_610 <bound method Var.getAttr of <gurobi.Var x_610 (value 0.0)>>
# x_611 <bound method Var.getAttr of <gurobi.Var x_611 (value 1.0)>>
# x_612 <bound method Var.getAttr of <gurobi.Var x_612 (value 0.0)>>
# x_613 <bound method Var.getAttr of <gurobi.Var x_613 (value 0.0)>>
# x_614 <bound method Var.getAttr of <gurobi.Var x_614 (value 0.0)>>
# x_615 <bound method Var.getAttr of <gurobi.Var x_615 (value 0.0)>>
# x_616 <bound method Var.getAttr of <gurobi.Var x_616 (value 0.0)>>
# x_617 <bound method Var.getAttr of <gurobi.Var x_617 (value 1.0)>>
# x_618 <bound method Var.getAttr of <gurobi.Var x_618 (value 0.0)>>
# x_619 <bound method Var.getAttr of <gurobi.Var x_619 (value 0.0)>>
# x_620 <bound method Var.getAttr of <gurobi.Var x_620 (value 0.0)>>
# x_621 <bound method Var.getAttr of <gurobi.Var x_621 (value 0.0)>>
# x_622 <bound method Var.getAttr of <gurobi.Var x_622 (value 0.0)>>
# x_623 <bound method Var.getAttr of <gurobi.Var x_623 (value 0.0)>>
# x_624 <bound method Var.getAttr of <gurobi.Var x_624 (value 0.0)>>
# x_625 <bound method Var.getAttr of <gurobi.Var x_625 (value 0.0)>>
# x_626 <bound method Var.getAttr of <gurobi.Var x_626 (value 0.0)>>
# x_627 <bound method Var.getAttr of <gurobi.Var x_627 (value 0.0)>>
# x_628 <bound method Var.getAttr of <gurobi.Var x_628 (value 0.0)>>
# x_629 <bound method Var.getAttr of <gurobi.Var x_629 (value 0.0)>>
# x_630 <bound method Var.getAttr of <gurobi.Var x_630 (value 1.0)>>
# x_631 <bound method Var.getAttr of <gurobi.Var x_631 (value 0.0)>>
# x_632 <bound method Var.getAttr of <gurobi.Var x_632 (value 0.0)>>
# x_633 <bound method Var.getAttr of <gurobi.Var x_633 (value 0.0)>>
# x_634 <bound method Var.getAttr of <gurobi.Var x_634 (value 0.0)>>
# x_635 <bound method Var.getAttr of <gurobi.Var x_635 (value 0.0)>>
# x_636 <bound method Var.getAttr of <gurobi.Var x_636 (value 1.0)>>
# x_637 <bound method Var.getAttr of <gurobi.Var x_637 (value 0.0)>>
# x_638 <bound method Var.getAttr of <gurobi.Var x_638 (value 0.0)>>
# x_639 <bound method Var.getAttr of <gurobi.Var x_639 (value 0.0)>>
# x_640 <bound method Var.getAttr of <gurobi.Var x_640 (value 0.0)>>
# x_641 <bound method Var.getAttr of <gurobi.Var x_641 (value 0.0)>>
# x_642 <bound method Var.getAttr of <gurobi.Var x_642 (value 0.0)>>
# x_643 <bound method Var.getAttr of <gurobi.Var x_643 (value 0.0)>>
# x_644 <bound method Var.getAttr of <gurobi.Var x_644 (value 0.0)>>
# x_645 <bound method Var.getAttr of <gurobi.Var x_645 (value 0.0)>>
# x_646 <bound method Var.getAttr of <gurobi.Var x_646 (value 0.0)>>
# x_647 <bound method Var.getAttr of <gurobi.Var x_647 (value 0.0)>>
# x_648 <bound method Var.getAttr of <gurobi.Var x_648 (value 1.0)>>
# x_649 <bound method Var.getAttr of <gurobi.Var x_649 (value 0.0)>>
# x_650 <bound method Var.getAttr of <gurobi.Var x_650 (value 0.0)>>
# x_651 <bound method Var.getAttr of <gurobi.Var x_651 (value 0.0)>>
# x_652 <bound method Var.getAttr of <gurobi.Var x_652 (value 0.0)>>
# x_653 <bound method Var.getAttr of <gurobi.Var x_653 (value 0.0)>>
# d_0 0.0
# d_1 0.0
# d_2 0.0
# d_3 0.0
# d_4 0.0
# d_5 0.0
# d_6 0.0
# d_7 0.0
# d_8 0.0
# d_9 0.0
# d_10 0.0
# d_11 0.0
# d_12 0.0
# d_13 0.0
# d_14 0.0
# d_15 0.0
# d_16 0.0
# d_17 0.0
# d_18 0.0
# d_19 0.0
# d_20 0.0
# d_21 0.0
# d_22 0.0
# d_23 0.0
# d_24 0.0
# d_25 0.0
# d_26 0.0
# d_27 0.0
# d_28 0.0
# d_29 0.0
# d_30 0.0
# d_31 0.0
# d_32 0.0
# d_33 0.0
# d_34 0.0
# d_35 0.0
# d_36 0.0
# d_37 0.0
# d_38 0.0
# d_39 0.0
# d_40 0.0
# d_41 0.0
# d_42 0.0
# d_43 0.0
# d_44 0.0
# d_45 0.0
# d_46 0.0
# d_47 0.0
# d_48 0.0
# d_49 0.0
# d_50 0.0
# d_51 0.0
# d_52 0.0
# d_53 0.0
# d_54 0.0
# d_55 0.0
# d_56 0.0
# d_57 0.0
# d_58 0.0
# d_59 0.0
# d_60 0.0
# d_61 0.0
# d_62 0.0
# d_63 0.0
# d_64 0.0
# d_65 0.0
# d_66 0.0
# d_67 0.0
# d_68 0.0
# d_69 0.0
# d_70 0.0
# d_71 0.0
# d_72 0.0
# d_73 0.0
# d_74 0.0
# d_75 0.0
# d_76 0.0
# d_77 0.0
# d_78 0.0
# d_79 0.0
# d_80 0.0
# d_81 0.0
# d_82 0.0
# d_83 0.0
# d_84 0.0
# d_85 0.0
# d_86 0.0
# d_87 0.0
# d_88 0.0
# d_89 0.0
# d_90 0.0
# d_91 0.0
# d_92 0.0
# d_93 0.0
# d_94 0.0
# d_95 0.0
# d_96 0.0
# d_97 0.0
# d_98 0.0
# d_99 0.0
