# %%
import pandas as pd
import os
from multiprocessing import Process
import copy
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# Node의 부모 Class
class Node:
    def __init__(self, node_name):
        self.node_name = node_name

# Edge의 부모 Class
class Edge:
    def __init__(self, origin, dest):
        self.origin = origin
        self.dest = dest

# Airport Class
class Airport(Node):
    def __init__(self, airport_name):
        super().__init__(airport_name)

# Flight Class
class Flight(Edge):
    def __init__(self, index, origin, dest, origin_date, dest_date, flight_duration, flight_type):
        super().__init__(origin, dest)
        self.index = index
        self.origin_date = origin_date
        self.dest_date = dest_date
        self.flight_duration = flight_duration
        self.flight_type = flight_type

    def print(self):
        print(self.index, self.origin, self.origin_date, self.dest,
              self.dest_date, self.flight_duration, self.flight_type)
        

# Stack Node의 구조
class Stackitem:
    def __init__(self, flight: Flight, flights_sequence: list = None, landing_number = None):
        if flights_sequence:
            self.flight = flight
            flights_sequence.append(flight.index)
            self.flights_sequence = flights_sequence
            self.landing_number = landing_number + 1
            # self.time = time + dt.timedelta(flight.flight_duration)
        else:
            self.flight = flight
            self.flights_sequence = [flight.index]
            self.landing_number = 1
            # self.time = flight.flight_duration;

# %%
# Initial Setting - Test
flight_graph = dict()
flight_excel = pd.read_excel("flight.xlsx")
flight_excel.columns = ['INDEX', 'ORIGIN', 'ORIGIN_DATE', 'DEST','DEST_DATE', 'FLIGHT_DURATION','AIRCRAFT_TYPE' ]
airports_set = set()

# %%
# Graph insert Node
for i in range(100) :
    airports_set.add(flight_excel.loc[i]['ORIGIN'])
    airports_set.add(flight_excel.loc[i]['DEST'])
    
for airports in airports_set :
    flight_graph[airports] = list()

# Graph insert Edge
for i in range(100) :
    flight_graph[flight_excel.loc[i]['ORIGIN']].append(Flight(flight_excel.loc[i]['INDEX'], flight_excel.loc[i]['ORIGIN'], flight_excel.loc[i]['DEST'],
                                                              flight_excel.loc[i]['ORIGIN_DATE'], flight_excel.loc[i]['DEST_DATE'],
                                                              flight_excel.loc[i]['FLIGHT_DURATION'], flight_excel.loc[i]['AIRCRAFT_TYPE']))

# %%
print(len(airports_set))
# Out:
# 5

# %%
pairing_set = list()

# clustering을 통한 flights set의 크기를 줄여야지 경우의 수가 줄어듬
# 하지만 그렇다면 시간을 어떻게 배분해야하는가? 기준은? 시간 → 기종? 조금더 생각해봐야 할 거 같다.

# 여기서 Node 시작에 따라 끝나는 경우는
# 만나는 Base가 같은경우가 있고,
# 만약 끝이 Base가 아닌데 갈 곳이 없는 경우가 있다.
# 그렇다면 모든 pairing의 모든 경우를 넣어도 모든 경우가 나온다!
# 

for airport in airports_set :
    # pairing_set.append(["-" * 10, airport, "-" * 10])

    for flight in flight_graph[airport] :
        # 항공편, 항공편의 순서를 넣는다
        stack_temp = [Stackitem(flight)]
        
        while stack_temp:
            # 현재 진행 중인 항공편의 정보
            flights_information_now = stack_temp.pop()

            pairing_set.append(copy.deepcopy(flights_information_now.flights_sequence))
            # 만약 해당 항공편이 진행됨으로서 base로 간다면 해당 항공편은 더 진행할 필요가 없음
            if (flights_information_now.flight.dest == flight.origin) :
                continue
            
            else :
                pairing_set[-1].append("DeadHead")

            # Search Space Extend
            for flight_next in flight_graph[flights_information_now.flight.dest] :
                # 항공기 기종이 같은지? 시간이 가능한지? (날짜가 같다면 시간까지 비교, 다르다면 날짜 비교)
                flight_type_equal = (flights_information_now.flight.flight_type == flight_next.flight_type)
                flight_time_possible = flights_information_now.flight.dest_date < flight_next.origin_date and (flight_next.origin_date - flights_information_now.flight.dest_date).seconds/3600 >= 3
                flight_day_possible = (flight_next.dest_date  - flight.origin_date).days <= 7
                flight_landing_possible = (flights_information_now.landing_number <= 3)

                # 기종이 다르거나 시간이 불가능하면 해당 항공편은 Search에 사용하지 않음
                if (not flight_type_equal or not flight_time_possible or not flight_day_possible or not flight_landing_possible) :
                    continue

                # 기종이 같고, 시간이 가능하다면 Search를 위해 stack에 추가(항공편의 순서까지)
                temp_list = copy.deepcopy(flights_information_now.flights_sequence)
                #if (flights_information_now.flight.dest_date < flight_next.origin_date) :
                    #for i in range(0, int(flight_next.origin_date.day - flights_information_now.flight.dest_date.day)) :
                        #temp_list.append("Layover")
                        
                stack_temp.append(Stackitem(flight_next, temp_list, flights_information_now.landing_number))
                

#for pairing in pairing_set :
    #print(pairing)

# 첫번째 방안 : 모든 항공편들의 순서를 저장한다
# 그렇다면 만들 수 있는(DeadHead, Layover, Feasible) Pairing의 모든 경우가 나온다.
# 하지만 이럴때는 시간이 n^n까지 나올 수 있는 것으로 보인다.
# 여기서 경우의 수를 줄이는 조건을 넣을 때
# 첫번째 - 항공기 종류
# 두번째 - 전 항공편의 도착시간보다 현 항공편의 출발시간이 느려야한다
# 세번째 - Crew의 Trun Time이 MMT보다 크거나 같아야 한다.(Slack Time은 어떻게 될려나?)
# feasible pairing은 좀 많다. -> 그럼 DeadHead가 존재하는 pairing은 넣어야하는 것인가?
# 지연전파? 존재한다?

# stack에 넣을 때 모든 정보를 넣어버린다면? 오히려 쉬워진다. 하지만 메모리를 많이 쓰므로 최적화가 필요함(조건을 생각해야 함)

# %%
import re

# 엑셀 파일명
filename = 'output.xlsx'

# 데이터프레임으로 변환
df = pd.DataFrame(pairing_set)

# 엑셀로 출력
df.to_excel(filename, index=False, header=False)

# %%
# 비행기 기종 : {크루원 수, 비행 수당, 기본급}
salary={}

salary_excel = pd.read_excel("salary.xlsx")
for index, row in salary_excel.iterrows():
    aircraft = row['AIRCRAFT']
    crew_num = row['CREW_NUM']
    flight_salary = row['FLIGHT_SALARY']
    base_salary = row['BASE_SALARY']
    layover_cost = row['BASE_SALARY']
    salary[aircraft] = {'CREW_NUM': crew_num, 'FLIGHT_SALARY': flight_salary, 'BASE_SALARY': base_salary,'LAYOVER_COST': layover_cost}


total = []

for pairing in pairing_set :
    crew_num = salary[flight_excel.loc[int(re.search(r'\d+', pairing[0]).group())-1]['AIRCRAFT_TYPE']]['CREW_NUM']
    base_salary = salary[flight_excel.loc[int(re.search(r'\d+', pairing[0]).group())-1]['AIRCRAFT_TYPE']]['BASE_SALARY']
    flight_salary = salary[flight_excel.loc[int(re.search(r'\d+', pairing[0]).group())-1]['AIRCRAFT_TYPE']]['FLIGHT_SALARY']
    layover_cost =  salary[flight_excel.loc[int(re.search(r'\d+', pairing[0]).group())-1]['AIRCRAFT_TYPE']]['LAYOVER_COST']
    layover_time = 0
    flight_time = flight_excel.loc[int(re.search(r'\d+', pairing[0]).group())]['FLIGHT_DURATION']
    deadhead=0
    for idx,pair in enumerate(pairing[1:],start=1):
        if(pair != "DeadHead") :
            n = int(re.search(r'\d+', pair).group())
            flight_time+=flight_excel.loc[n-1]['FLIGHT_DURATION']
            before_flight = flight_excel.loc[int(re.search(r'\d+', pairing[idx-1]).group())-1]['ORIGIN_DATE']
            current_flight = flight_excel.loc[int(re.search(r'\d+', pair).group())-1]['ORIGIN_DATE']
            layover_time += (current_flight-before_flight).seconds/3600
        else :
            #deadhead cost 정의하기
            deadhead_cost = 100
            deadhead = deadhead_cost * crew_num
        
            

    print(pairing)
    #print('base_salary :',base_salary,'flight_salary :', flight_salary*flight_time,'layover_cost :',layover_cost*layover_time,'deadhead :',deadhead)
    total.append(base_salary+flight_salary*flight_time+layover_cost*layover_time)
    #print('Total: ',base_salary+flight_salary*flight_time+layover_cost*layover_time)
        
    #print(pairing)
    #print(total)
# Out:
# ['F1', 'DeadHead']
# ['F1', 'F37', 'DeadHead']
# ['F1', 'F37', 'F65', 'DeadHead']
# ['F1', 'F18', 'DeadHead']
# ['F1', 'F18', 'F79', 'DeadHead']
# ['F1', 'F18', 'F79', 'F48', 'DeadHead']
# ['F1', 'F18', 'F76', 'DeadHead']
# ['F1', 'F18', 'F76', 'F48', 'DeadHead']
# ['F1', 'F18', 'F8', 'DeadHead']
# ['F1', 'F18', 'F8', 'F90', 'DeadHead']
# ['F1', 'F18', 'F8', 'F66', 'DeadHead']
# ['F1', 'F18', 'F5', 'DeadHead']
# ['F19', 'DeadHead']
# ['F19', 'F81']
# ['F19', 'F15']
# ['F24', 'DeadHead']
# ['F24', 'F81']
# ['F24', 'F53']
# ['F24', 'F31']
# ['F24', 'F15']
# ['F27', 'DeadHead']
# ['F27', 'F81']
# ['F27', 'F31']
# ['F27', 'F15']
# ['F38', 'DeadHead']
# ['F38', 'F65', 'DeadHead']
# ['F45', 'DeadHead']
# ['F45', 'F91', 'DeadHead']
# ['F45', 'F77', 'DeadHead']
# ['F45', 'F57', 'DeadHead']
# ['F45', 'F16', 'DeadHead']
# ['F45', 'F3']
# ['F50', 'DeadHead']
# ['F50', 'F91', 'DeadHead']
# ['F50', 'F77', 'DeadHead']
# ['F50', 'F57', 'DeadHead']
# ['F50', 'F16', 'DeadHead']
# ['F50', 'F3']
# ['F54', 'DeadHead']
# ['F54', 'F3']
# ['F58', 'DeadHead']
# ['F58', 'F81']
# ['F58', 'F31']
# ['F58', 'F15']
# ['F60', 'DeadHead']
# ['F60', 'F96']
# ['F60', 'F61', 'DeadHead']
# ['F60', 'F61', 'F85']
# ['F60', 'F61', 'F82', 'DeadHead']
# ['F60', 'F61', 'F82', 'F49', 'DeadHead']
# ['F60', 'F61', 'F82', 'F22', 'DeadHead']
# ['F60', 'F61', 'F36', 'DeadHead']
# ['F60', 'F61', 'F28', 'DeadHead']
# ['F60', 'F61', 'F28', 'F22', 'DeadHead']
# ['F60', 'F61', 'F7', 'DeadHead']
# ['F60', 'F49', 'DeadHead']
# ['F60', 'F29', 'DeadHead']
# ['F60', 'F29', 'F99']
# ['F60', 'F29', 'F63']
# ['F60', 'F29', 'F23', 'DeadHead']
# ['F60', 'F22', 'DeadHead']
# ['F60', 'F2', 'DeadHead']
# ['F60', 'F2', 'F85']
# ['F60', 'F2', 'F82', 'DeadHead']
# ['F60', 'F2', 'F82', 'F49', 'DeadHead']
# ['F60', 'F2', 'F82', 'F22', 'DeadHead']
# ['F60', 'F2', 'F36', 'DeadHead']
# ['F60', 'F2', 'F28', 'DeadHead']
# ['F60', 'F2', 'F28', 'F22', 'DeadHead']
# ['F60', 'F2', 'F7', 'DeadHead']
# ['F62', 'DeadHead']
# ['F62', 'F81']
# ['F62', 'F15']
# ['F69', 'DeadHead']
# ['F69', 'F90', 'DeadHead']
# ['F69', 'F84']
# ['F69', 'F66', 'DeadHead']
# ['F69', 'F41']
# ['F69', 'F12']
# ['F73', 'DeadHead']
# ['F73', 'F84']
# ['F73', 'F66', 'DeadHead']
# ['F73', 'F56', 'DeadHead']
# ['F73', 'F56', 'F79', 'DeadHead']
# ['F73', 'F56', 'F79', 'F48', 'DeadHead']
# ['F73', 'F56', 'F8', 'DeadHead']
# ['F73', 'F56', 'F8', 'F90', 'DeadHead']
# ['F73', 'F56', 'F8', 'F66', 'DeadHead']
# ['F73', 'F56', 'F5', 'DeadHead']
# ['F73', 'F41']
# ['F73', 'F12']
# ['F80', 'DeadHead']
# ['F80', 'F96']
# ['F80', 'F61', 'DeadHead']
# ['F80', 'F61', 'F85']
# ['F80', 'F61', 'F82', 'DeadHead']
# ['F80', 'F61', 'F82', 'F49', 'DeadHead']
# ['F80', 'F61', 'F82', 'F22', 'DeadHead']
# ['F80', 'F61', 'F36', 'DeadHead']
# ['F80', 'F61', 'F28', 'DeadHead']
# ['F80', 'F61', 'F28', 'F22', 'DeadHead']
# ['F80', 'F61', 'F7', 'DeadHead']
# ['F80', 'F49', 'DeadHead']
# ['F80', 'F29', 'DeadHead']
# ['F80', 'F29', 'F99']
# ['F80', 'F29', 'F63']
# ['F80', 'F29', 'F23', 'DeadHead']
# ['F80', 'F22', 'DeadHead']
# ['F80', 'F2', 'DeadHead']
# ['F80', 'F2', 'F85']
# ['F80', 'F2', 'F82', 'DeadHead']
# ['F80', 'F2', 'F82', 'F49', 'DeadHead']
# ['F80', 'F2', 'F82', 'F22', 'DeadHead']
# ['F80', 'F2', 'F36', 'DeadHead']
# ['F80', 'F2', 'F28', 'DeadHead']
# ['F80', 'F2', 'F28', 'F22', 'DeadHead']
# ['F80', 'F2', 'F7', 'DeadHead']
# ['F86', 'DeadHead']
# ['F86', 'F91', 'DeadHead']
# ['F86', 'F77', 'DeadHead']
# ['F86', 'F57', 'DeadHead']
# ['F86', 'F44']
# ['F86', 'F43', 'DeadHead']
# ['F86', 'F43', 'F71', 'DeadHead']
# ['F86', 'F43', 'F67', 'DeadHead']
# ['F86', 'F43', 'F67', 'F77', 'DeadHead']
# ['F86', 'F43', 'F67', 'F3']
# ['F86', 'F43', 'F52', 'DeadHead']
# ['F86', 'F43', 'F52', 'F40', 'DeadHead']
# ['F86', 'F43', 'F52', 'F11', 'DeadHead']
# ['F86', 'F43', 'F21', 'DeadHead']
# ['F86', 'F43', 'F21', 'F77', 'DeadHead']
# ['F86', 'F43', 'F21', 'F3']
# ['F86', 'F43', 'F6', 'DeadHead']
# ['F86', 'F43', 'F6', 'F97', 'DeadHead']
# ['F86', 'F43', 'F6', 'F95', 'DeadHead']
# ['F86', 'F43', 'F6', 'F64', 'DeadHead']
# ['F86', 'F43', 'F6', 'F59', 'DeadHead']
# ['F86', 'F16', 'DeadHead']
# ['F86', 'F3']
# ['F2', 'DeadHead']
# ['F2', 'F85', 'DeadHead']
# ['F2', 'F82']
# ['F2', 'F36']
# ['F2', 'F28']
# ['F2', 'F7']
# ['F4', 'DeadHead']
# ['F4', 'F71']
# ['F4', 'F67', 'DeadHead']
# ['F4', 'F67', 'F77', 'DeadHead']
# ['F4', 'F67', 'F3', 'DeadHead']
# ['F4', 'F52', 'DeadHead']
# ['F4', 'F52', 'F40', 'DeadHead']
# ['F4', 'F52', 'F40', 'F91', 'DeadHead']
# ['F4', 'F52', 'F40', 'F16', 'DeadHead']
# ['F4', 'F52', 'F40', 'F3', 'DeadHead']
# ['F4', 'F52', 'F11']
# ['F4', 'F21', 'DeadHead']
# ['F4', 'F21', 'F77', 'DeadHead']
# ['F4', 'F21', 'F3', 'DeadHead']
# ['F4', 'F6']
# ['F9', 'DeadHead']
# ['F9', 'F90']
# ['F9', 'F89', 'DeadHead']
# ['F9', 'F89', 'F73', 'DeadHead']
# ['F9', 'F89', 'F73', 'F84', 'DeadHead']
# ['F9', 'F89', 'F73', 'F66']
# ['F9', 'F89', 'F73', 'F56', 'DeadHead']
# ['F9', 'F89', 'F73', 'F41', 'DeadHead']
# ['F9', 'F89', 'F73', 'F12', 'DeadHead']
# ['F9', 'F56', 'DeadHead']
# ['F9', 'F56', 'F79']
# ['F9', 'F56', 'F8', 'DeadHead']
# ['F9', 'F56', 'F8', 'F90']
# ['F9', 'F56', 'F8', 'F66']
# ['F9', 'F56', 'F5', 'DeadHead']
# ['F9', 'F34', 'DeadHead']
# ['F9', 'F34', 'F79']
# ['F9', 'F34', 'F76']
# ['F9', 'F34', 'F33']
# ['F9', 'F34', 'F8', 'DeadHead']
# ['F9', 'F34', 'F8', 'F90']
# ['F9', 'F34', 'F8', 'F66']
# ['F9', 'F34', 'F5', 'DeadHead']
# ['F15', 'DeadHead']
# ['F18', 'DeadHead']
# ['F18', 'F79']
# ['F18', 'F76']
# ['F18', 'F8', 'DeadHead']
# ['F18', 'F8', 'F90']
# ['F18', 'F8', 'F66']
# ['F18', 'F5', 'DeadHead']
# ['F22', 'DeadHead']
# ['F29', 'DeadHead']
# ['F29', 'F99', 'DeadHead']
# ['F29', 'F63', 'DeadHead']
# ['F29', 'F23', 'DeadHead']
# ['F31', 'DeadHead']
# ['F31', 'F62']
# ['F31', 'F19']
# ['F32', 'DeadHead']
# ['F32', 'F100', 'DeadHead']
# ['F32', 'F100', 'F91', 'DeadHead']
# ['F32', 'F100', 'F77', 'DeadHead']
# ['F32', 'F100', 'F57', 'DeadHead']
# ['F32', 'F100', 'F16', 'DeadHead']
# ['F32', 'F100', 'F3', 'DeadHead']
# ['F32', 'F55']
# ['F32', 'F40', 'DeadHead']
# ['F32', 'F40', 'F91', 'DeadHead']
# ['F32', 'F40', 'F16', 'DeadHead']
# ['F32', 'F40', 'F3', 'DeadHead']
# ['F32', 'F20', 'DeadHead']
# ['F32', 'F20', 'F74']
# ['F32', 'F20', 'F52', 'DeadHead']
# ['F32', 'F20', 'F52', 'F40', 'DeadHead']
# ['F32', 'F20', 'F52', 'F11']
# ['F32', 'F20', 'F51']
# ['F32', 'F20', 'F6']
# ['F32', 'F11']
# ['F35', 'DeadHead']
# ['F35', 'F71']
# ['F35', 'F67', 'DeadHead']
# ['F35', 'F67', 'F77', 'DeadHead']
# ['F35', 'F67', 'F3', 'DeadHead']
# ['F35', 'F52', 'DeadHead']
# ['F35', 'F52', 'F40', 'DeadHead']
# ['F35', 'F52', 'F40', 'F91', 'DeadHead']
# ['F35', 'F52', 'F40', 'F16', 'DeadHead']
# ['F35', 'F52', 'F40', 'F3', 'DeadHead']
# ['F35', 'F52', 'F11']
# ['F35', 'F21', 'DeadHead']
# ['F35', 'F21', 'F77', 'DeadHead']
# ['F35', 'F21', 'F3', 'DeadHead']
# ['F37', 'DeadHead']
# ['F37', 'F65', 'DeadHead']
# ['F48', 'DeadHead']
# ['F48', 'F5', 'DeadHead']
# ['F49', 'DeadHead']
# ['F53', 'DeadHead']
# ['F53', 'F62']
# ['F53', 'F58']
# ['F59', 'DeadHead']
# ['F59', 'F40', 'DeadHead']
# ['F59', 'F40', 'F91', 'DeadHead']
# ['F59', 'F40', 'F16', 'DeadHead']
# ['F59', 'F40', 'F3', 'DeadHead']
# ['F59', 'F11']
# ['F61', 'DeadHead']
# ['F61', 'F85', 'DeadHead']
# ['F61', 'F82']
# ['F61', 'F36']
# ['F61', 'F28']
# ['F61', 'F7']
# ['F64', 'DeadHead']
# ['F64', 'F67', 'DeadHead']
# ['F64', 'F67', 'F77', 'DeadHead']
# ['F64', 'F67', 'F3', 'DeadHead']
# ['F64', 'F52', 'DeadHead']
# ['F64', 'F52', 'F40', 'DeadHead']
# ['F64', 'F52', 'F40', 'F91', 'DeadHead']
# ['F64', 'F52', 'F40', 'F16', 'DeadHead']
# ['F64', 'F52', 'F40', 'F3', 'DeadHead']
# ['F64', 'F52', 'F11']
# ['F81', 'DeadHead']
# ['F92', 'DeadHead']
# ['F92', 'F87', 'DeadHead']
# ['F92', 'F87', 'F85', 'DeadHead']
# ['F92', 'F87', 'F36']
# ['F92', 'F87', 'F28']
# ['F92', 'F87', 'F25']
# ['F92', 'F87', 'F7']
# ['F92', 'F83', 'DeadHead']
# ['F92', 'F83', 'F99', 'DeadHead']
# ['F92', 'F83', 'F68', 'DeadHead']
# ['F92', 'F83', 'F63', 'DeadHead']
# ['F92', 'F75']
# ['F92', 'F17']
# ['F95', 'DeadHead']
# ['F96', 'DeadHead']
# ['F97', 'DeadHead']
# ['F97', 'F67', 'DeadHead']
# ['F97', 'F67', 'F77', 'DeadHead']
# ['F97', 'F67', 'F3', 'DeadHead']
# ['F97', 'F52', 'DeadHead']
# ['F97', 'F52', 'F40', 'DeadHead']
# ['F97', 'F52', 'F40', 'F91', 'DeadHead']
# ['F97', 'F52', 'F40', 'F16', 'DeadHead']
# ['F97', 'F52', 'F40', 'F3', 'DeadHead']
# ['F97', 'F52', 'F11']
# ['F98', 'DeadHead']
# ['F98', 'F71']
# ['F98', 'F67', 'DeadHead']
# ['F98', 'F67', 'F77', 'DeadHead']
# ['F98', 'F67', 'F3', 'DeadHead']
# ['F98', 'F52', 'DeadHead']
# ['F98', 'F52', 'F40', 'DeadHead']
# ['F98', 'F52', 'F40', 'F91', 'DeadHead']
# ['F98', 'F52', 'F40', 'F16', 'DeadHead']
# ['F98', 'F52', 'F40', 'F3', 'DeadHead']
# ['F98', 'F52', 'F11']
# ['F98', 'F21', 'DeadHead']
# ['F98', 'F21', 'F77', 'DeadHead']
# ['F98', 'F21', 'F3', 'DeadHead']
# ['F7', 'DeadHead']
# ['F11', 'DeadHead']
# ['F12', 'DeadHead']
# ['F14', 'DeadHead']
# ['F14', 'F96', 'DeadHead']
# ['F14', 'F92', 'DeadHead']
# ['F14', 'F92', 'F87']
# ['F14', 'F92', 'F83', 'DeadHead']
# ['F14', 'F92', 'F83', 'F99', 'DeadHead']
# ['F14', 'F92', 'F83', 'F68', 'DeadHead']
# ['F14', 'F92', 'F83', 'F63', 'DeadHead']
# ['F14', 'F92', 'F75', 'DeadHead']
# ['F14', 'F92', 'F75', 'F22', 'DeadHead']
# ['F14', 'F92', 'F17', 'DeadHead']
# ['F14', 'F92', 'F17', 'F49', 'DeadHead']
# ['F14', 'F61']
# ['F14', 'F2']
# ['F20', 'DeadHead']
# ['F20', 'F74', 'DeadHead']
# ['F20', 'F74', 'F98', 'DeadHead']
# ['F20', 'F74', 'F98', 'F71', 'DeadHead']
# ['F20', 'F74', 'F98', 'F67', 'DeadHead']
# ['F20', 'F74', 'F98', 'F52']
# ['F20', 'F74', 'F98', 'F21', 'DeadHead']
# ['F20', 'F74', 'F97', 'DeadHead']
# ['F20', 'F74', 'F97', 'F67', 'DeadHead']
# ['F20', 'F74', 'F97', 'F52']
# ['F20', 'F74', 'F64', 'DeadHead']
# ['F20', 'F74', 'F64', 'F67', 'DeadHead']
# ['F20', 'F74', 'F64', 'F52']
# ['F20', 'F74', 'F59']
# ['F20', 'F74', 'F4', 'DeadHead']
# ['F20', 'F74', 'F4', 'F71', 'DeadHead']
# ['F20', 'F74', 'F4', 'F67', 'DeadHead']
# ['F20', 'F74', 'F4', 'F52']
# ['F20', 'F74', 'F4', 'F21', 'DeadHead']
# ['F20', 'F74', 'F4', 'F6', 'DeadHead']
# ['F20', 'F52']
# ['F20', 'F51', 'DeadHead']
# ['F20', 'F51', 'F98', 'DeadHead']
# ['F20', 'F51', 'F98', 'F71', 'DeadHead']
# ['F20', 'F51', 'F98', 'F67', 'DeadHead']
# ['F20', 'F51', 'F98', 'F52']
# ['F20', 'F51', 'F98', 'F21', 'DeadHead']
# ['F20', 'F51', 'F97', 'DeadHead']
# ['F20', 'F51', 'F97', 'F67', 'DeadHead']
# ['F20', 'F51', 'F97', 'F52']
# ['F20', 'F51', 'F95']
# ['F20', 'F51', 'F64', 'DeadHead']
# ['F20', 'F51', 'F64', 'F67', 'DeadHead']
# ['F20', 'F51', 'F64', 'F52']
# ['F20', 'F51', 'F59']
# ['F20', 'F51', 'F4', 'DeadHead']
# ['F20', 'F51', 'F4', 'F71', 'DeadHead']
# ['F20', 'F51', 'F4', 'F67', 'DeadHead']
# ['F20', 'F51', 'F4', 'F52']
# ['F20', 'F51', 'F4', 'F21', 'DeadHead']
# ['F20', 'F51', 'F4', 'F6', 'DeadHead']
# ['F20', 'F6', 'DeadHead']
# ['F20', 'F6', 'F97', 'DeadHead']
# ['F20', 'F6', 'F97', 'F67', 'DeadHead']
# ['F20', 'F6', 'F97', 'F52']
# ['F20', 'F6', 'F95']
# ['F20', 'F6', 'F64', 'DeadHead']
# ['F20', 'F6', 'F64', 'F67', 'DeadHead']
# ['F20', 'F6', 'F64', 'F52']
# ['F20', 'F6', 'F59']
# ['F25', 'DeadHead']
# ['F26', 'DeadHead']
# ['F28', 'DeadHead']
# ['F28', 'F22', 'DeadHead']
# ['F34', 'DeadHead']
# ['F34', 'F79', 'DeadHead']
# ['F34', 'F79', 'F48', 'DeadHead']
# ['F34', 'F79', 'F48', 'F5', 'DeadHead']
# ['F34', 'F76', 'DeadHead']
# ['F34', 'F76', 'F48', 'DeadHead']
# ['F34', 'F76', 'F48', 'F5', 'DeadHead']
# ['F34', 'F33', 'DeadHead']
# ['F34', 'F33', 'F48', 'DeadHead']
# ['F34', 'F33', 'F48', 'F5', 'DeadHead']
# ['F34', 'F33', 'F18', 'DeadHead']
# ['F34', 'F33', 'F18', 'F79', 'DeadHead']
# ['F34', 'F33', 'F18', 'F76', 'DeadHead']
# ['F34', 'F33', 'F18', 'F8']
# ['F34', 'F33', 'F18', 'F5', 'DeadHead']
# ['F34', 'F8']
# ['F34', 'F5', 'DeadHead']
# ['F36', 'DeadHead']
# ['F40', 'DeadHead']
# ['F40', 'F91']
# ['F40', 'F16']
# ['F40', 'F3', 'DeadHead']
# ['F41', 'DeadHead']
# ['F46', 'DeadHead']
# ['F46', 'F73']
# ['F46', 'F69']
# ['F46', 'F38', 'DeadHead']
# ['F46', 'F1', 'DeadHead']
# ['F46', 'F1', 'F37', 'DeadHead']
# ['F46', 'F1', 'F18', 'DeadHead']
# ['F46', 'F1', 'F18', 'F79', 'DeadHead']
# ['F46', 'F1', 'F18', 'F76', 'DeadHead']
# ['F46', 'F1', 'F18', 'F8']
# ['F55', 'DeadHead']
# ['F55', 'F95']
# ['F55', 'F59']
# ['F56', 'DeadHead']
# ['F56', 'F79', 'DeadHead']
# ['F56', 'F79', 'F48', 'DeadHead']
# ['F56', 'F79', 'F48', 'F5', 'DeadHead']
# ['F56', 'F8']
# ['F56', 'F5', 'DeadHead']
# ['F66', 'DeadHead']
# ['F82', 'DeadHead']
# ['F82', 'F49', 'DeadHead']
# ['F82', 'F22', 'DeadHead']
# ['F84', 'DeadHead']
# ['F84', 'F38', 'DeadHead']
# ['F84', 'F38', 'F65', 'DeadHead']
# ['F85', 'DeadHead']
# ['F89', 'DeadHead']
# ['F89', 'F73']
# ['F90', 'DeadHead']
# ['F100', 'DeadHead']
# ['F100', 'F91']
# ['F100', 'F77', 'DeadHead']
# ['F100', 'F57', 'DeadHead']
# ['F100', 'F16']
# ['F100', 'F3', 'DeadHead']
# ['F3', 'DeadHead']
# ['F13', 'DeadHead']
# ['F13', 'F85', 'DeadHead']
# ['F13', 'F36', 'DeadHead']
# ['F13', 'F28', 'DeadHead']
# ['F13', 'F28', 'F22', 'DeadHead']
# ['F13', 'F7', 'DeadHead']
# ['F16', 'DeadHead']
# ['F23', 'DeadHead']
# ['F42', 'DeadHead']
# ['F42', 'F69', 'DeadHead']
# ['F42', 'F69', 'F90', 'DeadHead']
# ['F42', 'F69', 'F84', 'DeadHead']
# ['F42', 'F69', 'F84', 'F38']
# ['F42', 'F69', 'F66', 'DeadHead']
# ['F42', 'F69', 'F41', 'DeadHead']
# ['F42', 'F69', 'F12', 'DeadHead']
# ['F42', 'F38']
# ['F42', 'F1', 'DeadHead']
# ['F42', 'F1', 'F37']
# ['F42', 'F1', 'F18', 'DeadHead']
# ['F42', 'F1', 'F18', 'F79', 'DeadHead']
# ['F42', 'F1', 'F18', 'F76', 'DeadHead']
# ['F42', 'F1', 'F18', 'F8', 'DeadHead']
# ['F43', 'DeadHead']
# ['F43', 'F71', 'DeadHead']
# ['F43', 'F67']
# ['F43', 'F52', 'DeadHead']
# ['F43', 'F52', 'F40']
# ['F43', 'F52', 'F11', 'DeadHead']
# ['F43', 'F21']
# ['F43', 'F6', 'DeadHead']
# ['F43', 'F6', 'F97', 'DeadHead']
# ['F43', 'F6', 'F97', 'F67']
# ['F43', 'F6', 'F97', 'F52', 'DeadHead']
# ['F43', 'F6', 'F95', 'DeadHead']
# ['F43', 'F6', 'F64', 'DeadHead']
# ['F43', 'F6', 'F64', 'F67']
# ['F43', 'F6', 'F64', 'F52', 'DeadHead']
# ['F43', 'F6', 'F59', 'DeadHead']
# ['F43', 'F6', 'F59', 'F40']
# ['F43', 'F6', 'F59', 'F11', 'DeadHead']
# ['F44', 'DeadHead']
# ['F44', 'F54']
# ['F44', 'F50']
# ['F44', 'F45']
# ['F47', 'DeadHead']
# ['F47', 'F76', 'DeadHead']
# ['F47', 'F76', 'F48', 'DeadHead']
# ['F47', 'F76', 'F48', 'F5']
# ['F47', 'F33', 'DeadHead']
# ['F47', 'F33', 'F48', 'DeadHead']
# ['F47', 'F33', 'F48', 'F5']
# ['F47', 'F33', 'F18', 'DeadHead']
# ['F47', 'F33', 'F18', 'F79', 'DeadHead']
# ['F47', 'F33', 'F18', 'F76', 'DeadHead']
# ['F47', 'F33', 'F18', 'F8', 'DeadHead']
# ['F47', 'F33', 'F18', 'F5']
# ['F47', 'F8', 'DeadHead']
# ['F47', 'F8', 'F90', 'DeadHead']
# ['F47', 'F8', 'F66', 'DeadHead']
# ['F57', 'DeadHead']
# ['F63', 'DeadHead']
# ['F65', 'DeadHead']
# ['F68', 'DeadHead']
# ['F77', 'DeadHead']
# ['F88', 'DeadHead']
# ['F88', 'F75', 'DeadHead']
# ['F88', 'F75', 'F22', 'DeadHead']
# ['F91', 'DeadHead']
# ['F94', 'DeadHead']
# ['F94', 'F69', 'DeadHead']
# ['F94', 'F69', 'F90', 'DeadHead']
# ['F94', 'F69', 'F84', 'DeadHead']
# ['F94', 'F69', 'F84', 'F38']
# ['F94', 'F69', 'F66', 'DeadHead']
# ['F94', 'F69', 'F41', 'DeadHead']
# ['F94', 'F69', 'F12', 'DeadHead']
# ['F94', 'F38']
# ['F94', 'F1', 'DeadHead']
# ['F94', 'F1', 'F37']
# ['F94', 'F1', 'F18', 'DeadHead']
# ['F94', 'F1', 'F18', 'F79', 'DeadHead']
# ['F94', 'F1', 'F18', 'F76', 'DeadHead']
# ['F94', 'F1', 'F18', 'F8', 'DeadHead']
# ['F99', 'DeadHead']
# ['F5', 'DeadHead']
# ['F6', 'DeadHead']
# ['F6', 'F97']
# ['F6', 'F95', 'DeadHead']
# ['F6', 'F64']
# ['F6', 'F59', 'DeadHead']
# ['F6', 'F59', 'F40', 'DeadHead']
# ['F6', 'F59', 'F40', 'F91', 'DeadHead']
# ['F6', 'F59', 'F40', 'F16', 'DeadHead']
# ['F6', 'F59', 'F40', 'F3', 'DeadHead']
# ['F6', 'F59', 'F11', 'DeadHead']
# ['F8', 'DeadHead']
# ['F8', 'F90', 'DeadHead']
# ['F8', 'F66', 'DeadHead']
# ['F10', 'DeadHead']
# ['F10', 'F77']
# ['F10', 'F3', 'DeadHead']
# ['F17', 'DeadHead']
# ['F17', 'F49']
# ['F21', 'DeadHead']
# ['F21', 'F77']
# ['F21', 'F3', 'DeadHead']
# ['F30', 'DeadHead']
# ['F30', 'F88']
# ['F30', 'F68', 'DeadHead']
# ['F30', 'F63', 'DeadHead']
# ['F30', 'F23']
# ['F30', 'F13', 'DeadHead']
# ['F30', 'F13', 'F85', 'DeadHead']
# ['F30', 'F13', 'F36', 'DeadHead']
# ['F30', 'F13', 'F28', 'DeadHead']
# ['F30', 'F13', 'F28', 'F22']
# ['F30', 'F13', 'F7', 'DeadHead']
# ['F33', 'DeadHead']
# ['F33', 'F48']
# ['F33', 'F18']
# ['F39', 'DeadHead']
# ['F39', 'F55', 'DeadHead']
# ['F39', 'F55', 'F95', 'DeadHead']
# ['F39', 'F55', 'F59', 'DeadHead']
# ['F39', 'F55', 'F59', 'F40', 'DeadHead']
# ['F39', 'F55', 'F59', 'F11', 'DeadHead']
# ['F39', 'F40', 'DeadHead']
# ['F39', 'F20']
# ['F51', 'DeadHead']
# ['F51', 'F98']
# ['F51', 'F97']
# ['F51', 'F95', 'DeadHead']
# ['F51', 'F64']
# ['F51', 'F59', 'DeadHead']
# ['F51', 'F59', 'F40', 'DeadHead']
# ['F51', 'F59', 'F40', 'F91', 'DeadHead']
# ['F51', 'F59', 'F40', 'F16', 'DeadHead']
# ['F51', 'F59', 'F40', 'F3', 'DeadHead']
# ['F51', 'F59', 'F11', 'DeadHead']
# ['F51', 'F4']
# ['F52', 'DeadHead']
# ['F52', 'F40', 'DeadHead']
# ['F52', 'F40', 'F91', 'DeadHead']
# ['F52', 'F40', 'F16', 'DeadHead']
# ['F52', 'F40', 'F3', 'DeadHead']
# ['F52', 'F11', 'DeadHead']
# ['F67', 'DeadHead']
# ['F67', 'F77']
# ['F67', 'F3', 'DeadHead']
# ['F70', 'DeadHead']
# ['F70', 'F91', 'DeadHead']
# ['F70', 'F77']
# ['F70', 'F16', 'DeadHead']
# ['F70', 'F3', 'DeadHead']
# ['F71', 'DeadHead']
# ['F72', 'DeadHead']
# ['F72', 'F77']
# ['F72', 'F44', 'DeadHead']
# ['F72', 'F44', 'F54', 'DeadHead']
# ['F72', 'F44', 'F54', 'F3', 'DeadHead']
# ['F72', 'F44', 'F50', 'DeadHead']
# ['F72', 'F44', 'F50', 'F91', 'DeadHead']
# ['F72', 'F44', 'F50', 'F77']
# ['F72', 'F44', 'F50', 'F57']
# ['F72', 'F44', 'F50', 'F16', 'DeadHead']
# ['F72', 'F44', 'F50', 'F3', 'DeadHead']
# ['F72', 'F44', 'F45', 'DeadHead']
# ['F72', 'F44', 'F45', 'F91', 'DeadHead']
# ['F72', 'F44', 'F45', 'F77']
# ['F72', 'F44', 'F45', 'F57']
# ['F72', 'F44', 'F45', 'F16', 'DeadHead']
# ['F72', 'F44', 'F45', 'F3', 'DeadHead']
# ['F72', 'F43']
# ['F72', 'F3', 'DeadHead']
# ['F74', 'DeadHead']
# ['F74', 'F98']
# ['F74', 'F97']
# ['F74', 'F64']
# ['F74', 'F59', 'DeadHead']
# ['F74', 'F59', 'F40', 'DeadHead']
# ['F74', 'F59', 'F40', 'F91', 'DeadHead']
# ['F74', 'F59', 'F40', 'F16', 'DeadHead']
# ['F74', 'F59', 'F40', 'F3', 'DeadHead']
# ['F74', 'F59', 'F11', 'DeadHead']
# ['F74', 'F4']
# ['F75', 'DeadHead']
# ['F75', 'F22']
# ['F76', 'DeadHead']
# ['F76', 'F48']
# ['F78', 'DeadHead']
# ['F78', 'F77']
# ['F78', 'F3', 'DeadHead']
# ['F79', 'DeadHead']
# ['F79', 'F48']
# ['F83', 'DeadHead']
# ['F83', 'F99', 'DeadHead']
# ['F83', 'F68', 'DeadHead']
# ['F83', 'F63', 'DeadHead']
# ['F87', 'DeadHead']
# ['F87', 'F85', 'DeadHead']
# ['F87', 'F36', 'DeadHead']
# ['F87', 'F28', 'DeadHead']
# ['F87', 'F28', 'F22']
# ['F87', 'F25', 'DeadHead']
# ['F87', 'F7', 'DeadHead']
# ['F93', 'DeadHead']
# ['F93', 'F98']
# ['F93', 'F97']
# ['F93', 'F95', 'DeadHead']
# ['F93', 'F64']
# ['F93', 'F59', 'DeadHead']
# ['F93', 'F59', 'F40', 'DeadHead']
# ['F93', 'F59', 'F40', 'F91', 'DeadHead']
# ['F93', 'F59', 'F40', 'F16', 'DeadHead']
# ['F93', 'F59', 'F40', 'F3', 'DeadHead']
# ['F93', 'F59', 'F11', 'DeadHead']
# ['F93', 'F35']
# ['F93', 'F4']

# %%
import gurobipy as gp
from gurobipy import GRB

def delta(pair, num):
        for p in pair:
            if p.startswith('F'):
                if p[1:] == str(num):
                    return 1
        return 0



# 최적화 모델 생성
model = gp.Model('Crew_Pairing')

# 변수 추가
c = []
x = []

for j in range(100):
    c_j = model.addVar(vtype=GRB.CONTINUOUS, name='c_%s' % j)
    c.append(c_j)
    model.setAttr("Start", c_j, total[j])

for j in range(100):
    x_j = model.addVar(vtype=GRB.BINARY, name='x_%s' % j)
    x.append(x_j)
    model.setAttr("Start", x_j, 1)


for j in range(100) :
    #비행편 마다의 제약 조건 추가?..
        model.addConstr(delta(pairing[j],j+1)*x[j]==1, name='d_%s' % j)

# objective function 설정
obj = gp.quicksum(x[i] * c[i] for i in range(100))

model.setObjective(obj, GRB.MINIMIZE)
model.optimize()

#for j in range(100):
    #c_value = model.getAttr("X", c[j])
    #print("c[", j, "] = ", c_value)


# 변수 값 출력
#for v in model.getVars():
    #print(v.varName)

#print(x,total)

# 제약 조건 슬랙 출력
#for c in model.getConstrs():
    #print(c.constrName, c.slack)
# Out:
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i5-8265U CPU @ 1.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license - for non-commercial use only - registered to skxkswls@gmail.com
# Optimize a model with 100 rows, 200 columns and 0 nonzeros
# Model fingerprint: 0x4d5da662
# Model has 100 quadratic objective terms
# Variable types: 100 continuous, 100 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [0e+00, 0e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# User MIP start did not produce a new incumbent solution
# User MIP start violates constraint d_0 by 1.000000000
#
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 1.53 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible or unbounded
# Best objective -, best bound -, gap -
