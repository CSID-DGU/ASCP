# %%
import pandas as pd
import os
from multiprocessing import Process
import copy
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# Node의 부모 Class
class Node:
    def __init__(self, node_name):
        self.node_name = node_name

# Edge의 부모 Class
class Edge:
    def __init__(self, origin, dest):
        self.origin = origin
        self.dest = dest

# Airport Class
class Airport(Node):
    def __init__(self, airport_name):
        super().__init__(airport_name)

# Flight Class
class Flight(Edge):
    def __init__(self, index, origin, dest, origin_date, dest_date, flight_duration, flight_type):
        super().__init__(origin, dest)
        self.index = index
        self.origin_date = origin_date
        self.dest_date = dest_date
        self.flight_duration = flight_duration
        self.flight_type = flight_type

    def print(self):
        print(self.index, self.origin, self.origin_date, self.dest,
              self.dest_date, self.flight_duration, self.flight_type)
        

# Stack Node의 구조
class Stackitem:
    def __init__(self, flight: Flight, flights_sequence: list = None, landing_number = None):
        if flights_sequence:
            self.flight = flight
            flights_sequence.append(flight.index)
            self.flights_sequence = flights_sequence
            self.landing_number = landing_number + 1
            # self.time = time + dt.timedelta(flight.flight_duration)
        else:
            self.flight = flight
            self.flights_sequence = [flight.index]
            self.landing_number = 1
            # self.time = flight.flight_duration;

# %%
# Initial Setting - Test
flight_graph = dict()
flight_excel = pd.read_excel("flight.xlsx")
flight_excel.columns = ['INDEX', 'ORIGIN', 'ORIGIN_DATE', 'DEST','DEST_DATE', 'FLIGHT_DURATION','AIRCRAFT_TYPE' ]
airports_set = set()

# %%
# Graph insert Node
for i in range(100) :
    airports_set.add(flight_excel.loc[i]['ORIGIN'])
    airports_set.add(flight_excel.loc[i]['DEST'])
    
for airports in airports_set :
    flight_graph[airports] = list()

# Graph insert Edge
for i in range(100) :
    flight_graph[flight_excel.loc[i]['ORIGIN']].append(Flight(flight_excel.loc[i]['INDEX'], flight_excel.loc[i]['ORIGIN'], flight_excel.loc[i]['DEST'],
                                                              flight_excel.loc[i]['ORIGIN_DATE'], flight_excel.loc[i]['DEST_DATE'],
                                                              flight_excel.loc[i]['FLIGHT_DURATION'], flight_excel.loc[i]['AIRCRAFT_TYPE']))

# %%
print(len(airports_set))
# Out:
# 5

# %%
pairing_set = list()

# clustering을 통한 flights set의 크기를 줄여야지 경우의 수가 줄어듬
# 하지만 그렇다면 시간을 어떻게 배분해야하는가? 기준은? 시간 → 기종? 조금더 생각해봐야 할 거 같다.

# 여기서 Node 시작에 따라 끝나는 경우는
# 만나는 Base가 같은경우가 있고,
# 만약 끝이 Base가 아닌데 갈 곳이 없는 경우가 있다.
# 그렇다면 모든 pairing의 모든 경우를 넣어도 모든 경우가 나온다!
# 

for airport in airports_set :
    # pairing_set.append(["-" * 10, airport, "-" * 10])

    for flight in flight_graph[airport] :
        # 항공편, 항공편의 순서를 넣는다
        stack_temp = [Stackitem(flight)]
        
        while stack_temp:
            # 현재 진행 중인 항공편의 정보
            flights_information_now = stack_temp.pop()

            pairing_set.append(copy.deepcopy(flights_information_now.flights_sequence))
            # 만약 해당 항공편이 진행됨으로서 base로 간다면 해당 항공편은 더 진행할 필요가 없음
            if (flights_information_now.flight.dest == flight.origin) :
                continue
            
            else :
                pairing_set[-1].append("DeadHead")

            # Search Space Extend
            for flight_next in flight_graph[flights_information_now.flight.dest] :
                # 항공기 기종이 같은지? 시간이 가능한지? (날짜가 같다면 시간까지 비교, 다르다면 날짜 비교)
                flight_type_equal = (flights_information_now.flight.flight_type == flight_next.flight_type)
                flight_time_possible = flights_information_now.flight.dest_date < flight_next.origin_date and (flight_next.origin_date - flights_information_now.flight.dest_date).seconds/3600 >= 3
                flight_day_possible = (flight_next.dest_date  - flight.origin_date).days <= 7
                flight_landing_possible = (flights_information_now.landing_number <= 3)

                # 기종이 다르거나 시간이 불가능하면 해당 항공편은 Search에 사용하지 않음
                if (not flight_type_equal or not flight_time_possible or not flight_day_possible or not flight_landing_possible) :
                    continue

                # 기종이 같고, 시간이 가능하다면 Search를 위해 stack에 추가(항공편의 순서까지)
                temp_list = copy.deepcopy(flights_information_now.flights_sequence)
                #if (flights_information_now.flight.dest_date < flight_next.origin_date) :
                    #for i in range(0, int(flight_next.origin_date.day - flights_information_now.flight.dest_date.day)) :
                        #temp_list.append("Layover")
                        
                stack_temp.append(Stackitem(flight_next, temp_list, flights_information_now.landing_number))
                

#for pairing in pairing_set :
    #print(pairing)

# 첫번째 방안 : 모든 항공편들의 순서를 저장한다
# 그렇다면 만들 수 있는(DeadHead, Layover, Feasible) Pairing의 모든 경우가 나온다.
# 하지만 이럴때는 시간이 n^n까지 나올 수 있는 것으로 보인다.
# 여기서 경우의 수를 줄이는 조건을 넣을 때
# 첫번째 - 항공기 종류
# 두번째 - 전 항공편의 도착시간보다 현 항공편의 출발시간이 느려야한다
# 세번째 - Crew의 Trun Time이 MMT보다 크거나 같아야 한다.(Slack Time은 어떻게 될려나?)
# feasible pairing은 좀 많다. -> 그럼 DeadHead가 존재하는 pairing은 넣어야하는 것인가?
# 지연전파? 존재한다?

# stack에 넣을 때 모든 정보를 넣어버린다면? 오히려 쉬워진다. 하지만 메모리를 많이 쓰므로 최적화가 필요함(조건을 생각해야 함)

# %%
import re

# 엑셀 파일명
filename = 'output.xlsx'

# 데이터프레임으로 변환
df = pd.DataFrame(pairing_set)

# 엑셀로 출력
df.to_excel(filename, index=False, header=False)

# %%
# 비행기 기종 : {크루원 수, 비행 수당, 기본급}
salary={}

salary_excel = pd.read_excel("salary.xlsx")
for index, row in salary_excel.iterrows():
    aircraft = row['AIRCRAFT']
    crew_num = row['CREW_NUM']
    flight_salary = row['FLIGHT_SALARY']
    base_salary = row['BASE_SALARY']
    layover_cost = row['BASE_SALARY']
    salary[aircraft] = {'CREW_NUM': crew_num, 'FLIGHT_SALARY': flight_salary, 'BASE_SALARY': base_salary,'LAYOVER_COST': layover_cost}


total = []

for pairing in pairing_set :
    crew_num = salary[flight_excel.loc[int(re.search(r'\d+', pairing[0]).group())-1]['AIRCRAFT_TYPE']]['CREW_NUM']
    base_salary = salary[flight_excel.loc[int(re.search(r'\d+', pairing[0]).group())-1]['AIRCRAFT_TYPE']]['BASE_SALARY']
    flight_salary = salary[flight_excel.loc[int(re.search(r'\d+', pairing[0]).group())-1]['AIRCRAFT_TYPE']]['FLIGHT_SALARY']
    layover_cost =  salary[flight_excel.loc[int(re.search(r'\d+', pairing[0]).group())-1]['AIRCRAFT_TYPE']]['LAYOVER_COST']
    layover_time = 0
    flight_time = flight_excel.loc[int(re.search(r'\d+', pairing[0]).group())-1]['FLIGHT_DURATION']
    deadhead=0
    for idx,pair in enumerate(pairing[1:],start=1):
        if(pair != "DeadHead") :
            n = int(re.search(r'\d+', pair).group())
            flight_time+=flight_excel.loc[n-1]['FLIGHT_DURATION']
            before_flight = flight_excel.loc[int(re.search(r'\d+', pairing[idx-1]).group())-1]['ORIGIN_DATE']
            current_flight = flight_excel.loc[int(re.search(r'\d+', pair).group())-1]['ORIGIN_DATE']
            layover_time += (current_flight-before_flight).seconds/3600
        else :
            #deadhead cost 정의하기
            deadhead_cost = 100
            deadhead = deadhead_cost * crew_num
        
            

    #print(pairing)
    
    #print('base_salary :',base_salary,'flight_salary :', flight_salary*flight_time,'layover_cost :',layover_cost*layover_time,'deadhead :',deadhead)
    total.append(base_salary+flight_salary*flight_time+layover_cost*layover_time)
    #print('Total: ',base_salary+flight_salary*flight_time+layover_cost*layover_time)
    #print(pairing)
    #print(total)
print('Total paring :',len(pairing_set))
# Out:
# Total paring : 654

# %%
import gurobipy as gp
from gurobipy import GRB

def delta(pair, num):
    for p in pair:
      if p.startswith('F'):
            if p[1:] == str(num):
               return 1
    return 0

total_flight_num = 100


# 최적화 모델 생성
model = gp.Model('Crew_Pairing')


# 변수 추가
c = []
x = []

for j in range(len(pairing_set)):
    c_j = model.addVar(vtype=GRB.CONTINUOUS, name='c_%s' % j)
    c.append(c_j)
    model.setAttr("Start", c_j, total[j])

for j in range(len(pairing_set)):
    x_j = model.addVar(vtype=GRB.BINARY, name='x_%s' % j)
    x.append(x_j)
#   model.setAttr("Start", x_j, 1)
    


for j in range(total_flight_num) :
    #비행편 마다의 제약 조건 추가?..
        model.addConstr(gp.quicksum(delta(pairing_set[i],j+1)*x[i] for i in range(len(pairing_set)))==1, name='d_%s' % j)

# objective function 설정
obj = gp.quicksum(x[i] * c[i] for i in range(len(pairing_set)))

model.setObjective(obj, GRB.MINIMIZE)
model.optimize()

if(model.Status==GRB.OPTIMAL) :
    print("최적해 찾음!!")
#print(model.ObjNVal)

# 변수 값 출력
for v in model.getVars():
    print(v.varName,v.getAttr)

#print(x,total)

# 제약 조건 슬랙 출력
for c in model.getConstrs():
   print(c.constrName,c.Slack)
# Out:
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i5-8265U CPU @ 1.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license - for non-commercial use only - registered to skxkswls@gmail.com
# Optimize a model with 100 rows, 1308 columns and 1676 nonzeros
# Model fingerprint: 0x9394597e
# Model has 654 quadratic objective terms
# Variable types: 654 continuous, 654 integer (654 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   QObjective range [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Warning: Completing partial solution with 654 unfixed non-continuous variables out of 654
# User MIP start produced solution with objective 250965 (0.03s)
# Loaded user MIP start with objective 250965
#
# Presolve removed 63 rows and 993 columns
# Presolve time: 0.02s
# Presolved: 37 rows, 315 columns, 852 nonzeros
# Found heuristic solution: objective 0.0000000
# Variable types: 0 continuous, 315 integer (315 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.07 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0 250965
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# 최적해 찾음!!
# c_0 <bound method Var.getAttr of <gurobi.Var c_0 (value 0.0)>>
# c_1 <bound method Var.getAttr of <gurobi.Var c_1 (value 0.0)>>
# c_2 <bound method Var.getAttr of <gurobi.Var c_2 (value 0.0)>>
# c_3 <bound method Var.getAttr of <gurobi.Var c_3 (value 0.0)>>
# c_4 <bound method Var.getAttr of <gurobi.Var c_4 (value 0.0)>>
# c_5 <bound method Var.getAttr of <gurobi.Var c_5 (value 0.0)>>
# c_6 <bound method Var.getAttr of <gurobi.Var c_6 (value 0.0)>>
# c_7 <bound method Var.getAttr of <gurobi.Var c_7 (value 0.0)>>
# c_8 <bound method Var.getAttr of <gurobi.Var c_8 (value 0.0)>>
# c_9 <bound method Var.getAttr of <gurobi.Var c_9 (value 0.0)>>
# c_10 <bound method Var.getAttr of <gurobi.Var c_10 (value 0.0)>>
# c_11 <bound method Var.getAttr of <gurobi.Var c_11 (value 0.0)>>
# c_12 <bound method Var.getAttr of <gurobi.Var c_12 (value 0.0)>>
# c_13 <bound method Var.getAttr of <gurobi.Var c_13 (value 0.0)>>
# c_14 <bound method Var.getAttr of <gurobi.Var c_14 (value 0.0)>>
# c_15 <bound method Var.getAttr of <gurobi.Var c_15 (value 0.0)>>
# c_16 <bound method Var.getAttr of <gurobi.Var c_16 (value 0.0)>>
# c_17 <bound method Var.getAttr of <gurobi.Var c_17 (value 0.0)>>
# c_18 <bound method Var.getAttr of <gurobi.Var c_18 (value 0.0)>>
# c_19 <bound method Var.getAttr of <gurobi.Var c_19 (value 0.0)>>
# c_20 <bound method Var.getAttr of <gurobi.Var c_20 (value 0.0)>>
# c_21 <bound method Var.getAttr of <gurobi.Var c_21 (value 0.0)>>
# c_22 <bound method Var.getAttr of <gurobi.Var c_22 (value 0.0)>>
# c_23 <bound method Var.getAttr of <gurobi.Var c_23 (value 0.0)>>
# c_24 <bound method Var.getAttr of <gurobi.Var c_24 (value 0.0)>>
# c_25 <bound method Var.getAttr of <gurobi.Var c_25 (value 0.0)>>
# c_26 <bound method Var.getAttr of <gurobi.Var c_26 (value 0.0)>>
# c_27 <bound method Var.getAttr of <gurobi.Var c_27 (value 0.0)>>
# c_28 <bound method Var.getAttr of <gurobi.Var c_28 (value 0.0)>>
# c_29 <bound method Var.getAttr of <gurobi.Var c_29 (value 0.0)>>
# c_30 <bound method Var.getAttr of <gurobi.Var c_30 (value 0.0)>>
# c_31 <bound method Var.getAttr of <gurobi.Var c_31 (value 0.0)>>
# c_32 <bound method Var.getAttr of <gurobi.Var c_32 (value 0.0)>>
# c_33 <bound method Var.getAttr of <gurobi.Var c_33 (value 0.0)>>
# c_34 <bound method Var.getAttr of <gurobi.Var c_34 (value 0.0)>>
# c_35 <bound method Var.getAttr of <gurobi.Var c_35 (value 0.0)>>
# c_36 <bound method Var.getAttr of <gurobi.Var c_36 (value 0.0)>>
# c_37 <bound method Var.getAttr of <gurobi.Var c_37 (value 0.0)>>
# c_38 <bound method Var.getAttr of <gurobi.Var c_38 (value 0.0)>>
# c_39 <bound method Var.getAttr of <gurobi.Var c_39 (value 0.0)>>
# c_40 <bound method Var.getAttr of <gurobi.Var c_40 (value 0.0)>>
# c_41 <bound method Var.getAttr of <gurobi.Var c_41 (value 0.0)>>
# c_42 <bound method Var.getAttr of <gurobi.Var c_42 (value 0.0)>>
# c_43 <bound method Var.getAttr of <gurobi.Var c_43 (value 0.0)>>
# c_44 <bound method Var.getAttr of <gurobi.Var c_44 (value 0.0)>>
# c_45 <bound method Var.getAttr of <gurobi.Var c_45 (value 0.0)>>
# c_46 <bound method Var.getAttr of <gurobi.Var c_46 (value 0.0)>>
# c_47 <bound method Var.getAttr of <gurobi.Var c_47 (value 0.0)>>
# c_48 <bound method Var.getAttr of <gurobi.Var c_48 (value 0.0)>>
# c_49 <bound method Var.getAttr of <gurobi.Var c_49 (value 0.0)>>
# c_50 <bound method Var.getAttr of <gurobi.Var c_50 (value 0.0)>>
# c_51 <bound method Var.getAttr of <gurobi.Var c_51 (value 0.0)>>
# c_52 <bound method Var.getAttr of <gurobi.Var c_52 (value 0.0)>>
# c_53 <bound method Var.getAttr of <gurobi.Var c_53 (value 0.0)>>
# c_54 <bound method Var.getAttr of <gurobi.Var c_54 (value 0.0)>>
# c_55 <bound method Var.getAttr of <gurobi.Var c_55 (value 0.0)>>
# c_56 <bound method Var.getAttr of <gurobi.Var c_56 (value 0.0)>>
# c_57 <bound method Var.getAttr of <gurobi.Var c_57 (value 0.0)>>
# c_58 <bound method Var.getAttr of <gurobi.Var c_58 (value 0.0)>>
# c_59 <bound method Var.getAttr of <gurobi.Var c_59 (value 0.0)>>
# c_60 <bound method Var.getAttr of <gurobi.Var c_60 (value 0.0)>>
# c_61 <bound method Var.getAttr of <gurobi.Var c_61 (value 0.0)>>
# c_62 <bound method Var.getAttr of <gurobi.Var c_62 (value 0.0)>>
# c_63 <bound method Var.getAttr of <gurobi.Var c_63 (value 0.0)>>
# c_64 <bound method Var.getAttr of <gurobi.Var c_64 (value 0.0)>>
# c_65 <bound method Var.getAttr of <gurobi.Var c_65 (value 0.0)>>
# c_66 <bound method Var.getAttr of <gurobi.Var c_66 (value 0.0)>>
# c_67 <bound method Var.getAttr of <gurobi.Var c_67 (value 0.0)>>
# c_68 <bound method Var.getAttr of <gurobi.Var c_68 (value 0.0)>>
# c_69 <bound method Var.getAttr of <gurobi.Var c_69 (value 0.0)>>
# c_70 <bound method Var.getAttr of <gurobi.Var c_70 (value 0.0)>>
# c_71 <bound method Var.getAttr of <gurobi.Var c_71 (value 0.0)>>
# c_72 <bound method Var.getAttr of <gurobi.Var c_72 (value 0.0)>>
# c_73 <bound method Var.getAttr of <gurobi.Var c_73 (value 0.0)>>
# c_74 <bound method Var.getAttr of <gurobi.Var c_74 (value 0.0)>>
# c_75 <bound method Var.getAttr of <gurobi.Var c_75 (value 0.0)>>
# c_76 <bound method Var.getAttr of <gurobi.Var c_76 (value 0.0)>>
# c_77 <bound method Var.getAttr of <gurobi.Var c_77 (value 0.0)>>
# c_78 <bound method Var.getAttr of <gurobi.Var c_78 (value 0.0)>>
# c_79 <bound method Var.getAttr of <gurobi.Var c_79 (value 0.0)>>
# c_80 <bound method Var.getAttr of <gurobi.Var c_80 (value 0.0)>>
# c_81 <bound method Var.getAttr of <gurobi.Var c_81 (value 0.0)>>
# c_82 <bound method Var.getAttr of <gurobi.Var c_82 (value 0.0)>>
# c_83 <bound method Var.getAttr of <gurobi.Var c_83 (value 0.0)>>
# c_84 <bound method Var.getAttr of <gurobi.Var c_84 (value 0.0)>>
# c_85 <bound method Var.getAttr of <gurobi.Var c_85 (value 0.0)>>
# c_86 <bound method Var.getAttr of <gurobi.Var c_86 (value 0.0)>>
# c_87 <bound method Var.getAttr of <gurobi.Var c_87 (value 0.0)>>
# c_88 <bound method Var.getAttr of <gurobi.Var c_88 (value 0.0)>>
# c_89 <bound method Var.getAttr of <gurobi.Var c_89 (value 0.0)>>
# c_90 <bound method Var.getAttr of <gurobi.Var c_90 (value 0.0)>>
# c_91 <bound method Var.getAttr of <gurobi.Var c_91 (value 0.0)>>
# c_92 <bound method Var.getAttr of <gurobi.Var c_92 (value 0.0)>>
# c_93 <bound method Var.getAttr of <gurobi.Var c_93 (value 0.0)>>
# c_94 <bound method Var.getAttr of <gurobi.Var c_94 (value 0.0)>>
# c_95 <bound method Var.getAttr of <gurobi.Var c_95 (value 0.0)>>
# c_96 <bound method Var.getAttr of <gurobi.Var c_96 (value 0.0)>>
# c_97 <bound method Var.getAttr of <gurobi.Var c_97 (value 0.0)>>
# c_98 <bound method Var.getAttr of <gurobi.Var c_98 (value 0.0)>>
# c_99 <bound method Var.getAttr of <gurobi.Var c_99 (value 0.0)>>
# c_100 <bound method Var.getAttr of <gurobi.Var c_100 (value 0.0)>>
# c_101 <bound method Var.getAttr of <gurobi.Var c_101 (value 0.0)>>
# c_102 <bound method Var.getAttr of <gurobi.Var c_102 (value 0.0)>>
# c_103 <bound method Var.getAttr of <gurobi.Var c_103 (value 0.0)>>
# c_104 <bound method Var.getAttr of <gurobi.Var c_104 (value 0.0)>>
# c_105 <bound method Var.getAttr of <gurobi.Var c_105 (value 0.0)>>
# c_106 <bound method Var.getAttr of <gurobi.Var c_106 (value 0.0)>>
# c_107 <bound method Var.getAttr of <gurobi.Var c_107 (value 0.0)>>
# c_108 <bound method Var.getAttr of <gurobi.Var c_108 (value 0.0)>>
# c_109 <bound method Var.getAttr of <gurobi.Var c_109 (value 0.0)>>
# c_110 <bound method Var.getAttr of <gurobi.Var c_110 (value 0.0)>>
# c_111 <bound method Var.getAttr of <gurobi.Var c_111 (value 0.0)>>
# c_112 <bound method Var.getAttr of <gurobi.Var c_112 (value 0.0)>>
# c_113 <bound method Var.getAttr of <gurobi.Var c_113 (value 0.0)>>
# c_114 <bound method Var.getAttr of <gurobi.Var c_114 (value 0.0)>>
# c_115 <bound method Var.getAttr of <gurobi.Var c_115 (value 0.0)>>
# c_116 <bound method Var.getAttr of <gurobi.Var c_116 (value 0.0)>>
# c_117 <bound method Var.getAttr of <gurobi.Var c_117 (value 0.0)>>
# c_118 <bound method Var.getAttr of <gurobi.Var c_118 (value 0.0)>>
# c_119 <bound method Var.getAttr of <gurobi.Var c_119 (value 0.0)>>
# c_120 <bound method Var.getAttr of <gurobi.Var c_120 (value 0.0)>>
# c_121 <bound method Var.getAttr of <gurobi.Var c_121 (value 0.0)>>
# c_122 <bound method Var.getAttr of <gurobi.Var c_122 (value 0.0)>>
# c_123 <bound method Var.getAttr of <gurobi.Var c_123 (value 0.0)>>
# c_124 <bound method Var.getAttr of <gurobi.Var c_124 (value 0.0)>>
# c_125 <bound method Var.getAttr of <gurobi.Var c_125 (value 0.0)>>
# c_126 <bound method Var.getAttr of <gurobi.Var c_126 (value 0.0)>>
# c_127 <bound method Var.getAttr of <gurobi.Var c_127 (value 0.0)>>
# c_128 <bound method Var.getAttr of <gurobi.Var c_128 (value 0.0)>>
# c_129 <bound method Var.getAttr of <gurobi.Var c_129 (value 0.0)>>
# c_130 <bound method Var.getAttr of <gurobi.Var c_130 (value 0.0)>>
# c_131 <bound method Var.getAttr of <gurobi.Var c_131 (value 0.0)>>
# c_132 <bound method Var.getAttr of <gurobi.Var c_132 (value 0.0)>>
# c_133 <bound method Var.getAttr of <gurobi.Var c_133 (value 0.0)>>
# c_134 <bound method Var.getAttr of <gurobi.Var c_134 (value 0.0)>>
# c_135 <bound method Var.getAttr of <gurobi.Var c_135 (value 0.0)>>
# c_136 <bound method Var.getAttr of <gurobi.Var c_136 (value 0.0)>>
# c_137 <bound method Var.getAttr of <gurobi.Var c_137 (value 0.0)>>
# c_138 <bound method Var.getAttr of <gurobi.Var c_138 (value 0.0)>>
# c_139 <bound method Var.getAttr of <gurobi.Var c_139 (value 0.0)>>
# c_140 <bound method Var.getAttr of <gurobi.Var c_140 (value 0.0)>>
# c_141 <bound method Var.getAttr of <gurobi.Var c_141 (value 0.0)>>
# c_142 <bound method Var.getAttr of <gurobi.Var c_142 (value 0.0)>>
# c_143 <bound method Var.getAttr of <gurobi.Var c_143 (value 0.0)>>
# c_144 <bound method Var.getAttr of <gurobi.Var c_144 (value 0.0)>>
# c_145 <bound method Var.getAttr of <gurobi.Var c_145 (value 0.0)>>
# c_146 <bound method Var.getAttr of <gurobi.Var c_146 (value 0.0)>>
# c_147 <bound method Var.getAttr of <gurobi.Var c_147 (value 0.0)>>
# c_148 <bound method Var.getAttr of <gurobi.Var c_148 (value 0.0)>>
# c_149 <bound method Var.getAttr of <gurobi.Var c_149 (value 0.0)>>
# c_150 <bound method Var.getAttr of <gurobi.Var c_150 (value 0.0)>>
# c_151 <bound method Var.getAttr of <gurobi.Var c_151 (value 0.0)>>
# c_152 <bound method Var.getAttr of <gurobi.Var c_152 (value 0.0)>>
# c_153 <bound method Var.getAttr of <gurobi.Var c_153 (value 0.0)>>
# c_154 <bound method Var.getAttr of <gurobi.Var c_154 (value 0.0)>>
# c_155 <bound method Var.getAttr of <gurobi.Var c_155 (value 0.0)>>
# c_156 <bound method Var.getAttr of <gurobi.Var c_156 (value 0.0)>>
# c_157 <bound method Var.getAttr of <gurobi.Var c_157 (value 0.0)>>
# c_158 <bound method Var.getAttr of <gurobi.Var c_158 (value 0.0)>>
# c_159 <bound method Var.getAttr of <gurobi.Var c_159 (value 0.0)>>
# c_160 <bound method Var.getAttr of <gurobi.Var c_160 (value 0.0)>>
# c_161 <bound method Var.getAttr of <gurobi.Var c_161 (value 0.0)>>
# c_162 <bound method Var.getAttr of <gurobi.Var c_162 (value 0.0)>>
# c_163 <bound method Var.getAttr of <gurobi.Var c_163 (value 0.0)>>
# c_164 <bound method Var.getAttr of <gurobi.Var c_164 (value 0.0)>>
# c_165 <bound method Var.getAttr of <gurobi.Var c_165 (value 0.0)>>
# c_166 <bound method Var.getAttr of <gurobi.Var c_166 (value 0.0)>>
# c_167 <bound method Var.getAttr of <gurobi.Var c_167 (value 0.0)>>
# c_168 <bound method Var.getAttr of <gurobi.Var c_168 (value 0.0)>>
# c_169 <bound method Var.getAttr of <gurobi.Var c_169 (value 0.0)>>
# c_170 <bound method Var.getAttr of <gurobi.Var c_170 (value 0.0)>>
# c_171 <bound method Var.getAttr of <gurobi.Var c_171 (value 0.0)>>
# c_172 <bound method Var.getAttr of <gurobi.Var c_172 (value 0.0)>>
# c_173 <bound method Var.getAttr of <gurobi.Var c_173 (value 0.0)>>
# c_174 <bound method Var.getAttr of <gurobi.Var c_174 (value 0.0)>>
# c_175 <bound method Var.getAttr of <gurobi.Var c_175 (value 0.0)>>
# c_176 <bound method Var.getAttr of <gurobi.Var c_176 (value 0.0)>>
# c_177 <bound method Var.getAttr of <gurobi.Var c_177 (value 0.0)>>
# c_178 <bound method Var.getAttr of <gurobi.Var c_178 (value 0.0)>>
# c_179 <bound method Var.getAttr of <gurobi.Var c_179 (value 0.0)>>
# c_180 <bound method Var.getAttr of <gurobi.Var c_180 (value 0.0)>>
# c_181 <bound method Var.getAttr of <gurobi.Var c_181 (value 0.0)>>
# c_182 <bound method Var.getAttr of <gurobi.Var c_182 (value 0.0)>>
# c_183 <bound method Var.getAttr of <gurobi.Var c_183 (value 0.0)>>
# c_184 <bound method Var.getAttr of <gurobi.Var c_184 (value 0.0)>>
# c_185 <bound method Var.getAttr of <gurobi.Var c_185 (value 0.0)>>
# c_186 <bound method Var.getAttr of <gurobi.Var c_186 (value 0.0)>>
# c_187 <bound method Var.getAttr of <gurobi.Var c_187 (value 0.0)>>
# c_188 <bound method Var.getAttr of <gurobi.Var c_188 (value 0.0)>>
# c_189 <bound method Var.getAttr of <gurobi.Var c_189 (value 0.0)>>
# c_190 <bound method Var.getAttr of <gurobi.Var c_190 (value 0.0)>>
# c_191 <bound method Var.getAttr of <gurobi.Var c_191 (value 0.0)>>
# c_192 <bound method Var.getAttr of <gurobi.Var c_192 (value 0.0)>>
# c_193 <bound method Var.getAttr of <gurobi.Var c_193 (value 0.0)>>
# c_194 <bound method Var.getAttr of <gurobi.Var c_194 (value 0.0)>>
# c_195 <bound method Var.getAttr of <gurobi.Var c_195 (value 0.0)>>
# c_196 <bound method Var.getAttr of <gurobi.Var c_196 (value 0.0)>>
# c_197 <bound method Var.getAttr of <gurobi.Var c_197 (value 0.0)>>
# c_198 <bound method Var.getAttr of <gurobi.Var c_198 (value 0.0)>>
# c_199 <bound method Var.getAttr of <gurobi.Var c_199 (value 0.0)>>
# c_200 <bound method Var.getAttr of <gurobi.Var c_200 (value 0.0)>>
# c_201 <bound method Var.getAttr of <gurobi.Var c_201 (value 0.0)>>
# c_202 <bound method Var.getAttr of <gurobi.Var c_202 (value 0.0)>>
# c_203 <bound method Var.getAttr of <gurobi.Var c_203 (value 0.0)>>
# c_204 <bound method Var.getAttr of <gurobi.Var c_204 (value 0.0)>>
# c_205 <bound method Var.getAttr of <gurobi.Var c_205 (value 0.0)>>
# c_206 <bound method Var.getAttr of <gurobi.Var c_206 (value 0.0)>>
# c_207 <bound method Var.getAttr of <gurobi.Var c_207 (value 0.0)>>
# c_208 <bound method Var.getAttr of <gurobi.Var c_208 (value 0.0)>>
# c_209 <bound method Var.getAttr of <gurobi.Var c_209 (value 0.0)>>
# c_210 <bound method Var.getAttr of <gurobi.Var c_210 (value 0.0)>>
# c_211 <bound method Var.getAttr of <gurobi.Var c_211 (value 0.0)>>
# c_212 <bound method Var.getAttr of <gurobi.Var c_212 (value 0.0)>>
# c_213 <bound method Var.getAttr of <gurobi.Var c_213 (value 0.0)>>
# c_214 <bound method Var.getAttr of <gurobi.Var c_214 (value 0.0)>>
# c_215 <bound method Var.getAttr of <gurobi.Var c_215 (value 0.0)>>
# c_216 <bound method Var.getAttr of <gurobi.Var c_216 (value 0.0)>>
# c_217 <bound method Var.getAttr of <gurobi.Var c_217 (value 0.0)>>
# c_218 <bound method Var.getAttr of <gurobi.Var c_218 (value 0.0)>>
# c_219 <bound method Var.getAttr of <gurobi.Var c_219 (value 0.0)>>
# c_220 <bound method Var.getAttr of <gurobi.Var c_220 (value 0.0)>>
# c_221 <bound method Var.getAttr of <gurobi.Var c_221 (value 0.0)>>
# c_222 <bound method Var.getAttr of <gurobi.Var c_222 (value 0.0)>>
# c_223 <bound method Var.getAttr of <gurobi.Var c_223 (value 0.0)>>
# c_224 <bound method Var.getAttr of <gurobi.Var c_224 (value 0.0)>>
# c_225 <bound method Var.getAttr of <gurobi.Var c_225 (value 0.0)>>
# c_226 <bound method Var.getAttr of <gurobi.Var c_226 (value 0.0)>>
# c_227 <bound method Var.getAttr of <gurobi.Var c_227 (value 0.0)>>
# c_228 <bound method Var.getAttr of <gurobi.Var c_228 (value 0.0)>>
# c_229 <bound method Var.getAttr of <gurobi.Var c_229 (value 0.0)>>
# c_230 <bound method Var.getAttr of <gurobi.Var c_230 (value 0.0)>>
# c_231 <bound method Var.getAttr of <gurobi.Var c_231 (value 0.0)>>
# c_232 <bound method Var.getAttr of <gurobi.Var c_232 (value 0.0)>>
# c_233 <bound method Var.getAttr of <gurobi.Var c_233 (value 0.0)>>
# c_234 <bound method Var.getAttr of <gurobi.Var c_234 (value 0.0)>>
# c_235 <bound method Var.getAttr of <gurobi.Var c_235 (value 0.0)>>
# c_236 <bound method Var.getAttr of <gurobi.Var c_236 (value 0.0)>>
# c_237 <bound method Var.getAttr of <gurobi.Var c_237 (value 0.0)>>
# c_238 <bound method Var.getAttr of <gurobi.Var c_238 (value 0.0)>>
# c_239 <bound method Var.getAttr of <gurobi.Var c_239 (value 0.0)>>
# c_240 <bound method Var.getAttr of <gurobi.Var c_240 (value 0.0)>>
# c_241 <bound method Var.getAttr of <gurobi.Var c_241 (value 0.0)>>
# c_242 <bound method Var.getAttr of <gurobi.Var c_242 (value 0.0)>>
# c_243 <bound method Var.getAttr of <gurobi.Var c_243 (value 0.0)>>
# c_244 <bound method Var.getAttr of <gurobi.Var c_244 (value 0.0)>>
# c_245 <bound method Var.getAttr of <gurobi.Var c_245 (value 0.0)>>
# c_246 <bound method Var.getAttr of <gurobi.Var c_246 (value 0.0)>>
# c_247 <bound method Var.getAttr of <gurobi.Var c_247 (value 0.0)>>
# c_248 <bound method Var.getAttr of <gurobi.Var c_248 (value 0.0)>>
# c_249 <bound method Var.getAttr of <gurobi.Var c_249 (value 0.0)>>
# c_250 <bound method Var.getAttr of <gurobi.Var c_250 (value 0.0)>>
# c_251 <bound method Var.getAttr of <gurobi.Var c_251 (value 0.0)>>
# c_252 <bound method Var.getAttr of <gurobi.Var c_252 (value 0.0)>>
# c_253 <bound method Var.getAttr of <gurobi.Var c_253 (value 0.0)>>
# c_254 <bound method Var.getAttr of <gurobi.Var c_254 (value 0.0)>>
# c_255 <bound method Var.getAttr of <gurobi.Var c_255 (value 0.0)>>
# c_256 <bound method Var.getAttr of <gurobi.Var c_256 (value 0.0)>>
# c_257 <bound method Var.getAttr of <gurobi.Var c_257 (value 0.0)>>
# c_258 <bound method Var.getAttr of <gurobi.Var c_258 (value 0.0)>>
# c_259 <bound method Var.getAttr of <gurobi.Var c_259 (value 0.0)>>
# c_260 <bound method Var.getAttr of <gurobi.Var c_260 (value 0.0)>>
# c_261 <bound method Var.getAttr of <gurobi.Var c_261 (value 0.0)>>
# c_262 <bound method Var.getAttr of <gurobi.Var c_262 (value 0.0)>>
# c_263 <bound method Var.getAttr of <gurobi.Var c_263 (value 0.0)>>
# c_264 <bound method Var.getAttr of <gurobi.Var c_264 (value 0.0)>>
# c_265 <bound method Var.getAttr of <gurobi.Var c_265 (value 0.0)>>
# c_266 <bound method Var.getAttr of <gurobi.Var c_266 (value 0.0)>>
# c_267 <bound method Var.getAttr of <gurobi.Var c_267 (value 0.0)>>
# c_268 <bound method Var.getAttr of <gurobi.Var c_268 (value 0.0)>>
# c_269 <bound method Var.getAttr of <gurobi.Var c_269 (value 0.0)>>
# c_270 <bound method Var.getAttr of <gurobi.Var c_270 (value 0.0)>>
# c_271 <bound method Var.getAttr of <gurobi.Var c_271 (value 0.0)>>
# c_272 <bound method Var.getAttr of <gurobi.Var c_272 (value 0.0)>>
# c_273 <bound method Var.getAttr of <gurobi.Var c_273 (value 0.0)>>
# c_274 <bound method Var.getAttr of <gurobi.Var c_274 (value 0.0)>>
# c_275 <bound method Var.getAttr of <gurobi.Var c_275 (value 0.0)>>
# c_276 <bound method Var.getAttr of <gurobi.Var c_276 (value 0.0)>>
# c_277 <bound method Var.getAttr of <gurobi.Var c_277 (value 0.0)>>
# c_278 <bound method Var.getAttr of <gurobi.Var c_278 (value 0.0)>>
# c_279 <bound method Var.getAttr of <gurobi.Var c_279 (value 0.0)>>
# c_280 <bound method Var.getAttr of <gurobi.Var c_280 (value 0.0)>>
# c_281 <bound method Var.getAttr of <gurobi.Var c_281 (value 0.0)>>
# c_282 <bound method Var.getAttr of <gurobi.Var c_282 (value 0.0)>>
# c_283 <bound method Var.getAttr of <gurobi.Var c_283 (value 0.0)>>
# c_284 <bound method Var.getAttr of <gurobi.Var c_284 (value 0.0)>>
# c_285 <bound method Var.getAttr of <gurobi.Var c_285 (value 0.0)>>
# c_286 <bound method Var.getAttr of <gurobi.Var c_286 (value 0.0)>>
# c_287 <bound method Var.getAttr of <gurobi.Var c_287 (value 0.0)>>
# c_288 <bound method Var.getAttr of <gurobi.Var c_288 (value 0.0)>>
# c_289 <bound method Var.getAttr of <gurobi.Var c_289 (value 0.0)>>
# c_290 <bound method Var.getAttr of <gurobi.Var c_290 (value 0.0)>>
# c_291 <bound method Var.getAttr of <gurobi.Var c_291 (value 0.0)>>
# c_292 <bound method Var.getAttr of <gurobi.Var c_292 (value 0.0)>>
# c_293 <bound method Var.getAttr of <gurobi.Var c_293 (value 0.0)>>
# c_294 <bound method Var.getAttr of <gurobi.Var c_294 (value 0.0)>>
# c_295 <bound method Var.getAttr of <gurobi.Var c_295 (value 0.0)>>
# c_296 <bound method Var.getAttr of <gurobi.Var c_296 (value 0.0)>>
# c_297 <bound method Var.getAttr of <gurobi.Var c_297 (value 0.0)>>
# c_298 <bound method Var.getAttr of <gurobi.Var c_298 (value 0.0)>>
# c_299 <bound method Var.getAttr of <gurobi.Var c_299 (value 0.0)>>
# c_300 <bound method Var.getAttr of <gurobi.Var c_300 (value 0.0)>>
# c_301 <bound method Var.getAttr of <gurobi.Var c_301 (value 0.0)>>
# c_302 <bound method Var.getAttr of <gurobi.Var c_302 (value 0.0)>>
# c_303 <bound method Var.getAttr of <gurobi.Var c_303 (value 0.0)>>
# c_304 <bound method Var.getAttr of <gurobi.Var c_304 (value 0.0)>>
# c_305 <bound method Var.getAttr of <gurobi.Var c_305 (value 0.0)>>
# c_306 <bound method Var.getAttr of <gurobi.Var c_306 (value 0.0)>>
# c_307 <bound method Var.getAttr of <gurobi.Var c_307 (value 0.0)>>
# c_308 <bound method Var.getAttr of <gurobi.Var c_308 (value 0.0)>>
# c_309 <bound method Var.getAttr of <gurobi.Var c_309 (value 0.0)>>
# c_310 <bound method Var.getAttr of <gurobi.Var c_310 (value 0.0)>>
# c_311 <bound method Var.getAttr of <gurobi.Var c_311 (value 0.0)>>
# c_312 <bound method Var.getAttr of <gurobi.Var c_312 (value 0.0)>>
# c_313 <bound method Var.getAttr of <gurobi.Var c_313 (value 0.0)>>
# c_314 <bound method Var.getAttr of <gurobi.Var c_314 (value 0.0)>>
# c_315 <bound method Var.getAttr of <gurobi.Var c_315 (value 0.0)>>
# c_316 <bound method Var.getAttr of <gurobi.Var c_316 (value 0.0)>>
# c_317 <bound method Var.getAttr of <gurobi.Var c_317 (value 0.0)>>
# c_318 <bound method Var.getAttr of <gurobi.Var c_318 (value 0.0)>>
# c_319 <bound method Var.getAttr of <gurobi.Var c_319 (value 0.0)>>
# c_320 <bound method Var.getAttr of <gurobi.Var c_320 (value 0.0)>>
# c_321 <bound method Var.getAttr of <gurobi.Var c_321 (value 0.0)>>
# c_322 <bound method Var.getAttr of <gurobi.Var c_322 (value 0.0)>>
# c_323 <bound method Var.getAttr of <gurobi.Var c_323 (value 0.0)>>
# c_324 <bound method Var.getAttr of <gurobi.Var c_324 (value 0.0)>>
# c_325 <bound method Var.getAttr of <gurobi.Var c_325 (value 0.0)>>
# c_326 <bound method Var.getAttr of <gurobi.Var c_326 (value 0.0)>>
# c_327 <bound method Var.getAttr of <gurobi.Var c_327 (value 0.0)>>
# c_328 <bound method Var.getAttr of <gurobi.Var c_328 (value 0.0)>>
# c_329 <bound method Var.getAttr of <gurobi.Var c_329 (value 0.0)>>
# c_330 <bound method Var.getAttr of <gurobi.Var c_330 (value 0.0)>>
# c_331 <bound method Var.getAttr of <gurobi.Var c_331 (value 0.0)>>
# c_332 <bound method Var.getAttr of <gurobi.Var c_332 (value 0.0)>>
# c_333 <bound method Var.getAttr of <gurobi.Var c_333 (value 0.0)>>
# c_334 <bound method Var.getAttr of <gurobi.Var c_334 (value 0.0)>>
# c_335 <bound method Var.getAttr of <gurobi.Var c_335 (value 0.0)>>
# c_336 <bound method Var.getAttr of <gurobi.Var c_336 (value 0.0)>>
# c_337 <bound method Var.getAttr of <gurobi.Var c_337 (value 0.0)>>
# c_338 <bound method Var.getAttr of <gurobi.Var c_338 (value 0.0)>>
# c_339 <bound method Var.getAttr of <gurobi.Var c_339 (value 0.0)>>
# c_340 <bound method Var.getAttr of <gurobi.Var c_340 (value 0.0)>>
# c_341 <bound method Var.getAttr of <gurobi.Var c_341 (value 0.0)>>
# c_342 <bound method Var.getAttr of <gurobi.Var c_342 (value 0.0)>>
# c_343 <bound method Var.getAttr of <gurobi.Var c_343 (value 0.0)>>
# c_344 <bound method Var.getAttr of <gurobi.Var c_344 (value 0.0)>>
# c_345 <bound method Var.getAttr of <gurobi.Var c_345 (value 0.0)>>
# c_346 <bound method Var.getAttr of <gurobi.Var c_346 (value 0.0)>>
# c_347 <bound method Var.getAttr of <gurobi.Var c_347 (value 0.0)>>
# c_348 <bound method Var.getAttr of <gurobi.Var c_348 (value 0.0)>>
# c_349 <bound method Var.getAttr of <gurobi.Var c_349 (value 0.0)>>
# c_350 <bound method Var.getAttr of <gurobi.Var c_350 (value 0.0)>>
# c_351 <bound method Var.getAttr of <gurobi.Var c_351 (value 0.0)>>
# c_352 <bound method Var.getAttr of <gurobi.Var c_352 (value 0.0)>>
# c_353 <bound method Var.getAttr of <gurobi.Var c_353 (value 0.0)>>
# c_354 <bound method Var.getAttr of <gurobi.Var c_354 (value 0.0)>>
# c_355 <bound method Var.getAttr of <gurobi.Var c_355 (value 0.0)>>
# c_356 <bound method Var.getAttr of <gurobi.Var c_356 (value 0.0)>>
# c_357 <bound method Var.getAttr of <gurobi.Var c_357 (value 0.0)>>
# c_358 <bound method Var.getAttr of <gurobi.Var c_358 (value 0.0)>>
# c_359 <bound method Var.getAttr of <gurobi.Var c_359 (value 0.0)>>
# c_360 <bound method Var.getAttr of <gurobi.Var c_360 (value 0.0)>>
# c_361 <bound method Var.getAttr of <gurobi.Var c_361 (value 0.0)>>
# c_362 <bound method Var.getAttr of <gurobi.Var c_362 (value 0.0)>>
# c_363 <bound method Var.getAttr of <gurobi.Var c_363 (value 0.0)>>
# c_364 <bound method Var.getAttr of <gurobi.Var c_364 (value 0.0)>>
# c_365 <bound method Var.getAttr of <gurobi.Var c_365 (value 0.0)>>
# c_366 <bound method Var.getAttr of <gurobi.Var c_366 (value 0.0)>>
# c_367 <bound method Var.getAttr of <gurobi.Var c_367 (value 0.0)>>
# c_368 <bound method Var.getAttr of <gurobi.Var c_368 (value 0.0)>>
# c_369 <bound method Var.getAttr of <gurobi.Var c_369 (value 0.0)>>
# c_370 <bound method Var.getAttr of <gurobi.Var c_370 (value 0.0)>>
# c_371 <bound method Var.getAttr of <gurobi.Var c_371 (value 0.0)>>
# c_372 <bound method Var.getAttr of <gurobi.Var c_372 (value 0.0)>>
# c_373 <bound method Var.getAttr of <gurobi.Var c_373 (value 0.0)>>
# c_374 <bound method Var.getAttr of <gurobi.Var c_374 (value 0.0)>>
# c_375 <bound method Var.getAttr of <gurobi.Var c_375 (value 0.0)>>
# c_376 <bound method Var.getAttr of <gurobi.Var c_376 (value 0.0)>>
# c_377 <bound method Var.getAttr of <gurobi.Var c_377 (value 0.0)>>
# c_378 <bound method Var.getAttr of <gurobi.Var c_378 (value 0.0)>>
# c_379 <bound method Var.getAttr of <gurobi.Var c_379 (value 0.0)>>
# c_380 <bound method Var.getAttr of <gurobi.Var c_380 (value 0.0)>>
# c_381 <bound method Var.getAttr of <gurobi.Var c_381 (value 0.0)>>
# c_382 <bound method Var.getAttr of <gurobi.Var c_382 (value 0.0)>>
# c_383 <bound method Var.getAttr of <gurobi.Var c_383 (value 0.0)>>
# c_384 <bound method Var.getAttr of <gurobi.Var c_384 (value 0.0)>>
# c_385 <bound method Var.getAttr of <gurobi.Var c_385 (value 0.0)>>
# c_386 <bound method Var.getAttr of <gurobi.Var c_386 (value 0.0)>>
# c_387 <bound method Var.getAttr of <gurobi.Var c_387 (value 0.0)>>
# c_388 <bound method Var.getAttr of <gurobi.Var c_388 (value 0.0)>>
# c_389 <bound method Var.getAttr of <gurobi.Var c_389 (value 0.0)>>
# c_390 <bound method Var.getAttr of <gurobi.Var c_390 (value 0.0)>>
# c_391 <bound method Var.getAttr of <gurobi.Var c_391 (value 0.0)>>
# c_392 <bound method Var.getAttr of <gurobi.Var c_392 (value 0.0)>>
# c_393 <bound method Var.getAttr of <gurobi.Var c_393 (value 0.0)>>
# c_394 <bound method Var.getAttr of <gurobi.Var c_394 (value 0.0)>>
# c_395 <bound method Var.getAttr of <gurobi.Var c_395 (value 0.0)>>
# c_396 <bound method Var.getAttr of <gurobi.Var c_396 (value 0.0)>>
# c_397 <bound method Var.getAttr of <gurobi.Var c_397 (value 0.0)>>
# c_398 <bound method Var.getAttr of <gurobi.Var c_398 (value 0.0)>>
# c_399 <bound method Var.getAttr of <gurobi.Var c_399 (value 0.0)>>
# c_400 <bound method Var.getAttr of <gurobi.Var c_400 (value 0.0)>>
# c_401 <bound method Var.getAttr of <gurobi.Var c_401 (value 0.0)>>
# c_402 <bound method Var.getAttr of <gurobi.Var c_402 (value 0.0)>>
# c_403 <bound method Var.getAttr of <gurobi.Var c_403 (value 0.0)>>
# c_404 <bound method Var.getAttr of <gurobi.Var c_404 (value 0.0)>>
# c_405 <bound method Var.getAttr of <gurobi.Var c_405 (value 0.0)>>
# c_406 <bound method Var.getAttr of <gurobi.Var c_406 (value 0.0)>>
# c_407 <bound method Var.getAttr of <gurobi.Var c_407 (value 0.0)>>
# c_408 <bound method Var.getAttr of <gurobi.Var c_408 (value 0.0)>>
# c_409 <bound method Var.getAttr of <gurobi.Var c_409 (value 0.0)>>
# c_410 <bound method Var.getAttr of <gurobi.Var c_410 (value 0.0)>>
# c_411 <bound method Var.getAttr of <gurobi.Var c_411 (value 0.0)>>
# c_412 <bound method Var.getAttr of <gurobi.Var c_412 (value 0.0)>>
# c_413 <bound method Var.getAttr of <gurobi.Var c_413 (value 0.0)>>
# c_414 <bound method Var.getAttr of <gurobi.Var c_414 (value 0.0)>>
# c_415 <bound method Var.getAttr of <gurobi.Var c_415 (value 0.0)>>
# c_416 <bound method Var.getAttr of <gurobi.Var c_416 (value 0.0)>>
# c_417 <bound method Var.getAttr of <gurobi.Var c_417 (value 0.0)>>
# c_418 <bound method Var.getAttr of <gurobi.Var c_418 (value 0.0)>>
# c_419 <bound method Var.getAttr of <gurobi.Var c_419 (value 0.0)>>
# c_420 <bound method Var.getAttr of <gurobi.Var c_420 (value 0.0)>>
# c_421 <bound method Var.getAttr of <gurobi.Var c_421 (value 0.0)>>
# c_422 <bound method Var.getAttr of <gurobi.Var c_422 (value 0.0)>>
# c_423 <bound method Var.getAttr of <gurobi.Var c_423 (value 0.0)>>
# c_424 <bound method Var.getAttr of <gurobi.Var c_424 (value 0.0)>>
# c_425 <bound method Var.getAttr of <gurobi.Var c_425 (value 0.0)>>
# c_426 <bound method Var.getAttr of <gurobi.Var c_426 (value 0.0)>>
# c_427 <bound method Var.getAttr of <gurobi.Var c_427 (value 0.0)>>
# c_428 <bound method Var.getAttr of <gurobi.Var c_428 (value 0.0)>>
# c_429 <bound method Var.getAttr of <gurobi.Var c_429 (value 0.0)>>
# c_430 <bound method Var.getAttr of <gurobi.Var c_430 (value 0.0)>>
# c_431 <bound method Var.getAttr of <gurobi.Var c_431 (value 0.0)>>
# c_432 <bound method Var.getAttr of <gurobi.Var c_432 (value 0.0)>>
# c_433 <bound method Var.getAttr of <gurobi.Var c_433 (value 0.0)>>
# c_434 <bound method Var.getAttr of <gurobi.Var c_434 (value 0.0)>>
# c_435 <bound method Var.getAttr of <gurobi.Var c_435 (value 0.0)>>
# c_436 <bound method Var.getAttr of <gurobi.Var c_436 (value 0.0)>>
# c_437 <bound method Var.getAttr of <gurobi.Var c_437 (value 0.0)>>
# c_438 <bound method Var.getAttr of <gurobi.Var c_438 (value 0.0)>>
# c_439 <bound method Var.getAttr of <gurobi.Var c_439 (value 0.0)>>
# c_440 <bound method Var.getAttr of <gurobi.Var c_440 (value 0.0)>>
# c_441 <bound method Var.getAttr of <gurobi.Var c_441 (value 0.0)>>
# c_442 <bound method Var.getAttr of <gurobi.Var c_442 (value 0.0)>>
# c_443 <bound method Var.getAttr of <gurobi.Var c_443 (value 0.0)>>
# c_444 <bound method Var.getAttr of <gurobi.Var c_444 (value 0.0)>>
# c_445 <bound method Var.getAttr of <gurobi.Var c_445 (value 0.0)>>
# c_446 <bound method Var.getAttr of <gurobi.Var c_446 (value 0.0)>>
# c_447 <bound method Var.getAttr of <gurobi.Var c_447 (value 0.0)>>
# c_448 <bound method Var.getAttr of <gurobi.Var c_448 (value 0.0)>>
# c_449 <bound method Var.getAttr of <gurobi.Var c_449 (value 0.0)>>
# c_450 <bound method Var.getAttr of <gurobi.Var c_450 (value 0.0)>>
# c_451 <bound method Var.getAttr of <gurobi.Var c_451 (value 0.0)>>
# c_452 <bound method Var.getAttr of <gurobi.Var c_452 (value 0.0)>>
# c_453 <bound method Var.getAttr of <gurobi.Var c_453 (value 0.0)>>
# c_454 <bound method Var.getAttr of <gurobi.Var c_454 (value 0.0)>>
# c_455 <bound method Var.getAttr of <gurobi.Var c_455 (value 0.0)>>
# c_456 <bound method Var.getAttr of <gurobi.Var c_456 (value 0.0)>>
# c_457 <bound method Var.getAttr of <gurobi.Var c_457 (value 0.0)>>
# c_458 <bound method Var.getAttr of <gurobi.Var c_458 (value 0.0)>>
# c_459 <bound method Var.getAttr of <gurobi.Var c_459 (value 0.0)>>
# c_460 <bound method Var.getAttr of <gurobi.Var c_460 (value 0.0)>>
# c_461 <bound method Var.getAttr of <gurobi.Var c_461 (value 0.0)>>
# c_462 <bound method Var.getAttr of <gurobi.Var c_462 (value 0.0)>>
# c_463 <bound method Var.getAttr of <gurobi.Var c_463 (value 0.0)>>
# c_464 <bound method Var.getAttr of <gurobi.Var c_464 (value 0.0)>>
# c_465 <bound method Var.getAttr of <gurobi.Var c_465 (value 0.0)>>
# c_466 <bound method Var.getAttr of <gurobi.Var c_466 (value 0.0)>>
# c_467 <bound method Var.getAttr of <gurobi.Var c_467 (value 0.0)>>
# c_468 <bound method Var.getAttr of <gurobi.Var c_468 (value 0.0)>>
# c_469 <bound method Var.getAttr of <gurobi.Var c_469 (value 0.0)>>
# c_470 <bound method Var.getAttr of <gurobi.Var c_470 (value 0.0)>>
# c_471 <bound method Var.getAttr of <gurobi.Var c_471 (value 0.0)>>
# c_472 <bound method Var.getAttr of <gurobi.Var c_472 (value 0.0)>>
# c_473 <bound method Var.getAttr of <gurobi.Var c_473 (value 0.0)>>
# c_474 <bound method Var.getAttr of <gurobi.Var c_474 (value 0.0)>>
# c_475 <bound method Var.getAttr of <gurobi.Var c_475 (value 0.0)>>
# c_476 <bound method Var.getAttr of <gurobi.Var c_476 (value 0.0)>>
# c_477 <bound method Var.getAttr of <gurobi.Var c_477 (value 0.0)>>
# c_478 <bound method Var.getAttr of <gurobi.Var c_478 (value 0.0)>>
# c_479 <bound method Var.getAttr of <gurobi.Var c_479 (value 0.0)>>
# c_480 <bound method Var.getAttr of <gurobi.Var c_480 (value 0.0)>>
# c_481 <bound method Var.getAttr of <gurobi.Var c_481 (value 0.0)>>
# c_482 <bound method Var.getAttr of <gurobi.Var c_482 (value 0.0)>>
# c_483 <bound method Var.getAttr of <gurobi.Var c_483 (value 0.0)>>
# c_484 <bound method Var.getAttr of <gurobi.Var c_484 (value 0.0)>>
# c_485 <bound method Var.getAttr of <gurobi.Var c_485 (value 0.0)>>
# c_486 <bound method Var.getAttr of <gurobi.Var c_486 (value 0.0)>>
# c_487 <bound method Var.getAttr of <gurobi.Var c_487 (value 0.0)>>
# c_488 <bound method Var.getAttr of <gurobi.Var c_488 (value 0.0)>>
# c_489 <bound method Var.getAttr of <gurobi.Var c_489 (value 0.0)>>
# c_490 <bound method Var.getAttr of <gurobi.Var c_490 (value 0.0)>>
# c_491 <bound method Var.getAttr of <gurobi.Var c_491 (value 0.0)>>
# c_492 <bound method Var.getAttr of <gurobi.Var c_492 (value 0.0)>>
# c_493 <bound method Var.getAttr of <gurobi.Var c_493 (value 0.0)>>
# c_494 <bound method Var.getAttr of <gurobi.Var c_494 (value 0.0)>>
# c_495 <bound method Var.getAttr of <gurobi.Var c_495 (value 0.0)>>
# c_496 <bound method Var.getAttr of <gurobi.Var c_496 (value 0.0)>>
# c_497 <bound method Var.getAttr of <gurobi.Var c_497 (value 0.0)>>
# c_498 <bound method Var.getAttr of <gurobi.Var c_498 (value 0.0)>>
# c_499 <bound method Var.getAttr of <gurobi.Var c_499 (value 0.0)>>
# c_500 <bound method Var.getAttr of <gurobi.Var c_500 (value 0.0)>>
# c_501 <bound method Var.getAttr of <gurobi.Var c_501 (value 0.0)>>
# c_502 <bound method Var.getAttr of <gurobi.Var c_502 (value 0.0)>>
# c_503 <bound method Var.getAttr of <gurobi.Var c_503 (value 0.0)>>
# c_504 <bound method Var.getAttr of <gurobi.Var c_504 (value 0.0)>>
# c_505 <bound method Var.getAttr of <gurobi.Var c_505 (value 0.0)>>
# c_506 <bound method Var.getAttr of <gurobi.Var c_506 (value 0.0)>>
# c_507 <bound method Var.getAttr of <gurobi.Var c_507 (value 0.0)>>
# c_508 <bound method Var.getAttr of <gurobi.Var c_508 (value 0.0)>>
# c_509 <bound method Var.getAttr of <gurobi.Var c_509 (value 0.0)>>
# c_510 <bound method Var.getAttr of <gurobi.Var c_510 (value 0.0)>>
# c_511 <bound method Var.getAttr of <gurobi.Var c_511 (value 0.0)>>
# c_512 <bound method Var.getAttr of <gurobi.Var c_512 (value 0.0)>>
# c_513 <bound method Var.getAttr of <gurobi.Var c_513 (value 0.0)>>
# c_514 <bound method Var.getAttr of <gurobi.Var c_514 (value 0.0)>>
# c_515 <bound method Var.getAttr of <gurobi.Var c_515 (value 0.0)>>
# c_516 <bound method Var.getAttr of <gurobi.Var c_516 (value 0.0)>>
# c_517 <bound method Var.getAttr of <gurobi.Var c_517 (value 0.0)>>
# c_518 <bound method Var.getAttr of <gurobi.Var c_518 (value 0.0)>>
# c_519 <bound method Var.getAttr of <gurobi.Var c_519 (value 0.0)>>
# c_520 <bound method Var.getAttr of <gurobi.Var c_520 (value 0.0)>>
# c_521 <bound method Var.getAttr of <gurobi.Var c_521 (value 0.0)>>
# c_522 <bound method Var.getAttr of <gurobi.Var c_522 (value 0.0)>>
# c_523 <bound method Var.getAttr of <gurobi.Var c_523 (value 0.0)>>
# c_524 <bound method Var.getAttr of <gurobi.Var c_524 (value 0.0)>>
# c_525 <bound method Var.getAttr of <gurobi.Var c_525 (value 0.0)>>
# c_526 <bound method Var.getAttr of <gurobi.Var c_526 (value 0.0)>>
# c_527 <bound method Var.getAttr of <gurobi.Var c_527 (value 0.0)>>
# c_528 <bound method Var.getAttr of <gurobi.Var c_528 (value 0.0)>>
# c_529 <bound method Var.getAttr of <gurobi.Var c_529 (value 0.0)>>
# c_530 <bound method Var.getAttr of <gurobi.Var c_530 (value 0.0)>>
# c_531 <bound method Var.getAttr of <gurobi.Var c_531 (value 0.0)>>
# c_532 <bound method Var.getAttr of <gurobi.Var c_532 (value 0.0)>>
# c_533 <bound method Var.getAttr of <gurobi.Var c_533 (value 0.0)>>
# c_534 <bound method Var.getAttr of <gurobi.Var c_534 (value 0.0)>>
# c_535 <bound method Var.getAttr of <gurobi.Var c_535 (value 0.0)>>
# c_536 <bound method Var.getAttr of <gurobi.Var c_536 (value 0.0)>>
# c_537 <bound method Var.getAttr of <gurobi.Var c_537 (value 0.0)>>
# c_538 <bound method Var.getAttr of <gurobi.Var c_538 (value 0.0)>>
# c_539 <bound method Var.getAttr of <gurobi.Var c_539 (value 0.0)>>
# c_540 <bound method Var.getAttr of <gurobi.Var c_540 (value 0.0)>>
# c_541 <bound method Var.getAttr of <gurobi.Var c_541 (value 0.0)>>
# c_542 <bound method Var.getAttr of <gurobi.Var c_542 (value 0.0)>>
# c_543 <bound method Var.getAttr of <gurobi.Var c_543 (value 0.0)>>
# c_544 <bound method Var.getAttr of <gurobi.Var c_544 (value 0.0)>>
# c_545 <bound method Var.getAttr of <gurobi.Var c_545 (value 0.0)>>
# c_546 <bound method Var.getAttr of <gurobi.Var c_546 (value 0.0)>>
# c_547 <bound method Var.getAttr of <gurobi.Var c_547 (value 0.0)>>
# c_548 <bound method Var.getAttr of <gurobi.Var c_548 (value 0.0)>>
# c_549 <bound method Var.getAttr of <gurobi.Var c_549 (value 0.0)>>
# c_550 <bound method Var.getAttr of <gurobi.Var c_550 (value 0.0)>>
# c_551 <bound method Var.getAttr of <gurobi.Var c_551 (value 0.0)>>
# c_552 <bound method Var.getAttr of <gurobi.Var c_552 (value 0.0)>>
# c_553 <bound method Var.getAttr of <gurobi.Var c_553 (value 0.0)>>
# c_554 <bound method Var.getAttr of <gurobi.Var c_554 (value 0.0)>>
# c_555 <bound method Var.getAttr of <gurobi.Var c_555 (value 0.0)>>
# c_556 <bound method Var.getAttr of <gurobi.Var c_556 (value 0.0)>>
# c_557 <bound method Var.getAttr of <gurobi.Var c_557 (value 0.0)>>
# c_558 <bound method Var.getAttr of <gurobi.Var c_558 (value 0.0)>>
# c_559 <bound method Var.getAttr of <gurobi.Var c_559 (value 0.0)>>
# c_560 <bound method Var.getAttr of <gurobi.Var c_560 (value 0.0)>>
# c_561 <bound method Var.getAttr of <gurobi.Var c_561 (value 0.0)>>
# c_562 <bound method Var.getAttr of <gurobi.Var c_562 (value 0.0)>>
# c_563 <bound method Var.getAttr of <gurobi.Var c_563 (value 0.0)>>
# c_564 <bound method Var.getAttr of <gurobi.Var c_564 (value 0.0)>>
# c_565 <bound method Var.getAttr of <gurobi.Var c_565 (value 0.0)>>
# c_566 <bound method Var.getAttr of <gurobi.Var c_566 (value 0.0)>>
# c_567 <bound method Var.getAttr of <gurobi.Var c_567 (value 0.0)>>
# c_568 <bound method Var.getAttr of <gurobi.Var c_568 (value 0.0)>>
# c_569 <bound method Var.getAttr of <gurobi.Var c_569 (value 0.0)>>
# c_570 <bound method Var.getAttr of <gurobi.Var c_570 (value 0.0)>>
# c_571 <bound method Var.getAttr of <gurobi.Var c_571 (value 0.0)>>
# c_572 <bound method Var.getAttr of <gurobi.Var c_572 (value 0.0)>>
# c_573 <bound method Var.getAttr of <gurobi.Var c_573 (value 0.0)>>
# c_574 <bound method Var.getAttr of <gurobi.Var c_574 (value 0.0)>>
# c_575 <bound method Var.getAttr of <gurobi.Var c_575 (value 0.0)>>
# c_576 <bound method Var.getAttr of <gurobi.Var c_576 (value 0.0)>>
# c_577 <bound method Var.getAttr of <gurobi.Var c_577 (value 0.0)>>
# c_578 <bound method Var.getAttr of <gurobi.Var c_578 (value 0.0)>>
# c_579 <bound method Var.getAttr of <gurobi.Var c_579 (value 0.0)>>
# c_580 <bound method Var.getAttr of <gurobi.Var c_580 (value 0.0)>>
# c_581 <bound method Var.getAttr of <gurobi.Var c_581 (value 0.0)>>
# c_582 <bound method Var.getAttr of <gurobi.Var c_582 (value 0.0)>>
# c_583 <bound method Var.getAttr of <gurobi.Var c_583 (value 0.0)>>
# c_584 <bound method Var.getAttr of <gurobi.Var c_584 (value 0.0)>>
# c_585 <bound method Var.getAttr of <gurobi.Var c_585 (value 0.0)>>
# c_586 <bound method Var.getAttr of <gurobi.Var c_586 (value 0.0)>>
# c_587 <bound method Var.getAttr of <gurobi.Var c_587 (value 0.0)>>
# c_588 <bound method Var.getAttr of <gurobi.Var c_588 (value 0.0)>>
# c_589 <bound method Var.getAttr of <gurobi.Var c_589 (value 0.0)>>
# c_590 <bound method Var.getAttr of <gurobi.Var c_590 (value 0.0)>>
# c_591 <bound method Var.getAttr of <gurobi.Var c_591 (value 0.0)>>
# c_592 <bound method Var.getAttr of <gurobi.Var c_592 (value 0.0)>>
# c_593 <bound method Var.getAttr of <gurobi.Var c_593 (value 0.0)>>
# c_594 <bound method Var.getAttr of <gurobi.Var c_594 (value 0.0)>>
# c_595 <bound method Var.getAttr of <gurobi.Var c_595 (value 0.0)>>
# c_596 <bound method Var.getAttr of <gurobi.Var c_596 (value 0.0)>>
# c_597 <bound method Var.getAttr of <gurobi.Var c_597 (value 0.0)>>
# c_598 <bound method Var.getAttr of <gurobi.Var c_598 (value 0.0)>>
# c_599 <bound method Var.getAttr of <gurobi.Var c_599 (value 0.0)>>
# c_600 <bound method Var.getAttr of <gurobi.Var c_600 (value 0.0)>>
# c_601 <bound method Var.getAttr of <gurobi.Var c_601 (value 0.0)>>
# c_602 <bound method Var.getAttr of <gurobi.Var c_602 (value 0.0)>>
# c_603 <bound method Var.getAttr of <gurobi.Var c_603 (value 0.0)>>
# c_604 <bound method Var.getAttr of <gurobi.Var c_604 (value 0.0)>>
# c_605 <bound method Var.getAttr of <gurobi.Var c_605 (value 0.0)>>
# c_606 <bound method Var.getAttr of <gurobi.Var c_606 (value 0.0)>>
# c_607 <bound method Var.getAttr of <gurobi.Var c_607 (value 0.0)>>
# c_608 <bound method Var.getAttr of <gurobi.Var c_608 (value 0.0)>>
# c_609 <bound method Var.getAttr of <gurobi.Var c_609 (value 0.0)>>
# c_610 <bound method Var.getAttr of <gurobi.Var c_610 (value 0.0)>>
# c_611 <bound method Var.getAttr of <gurobi.Var c_611 (value 0.0)>>
# c_612 <bound method Var.getAttr of <gurobi.Var c_612 (value 0.0)>>
# c_613 <bound method Var.getAttr of <gurobi.Var c_613 (value 0.0)>>
# c_614 <bound method Var.getAttr of <gurobi.Var c_614 (value 0.0)>>
# c_615 <bound method Var.getAttr of <gurobi.Var c_615 (value 0.0)>>
# c_616 <bound method Var.getAttr of <gurobi.Var c_616 (value 0.0)>>
# c_617 <bound method Var.getAttr of <gurobi.Var c_617 (value 0.0)>>
# c_618 <bound method Var.getAttr of <gurobi.Var c_618 (value 0.0)>>
# c_619 <bound method Var.getAttr of <gurobi.Var c_619 (value 0.0)>>
# c_620 <bound method Var.getAttr of <gurobi.Var c_620 (value 0.0)>>
# c_621 <bound method Var.getAttr of <gurobi.Var c_621 (value 0.0)>>
# c_622 <bound method Var.getAttr of <gurobi.Var c_622 (value 0.0)>>
# c_623 <bound method Var.getAttr of <gurobi.Var c_623 (value 0.0)>>
# c_624 <bound method Var.getAttr of <gurobi.Var c_624 (value 0.0)>>
# c_625 <bound method Var.getAttr of <gurobi.Var c_625 (value 0.0)>>
# c_626 <bound method Var.getAttr of <gurobi.Var c_626 (value 0.0)>>
# c_627 <bound method Var.getAttr of <gurobi.Var c_627 (value 0.0)>>
# c_628 <bound method Var.getAttr of <gurobi.Var c_628 (value 0.0)>>
# c_629 <bound method Var.getAttr of <gurobi.Var c_629 (value 0.0)>>
# c_630 <bound method Var.getAttr of <gurobi.Var c_630 (value 0.0)>>
# c_631 <bound method Var.getAttr of <gurobi.Var c_631 (value 0.0)>>
# c_632 <bound method Var.getAttr of <gurobi.Var c_632 (value 0.0)>>
# c_633 <bound method Var.getAttr of <gurobi.Var c_633 (value 0.0)>>
# c_634 <bound method Var.getAttr of <gurobi.Var c_634 (value 0.0)>>
# c_635 <bound method Var.getAttr of <gurobi.Var c_635 (value 0.0)>>
# c_636 <bound method Var.getAttr of <gurobi.Var c_636 (value 0.0)>>
# c_637 <bound method Var.getAttr of <gurobi.Var c_637 (value 0.0)>>
# c_638 <bound method Var.getAttr of <gurobi.Var c_638 (value 0.0)>>
# c_639 <bound method Var.getAttr of <gurobi.Var c_639 (value 0.0)>>
# c_640 <bound method Var.getAttr of <gurobi.Var c_640 (value 0.0)>>
# c_641 <bound method Var.getAttr of <gurobi.Var c_641 (value 0.0)>>
# c_642 <bound method Var.getAttr of <gurobi.Var c_642 (value 0.0)>>
# c_643 <bound method Var.getAttr of <gurobi.Var c_643 (value 0.0)>>
# c_644 <bound method Var.getAttr of <gurobi.Var c_644 (value 0.0)>>
# c_645 <bound method Var.getAttr of <gurobi.Var c_645 (value 0.0)>>
# c_646 <bound method Var.getAttr of <gurobi.Var c_646 (value 0.0)>>
# c_647 <bound method Var.getAttr of <gurobi.Var c_647 (value 0.0)>>
# c_648 <bound method Var.getAttr of <gurobi.Var c_648 (value 0.0)>>
# c_649 <bound method Var.getAttr of <gurobi.Var c_649 (value 0.0)>>
# c_650 <bound method Var.getAttr of <gurobi.Var c_650 (value 0.0)>>
# c_651 <bound method Var.getAttr of <gurobi.Var c_651 (value 0.0)>>
# c_652 <bound method Var.getAttr of <gurobi.Var c_652 (value 0.0)>>
# c_653 <bound method Var.getAttr of <gurobi.Var c_653 (value 0.0)>>
# x_0 <bound method Var.getAttr of <gurobi.Var x_0 (value 1.0)>>
# x_1 <bound method Var.getAttr of <gurobi.Var x_1 (value 1.0)>>
# x_2 <bound method Var.getAttr of <gurobi.Var x_2 (value 0.0)>>
# x_3 <bound method Var.getAttr of <gurobi.Var x_3 (value 0.0)>>
# x_4 <bound method Var.getAttr of <gurobi.Var x_4 (value 0.0)>>
# x_5 <bound method Var.getAttr of <gurobi.Var x_5 (value 0.0)>>
# x_6 <bound method Var.getAttr of <gurobi.Var x_6 (value 0.0)>>
# x_7 <bound method Var.getAttr of <gurobi.Var x_7 (value 1.0)>>
# x_8 <bound method Var.getAttr of <gurobi.Var x_8 (value 1.0)>>
# x_9 <bound method Var.getAttr of <gurobi.Var x_9 (value 1.0)>>
# x_10 <bound method Var.getAttr of <gurobi.Var x_10 (value 0.0)>>
# x_11 <bound method Var.getAttr of <gurobi.Var x_11 (value 0.0)>>
# x_12 <bound method Var.getAttr of <gurobi.Var x_12 (value 0.0)>>
# x_13 <bound method Var.getAttr of <gurobi.Var x_13 (value 0.0)>>
# x_14 <bound method Var.getAttr of <gurobi.Var x_14 (value 0.0)>>
# x_15 <bound method Var.getAttr of <gurobi.Var x_15 (value 0.0)>>
# x_16 <bound method Var.getAttr of <gurobi.Var x_16 (value 0.0)>>
# x_17 <bound method Var.getAttr of <gurobi.Var x_17 (value 0.0)>>
# x_18 <bound method Var.getAttr of <gurobi.Var x_18 (value 0.0)>>
# x_19 <bound method Var.getAttr of <gurobi.Var x_19 (value 0.0)>>
# x_20 <bound method Var.getAttr of <gurobi.Var x_20 (value 0.0)>>
# x_21 <bound method Var.getAttr of <gurobi.Var x_21 (value 0.0)>>
# x_22 <bound method Var.getAttr of <gurobi.Var x_22 (value 0.0)>>
# x_23 <bound method Var.getAttr of <gurobi.Var x_23 (value 0.0)>>
# x_24 <bound method Var.getAttr of <gurobi.Var x_24 (value -0.0)>>
# x_25 <bound method Var.getAttr of <gurobi.Var x_25 (value -0.0)>>
# x_26 <bound method Var.getAttr of <gurobi.Var x_26 (value -0.0)>>
# x_27 <bound method Var.getAttr of <gurobi.Var x_27 (value -0.0)>>
# x_28 <bound method Var.getAttr of <gurobi.Var x_28 (value -0.0)>>
# x_29 <bound method Var.getAttr of <gurobi.Var x_29 (value -0.0)>>
# x_30 <bound method Var.getAttr of <gurobi.Var x_30 (value 1.0)>>
# x_31 <bound method Var.getAttr of <gurobi.Var x_31 (value -0.0)>>
# x_32 <bound method Var.getAttr of <gurobi.Var x_32 (value -0.0)>>
# x_33 <bound method Var.getAttr of <gurobi.Var x_33 (value -0.0)>>
# x_34 <bound method Var.getAttr of <gurobi.Var x_34 (value -0.0)>>
# x_35 <bound method Var.getAttr of <gurobi.Var x_35 (value -0.0)>>
# x_36 <bound method Var.getAttr of <gurobi.Var x_36 (value -0.0)>>
# x_37 <bound method Var.getAttr of <gurobi.Var x_37 (value -0.0)>>
# x_38 <bound method Var.getAttr of <gurobi.Var x_38 (value -0.0)>>
# x_39 <bound method Var.getAttr of <gurobi.Var x_39 (value -0.0)>>
# x_40 <bound method Var.getAttr of <gurobi.Var x_40 (value -0.0)>>
# x_41 <bound method Var.getAttr of <gurobi.Var x_41 (value -0.0)>>
# x_42 <bound method Var.getAttr of <gurobi.Var x_42 (value 1.0)>>
# x_43 <bound method Var.getAttr of <gurobi.Var x_43 (value -0.0)>>
# x_44 <bound method Var.getAttr of <gurobi.Var x_44 (value -0.0)>>
# x_45 <bound method Var.getAttr of <gurobi.Var x_45 (value -0.0)>>
# ...
# x_430 <bound method Var.getAttr of <gurobi.Var x_430 (value 0.0)>>
# x_431 <bound method Var.getAttr of <gurobi.Var x_431 (value 1.0)>>
# x_432 <bound method Var.getAttr of <gurobi.Var x_432 (value 0.0)>>
# x_433 <bound method Var.getAttr of <gurobi.Var x_433 (value 0.0)>>
# x_434 <bound method Var.getAttr of <gurobi.Var x_434 (value 0.0)>>
# x_435 <bound method Var.getAttr of <gurobi.Var x_435 (value 0.0)>>
# x_436 <bound method Var.getAttr of <gurobi.Var x_436 (value 0.0)>>
# x_437 <bound method Var.getAttr of <gurobi.Var x_437 (value 0.0)>>
# x_438 <bound method Var.getAttr of <gurobi.Var x_438 (value 0.0)>>
# x_439 <bound method Var.getAttr of <gurobi.Var x_439 (value 0.0)>>
# x_440 <bound method Var.getAttr of <gurobi.Var x_440 (value 0.0)>>
# x_441 <bound method Var.getAttr of <gurobi.Var x_441 (value 0.0)>>
# x_442 <bound method Var.getAttr of <gurobi.Var x_442 (value 0.0)>>
# x_443 <bound method Var.getAttr of <gurobi.Var x_443 (value 0.0)>>
# x_444 <bound method Var.getAttr of <gurobi.Var x_444 (value 0.0)>>
# x_445 <bound method Var.getAttr of <gurobi.Var x_445 (value 0.0)>>
# x_446 <bound method Var.getAttr of <gurobi.Var x_446 (value 0.0)>>
# x_447 <bound method Var.getAttr of <gurobi.Var x_447 (value 0.0)>>
# x_448 <bound method Var.getAttr of <gurobi.Var x_448 (value 1.0)>>
# x_449 <bound method Var.getAttr of <gurobi.Var x_449 (value 1.0)>>
# x_450 <bound method Var.getAttr of <gurobi.Var x_450 (value -0.0)>>
# x_451 <bound method Var.getAttr of <gurobi.Var x_451 (value -0.0)>>
# x_452 <bound method Var.getAttr of <gurobi.Var x_452 (value -0.0)>>
# x_453 <bound method Var.getAttr of <gurobi.Var x_453 (value 1.0)>>
# x_454 <bound method Var.getAttr of <gurobi.Var x_454 (value 1.0)>>
# x_455 <bound method Var.getAttr of <gurobi.Var x_455 (value 0.0)>>
# x_456 <bound method Var.getAttr of <gurobi.Var x_456 (value 0.0)>>
# x_457 <bound method Var.getAttr of <gurobi.Var x_457 (value 0.0)>>
# x_458 <bound method Var.getAttr of <gurobi.Var x_458 (value 0.0)>>
# x_459 <bound method Var.getAttr of <gurobi.Var x_459 (value 0.0)>>
# x_460 <bound method Var.getAttr of <gurobi.Var x_460 (value 0.0)>>
# x_461 <bound method Var.getAttr of <gurobi.Var x_461 (value 0.0)>>
# x_462 <bound method Var.getAttr of <gurobi.Var x_462 (value 0.0)>>
# x_463 <bound method Var.getAttr of <gurobi.Var x_463 (value 0.0)>>
# x_464 <bound method Var.getAttr of <gurobi.Var x_464 (value 1.0)>>
# x_465 <bound method Var.getAttr of <gurobi.Var x_465 (value -0.0)>>
# x_466 <bound method Var.getAttr of <gurobi.Var x_466 (value -0.0)>>
# x_467 <bound method Var.getAttr of <gurobi.Var x_467 (value 1.0)>>
# x_468 <bound method Var.getAttr of <gurobi.Var x_468 (value 0.0)>>
# x_469 <bound method Var.getAttr of <gurobi.Var x_469 (value 0.0)>>
# x_470 <bound method Var.getAttr of <gurobi.Var x_470 (value 0.0)>>
# x_471 <bound method Var.getAttr of <gurobi.Var x_471 (value 0.0)>>
# x_472 <bound method Var.getAttr of <gurobi.Var x_472 (value 0.0)>>
# x_473 <bound method Var.getAttr of <gurobi.Var x_473 (value 1.0)>>
# x_474 <bound method Var.getAttr of <gurobi.Var x_474 (value 1.0)>>
# x_475 <bound method Var.getAttr of <gurobi.Var x_475 (value 0.0)>>
# x_476 <bound method Var.getAttr of <gurobi.Var x_476 (value 0.0)>>
# x_477 <bound method Var.getAttr of <gurobi.Var x_477 (value 1.0)>>
# x_478 <bound method Var.getAttr of <gurobi.Var x_478 (value 0.0)>>
# x_479 <bound method Var.getAttr of <gurobi.Var x_479 (value 0.0)>>
# x_480 <bound method Var.getAttr of <gurobi.Var x_480 (value 1.0)>>
# x_481 <bound method Var.getAttr of <gurobi.Var x_481 (value 1.0)>>
# x_482 <bound method Var.getAttr of <gurobi.Var x_482 (value 0.0)>>
# x_483 <bound method Var.getAttr of <gurobi.Var x_483 (value 1.0)>>
# x_484 <bound method Var.getAttr of <gurobi.Var x_484 (value -0.0)>>
# x_485 <bound method Var.getAttr of <gurobi.Var x_485 (value -0.0)>>
# x_486 <bound method Var.getAttr of <gurobi.Var x_486 (value -0.0)>>
# x_487 <bound method Var.getAttr of <gurobi.Var x_487 (value 1.0)>>
# x_488 <bound method Var.getAttr of <gurobi.Var x_488 (value -0.0)>>
# x_489 <bound method Var.getAttr of <gurobi.Var x_489 (value -0.0)>>
# x_490 <bound method Var.getAttr of <gurobi.Var x_490 (value 1.0)>>
# x_491 <bound method Var.getAttr of <gurobi.Var x_491 (value 0.0)>>
# x_492 <bound method Var.getAttr of <gurobi.Var x_492 (value 0.0)>>
# x_493 <bound method Var.getAttr of <gurobi.Var x_493 (value 0.0)>>
# x_494 <bound method Var.getAttr of <gurobi.Var x_494 (value 0.0)>>
# x_495 <bound method Var.getAttr of <gurobi.Var x_495 (value 0.0)>>
# x_496 <bound method Var.getAttr of <gurobi.Var x_496 (value 1.0)>>
# x_497 <bound method Var.getAttr of <gurobi.Var x_497 (value -0.0)>>
# x_498 <bound method Var.getAttr of <gurobi.Var x_498 (value -0.0)>>
# x_499 <bound method Var.getAttr of <gurobi.Var x_499 (value -0.0)>>
# x_500 <bound method Var.getAttr of <gurobi.Var x_500 (value -0.0)>>
# x_501 <bound method Var.getAttr of <gurobi.Var x_501 (value -0.0)>>
# x_502 <bound method Var.getAttr of <gurobi.Var x_502 (value -0.0)>>
# x_503 <bound method Var.getAttr of <gurobi.Var x_503 (value -0.0)>>
# x_504 <bound method Var.getAttr of <gurobi.Var x_504 (value -0.0)>>
# x_505 <bound method Var.getAttr of <gurobi.Var x_505 (value -0.0)>>
# x_506 <bound method Var.getAttr of <gurobi.Var x_506 (value -0.0)>>
# x_507 <bound method Var.getAttr of <gurobi.Var x_507 (value 0.0)>>
# x_508 <bound method Var.getAttr of <gurobi.Var x_508 (value -0.0)>>
# x_509 <bound method Var.getAttr of <gurobi.Var x_509 (value -0.0)>>
# x_510 <bound method Var.getAttr of <gurobi.Var x_510 (value -0.0)>>
# x_511 <bound method Var.getAttr of <gurobi.Var x_511 (value 1.0)>>
# x_512 <bound method Var.getAttr of <gurobi.Var x_512 (value 0.0)>>
# x_513 <bound method Var.getAttr of <gurobi.Var x_513 (value 0.0)>>
# x_514 <bound method Var.getAttr of <gurobi.Var x_514 (value 0.0)>>
# x_515 <bound method Var.getAttr of <gurobi.Var x_515 (value 0.0)>>
# x_516 <bound method Var.getAttr of <gurobi.Var x_516 (value 0.0)>>
# x_517 <bound method Var.getAttr of <gurobi.Var x_517 (value 0.0)>>
# x_518 <bound method Var.getAttr of <gurobi.Var x_518 (value 0.0)>>
# x_519 <bound method Var.getAttr of <gurobi.Var x_519 (value 0.0)>>
# x_520 <bound method Var.getAttr of <gurobi.Var x_520 (value 0.0)>>
# x_521 <bound method Var.getAttr of <gurobi.Var x_521 (value 0.0)>>
# x_522 <bound method Var.getAttr of <gurobi.Var x_522 (value 0.0)>>
# x_523 <bound method Var.getAttr of <gurobi.Var x_523 (value 0.0)>>
# x_524 <bound method Var.getAttr of <gurobi.Var x_524 (value 0.0)>>
# x_525 <bound method Var.getAttr of <gurobi.Var x_525 (value 0.0)>>
# x_526 <bound method Var.getAttr of <gurobi.Var x_526 (value 0.0)>>
# x_527 <bound method Var.getAttr of <gurobi.Var x_527 (value 0.0)>>
# x_528 <bound method Var.getAttr of <gurobi.Var x_528 (value 0.0)>>
# x_529 <bound method Var.getAttr of <gurobi.Var x_529 (value 0.0)>>
# x_530 <bound method Var.getAttr of <gurobi.Var x_530 (value 0.0)>>
# x_531 <bound method Var.getAttr of <gurobi.Var x_531 (value 0.0)>>
# x_532 <bound method Var.getAttr of <gurobi.Var x_532 (value 0.0)>>
# x_533 <bound method Var.getAttr of <gurobi.Var x_533 (value 0.0)>>
# x_534 <bound method Var.getAttr of <gurobi.Var x_534 (value 1.0)>>
# x_535 <bound method Var.getAttr of <gurobi.Var x_535 (value 1.0)>>
# x_536 <bound method Var.getAttr of <gurobi.Var x_536 (value 0.0)>>
# x_537 <bound method Var.getAttr of <gurobi.Var x_537 (value 0.0)>>
# x_538 <bound method Var.getAttr of <gurobi.Var x_538 (value 0.0)>>
# x_539 <bound method Var.getAttr of <gurobi.Var x_539 (value 0.0)>>
# x_540 <bound method Var.getAttr of <gurobi.Var x_540 (value 0.0)>>
# x_541 <bound method Var.getAttr of <gurobi.Var x_541 (value 0.0)>>
# x_542 <bound method Var.getAttr of <gurobi.Var x_542 (value 1.0)>>
# x_543 <bound method Var.getAttr of <gurobi.Var x_543 (value 1.0)>>
# x_544 <bound method Var.getAttr of <gurobi.Var x_544 (value 0.0)>>
# x_545 <bound method Var.getAttr of <gurobi.Var x_545 (value 0.0)>>
# x_546 <bound method Var.getAttr of <gurobi.Var x_546 (value 0.0)>>
# x_547 <bound method Var.getAttr of <gurobi.Var x_547 (value 1.0)>>
# x_548 <bound method Var.getAttr of <gurobi.Var x_548 (value 0.0)>>
# x_549 <bound method Var.getAttr of <gurobi.Var x_549 (value 0.0)>>
# x_550 <bound method Var.getAttr of <gurobi.Var x_550 (value 1.0)>>
# x_551 <bound method Var.getAttr of <gurobi.Var x_551 (value -0.0)>>
# x_552 <bound method Var.getAttr of <gurobi.Var x_552 (value -0.0)>>
# x_553 <bound method Var.getAttr of <gurobi.Var x_553 (value -0.0)>>
# x_554 <bound method Var.getAttr of <gurobi.Var x_554 (value -0.0)>>
# x_555 <bound method Var.getAttr of <gurobi.Var x_555 (value -0.0)>>
# x_556 <bound method Var.getAttr of <gurobi.Var x_556 (value -0.0)>>
# x_557 <bound method Var.getAttr of <gurobi.Var x_557 (value -0.0)>>
# x_558 <bound method Var.getAttr of <gurobi.Var x_558 (value -0.0)>>
# x_559 <bound method Var.getAttr of <gurobi.Var x_559 (value -0.0)>>
# x_560 <bound method Var.getAttr of <gurobi.Var x_560 (value -0.0)>>
# x_561 <bound method Var.getAttr of <gurobi.Var x_561 (value -0.0)>>
# x_562 <bound method Var.getAttr of <gurobi.Var x_562 (value -0.0)>>
# x_563 <bound method Var.getAttr of <gurobi.Var x_563 (value -0.0)>>
# x_564 <bound method Var.getAttr of <gurobi.Var x_564 (value -0.0)>>
# x_565 <bound method Var.getAttr of <gurobi.Var x_565 (value -0.0)>>
# x_566 <bound method Var.getAttr of <gurobi.Var x_566 (value -0.0)>>
# x_567 <bound method Var.getAttr of <gurobi.Var x_567 (value -0.0)>>
# x_568 <bound method Var.getAttr of <gurobi.Var x_568 (value -0.0)>>
# x_569 <bound method Var.getAttr of <gurobi.Var x_569 (value -0.0)>>
# x_570 <bound method Var.getAttr of <gurobi.Var x_570 (value 1.0)>>
# x_571 <bound method Var.getAttr of <gurobi.Var x_571 (value -0.0)>>
# x_572 <bound method Var.getAttr of <gurobi.Var x_572 (value -0.0)>>
# x_573 <bound method Var.getAttr of <gurobi.Var x_573 (value -0.0)>>
# x_574 <bound method Var.getAttr of <gurobi.Var x_574 (value -0.0)>>
# x_575 <bound method Var.getAttr of <gurobi.Var x_575 (value -0.0)>>
# x_576 <bound method Var.getAttr of <gurobi.Var x_576 (value -0.0)>>
# x_577 <bound method Var.getAttr of <gurobi.Var x_577 (value -0.0)>>
# x_578 <bound method Var.getAttr of <gurobi.Var x_578 (value -0.0)>>
# x_579 <bound method Var.getAttr of <gurobi.Var x_579 (value -0.0)>>
# x_580 <bound method Var.getAttr of <gurobi.Var x_580 (value -0.0)>>
# x_581 <bound method Var.getAttr of <gurobi.Var x_581 (value -0.0)>>
# x_582 <bound method Var.getAttr of <gurobi.Var x_582 (value -0.0)>>
# x_583 <bound method Var.getAttr of <gurobi.Var x_583 (value -0.0)>>
# x_584 <bound method Var.getAttr of <gurobi.Var x_584 (value 1.0)>>
# x_585 <bound method Var.getAttr of <gurobi.Var x_585 (value 0.0)>>
# x_586 <bound method Var.getAttr of <gurobi.Var x_586 (value 1.0)>>
# x_587 <bound method Var.getAttr of <gurobi.Var x_587 (value 0.0)>>
# x_588 <bound method Var.getAttr of <gurobi.Var x_588 (value 1.0)>>
# x_589 <bound method Var.getAttr of <gurobi.Var x_589 (value 1.0)>>
# x_590 <bound method Var.getAttr of <gurobi.Var x_590 (value 0.0)>>
# x_591 <bound method Var.getAttr of <gurobi.Var x_591 (value 0.0)>>
# x_592 <bound method Var.getAttr of <gurobi.Var x_592 (value 1.0)>>
# x_593 <bound method Var.getAttr of <gurobi.Var x_593 (value -0.0)>>
# x_594 <bound method Var.getAttr of <gurobi.Var x_594 (value -0.0)>>
# x_595 <bound method Var.getAttr of <gurobi.Var x_595 (value -0.0)>>
# x_596 <bound method Var.getAttr of <gurobi.Var x_596 (value -0.0)>>
# x_597 <bound method Var.getAttr of <gurobi.Var x_597 (value -0.0)>>
# x_598 <bound method Var.getAttr of <gurobi.Var x_598 (value 1.0)>>
# x_599 <bound method Var.getAttr of <gurobi.Var x_599 (value 0.0)>>
# x_600 <bound method Var.getAttr of <gurobi.Var x_600 (value 0.0)>>
# x_601 <bound method Var.getAttr of <gurobi.Var x_601 (value 0.0)>>
# x_602 <bound method Var.getAttr of <gurobi.Var x_602 (value 0.0)>>
# x_603 <bound method Var.getAttr of <gurobi.Var x_603 (value 0.0)>>
# x_604 <bound method Var.getAttr of <gurobi.Var x_604 (value -0.0)>>
# x_605 <bound method Var.getAttr of <gurobi.Var x_605 (value -0.0)>>
# x_606 <bound method Var.getAttr of <gurobi.Var x_606 (value -0.0)>>
# x_607 <bound method Var.getAttr of <gurobi.Var x_607 (value -0.0)>>
# x_608 <bound method Var.getAttr of <gurobi.Var x_608 (value -0.0)>>
# x_609 <bound method Var.getAttr of <gurobi.Var x_609 (value -0.0)>>
# x_610 <bound method Var.getAttr of <gurobi.Var x_610 (value -0.0)>>
# x_611 <bound method Var.getAttr of <gurobi.Var x_611 (value -0.0)>>
# x_612 <bound method Var.getAttr of <gurobi.Var x_612 (value -0.0)>>
# x_613 <bound method Var.getAttr of <gurobi.Var x_613 (value -0.0)>>
# x_614 <bound method Var.getAttr of <gurobi.Var x_614 (value 1.0)>>
# x_615 <bound method Var.getAttr of <gurobi.Var x_615 (value 1.0)>>
# x_616 <bound method Var.getAttr of <gurobi.Var x_616 (value 0.0)>>
# x_617 <bound method Var.getAttr of <gurobi.Var x_617 (value 0.0)>>
# x_618 <bound method Var.getAttr of <gurobi.Var x_618 (value 0.0)>>
# x_619 <bound method Var.getAttr of <gurobi.Var x_619 (value 0.0)>>
# x_620 <bound method Var.getAttr of <gurobi.Var x_620 (value 0.0)>>
# x_621 <bound method Var.getAttr of <gurobi.Var x_621 (value 0.0)>>
# x_622 <bound method Var.getAttr of <gurobi.Var x_622 (value 0.0)>>
# x_623 <bound method Var.getAttr of <gurobi.Var x_623 (value 0.0)>>
# x_624 <bound method Var.getAttr of <gurobi.Var x_624 (value 0.0)>>
# x_625 <bound method Var.getAttr of <gurobi.Var x_625 (value 0.0)>>
# x_626 <bound method Var.getAttr of <gurobi.Var x_626 (value 0.0)>>
# x_627 <bound method Var.getAttr of <gurobi.Var x_627 (value 0.0)>>
# x_628 <bound method Var.getAttr of <gurobi.Var x_628 (value 1.0)>>
# x_629 <bound method Var.getAttr of <gurobi.Var x_629 (value 1.0)>>
# x_630 <bound method Var.getAttr of <gurobi.Var x_630 (value 1.0)>>
# x_631 <bound method Var.getAttr of <gurobi.Var x_631 (value -0.0)>>
# x_632 <bound method Var.getAttr of <gurobi.Var x_632 (value -0.0)>>
# x_633 <bound method Var.getAttr of <gurobi.Var x_633 (value -0.0)>>
# x_634 <bound method Var.getAttr of <gurobi.Var x_634 (value -0.0)>>
# x_635 <bound method Var.getAttr of <gurobi.Var x_635 (value -0.0)>>
# x_636 <bound method Var.getAttr of <gurobi.Var x_636 (value -0.0)>>
# x_637 <bound method Var.getAttr of <gurobi.Var x_637 (value -0.0)>>
# x_638 <bound method Var.getAttr of <gurobi.Var x_638 (value -0.0)>>
# x_639 <bound method Var.getAttr of <gurobi.Var x_639 (value -0.0)>>
# x_640 <bound method Var.getAttr of <gurobi.Var x_640 (value 1.0)>>
# x_641 <bound method Var.getAttr of <gurobi.Var x_641 (value -0.0)>>
# x_642 <bound method Var.getAttr of <gurobi.Var x_642 (value -0.0)>>
# x_643 <bound method Var.getAttr of <gurobi.Var x_643 (value -0.0)>>
# x_644 <bound method Var.getAttr of <gurobi.Var x_644 (value -0.0)>>
# x_645 <bound method Var.getAttr of <gurobi.Var x_645 (value -0.0)>>
# x_646 <bound method Var.getAttr of <gurobi.Var x_646 (value -0.0)>>
# x_647 <bound method Var.getAttr of <gurobi.Var x_647 (value -0.0)>>
# x_648 <bound method Var.getAttr of <gurobi.Var x_648 (value -0.0)>>
# x_649 <bound method Var.getAttr of <gurobi.Var x_649 (value -0.0)>>
# x_650 <bound method Var.getAttr of <gurobi.Var x_650 (value -0.0)>>
# x_651 <bound method Var.getAttr of <gurobi.Var x_651 (value -0.0)>>
# x_652 <bound method Var.getAttr of <gurobi.Var x_652 (value -0.0)>>
# x_653 <bound method Var.getAttr of <gurobi.Var x_653 (value -0.0)>>
# d_0 0.0
# d_1 0.0
# d_2 0.0
# d_3 0.0
# d_4 0.0
# d_5 0.0
# d_6 0.0
# d_7 0.0
# d_8 0.0
# d_9 0.0
# d_10 0.0
# d_11 0.0
# d_12 0.0
# d_13 0.0
# d_14 0.0
# d_15 0.0
# d_16 0.0
# d_17 0.0
# d_18 0.0
# d_19 0.0
# d_20 0.0
# d_21 0.0
# d_22 0.0
# d_23 0.0
# d_24 0.0
# d_25 0.0
# d_26 0.0
# d_27 0.0
# d_28 0.0
# d_29 0.0
# d_30 0.0
# d_31 0.0
# d_32 0.0
# d_33 0.0
# d_34 0.0
# d_35 0.0
# d_36 0.0
# d_37 0.0
# d_38 0.0
# d_39 0.0
# d_40 0.0
# d_41 0.0
# d_42 0.0
# d_43 0.0
# d_44 0.0
# d_45 0.0
# d_46 0.0
# d_47 0.0
# d_48 0.0
# d_49 0.0
# d_50 0.0
# d_51 0.0
# d_52 0.0
# d_53 0.0
# d_54 0.0
# d_55 0.0
# d_56 0.0
# d_57 0.0
# d_58 0.0
# d_59 0.0
# d_60 0.0
# d_61 0.0
# d_62 0.0
# d_63 0.0
# d_64 0.0
# d_65 0.0
# d_66 0.0
# d_67 0.0
# d_68 0.0
# d_69 0.0
# d_70 0.0
# d_71 0.0
# d_72 0.0
# d_73 0.0
# d_74 0.0
# d_75 0.0
# d_76 0.0
# d_77 0.0
# d_78 0.0
# d_79 0.0
# d_80 0.0
# d_81 0.0
# d_82 0.0
# d_83 0.0
# d_84 0.0
# d_85 0.0
# d_86 0.0
# d_87 0.0
# d_88 0.0
# d_89 0.0
# d_90 0.0
# d_91 0.0
# d_92 0.0
# d_93 0.0
# d_94 0.0
# d_95 0.0
# d_96 0.0
# d_97 0.0
# d_98 0.0
# d_99 0.0
